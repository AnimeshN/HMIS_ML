# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.model_selection import TimeSeriesSplit

from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def lasso_regression_lags_only_cv(
    series,
    district_name,
    max_lags=3,
    differencing=True,
    alphas=np.logspace(-3, 1, 20),  # Range of alpha values to try
    cv=5,  # Number of cross-validation folds
    random_state=42
):
    """
    LASSO regression for time series forecasting with lag features only,
    using cross-validated alpha (L1 regularization strength).
    """
    # Create directory structure
    os.makedirs('LASSORegression', exist_ok=True)
    
    # 1. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 2. Feature Engineering - Lag features only
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 3. Train-Test Split (time-based)
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 4. Model Training with LASSO + Cross-Validation
    model = LassoCV(alphas=alphas, cv=TimeSeriesSplit(n_splits=5), random_state=random_state, max_iter=10000)
    model.fit(X_train, y_train)
    best_alpha = model.alpha_

    # 5. Forecasting
    pred_test = model.predict(X_test)

    # 6. Inverse Differencing if applied
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = np.cumsum(pred_test) + last_train_value
        y_test = original_series.iloc[-len(test):]
    
    # 7. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test
    })

    # 8. Save forecasts to CSV
    forecast_csv_path = os.path.join('LASSORegression', 'lasso_forecasts_lags_only_cv.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, mode='a', header=write_header, index=False)

    # 9. Calculate metrics
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    r_squared = model.score(X_train, y_train)
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'r_squared': r_squared,
        'coefficients': model.coef_.tolist(),
        'intercept': model.intercept_,
        'best_alpha': best_alpha,
        'alphas_tried': alphas.tolist(),
        'differencing': d
    }])

    metrics_csv_path = os.path.join('LASSORegression', 'lasso_metrics_lags_only_cv.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, mode='a', header=write_header_metrics, index=False)

    # 10. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', color='darkorange')
    plt.title(
        f'LASSO (CV) Regression (Lags Only) for {district_name}\n'
        f'Best alpha: {best_alpha:.4f} | RMSE: {rmse:.2f}, R²: {r_squared:.2f}'
    )
    plt.legend()
    plt.savefig(os.path.join('LASSORegression', f'LASSO_CV_forecast_lags_only_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_coefficients': model.coef_,
        'model_intercept': model.intercept_,
        'best_alpha': best_alpha,
        'alphas_tried': alphas
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I40"].asfreq('MS')
        
        results = lasso_regression_lags_only_cv(
            ts, 
            district, 
            max_lags=5, 
            differencing=True,
            alphas=np.logspace(-3, 1, 30),  # Try more alphas if you want
            cv=5
        )
        
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district        rmse  r_squared  \
# 0  AHMEDNAGAR  531.925517    0.08101
#
#                                         coefficients    intercept  best_alpha  \
# 0  [-0.038596158529227924, 0.015475550011280096, ...  8385.528295        10.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AHMEDNAGAR 2020-07-01  6478.0  6810.782296
# 1  AHMEDNAGAR 2020-08-01  5975.0  6566.470638
# 2  AHMEDNAGAR 2020-09-01  6550.0  6942.109824
# 3  AHMEDNAGAR 2020-10-01  6471.0  7081.510105
# 4  AHMEDNAGAR 2020-11-01  6107.0  7158.542236
# === Metrics ===
#   district        rmse  r_squared  \
# 0    AKOLA  295.673095    0.19196
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.16268711223932864, -0.17554680829749805, -0...  3712.028172        10.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    AKOLA 2020-07-01  3121.0  2906.433003
# 1    AKOLA 2020-08-01  3029.0  2674.950430
# 2    AKOLA 2020-09-01  2763.0  2622.092057
# 3    AKOLA 2020-10-01  2737.0  2544.853473
# 4    AKOLA 2020-11-01  2700.0  2601.795852
# === Metrics ===
#    district        rmse  r_squared  \
# 0  AMRAVATI  361.714698    0.27521
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.4363087203316295, -0.29650508730345226, -0....  4554.65646        10.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  AMRAVATI 2020-07-01  3459.0  3712.825143
# 1  AMRAVATI 2020-08-01  3049.0  3618.872874
# 2  AMRAVATI 2020-09-01  3325.0  3574.571004
# 3  AMRAVATI 2020-10-01  3191.0  3889.418700
# 4  AMRAVATI 2020-11-01  3502.0  3830.415987
# === Metrics ===
#      district        rmse  r_squared  \
# 0  AURANGABAD  402.756808   0.173511
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.24348322627357738, -0.060612282450809594, 0...  3154.115116        10.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AURANGABAD 2020-07-01  6028.0  6462.054297
# 1  AURANGABAD 2020-08-01  6173.0  6293.963414
# 2  AURANGABAD 2020-09-01  6644.0  6613.916132
# 3  AURANGABAD 2020-10-01  6246.0  6417.338576
# 4  AURANGABAD 2020-11-01  5765.0  6392.746841
# === Metrics ===
#   district        rmse  r_squared  \
# 0     BEED  352.487877   0.295761
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.2690187179144143, 0.12293559993044961, 0.10...  4176.532962        10.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-07-01  3821.0  4201.104421
# 1     BEED 2020-08-01  3261.0  3581.125829
# 2     BEED 2020-09-01  3819.0  3121.009393
# 3     BEED 2020-10-01  3751.0  3598.014038
# 4     BEED 2020-11-01  3332.0  3843.166309
# === Metrics ===
#    district        rmse  r_squared  \
# 0  BHANDARA  277.317432   0.099314
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.26498645701917994, -0.22433514836904947, -...  -3.185591        10.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BHANDARA 2020-07-01    1262  1396.640591
# 1  BHANDARA 2020-08-01    1185  1444.421012
# 2  BHANDARA 2020-09-01    1200  1489.451522
# 3  BHANDARA 2020-10-01    1233  1532.480897
# 4  BHANDARA 2020-11-01    1093  1550.949617
# === Metrics ===
#    district        rmse  r_squared  \
# 0  BULDHANA  342.718749   0.269564
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.0336274181257729, -0.15085963577651187, -0....  7174.884886        10.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-07-01  3900.0  
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 28
#      25         print(results['forecast_df'].head())
#      27     return results
# ---> 28 run_for_each_district()
#
# Cell In[4], line 11, in run_for_each_district()
#       8 district_data = data[data['district'] == district]
#       9 ts = district_data["I1"].asfreq('MS')
# ---> 11 results = lasso_regression_lags_only_cv(
#      12     ts,
#      13     district,
#      14     max_lags=5,
#      15     differencing=True,
#      16     alphas=np.logspace(-3, 1, 30),  # Try more alphas if you want
#      17     cv=5
#      18 )
#      21 # Show results
#      22 print("=== Metrics ===")
#
# Cell In[3], line 44, in lasso_regression_lags_only_cv(series, district_name, max_lags, differencing, alphas, cv, random_state)
#      42 # 4. Model Training with LASSO + Cross-Validation
#      43 model = LassoCV(alphas=alphas, cv=TimeSeriesSplit(n_splits=5), random_state=random_state, max_iter=10000)
# ---> 44 model.fit(X_train, y_train)
#      45 best_alpha = model.alpha_
#      47 # 5. Forecasting
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1728, in LinearModelCV.fit(self, X, y, sample_weight, **params)
#    1725     routed_params.splitter = Bunch(split=Bunch())
#    1727 # Compute path for all folds and compute MSE to get the best alpha
# -> 1728 folds = list(cv.split(X, y, **routed_params.splitter.split))
#    1729 best_mse = np.inf
#    1731 # We do a double for loop folded in one, in order to be able to
#    1732 # iterate in parallel on l1_ratio and folds
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:1177, in TimeSeriesSplit.split(self, X, y, groups)
#    1175 # Make sure we have enough samples for the given split parameters
#    1176 if n_folds > n_samples:
# -> 1177     raise ValueError(
#    1178         f"Cannot have number of folds={n_folds} greater"
#    1179         f" than the number of samples={n_samples}."
#    1180     )
#    1181 if n_samples - gap - (test_size * n_splits) <= 0:
#    1182     raise ValueError(
#    1183         f"Too many splits={n_splits} for number of samples"
#    1184         f"={n_samples} with test_size={test_size} and gap={gap}."
#    1185     )
#
# ValueError: Cannot have number of folds=6 greater than the number of samples=5.

# %%
from sklearn.preprocessing import StandardScaler

def normalize_series(series):
    """Normalize a pandas Series using StandardScaler"""
    scaler = StandardScaler()
    scaled_values = scaler.fit_transform(series.values.reshape(-1, 1))
    return pd.Series(scaled_values.flatten(), index=series.index), scaler

def run_for_each_district():
    results = {}
    rmse_values = []
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I8"].asfreq('MS')
        
        # Normalize the time series data
        scaled_ts, scaler = normalize_series(ts)
        
        # Run LASSO on normalized data
        results = lasso_regression_lags_only_cv(
            scaled_ts, 
            district, 
            max_lags=5, 
            differencing=True,
            alphas=np.logspace(-3, 1, 30),
            cv=5
        )
        
        # Convert forecasts back to original scale
        forecast_df = results['forecast_df']
        forecast_df['actual'] = scaler.inverse_transform(
            forecast_df[['actual']]
        ).flatten()
        forecast_df['forecast'] = scaler.inverse_transform(
            forecast_df[['forecast']]
        ).flatten()
        
        # Recalculate RMSE in original scale
        rmse = np.sqrt(mean_squared_error(
            forecast_df['actual'], 
            forecast_df['forecast']
        ))
        rmse_values.append(rmse)
        
        # Update results with transformed data
        results['forecast_df'] = forecast_df
        results['metrics_df']['rmse_original_scale'] = rmse  # Add new metric

        print(f"\n=== {district} ===")
        print(f"Normalized RMSE: {results['metrics_df']['rmse'].values[0]:.2f}")
        print(f"Original Scale RMSE: {rmse:.2f}")
        print("Forecast Preview:")
        print(forecast_df.head())
    
    return results, rmse_values

# Execute the analysis
final_results, district_rmses = run_for_each_district()
# Out:
# === AHMEDNAGAR ===
# Normalized RMSE: 1.02
# Original Scale RMSE: 546.43
# Forecast Preview:
#      district       date  actual     forecast
# 0  AHMEDNAGAR 2020-07-01  6478.0  6892.470588
# 1  AHMEDNAGAR 2020-08-01  5975.0  6892.470588
# 2  AHMEDNAGAR 2020-09-01  6550.0  6892.470588
# 3  AHMEDNAGAR 2020-10-01  6471.0  6892.470588
# 4  AHMEDNAGAR 2020-11-01  6107.0  6892.470588
#
# === AKOLA ===
# Normalized RMSE: 1.33
# Original Scale RMSE: 289.97
# Forecast Preview:
#   district       date  actual     forecast
# 0    AKOLA 2020-07-01  3121.0  2698.117647
# 1    AKOLA 2020-08-01  3029.0  2698.117647
# 2    AKOLA 2020-09-01  2763.0  2698.117647
# 3    AKOLA 2020-10-01  2737.0  2698.117647
# 4    AKOLA 2020-11-01  2700.0  2698.117647
#
# === AMRAVATI ===
# Normalized RMSE: 1.13
# Original Scale RMSE: 381.81
# Forecast Preview:
#    district       date  actual     forecast
# 0  AMRAVATI 2020-07-01  3459.0  3761.748022
# 1  AMRAVATI 2020-08-01  3049.0  3664.970695
# 2  AMRAVATI 2020-09-01  3325.0  3619.811042
# 3  AMRAVATI 2020-10-01  3191.0  3858.414017
# 4  AMRAVATI 2020-11-01  3502.0  3829.400305
#
# === AURANGABAD ===
# Normalized RMSE: 0.77
# Original Scale RMSE: 398.20
# Forecast Preview:
#      district       date  actual     forecast
# 0  AURANGABAD 2020-07-01  6028.0  6486.173494
# 1  AURANGABAD 2020-08-01  6173.0  6430.450054
# 2  AURANGABAD 2020-09-01  6644.0  6623.554018
# 3  AURANGABAD 2020-10-01  6246.0  6445.504111
# 4  AURANGABAD 2020-11-01  5765.0  6407.049734
#
# === BEED ===
# Normalized RMSE: 0.65
# Original Scale RMSE: 310.79
# Forecast Preview:
#   district       date  actual     forecast
# 0     BEED 2020-07-01  3821.0  3960.816502
# 1     BEED 2020-08-01  3261.0  3686.926793
# 2     BEED 2020-09-01  3819.0  3365.746899
# 3     BEED 2020-10-01  3751.0  3730.455920
# 4     BEED 2020-11-01  3332.0  3910.401601
#
# === BHANDARA ===
# Normalized RMSE: 1.29
# Original Scale RMSE: 222.67
# Forecast Preview:
#    district       date  actual  forecast
# 0  BHANDARA 2020-07-01  1262.0    1337.0
# 1  BHANDARA 2020-08-01  1185.0    1333.0
# 2  BHANDARA 2020-09-01  1200.0    1329.0
# 3  BHANDARA 2020-10-01  1233.0    1325.0
# 4  BHANDARA 2020-11-01  1093.0    1321.0
#
# === BULDHANA ===
# Normalized RMSE: 1.01
# Original Scale RMSE: 343.16
# Forecast Preview:
#    district       date  actual     forecast
# 0  BULDHANA 2020-07-01  3900.0  4113.370097
# 1  BULDHANA 2020-08-01  3612.0  4040.861166
# 2  BULDHANA 2020-09-01  4073.0  4154.681710
# 3  BULDHANA 2020-10-01  3614.0  4077.994329
# 4  BULDHANA 2020-11-01  3484.0  4198.963350
#
# === CHANDRAPUR ===
# Normalized RMSE: 0.63
# Original Scale RMSE: 225.12
# Forecast Preview:
#      district       date  actual     forecast
# 0  CHANDRAPUR 2020-07-01  2316.0  2484.538711
# 1  CHANDRAPUR 2020-08-01  2209.0  2395.878891
# 2  CHANDRAPUR 2020-09-01  2247.0  2372.924447
# 3  CHANDRAPUR 2020-10-01  2187.0  2497.491869
# 4  CHANDRAPUR 2020-11-01  2220.0  2566.437350
#
# === DHULE ===
# Normalized RMSE: 1.02
# Original Scale RMSE: 355.67
# Forecast Preview:
#   district       date  actual     forecast
# 0    DHULE 2020-07-01  3857.0  3794.824702
# 1    DHULE 2020-08-01  3076.0  3761.310461
# 2    DHULE 2020-09-01  3376.0  3571.639286
# 3    DHULE 2020-10-01  3157.0  3644.496331
# 4    DHULE 2020-11-01  3146.0  3591.310688
#
# === GADCHIROLI ===
# Normalized RMSE: 1.35
# Original Scale RMSE: 329.84
# Forecast Preview:
#      district       date  actual     forecast
# 0  GADCHIROLI 2020-07-01  1431.0  1677.515152
# 1  GADCHIROLI 2020-08-01  1224.0  1677.030303
# 2  GADCHIROLI 2020-09-01  1361.0  1676.545455
# 3  GADCHIROLI 2020-10-01  1251.0  1676.060606
# 4  GADCHIROLI 2020-11-01  1256.0  1675.575758
#
# === GONDIA ===
# Normalized RMSE: 0.82
# Original Scale RMSE: 142.49
# Forecast Preview:
#   district       date  actual     forecast
# 0   GONDIA 2020-07-01  1703.0  1681.798859
# 1   GONDIA 2020-08-01  1383.0  1612.055379
# 2   GONDIA 2020-09-01  1445.0  1493.919503
# 3   GONDIA 2020-10-01  1472.0  1511.906021
# 4   GONDIA 2020-11-01  1519.0  1583.894971
#
# === HINGOLI ===
# Normalized RMSE: 0.85
# Original Scale RMSE: 131.69
# Forecast Preview:
#   district       date  actual     forecast
# 0  HINGOLI 2020-07-01  1886.0  1954.823529
# 1  HINGOLI 2020-08-01  1692.0  1954.823529
# 2  HINGOLI 2020-09-01  2019.0  1954.823529
# 3  HINGOLI 2020-10-01  1976.0  1954.823529
# 4  HINGOLI 2020-11-01  1722.0  1954.823529
#
# === JALGAON ===
# Normalized RMSE: 1.06
# Original Scale RMSE: 587.50
# Forecast Preview:
#   district       date  actual     forecast
# 0  JALGAON 2020-07-01  6176.0  6857.515804
# 1  JALGAON 2020-08-01  5950.0  6692.980598
# 2  JALGAON 2020-09-01  6369.0  6669.530297
# 3  JALGAON 2020-10-01  6370.0  6763.027469
# 4  JALGAON 2020-11-01  6429.0  6732.099318
#
# === JALNA ===
# Normalized RMSE: 0.66
# Original Scale RMSE: 167.87
# Forecast Preview:
#   district       date  actual     forecast
# 0    JALNA 2020-07-01  3234.0  3552.158569
# 1    JALNA 2020-08-01  3247.0  3366.571014
# 2    JALNA 2020-09-01  3401.0  3451.686053
# 3    JALNA 2020-10-01  3244.0  3529.048273
# 4    JALNA 2020-11-01  3164.0  3328.519558
#
# === KOLHAPUR ===
# Normalized RMSE: 1.14
# Original Scale RMSE: 421.10
# Forecast Preview:
#    district       date  actual     forecast
# 0  KOLHAPUR 2020-07-01  4670.0  5167.705882
# 1  KOLHAPUR 2020-08-01  4437.0  5167.705882
# 2  KOLHAPUR 2020-09-01  5026.0  5167.705882
# 3  KOLHAPUR 2020-10-01  4973.0  5167.705882
# 4  KOLHAPUR 2020-11-01  4789.0  5167.705882
#
# === LATUR ===
# Normalized RMSE: 1.05
# Original Scale RMSE: 322.25
# Forecast Preview:
#   district       date  actual     forecast
# 0    LATUR 2020-07-01  3694.0  3903.382353
# 1    LATUR 2020-08-01  3498.0  3903.382353
# 2    LATUR 2020-09-01  3654.0  3903.382353
# 3    LATUR 2020-10-01  3751.0  3903.382353
# 4    LATUR 2020-11-01  3673.0  3903.382353
#
# === MUMBAI ===
# Normalized RMSE: 0.53
# Original Scale RMSE: 4043.55
# Forecast Preview:
#   district       date  actual     forecast
# 0   MUMBAI 2020-07-01  2916.0  3151.367160
# 1   MUMBAI 2020-08-01  2676.0  2432.072258
# 2   MUMBAI 2020-09-01  3035.0  1674.279998
# 3   MUMBAI 2020-10-01  2924.0   963.322102
# 4   MUMBAI 2020-11-01  3608.0   318.937662
#
# === NAGPUR ===
# Normalized RMSE: 1.34
# Original Scale RMSE: 1068.50
# Forecast Preview:
#   district       date  actual     forecast
# 0   NAGPUR 2020-07-01  7018.0  7113.750633
# 1   NAGPUR 2020-08-01  5585.0  7031.516191
# 2   NAGPUR 2020-09-01  5078.0  6694.824890
# 3   NAGPUR 2020-10-01  5618.0  6575.702426
# 4   NAGPUR 2020-11-01  6429.0  6702.578423
#
# === NANDED ===
# Normalized RMSE: 1.01
# Original Scale RMSE: 447.26
# Forecast Preview:
#   district       date  actual     forecast
# 0   NANDED 2020-07-01  5261.0  5665.745002
# 1   NANDED 2020-08-01  4984.0  5569.300385
# 2   NANDED 2020-09-01  5871.0  5521.909153
# 3   NANDED 2020-10-01  5214.0  5933.984112
# 4   NANDED 2020-11-01  5237.0  5426.772614
#
# === NANDURBAR ===
# Normalized RMSE: 0.49
# Original Scale RMSE: 217.94
# Forecast Preview:
#     district       date  actual     forecast
# 0  NANDURBAR 2020-07-01  3577.0  3543.603888
# 1  NANDURBAR 2020-08-01  2901.0  3303.546000
# 2  NANDURBAR 2020-09-01  3040.0  2930.880871
# 3  NANDURBAR 2020-10-01  2588.0  2899.404704
# 4  NANDURBAR 2020-11-01  2581.0  2746.024061
#
# === NASHIK ===
# Normalized RMSE: 0.63
# Original Scale RMSE: 584.24
# Forecast Preview:
#   district       date   actual      forecast
# 0   NASHIK 2020-07-01  10668.0  10758.186226
# 1   NASHIK 2020-08-01   9838.0  10762.481617
# 2   NASHIK 2020-09-01  10420.0  10613.932666
# 3   NASHIK 2020-10-01  10365.0  10718.095906
# 4   NASHIK 2020-11-01   9966.0  10708.252301
#
# === OSMANABAD ===
# Normalized RMSE: 0.91
# Original Scale RMSE: 214.50
# Forecast Preview:
#     district       date  actual     forecast
# 0  OSMANABAD 2020-07-01  2273.0  2454.414562
# 1  OSMANABAD 2020-08-01  1935.0  2416.979370
# 2  OSMANABAD 2020-09-01  2241.0  2179.289183
# 3  OSMANABAD 2020-10-01  2207.0  2290.252375
# 4  OSMANABAD 2020-11-01  2274.0  2362.195733
#
# === PALGHAR ===
# Normalized RMSE: 1.15
# Original Scale RMSE: 520.69
# Forecast Preview:
#   district       date  actual     forecast
# 0  PALGHAR 2020-07-01  4867.0  5431.800180
# 1  PALGHAR 2020-08-01  4606.0  5138.057319
# 2  PALGHAR 2020-09-01  4753.0  4965.671659
# 3  PALGHAR 2020-10-01  4616.0  4977.014368
# 4  PALGHAR 2020-11-01  4554.0  4970.643154
#
# === PARBHANI ===
# Normalized RMSE: 1.21
# Original Scale RMSE: 342.57
# Forecast Preview:
#    district       date  actual     forecast
# 0  PARBHANI 2020-07-01  3186.0  3138.355336
# 1  PARBHANI 2020-08-01  2743.0  3089.172149
# 2  PARBHANI 2020-09-01  3099.0  3031.070412
# 3  PARBHANI 2020-10-01  2920.0  3077.761650
# 4  PARBHANI 2020-11-01  2538.0  3054.284876
#
# === PUNE ===
# Normalized RMSE: 1.00
# Original Scale RMSE: 1366.47
# Forecast Preview:
#   district       date   actual      forecast
# 0     PUNE 2020-07-01  14939.0  16590.505364
# 1     PUNE 2020-08-01  14322.0  15753.198091
# 2     PUNE 2020-09-01  16328.0  15624.851533
# 3     PUNE 2020-10-01  15750.0  16369.973767
# 4     PUNE 2020-11-01  15551.0  16507.652871
#
# === RAIGAD ===
# Normalized RMSE: 2.02
# Original Scale RMSE: 1086.19
# Forecast Preview:
#   district       date  actual     forecast
# 0   RAIGAD 2020-07-01  3465.0  4037.385481
# 1   RAIGAD 2020-08-01  3013.0  4313.123785
# 2   RAIGAD 2020-09-01  3412.0  4694.943690
# 3   RAIGAD 2020-10-01  3704.0  4725.841650
# 4   RAIGAD 2020-11-01  3998.0  4641.100255
#
# === RATNAGIRI ===
# Normalized RMSE: 0.96
# Original Scale RMSE: 215.56
# Forecast Preview:
#     district       date  actual     forecast
# 0  RATNAGIRI 2020-07-01  1742.0  1708.652940
# 1  RATNAGIRI 2020-08-01  1206.0  1616.188723
# 2  RATNAGIRI 2020-09-01  1279.0  1364.610953
# 3  RATNAGIRI 2020-10-01  1186.0  1398.874343
# 4  RATNAGIRI 2020-11-01  1074.0  1355.223723
#
# === SANGLI ===
# Normalized RMSE: 1.17
# Original Scale RMSE: 268.99
# Forecast Preview:
#   district       date  actual     forecast
# 0   SANGLI 2020-07-01  4264.0  4303.303746
# 1   SANGLI 2020-08-01  3874.0  4235.264470
# 2   SANGLI 2020-09-01  3891.0  4117.049932
# 3   SANGLI 2020-10-01  3891.0  4117.323275
# 4   SANGLI 2020-11-01  3821.0  4042.265314
#
# === SATARA ===
# Normalized RMSE: 1.50
# Original Scale RMSE: 504.23
# Forecast Preview:
#   district       date  actual     forecast
# 0   SATARA 2020-07-01  3915.0  4045.529412
# 1   SATARA 2020-08-01  3233.0  4045.529412
# 2   SATARA 2020-09-01  3103.0  4045.529412
# 3   SATARA 2020-10-01  3760.0  4045.529412
# 4   SATARA 2020-11-01  3582.0  4045.529412
#
# === SINDHUDURG ===
# Normalized RMSE: 1.17
# Original Scale RMSE: 104.39
# Forecast Preview:
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01   721.0  674.029412
# 1  SINDHUDURG 2020-08-01   549.0  674.029412
# 2  SINDHUDURG 2020-09-01   579.0  674.029412
# 3  SINDHUDURG 2020-10-01   530.0  674.029412
# 4  SINDHUDURG 2020-11-01   476.0  674.029412
#
# === SOLAPUR ===
# Normalized RMSE: 1.11
# Original Scale RMSE: 524.89
# Forecast Preview:
#   district       date  actual     forecast
# 0  SOLAPUR 2020-07-01  6858.0  7033.448407
# 1  SOLAPUR 2020-08-01  6356.0  6990.233863
# 2  SOLAPUR 2020-09-01  6758.0  6799.184520
# 3  SOLAPUR 2020-10-01  6321.0  7072.443130
# 4  SOLAPUR 2020-11-01  6058.0  6794.846348
#
# === THANE ===
# Normalized RMSE: 1.51
# Original Scale RMSE: 1585.03
# Forecast Preview:
#   district       date   actual      forecast
# 0    THANE 2020-07-01  12050.0  13966.264754
# 1    THANE 2020-08-01  12215.0  13885.563206
# 2    THANE 2020-09-01  13770.0  13873.092971
# 3    THANE 2020-10-01  13402.0  13916.303923
# 4    THANE 2020-11-01  13995.0  13997.841277
#
# === WARDHA ===
# Normalized RMSE: 1.26
# Original Scale RMSE: 187.52
# Forecast Preview:
#   district       date  actual     forecast
# 0   WARDHA 2020-07-01  1452.0  1514.906632
# 1   WARDHA 2020-08-01  1358.0  1562.583891
# 2   WARDHA 2020-09-01  1360.0  1539.362830
# 3   WARDHA 2020-10-01  1306.0  1581.101420
# 4   WARDHA 2020-11-01  1196.0  1561.706719
#
# === WASHIM ===
# Normalized RMSE: 0.80
# Original Scale RMSE: 150.40
# Forecast Preview:
#   district       date  actual  forecast
# 0   WASHIM 2020-07-01  1629.0    1664.5
# 1   WASHIM 2020-08-01  1502.0    1664.5
# 2   WASHIM 2020-09-01  1599.0    1664.5
# 3   WASHIM 2020-10-01  1501.0    1664.5
# 4   WASHIM 2020-11-01  1453.0    1664.5
#
# === YAVATMAL ===
# Normalized RMSE: 0.70
# Original Scale RMSE: 251.78
# Forecast Preview:
#    district       date  actual     forecast
# 0  YAVATMAL 2020-07-01  3673.0  3856.888901
# 1  YAVATMAL 2020-08-01  3425.0  3831.753139
# 2  YAVATMAL 2020-09-01  3507.0  3817.623308
# 3  YAVATMAL 2020-10-01  3562.0  3803.545917
# 4  YAVATMAL 2020-11-01  3501.0  3814.423101
#
# === MUMBAI SUBURBAN ===
# Normalized RMSE: 0.19
# Original Scale RMSE: 469.46
# Forecast Preview:
#           district       date   actual      forecast
# 0  MUMBAI SUBURBAN 2021-02-01  13444.0  13607.088673
# 1  MUMBAI SUBURBAN 2021-03-01  13294.0  13937.569245
