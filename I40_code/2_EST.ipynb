# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def exponential_smoothing_forecast_district(series, district_name, seasonal=False, seasonal_periods=12):
    """
    Complete Exponential Smoothing forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('ExponentialSmoothing', exist_ok=True)
    
    # 1. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 2. Model Fitting
    if seasonal:
        model = ExponentialSmoothing(train, seasonal='add', seasonal_periods=seasonal_periods)
    else:
        model = ExponentialSmoothing(train)
    model_fit = model.fit()
    
    # 3. Forecasting
    forecast = model_fit.forecast(steps=len(test))

    # 4. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast.values
    })

    # 5. Save forecasts to CSV (append mode)
    forecast_csv_path = os.path.join('ExponentialSmoothing', 'exp_smoothing_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 6. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'seasonal': seasonal
    }])

    metrics_csv_path = os.path.join('ExponentialSmoothing', 'exp_smoothing_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 7. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(forecast, label='Forecast', color='darkorange')
    plt.title(f'Exponential Smoothing Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('ExponentialSmoothing', f'ExpSmoothing_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I40"].asfreq('MS')
        
        results = exponential_smoothing_forecast_district(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district      rmse  seasonal
# 0  AHMEDNAGAR  15.74677     False
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AHMEDNAGAR 2020-06-01      39  39.239214
# 1  AHMEDNAGAR 2020-07-01      40  39.239214
# 2  AHMEDNAGAR 2020-08-01      55  39.239214
# 3  AHMEDNAGAR 2020-09-01      36  39.239214
# 4  AHMEDNAGAR 2020-10-01      82  39.239214
# === Metrics ===
#   district      rmse  seasonal
# 0    AKOLA  9.123854     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    AKOLA 2020-06-01      37  42.079793
# 1    AKOLA 2020-07-01      34  42.079793
# 2    AKOLA 2020-08-01      45  42.079793
# 3    AKOLA 2020-09-01      54  42.079793
# 4    AKOLA 2020-10-01      48  42.079793
# === Metrics ===
#    district       rmse  seasonal
# 0  AMRAVATI  18.419143     False
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  AMRAVATI 2020-06-01      51  49.773196
# 1  AMRAVATI 2020-07-01      62  49.773196
# 2  AMRAVATI 2020-08-01      70  49.773196
# 3  AMRAVATI 2020-09-01      98  49.773196
# 4  AMRAVATI 2020-10-01      55  49.773196
# === Metrics ===
#      district       rmse  seasonal
# 0  AURANGABAD  13.761024     False
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AURANGABAD 2020-06-01      63  53.927078
# 1  AURANGABAD 2020-07-01      53  53.927078
# 2  AURANGABAD 2020-08-01      74  53.927078
# 3  AURANGABAD 2020-09-01      76  53.927078
# 4  AURANGABAD 2020-10-01      56  53.927078
# === Metrics ===
#   district       rmse  seasonal
# 0     BEED  10.556182     False
#
# === Forecast Data ===
#   district       date  actual  forecast
# 0     BEED 2020-06-01      21  27.55417
# 1     BEED 2020-07-01      30  27.55417
# 2     BEED 2020-08-01      30  27.55417
# 3     BEED 2020-09-01      33  27.55417
# 4     BEED 2020-10-01      16  27.55417
# === Metrics ===
#    district      rmse  seasonal
# 0  BHANDARA  4.706819     False
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BHANDARA 2020-06-01      16  19.131581
# 1  BHANDARA 2020-07-01      19  19.131581
# 2  BHANDARA 2020-08-01      22  19.131581
# 3  BHANDARA 2020-09-01      28  19.131581
# 4  BHANDARA 2020-10-01      22  19.131581
# === Metrics ===
#    district      rmse  seasonal
# 0  BULDHANA  6.660641     False
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BULDHANA 2020-06-01      25  27.434897
# 1  BULDHANA 2020-07-01      31  27.434897
# 2  BULDHANA 2020-08-01      25  27.434897
# 3  BULDHANA 2020-09-01      17  27.434897
# 4  BULDHANA 2020-10-01      19  27.434897
# === Metrics ===
#      district       rmse  seasonal
# 0  CHANDRAPUR  13.069718     False
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  CHANDRAPUR 2020-06-01      43  38.213288
# 1  CHANDRAPUR 2020-07-01      41  38.213288
# 2  CHANDRAPUR 2020-08-01      37  38.213288
# 3  CHANDRAPUR 2020-09-01      44  38.213288
# 4  CHANDRAPUR 2020-10-01      67  38.213288
# === Metrics ===
#   district       rmse  seasonal
# 0    DHULE  22.618992     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    DHULE 2020-06-01      20  13.109591
# 1    DHULE 2020-07-01      24  13.109591
# 2    DHULE 2020-08-01      31  13.109591
# 3    DHULE 2020-09-01      27  13.109591
# 4    DHULE 2020-10-01      50  13.109591
# === Metrics ===
#      district       rmse  seasonal
# 0  GADCHIROLI  13.185114     False
#
# === Forecast Data ===
#      district       date  actual  forecast
# 0  GADCHIROLI 2020-06-01      28  25.42355
# 1  GADCHIROLI 2020-07-01      46  25.42355
# 2  GADCHIROLI 2020-08-01      44  25.42355
# 3  GADCHIROLI 2020-09-01      44  25.42355
# 4  GADCHIROLI 2020-10-01      41  25.42355
# === Metrics ===
#   district       rmse  seasonal
# 0   GONDIA  10.262148     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   GONDIA 2020-06-01      20  15.722895
# 1   GONDIA 2020-07-01      23  15.722895
# 2   GONDIA 2020-08-01      21  15.722895
# 3   GONDIA 2020-09-01      28  15.722895
# 4   GONDIA 2020-10-01      39  15.722895
# === Metrics ===
#   district      rmse  seasonal
# 0  HINGOLI  4.756426     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  HINGOLI 2020-06-01       5  11.116673
# 1  HINGOLI 2020-07-01      12  11.116673
# 2  HINGOLI 2020-08-01      19  11.116673
# 3  HINGOLI 2020-09-01      14  11.116673
# 4  HINGOLI 2020-10-01      20  11.116673
# === Metrics ===
#   district       rmse  seasonal
# 0  JALGAON  15.106551     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  JALGAON 2020-06-01      29  38.539846
# 1  JALGAON 2020-07-01      21  38.539846
# 2  JALGAON 2020-08-01      25  38.539846
# 3  JALGAON 2020-09-01      41  38.539846
# 4  JALGAON 2020-10-01      37  38.539846
# === Metrics ===
#   district      rmse  seasonal
# 0    JALNA  5.139343     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    JALNA 2020-06-01      27  26.353364
# 1    JALNA 2020-07-01      38  26.353364
# 2    JALNA 2020-08-01      26  26.353364
# 3    JALNA 2020-09-01      25  26.353364
# 4    JALNA 2020-10-01      29  26.353364
# === Metrics ===
#    district      rmse  seasonal
# 0  KOLHAPUR  7.723258     False
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  KOLHAPUR 2020-06-01      27  24.549077
# 1  KOLHAPUR 2020-07-01      23  24.549077
# 2  KOLHAPUR 2020-08-01      20  24.549077
# 3  KOLHAPUR 2020-09-01      16  24.549077
# 4  KOLHAPUR 2020-10-01      14  24.549077
# === Metrics ===
#   district       rmse  seasonal
# 0    LATUR  16.355685     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    LATUR 2020-06-01      37  18.937189
# 1    LATUR 2020-07-01      16  18.937189
# 2    LATUR 2020-08-01      58  18.937189
# 3    LATUR 2020-09-01      35  18.937189
# 4    LATUR 2020-10-01      38  18.937189
# === Metrics ===
#   district       rmse  seasonal
# 0   MUMBAI  29.320891     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   MUMBAI 2020-06-01      77  89.461571
# 1   MUMBAI 2020-07-01      74  89.461571
# 2   MUMBAI 2020-08-01      66  89.461571
# 3   MUMBAI 2020-09-01      76  89.461571
# 4   MUMBAI 2020-10-01      90  89.461571
# === Metrics ===
#   district       rmse  seasonal
# 0   NAGPUR  16.879135     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NAGPUR 2020-06-01      63  59.623363
# 1   NAGPUR 2020-07-01      50  59.623363
# 2   NAGPUR 2020-08-01      52  59.623363
# 3   NAGPUR 2020-09-01      35  59.623363
# 4   NAGPUR 2020-10-01      76  59.623363
# === Metrics ===
#   district      rmse  seasonal
# 0   NANDED  9.888448     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NANDED 2020-06-01      25  22.808742
# 1   NANDED 2020-07-01      26  22.808742
# 2   NANDED 2020-08-01      32  22.808742
# 3   NANDED 2020-09-01      50  22.808742
# 4   NANDED 2020-10-01      21  22.808742
# === Metrics ===
#     district       rmse  seasonal
# 0  NANDURBAR  13.009235     False
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  NANDURBAR 2020-06-01      31  32.144672
# 1  NANDURBAR 2020-07-01      42  32.144672
# 2  NANDURBAR 2020-08-01      48  32.144672
# 3  NANDURBAR 2020-09-01      52  32.144672
# 4  NANDURBAR 2020-10-01      44  32.144672
# === Metrics ===
#   district       rmse  seasonal
# 0   NASHIK  19.972943     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NASHIK 2020-06-01      91  94.551455
# 1   NASHIK 2020-07-01      68  94.551455
# 2   NASHIK 2020-08-01      94  94.551455
# 3   NASHIK 2020-09-01     111  94.551455
# 4   NASHIK 2020-10-01      96  94.551455
# === Metrics ===
#     district     rmse  seasonal
# 0  OSMANABAD  6.48732     False
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  OSMANABAD 2020-06-01      20  17.141277
# 1  OSMANABAD 2020-07-01      28  17.141277
# 2  OSMANABAD 2020-08-01      30  17.141277
# 3  OSMANABAD 2020-09-01      26  17.141277
# 4  OSMANABAD 2020-10-01      17  17.141277
# === Metrics ===
#   district      rmse  seasonal
# 0  PALGHAR  9.403873     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  PALGHAR 2020-06-01      32  35.657902
# 1  PALGHAR 2020-07-01      45  35.657902
# 2  PALGHAR 2020-08-01      48  35.657902
# 3  PALGHAR 2020-09-01      33  35.657902
# 4  PALGHAR 2020-10-01      48  35.657902
# === Metrics ===
#    district      rmse  seasonal
# 0  PARBHANI  6.820048     False
#
# === Forecast Data ===
#    district       date  actual  forecast
# 0  PARBHANI 2020-06-01      13  15.87028
# 1  PARBHANI 2020-07-01      11  15.87028
# 2  PARBHANI 2020-08-01      33  15.87028
# 3  PARBHANI 2020-09-01      18  15.87028
# 4  PARBHANI 2020-10-01      12  15.87028
# === Metrics ===
#   district       rmse  seasonal
# 0     PUNE  15.368853     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     PUNE 2020-06-01      63  64.595935
# 1     PUNE 2020-07-01      72  64.595935
# 2     PUNE 2020-08-01      69  64.595935
# 3     PUNE 2020-09-01      70  64.595935
# 4     PUNE 2020-10-01      58  64.595935
# === Metrics ===
#   district      rmse  seasonal
# 0   RAIGAD  8.393771     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   RAIGAD 2020-06-01      27  18.982767
# 1   RAIGAD 2020-07-01      21  18.982767
# 2   RAIGAD 2020-08-01      29  18.982767
# 3   RAIGAD 2020-09-01      35  18.982767
# 4   RAIGAD 2020-10-01      32  18.982767
# === Metrics ===
#     district      rmse  seasonal
# 0  RATNAGIRI  5.862311     False
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  RATNAGIRI 2020-06-01      14  13.954278
# 1  RATNAGIRI 2020-07-01      23  13.954278
# 2  RATNAGIRI 2020-08-01      25  13.954278
# 3  RATNAGIRI 2020-09-01      22  13.954278
# 4  RATNAGIRI 2020-10-01      11  13.954278
# === Metrics ===
#   district     rmse  seasonal
# 0   SANGLI  8.00726     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SANGLI 2020-06-01      15  23.945794
# 1   SANGLI 2020-07-01      24  23.945794
# 2   SANGLI 2020-08-01      16  23.945794
# 3   SANGLI 2020-09-01      13  23.945794
# 4   SANGLI 2020-10-01      28  23.945794
# === Metrics ===
#   district    rmse  seasonal
# 0   SATARA  7.6446     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SATARA 2020-06-01      28  32.702103
# 1   SATARA 2020-07-01      40  32.702103
# 2   SATARA 2020-08-01      40  32.702103
# 3   SATARA 2020-09-01      49  32.702103
# 4   SATARA 2020-10-01      39  32.702103
# === Metrics ===
#      district      rmse  seasonal
# 0  SINDHUDURG  2.635077     False
#
# === Forecast Data ===
#      district       date  actual  forecast
# 0  SINDHUDURG 2020-06-01       9  5.868421
# 1  SINDHUDURG 2020-07-01       9  5.868421
# 2  SINDHUDURG 2020-08-01       3  5.868421
# 3  SINDHUDURG 2020-09-01      10  5.868421
# 4  SINDHUDURG 2020-10-01       4  5.868421
# === Metrics ===
#   district       rmse  seasonal
# 0  SOLAPUR  24.035576     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  SOLAPUR 2020-06-01      45  44.343115
# 1  SOLAPUR 2020-07-01      28  44.343115
# 2  SOLAPUR 2020-08-01      25  44.343115
# 3  SOLAPUR 2020-09-01      17  44.343115
# 4  SOLAPUR 2020-10-01      18  44.343115
# === Metrics ===
#   district       rmse  seasonal
# 0    THANE  21.296688     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    THANE 2020-06-01      75  85.695645
# 1    THANE 2020-07-01      98  85.695645
# 2    THANE 2020-08-01      79  85.695645
# 3    THANE 2020-09-01      76  85.695645
# 4    THANE 2020-10-01      68  85.695645
# === Metrics ===
#   district      rmse  seasonal
# 0   WARDHA  3.769438     False
#
# === Forecast Data ===
#   district       date  actual  forecast
# 0   WARDHA 2020-06-01       9  6.324094
# 1   WARDHA 2020-07-01       4  6.324094
# 2   WARDHA 2020-08-01       6  6.324094
# 3   WARDHA 2020-09-01       9  6.324094
# 4   WARDHA 2020-10-01      16  6.324094
# === Metrics ===
#   district      rmse  seasonal
# 0   WASHIM  4.133104     False
#
# === Forecast Data ===
#   district       date  actual  forecast
# 0   WASHIM 2020-06-01      11  8.578947
# 1   WASHIM 2020-07-01      13  8.578947
# 2   WASHIM 2020-08-01      18  8.578947
# 3   WASHIM 2020-09-01       7  8.578947
# 4   WASHIM 2020-10-01      10  8.578947
# === Metrics ===
#    district      rmse  seasonal
# 0  YAVATMAL  5.999371     False
#
# === Forecast Data ===
#    district       date  actual  forecast
# 0  YAVATMAL 2020-06-01       1  7.658644
# 1  YAVATMAL 2020-07-01       3  7.658644
# 2  YAVATMAL 2020-08-01       7  7.658644
# 3  YAVATMAL 2020-09-01       8  7.658644
# 4  YAVATMAL 2020-10-01      23  7.658644
# === Metrics ===
#           district       rmse  seasonal
# 0  MUMBAI SUBURBAN  21.663956     False
#
# === Forecast Data ===
#           district       date  actual   forecast
# 0  MUMBAI SUBURBAN 2021-01-01      36  51.999851
# 1  MUMBAI SUBURBAN 2021-02-01      28  51.999851
# 2  MUMBAI SUBURBAN 2021-03-01      28  51.999851
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual   forecast
#  0  MUMBAI SUBURBAN 2021-01-01      36  51.999851
#  1  MUMBAI SUBURBAN 2021-02-01      28  51.999851
#  2  MUMBAI SUBURBAN 2021-03-01      28  51.999851,
#  'metrics_df':           district       rmse  seasonal
#  0  MUMBAI SUBURBAN  21.663956     False}
