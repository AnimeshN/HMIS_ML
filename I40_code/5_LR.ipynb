# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox

from statsmodels.stats.stattools import durbin_watson
from statsmodels.graphics.tsaplots import plot_acf
from scipy.stats import shapiro
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def linear_regression_lags_only(series, district_name, max_lags=3, differencing=True):
    """
    Simplified linear regression for time series forecasting with:
    - Lag features only
    - Ordinary Least Squares (OLS) regression
    - Optional differencing for stationarity
    """
    # Create directory structure
    os.makedirs('LinearRegression', exist_ok=True)
    
    # 1. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 2. Feature Engineering - Lag features only
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 3. Train-Test Split (time-based)
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 4. Model Training with OLS
    X_train_sm = sm.add_constant(X_train)
    model = sm.OLS(y_train, X_train_sm).fit()

    # 5. Forecasting
    X_test_sm = sm.add_constant(X_test)
    pred_test = model.predict(X_test_sm)

    # 6. Inverse Differencing if applied
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = pred_test.cumsum() + last_train_value
        y_test = original_series.iloc[-len(test):]
    
    # 7. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test.values
    })

    # 8. Save forecasts to CSV
    forecast_csv_path = os.path.join('LinearRegression', 'linear_forecasts_lags_only.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, mode='a', header=write_header, index=False)

    # 9. Calculate metrics
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'r_squared': model.rsquared,
        'params': model.params.to_dict(),
        'differencing': d
    }])

    metrics_csv_path = os.path.join('LinearRegression', 'linear_metrics_lags_only.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, mode='a', header=write_header_metrics, index=False)

    # 10. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', color='darkorange')
    plt.title(f'Linear Regression (Lags Only) Forecast for {district_name}\nRMSE: {rmse:.2f}, R²: {model.rsquared:.2f}')
    plt.legend()
    plt.savefig(os.path.join('LinearRegression', f'Linear_forecast_lags_only_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_summary': model.summary().as_text()
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I40"].asfreq('MS')
        
        results = linear_regression_lags_only(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district       rmse  r_squared  \
# 0  AHMEDNAGAR  17.326589   0.128642
#
#                                               params  differencing
# 0  {'const': 28.04762203136159, 'lag_1': 0.332143...             0
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AHMEDNAGAR 2020-07-01    40.0  41.505914
# 1  AHMEDNAGAR 2020-08-01    55.0  41.924740
# 2  AHMEDNAGAR 2020-09-01    36.0  47.292783
# 3  AHMEDNAGAR 2020-10-01    82.0  38.916503
# 4  AHMEDNAGAR 2020-11-01    49.0  59.715028
# === Metrics ===
#   district      rmse  r_squared  \
# 0    AKOLA  9.307148   0.189983
#
#                                               params  differencing
# 0  {'const': 24.216776735618055, 'lag_1': 0.29752...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    AKOLA 2020-07-01    34.0  43.306225
# 1    AKOLA 2020-08-01    45.0  41.478628
# 2    AKOLA 2020-09-01    54.0  44.217118
# 3    AKOLA 2020-10-01    48.0  50.033932
# 4    AKOLA 2020-11-01    39.0  49.918409
# === Metrics ===
#    district       rmse  r_squared  \
# 0  AMRAVATI  18.403094   0.405086
#
#                                               params  differencing
# 0  {'const': 36.79715803062332, 'lag_1': 0.497158...             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  AMRAVATI 2020-07-01    62.0  58.305516
# 1  AMRAVATI 2020-08-01    70.0  61.625654
# 2  AMRAVATI 2020-09-01    98.0  69.036749
# 3  AMRAVATI 2020-10-01    55.0  80.727584
# 4  AMRAVATI 2020-11-01    45.0  64.652623
# === Metrics ===
#      district       rmse  r_squared  \
# 0  AURANGABAD  15.152805   0.050866
#
#                                               params  differencing
# 0  {'const': 0.476268388257527, 'lag_1': -0.21683...             1
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AURANGABAD 2020-07-01      53  61.260288
# 1  AURANGABAD 2020-08-01      74  64.067722
# 2  AURANGABAD 2020-09-01      76  59.597262
# 3  AURANGABAD 2020-10-01      56  60.376129
# 4  AURANGABAD 2020-11-01      57  64.840830
# === Metrics ===
#   district      rmse  r_squared  \
# 0     BEED  7.644339    0.28975
#
#                                               params  differencing
# 0  {'const': 16.6985496189312, 'lag_1': 0.5099448...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     BEED 2020-07-01    30.0  24.107256
# 1     BEED 2020-08-01    30.0  27.614470
# 2     BEED 2020-09-01    33.0  29.107371
# 3     BEED 2020-10-01    16.0  29.040377
# 4     BEED 2020-11-01    18.0  20.454955
# === Metrics ===
#    district      rmse  r_squared  \
# 0  BHANDARA  4.152846   0.088823
#
#                                               params  differencing
# 0  {'const': 12.896751058565311, 'lag_1': 0.26069...             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BHANDARA 2020-07-01    19.0  18.222347
# 1  BHANDARA 2020-08-01    22.0  19.004427
# 2  BHANDARA 2020-09-01    28.0  20.063187
# 3  BHANDARA 2020-10-01    22.0  21.843816
# 4  BHANDARA 2020-11-01    25.0  20.772803
# === Metrics ===
#    district       rmse  r_squared  \
# 0  BULDHANA  10.861012   0.291195
#
#                                               params  differencing
# 0  {'const': 0.5777459386435492, 'lag_1': -0.4607...             1
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BULDHANA 2020-07-01      31  26.628664
# 1  BULDHANA 2020-08-01      25  24.281620
# 2  BULDHANA 2020-09-01      17  28.109397
# 3  BULDHANA 2020-10-01      19  31.392799
# 4  BULDHANA 2020-11-01      24  32.050551
# === Metrics ===
#      district      rmse  r_squared  \
# 0  CHANDRAPUR  12.99063   0.040361
#
#                                               params  differencing
# 0  {'const': 38.11601223702265, 'lag_1': 0.171442...             0
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  CHANDRAPUR 2020-07-01    41.0  44.185697
# 1  CHANDRAPUR 2020-08-01    37.0  42.918994
# 2  CHANDRAPUR 2020-09-01    44.0  41.881759
# 3  CHANDRAPUR 2020-10-01    67.0  43.127841
# 4  CHANDRAPUR 2020-11-01    47.0  47.692657
# === Metrics ===
#   district       rmse  r_squared  \
# 0    DHULE  13.556639   0.410689
#
#                                               params  differencing
# 0  {'const': 5.820306475256454, 'lag_1': 0.459094...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    DHULE 2020-07-01    24.0  16.189170
# 1    DHULE 2020-08-01    31.0  21.872366
# 2    DHULE 2020-09-01    27.0  24.842307
# 3    DHULE 2020-10-01    50.0  23.584263
# 4    DHULE 2020-11-01    25.0  37.959963
# === Metrics ===
#      district      rmse  r_squared  \
# 0  GADCHIROLI  8.368714    0.13223
#
#                                               params  differencing
# 0  {'const': 24.95924146692228, 'lag_1': 0.301191...             0
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  GADCHIROLI 2020-07-01    46.0  30.059265
# 1  GADCHIROLI 2020-08-01    44.0  36.940430
# 2  GADCHIROLI 2020-09-01    44.0  37.061570
# 3  GADCHIROLI 2020-10-01    41.0  33.325351
# 4  GADCHIROLI 2020-11-01    40.0  32.815818
# === Metrics ===
#   district      rmse  r_squared  \
# 0   GONDIA  6.626647   0.148735
#
#                                               params  differencing
# 0  {'const': 11.64529070468701, 'lag_1': 0.348386...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   GONDIA 2020-07-01    23.0  20.227832
# 1   GONDIA 2020-08-01    21.0  21.107116
# 2   GONDIA 2020-09-01    28.0  21.005449
# 3   GONDIA 2020-10-01    39.0  23.725465
# 4   GONDIA 2020-11-01    30.0  27.396486
# === Metrics ===
#   district      rmse  r_squared  \
# 0  HINGOLI  4.177311   0.214391
#
#                                               params  differencing
# 0  {'const': 6.630507992577062, 'lag_1': 0.486966...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  HINGOLI 2020-07-01    12.0   9.182731
# 1  HINGOLI 2020-08-01    19.0  12.828258
# 2  HINGOLI 2020-09-01    14.0  15.720857
# 3  HINGOLI 2020-10-01    20.0  13.349234
# 4  HINGOLI 2020-11-01    12.0  16.689385
# === Metrics ===
#   district       rmse  r_squared  \
# 0  JALGAON  10.064882   0.303121
#
#                                               params  differencing
# 0  {'const': 13.852775386013539, 'lag_1': 0.51696...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  JALGAON 2020-07-01    21.0  31.562602
# 1  JALGAON 2020-08-01    25.0  27.575575
# 2  JALGAON 2020-09-01    41.0  28.908528
# 3  JALGAON 2020-10-01    37.0  36.590519
# 4  JALGAON 2020-11-01    39.0  34.814714
# === Metrics ===
#   district      rmse  r_squared  \
# 0    JALNA  6.342173   0.143365
#
#                                               params  differencing
# 0  {'const': 17.7248592537794, 'lag_1': 0.3768168...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    JALNA 2020-07-01    38.0  28.039073
# 1    JALNA 2020-08-01    26.0  32.919124
# 2    JALNA 2020-09-01    25.0  27.635985
# 3    JALNA 2020-10-01    29.0  28.657204
# 4    JALNA 2020-11-01    20.0  29.332382
# === Metrics ===
#    district      rmse  r_squared  \
# 0  KOLHAPUR  7.747126   0.265646
#
#                                               params  differencing
# 0  {'const': 9.012684391464136, 'lag_1': 0.391998...             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  KOLHAPUR 2020-07-01    23.0  24.713821
# 1  KOLHAPUR 2020-08-01    20.0  23.256184
# 2  KOLHAPUR 2020-09-01    16.0  23.044539
# 3  KOLHAPUR 2020-10-01    14.0  20.568221
# 4  KOLHAPUR 2020-11-01    15.0  19.064355
# === Metrics ===
#   district       rmse  r_squared  \
# 0    LATUR  19.486094   0.182445
#
#                                               params  differencing
# 0  {'const': 18.38214923335967, 'lag_1': 0.464243...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    LATUR 2020-07-01    16.0  30.436703
# 1    LATUR 2020-08-01    58.0  14.958341
# 2    LATUR 2020-09-01    35.0  43.668534
# 3    LATUR 2020-10-01    38.0  16.157929
# 4    LATUR 2020-11-01    14.0  30.003679
# === Metrics ===
#   district       rmse  r_squared  \
# 0   MUMBAI  23.104731   0.316552
#
#                                               params  differencing
# 0  {'const': -4.818197439148248, 'lag_1': -0.5820...             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   MUMBAI 2020-07-01      74  58.122569
# 1   MUMBAI 2020-08-01      66  53.855103
# 2   MUMBAI 2020-09-01      76  54.774483
# 3   MUMBAI 2020-10-01      90  44.495341
# 4   MUMBAI 2020-11-01      69  28.909329
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NAGPUR  16.878969    0.56576
#
#                                               params  differencing
# 0  {'const': 11.82658837799409, 'lag_1': 0.288878...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NAGPUR 2020-07-01    50.0  74.441311
# 1   NAGPUR 2020-08-01    52.0  55.568441
# 2   NAGPUR 2020-09-01    35.0  49.730092
# 3   NAGPUR 2020-10-01    76.0  47.877997
# 4   NAGPUR 2020-11-01    33.0  48.707513
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NANDED  13.816517   0.145499
#
#                                               params  differencing
# 0  {'const': -1.1046712478453167, 'lag_1': -0.338...             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NANDED 2020-07-01      26  21.757979
# 1   NANDED 2020-08-01      32  21.052573
# 2   NANDED 2020-09-01      50  17.784233
# 3   NANDED 2020-10-01      21   9.864594
# 4   NANDED 2020-11-01      33  16.633103
# === Metrics ===
#     district      rmse  r_squared  \
# 0  NANDURBAR  9.065023   0.360151
#
#                                               params  differencing
# 0  {'const': 18.374745203801908, 'lag_1': 0.64119...             0
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  NANDURBAR 2020-07-01    42.0  35.209842
# 1  NANDURBAR 2020-08-01    48.0  42.002742
# 2  NANDURBAR 2020-09-01    52.0  45.388933
# 3  NANDURBAR 2020-10-01    44.0  47.075428
# 4  NANDURBAR 2020-11-01    56.0  41.429474
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NASHIK  16.343854   0.330398
#
#                                               params  differencing
# 0  {'const': 54.175224132824106, 'lag_1': 0.57796...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NASHIK 2020-07-01    68.0   95.422775
# 1   NASHIK 2020-08-01    94.0   77.141805
# 2   NASHIK 2020-09-01   111.0   93.217522
# 3   NASHIK 2020-10-01    96.0  108.136138
# 4   NASHIK 2020-11-01    87.0   95.029848
# === Metrics ===
#     district      rmse  r_squared  \
# 0  OSMANABAD  5.906876   0.153218
#
#                                               params  differencing
# 0  {'const': 9.217573498732797, 'lag_1': 0.177099...             0
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  OSMANABAD 2020-07-01    28.0  19.019458
# 1  OSMANABAD 2020-08-01    30.0  22.741998
# 2  OSMANABAD 2020-09-01    26.0  22.867259
# 3  OSMANABAD 2020-10-01    17.0  24.355658
# 4  OSMANABAD 2020-11-01    19.0  22.754389
# === Metrics ===
#   district       rmse  r_squared  \
# 0  PALGHAR  12.300742   0.124782
#
#                                               params  differencing
# 0  {'const': -0.07723107494441211, 'lag_1': -0.32...             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  PALGHAR 2020-07-01      45  33.933550
# 1  PALGHAR 2020-08-01      48  29.021800
# 2  PALGHAR 2020-09-01      33  29.200750
# 3  PALGHAR 2020-10-01      48  31.817178
# 4  PALGHAR 2020-11-01      42  27.414616
# === Metrics ===
#    district      rmse  r_squared  \
# 0  PARBHANI  9.417901   0.529789
#
#                                               params  differencing
# 0  {'const': 3.8597754184662465, 'lag_1': 0.77734...             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  PARBHANI 2020-07-01    11.0  12.279577
# 1  PARBHANI 2020-08-01    33.0  10.601197
# 2  PARBHANI 2020-09-01    18.0  28.018999
# 3  PARBHANI 2020-10-01    12.0  15.342738
# 4  PARBHANI 2020-11-01    21.0   9.919490
# === Metrics ===
#   district       rmse  r_squared  \
# 0     PUNE  49.177784   0.503878
#
#                                               params  differencing
# 0  {'const': -5.245614002061473, 'lag_1': -0.7965...             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     PUNE 2020-07-01      72  46.820338
# 1     PUNE 2020-08-01      69  36.899125
# 2     PUNE 2020-09-01      70  29.559807
# 3     PUNE 2020-10-01      58  21.015382
# 4     PUNE 2020-11-01      98  26.162860
# === Metrics ===
#   district      rmse  r_squared  \
# 0   RAIGAD  8.566701   0.483913
#
#                                               params  differencing
# 0  {'const': 7.485468805595126, 'lag_1': 0.595672...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   RAIGAD 2020-07-01    21.0  27.108985
# 1   RAIGAD 2020-08-01    29.0  23.122789
# 2   RAIGAD 2020-09-01    35.0  26.329666
# 3   RAIGAD 2020-10-01    32.0  32.188901
# 4   RAIGAD 2020-11-01    11.0  30.820771
# === Metrics ===
#     district      rmse  r_squared  \
# 0  RATNAGIRI  5.778223   0.163917
#
#                                               params  differencing
# 0  {'const': 10.313340825683099, 'lag_1': 0.24806...             0
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  RATNAGIRI 2020-07-01    23.0  16.241572
# 1  RATNAGIRI 2020-08-01    25.0  13.178745
# 2  RATNAGIRI 2020-09-01    22.0  18.636077
# 3  RATNAGIRI 2020-10-01    11.0  15.690875
# 4  RATNAGIRI 2020-11-01    19.0  11.512749
# === Metrics ===
#   district     rmse  r_squared  \
# 0   SANGLI  8.27896   0.024284
#
#                                               params  differencing
# 0  {'const': 22.520926549393856, 'lag_1': 0.11682...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SANGLI 2020-07-01    24.0  24.887056
# 1   SANGLI 2020-08-01    16.0  26.549883
# 2   SANGLI 2020-09-01    13.0  24.402087
# 3   SANGLI 2020-10-01    28.0  25.397881
# 4   SANGLI 2020-11-01    34.0  26.558085
# === Metrics ===
#   district      rmse  r_squared  \
# 0   SATARA  6.177046   0.169662
#
#                                               params  differencing
# 0  {'const': 20.489483776990596, 'lag_1': 0.19092...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SATARA 2020-07-01    40.0  35.605400
# 1   SATARA 2020-08-01    40.0  32.953893
# 2   SATARA 2020-09-01    49.0  38.206731
# 3   SATARA 2020-10-01    39.0  38.471518
# 4   SATARA 2020-11-01    40.0  39.593392
# === Metrics ===
#      district      rmse  r_squared  \
# 0  SINDHUDURG  3.051089   0.125908
#
#                                               params  differencing
# 0  {'const': 8.095226508438262, 'lag_1': 0.061964...             0
#
# === Forecast Data ===
#      district       date  actual  forecast
# 0  SINDHUDURG 2020-07-01     9.0  6.100077
# 1  SINDHUDURG 2020-08-01     3.0  6.547157
# 2  SINDHUDURG 2020-09-01    10.0  4.324458
# 3  SINDHUDURG 2020-10-01     4.0  5.545071
# 4  SINDHUDURG 2020-11-01     6.0  6.106191
# === Metrics ===
#   district       rmse  r_squared  \
# 0  SOLAPUR  48.289015   0.445358
#
#                                               params  differencing
# 0  {'const': -0.035281470391094194, 'lag_1': -0.7...             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  SOLAPUR 2020-07-01      28  45.379359
# 1  SOLAPUR 2020-08-01      25  61.817094
# 2  SOLAPUR 2020-09-01      17  66.548707
# 3  SOLAPUR 2020-10-01      18  71.025693
# 4  SOLAPUR 2020-11-01      24  71.438306
# === Metrics ===
#   district       rmse  r_squared  \
# 0    THANE  17.322603   0.090072
#
#                                               params  differencing
# 0  {'const': -0.2923671234271612, 'lag_1': -0.263...             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    THANE 2020-07-01      98  78.373343
# 1    THANE 2020-08-01      79  71.096687
# 2    THANE 2020-09-01      76  77.600454
# 3    THANE 2020-10-01      68  76.734250
# 4    THANE 2020-11-01      78  78.127381
# === Metrics ===
#   district      rmse  r_squared  \
# 0   WARDHA  3.777699   0.176537
#
#                                               params  differencing
# 0  {'const': 3.3946308475359315, 'lag_1': 0.14339...             0
#
# === Forecast Data ===
#   district       date  actual  forecast
# 0   WARDHA 2020-07-01     4.0  6.925375
# 1   WARDHA 2020-08-01     6.0  7.328449
# 2   WARDHA 2020-09-01     9.0  7.014885
# 3   WARDHA 2020-10-01    16.0  6.925375
# 4   WARDHA 2020-11-01     7.0  9.049247
# === Metrics ===
#   district      rmse  r_squared  \
# 0   WASHIM  4.444859   0.134752
#
#                                               params  differencing
# 0  {'const': 7.717136484156898, 'lag_1': 0.348771...             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   WASHIM 2020-07-01    13.0   8.663412
# 1   WASHIM 2020-08-01    18.0   9.030594
# 2   WASHIM 2020-09-01     7.0  11.080792
# 3   WASHIM 2020-10-01    10.0   6.342298
# 4   WASHIM 2020-11-01     5.0   8.450798
# === Metrics ===
#    district     rmse  r_squared  \
# 0  YAVATMAL  6.86723    0.41175
#
#                                               params  differencing
# 0  {'const': 3.9083233277980183, 'lag_1': 0.55546...             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  YAVATMAL 2020-07-01     3.0   4.969563
# 1  YAVATMAL 2020-08-01     7.0   5.038285
# 2  YAVATMAL 2020-09-01     8.0   8.370564
# 3  YAVATMAL 2020-10-01    23.0   9.605690
# 4  YAVATMAL 2020-11-01     6.0  17.658138
# === Metrics ===
#           district      rmse  r_squared  \
# 0  MUMBAI SUBURBAN  2.137691   0.938541
#
#                                               params  differencing
# 0  {'const': -7.322588313794798, 'lag_1': -1.1423...             1
#
# === Forecast Data ===
#           district       date  actual   forecast
# 0  MUMBAI SUBURBAN 2021-02-01      28  25.148564
# 1  MUMBAI SUBURBAN 2021-03-01      28  29.004369
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual   forecast
#  0  MUMBAI SUBURBAN 2021-02-01      28  25.148564
#  1  MUMBAI SUBURBAN 2021-03-01      28  29.004369,
#  'metrics_df':           district      rmse  r_squared  \
#  0  MUMBAI SUBURBAN  2.137691   0.938541
#
#                                                params  differencing
#  0  {'const': -7.322588313794798, 'lag_1': -1.1423...             1  ,
#  'model_summary': '                            OLS Regression Results                            \n==============================================================================\nDep. Variable:                      y   R-squared:                       0.939\nModel:                            OLS   Adj. R-squared:                  0.846\nMethod:                 Least Squares   F-statistic:                     10.18\nDate:                Mon, 28 Apr 2025   Prob (F-statistic):             0.0908\nTime:                        22:45:01   Log-Likelihood:                -17.316\nNo. Observations:                   6   AIC:                             42.63\nDf Residuals:                       2   BIC:                             41.80\nDf Model:                           3                                         \nCovariance Type:            nonrobust                                         \n==============================================================================\n                 coef    std err          t      P>|t|      [0.025      0.975]\n------------------------------------------------------------------------------\nconst         -7.3226      6.751     -1.085      0.391     -36.369      21.724\nlag_1         -1.1423      0.642     -1.780      0.217      -3.904       1.620\nlag_2         -0.0479      0.969     -0.049      0.965      -4.218       4.123\nlag_3          0.3600      0.531      0.678      0.568      -1.925       2.645\n==============================================================================\nOmnibus:                          nan   Durbin-Watson:                   1.735\nProb(Omnibus):                    nan   Jarque-Bera (JB):                0.060\nSkew:                           0.191   Prob(JB):                        0.970\nKurtosis:                       2.691   Cond. No.                         63.9\n==============================================================================\n\nNotes:\n[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.'}
