# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from xgboost import XGBRegressor

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def xgboost_forecast_lags(
    series,
    district_name,
    max_lags=12,
    differencing=True,
    use_cv=True,
    cv_params=None,
    custom_params=None
):
    """
    XGBoost time series forecasting with error handling
    Returns (None, None) if insufficient data, allowing pipeline continuation
    """
    try:
        # 1. Directory setup
        os.makedirs('XGBoost_Forecasts', exist_ok=True)
        
        # 2. Stationarity and differencing
        original_series = series.copy()
        d = 0
        if differencing:
            adf_result = adfuller(series.dropna())
            if adf_result[1] > 0.05:
                d = 1
                series = series.diff().dropna()
                if len(series) < 5:  # Check after differencing
                    raise ValueError(f"Series too short after differencing: {len(series)}")

        # 3. Create lag features with validation
        df = pd.DataFrame({'y': series.astype(float)})
        for lag in range(1, max_lags + 1):
            df[f'lag_{lag}'] = df['y'].shift(lag)
        df = df.dropna()
        
        if len(df) < 10:
            raise ValueError(f"Only {len(df)} samples after lag features")

        # 4. Temporal split validation
        train_size = int(len(df) * 0.8)
        if train_size < 5 or (len(df) - train_size) < 2:
            raise ValueError(f"Insufficient split: {train_size} train, {len(df)-train_size} test")
            
        train = df.iloc[:train_size]
        test = df.iloc[train_size:]

        X_train = train.drop(columns=['y'])
        y_train = train['y']
        X_test = test.drop(columns=['y'])
        y_test = test['y']

        # 5. Dynamic cross-validation setup
        xgb_params = custom_params or {
            'n_estimators': 500,
            'learning_rate': 0.05,
            'max_depth': 3,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': 42
        }
        
        if use_cv:
            n_splits = min(5, max(2, len(X_train)//2))  # Ensure 2 ≤ splits ≤5
            param_grid = cv_params or {
                'n_estimators': [100, 300],
                'learning_rate': [0.01, 0.05],
                'max_depth': [3, 5]
            }
            tscv = TimeSeriesSplit(n_splits=n_splits)
            
            grid_search = GridSearchCV(
                XGBRegressor(**xgb_params, verbosity=0),
                param_grid,
                cv=tscv,
                scoring='neg_mean_squared_error',
                n_jobs=-1
            )
            grid_search.fit(X_train, y_train)
            model = grid_search.best_estimator_
            best_params = grid_search.best_params_
        else:
            model = XGBRegressor(**xgb_params, verbosity=0)
            model.fit(X_train, y_train)
            best_params = xgb_params

        # 6. Forecasting and post-processing
        pred_test = model.predict(X_test)

        if d == 1:
            last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
            pred_test = np.cumsum(pred_test) + last_train_value
            y_test = original_series.iloc[-len(test):]

        # 7. Save results
        forecast_df = pd.DataFrame({
            'district': district_name,
            'date': y_test.index,
            'actual': y_test.values,
            'forecast': pred_test
        })
        forecast_df.to_csv(
            os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.csv'), 
            index=False
        )

        # 8. Metrics and visualization
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        
        plt.figure(figsize=(14, 7))
        plt.plot(original_series.index, original_series, label='Original')
        plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', alpha=0.7)
        plt.title(f'{district_name} Forecast (RMSE: {rmse:.2f})')
        plt.legend()
        plt.savefig(os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.png'))
        plt.close()

        return {
            'district': district_name,
            'rmse': rmse,
            'best_params': best_params,
            'differencing': d,
            'feature_importances': dict(zip(X_train.columns, model.feature_importances_))
        }, forecast_df

    except (ValueError, IndexError) as e:
        print(f"⚠️ Skipping {district_name}: {str(e)}")
        return None, None

# %%
districts = data['district'].unique()
rmse_values = []

# Usage Example


def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I8"].asfreq('MS')
        
        results, forecast = xgboost_forecast_lags(
            series=ts,  # pd.Series with DatetimeIndex
            district_name=district,
            max_lags=6,
            use_cv=True,
            cv_params={
                'n_estimators': [200, 500],
                'learning_rate': [0.05, 0.1],
                'max_depth': [3, 5]
            },
            custom_params={
                'subsample': 0.8,
                'colsample_bytree': 0.8,
                'random_state': 42
            }
        )

        
    
        # Show results
        print("=== Metrics ===")
        print(results)
        print("\n=== Forecast Data ===")
        print(forecast)
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
# {'district': 'AHMEDNAGAR', 'rmse': 633.9316033947606, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.2376695, 'lag_2': 0.107895255, 'lag_3': 0.17539245, 'lag_4': 0.21550302, 'lag_5': 0.134771, 'lag_6': 0.1287687}}
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AHMEDNAGAR 2020-07-01    5982  6520.865723
# 1  AHMEDNAGAR 2020-08-01    5559  6358.687012
# 2  AHMEDNAGAR 2020-09-01    5903  6346.239258
# 3  AHMEDNAGAR 2020-10-01    5719  6302.272949
# 4  AHMEDNAGAR 2020-11-01    5427  6131.180664
# 5  AHMEDNAGAR 2020-12-01    6256  6090.711914
# 6  AHMEDNAGAR 2021-01-01    6196  6055.276367
# 7  AHMEDNAGAR 2021-02-01    6458  6752.680664
# 8  AHMEDNAGAR 2021-03-01    5735  6968.064941
# === Metrics ===
# {'district': 'AKOLA', 'rmse': 294.4102153015045, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.17795843, 'lag_2': 0.07719692, 'lag_3': 0.28499526, 'lag_4': 0.16959538, 'lag_5': 0.18175147, 'lag_6': 0.1085025}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    AKOLA 2020-07-01    1555  1680.332886
# 1    AKOLA 2020-08-01    1523  1620.134644
# 2    AKOLA 2020-09-01    1606  1651.143921
# 3    AKOLA 2020-10-01    1395  1734.484741
# 4    AKOLA 2020-11-01    1204  1698.138428
# 5    AKOLA 2020-12-01    1630  1767.339966
# 6    AKOLA 2021-01-01    1745  1858.968994
# 7    AKOLA 2021-02-01    1618  2103.823486
# 8    AKOLA 2021-03-01    1782  2136.424316
# === Metrics ===
# {'district': 'AMRAVATI', 'rmse': 362.4842676037002, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.13135068, 'lag_2': 0.06290216, 'lag_3': 0.067892425, 'lag_4': 0.047033437, 'lag_5': 0.23864831, 'lag_6': 0.45217294}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  AMRAVATI 2020-07-01  1905.0  2271.299316
# 1  AMRAVATI 2020-08-01  1776.0  2047.286377
# 2  AMRAVATI 2020-09-01  1794.0  2035.595215
# 3  AMRAVATI 2020-10-01  1814.0  2216.970947
# 4  AMRAVATI 2020-11-01  1896.0  2171.424072
# 5  AMRAVATI 2020-12-01  2379.0  2164.609863
# 6  AMRAVATI 2021-01-01  2249.0  2422.189697
# 7  AMRAVATI 2021-02-01  2476.0  1955.097534
# 8  AMRAVATI 2021-03-01  2570.0  1994.784668
# === Metrics ===
# {'district': 'AURANGABAD', 'rmse': 1099.2689796476254, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.1528855, 'lag_2': 0.1197437, 'lag_3': 0.09246329, 'lag_4': 0.10828096, 'lag_5': 0.16331592, 'lag_6': 0.3633106}}
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AURANGABAD 2020-07-01    2897  3559.267578
# 1  AURANGABAD 2020-08-01    3107  3665.429932
# 2  AURANGABAD 2020-09-01    3639  3809.338379
# 3  AURANGABAD 2020-10-01    5000  3444.121582
# 4  AURANGABAD 2020-11-01    4498  3487.981445
# 5  AURANGABAD 2020-12-01    5448  3762.336914
# 6  AURANGABAD 2021-01-01    5221  3775.163574
# 7  AURANGABAD 2021-02-01    5126  4127.556641
# 8  AURANGABAD 2021-03-01    4791  3938.717285
# === Metrics ===
# {'district': 'BEED', 'rmse': 280.9165143319705, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.16993794, 'lag_2': 0.06382867, 'lag_3': 0.12181194, 'lag_4': 0.17044725, 'lag_5': 0.2107867, 'lag_6': 0.2631875}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-07-01    3407  3370.671143
# 1     BEED 2020-08-01    2907  3380.828613
# 2     BEED 2020-09-01    3136  3325.381836
# 3     BEED 2020-10-01    3117  3275.483887
# 4     BEED 2020-11-01    2842  3305.150635
# 5     BEED 2020-12-01    3110  3400.692383
# 6     BEED 2021-01-01    3208  3361.181152
# 7     BEED 2021-02-01    3318  3346.254395
# 8     BEED 2021-03-01    3225  3541.445068
# === Metrics ===
# {'district': 'BHANDARA', 'rmse': 144.27201097676254, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.20135422, 'lag_2': 0.111236565, 'lag_3': 0.22747843, 'lag_4': 0.19371699, 'lag_5': 0.18126424, 'lag_6': 0.084949486}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BHANDARA 2020-07-01    1165  1272.405396
# 1  BHANDARA 2020-08-01    1101  1169.019165
# 2  BHANDARA 2020-09-01    1151  1183.423218
# 3  BHANDARA 2020-10-01    1152  1234.506104
# 4  BHANDARA 2020-11-01    1031  1242.731323
# 5  BHANDARA 2020-12-01    1279  1195.194336
# 6  BHANDARA 2021-01-01    1355  1229.456299
# 7  BHANDARA 2021-02-01    1557  1345.322876
# 8  BHANDARA 2021-03-01    1591  1365.419189
# === Metrics ===
# {'district': 'BULDHANA', 'rmse': 399.57864441046644, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.25014898, 'lag_2': 0.11942879, 'lag_3': 0.15852466, 'lag_4': 0.1281012, 'lag_5': 0.16177301, 'lag_6': 0.18202335}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-07-01    1439  1645.169312
# 1  BULDHANA 2020-08-01    1345  1817.051514
# 2  BULDHANA 2020-09-01    1602  1969.622803
# 3  BULDHANA 2020-10-01    1459  1905.842041
# 4  BULDHANA 2020-11-01    1389  1961.831787
# 5  BULDHANA 2020-12-01    1711  2172.539062
# 6  BULDHANA 2021-01-01    1734  2057.529785
# 7  BULDHANA 2021-02-01    1818  2157.210449
# 8  BULDHANA 2021-03-01    2057  2332.545410
# === Metrics ===
# {'district': 'CHANDRAPUR', 'rmse': 695.3161397913749, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.30920562, 'lag_2': 0.08763404, 'lag_3': 0.120406486, 'lag_4': 0.1821539, 'lag_5': 0.1900816, 'lag_6': 0.11051834}}
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  CHANDRAPUR 2020-07-01    2279  2372.434570
# 1  CHANDRAPUR 2020-08-01    2103  2392.737305
# 2  CHANDRAPUR 2020-09-01    2030  2666.801025
# 3  CHANDRAPUR 2020-10-01    2073  2871.166504
# 4  CHANDRAPUR 2020-11-01    1897  3105.662109
# 5  CHANDRAPUR 2020-12-01    2498  3408.673096
# 6  CHANDRAPUR 2021-01-01    2799  3598.948242
# 7  CHANDRAPUR 2021-02-01    3217  3686.492188
# 8  CHANDRAPUR 2021-03-01    3581  3836.710938
# === Metrics ===
# {'district': 'DHULE', 'rmse': 1155.8237509847102, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.21176927, 'lag_2': 0.11774326, 'lag_3': 0.089102454, 'lag_4': 0.15708382, 'lag_5': 0.15880513, 'lag_6': 0.26549608}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    DHULE 2020-07-01    3317  3698.238281
# 1    DHULE 2020-08-01    2764  4127.871582
# 2    DHULE 2020-09-01    3344  4455.647461
# 3    DHULE 2020-10-01    3020  4261.632324
# 4    DHULE 2020-11-01    2908  4452.051270
# 5    DHULE 2020-12-01    3477  4718.392578
# 6    DHULE 2021-01-01    3554  4583.335449
# 7    DHULE 2021-02-01    3873  4653.611328
# 8    DHULE 2021-03-01    3478  4761.129883
# === Metrics ===
# {'district': 'GADCHIROLI', 'rmse': 553.4931010114542, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.13901389, 'lag_2': 0.20382473, 'lag_3': 0.13103515, 'lag_4': 0.19332835, 'lag_5': 0.10926741, 'lag_6': 0.22353046}}
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  GADCHIROLI 2020-07-01    1437  1713.499878
# 1  GADCHIROLI 2020-08-01    1218  1842.787964
# 2  GADCHIROLI 2020-09-01    1327  1861.580078
# 3  GADCHIROLI 2020-10-01    1197  1869.456665
# 4  GADCHIROLI 2020-11-01    1211  1900.483398
# 5  GADCHIROLI 2020-12-01    1363  1936.342896
# 6  GADCHIROLI 2021-01-01    1302  1990.059326
# 7  GADCHIROLI 2021-02-01    1566  2009.895020
# 8  GADCHIROLI 2021-03-01    1609  1887.976074
# === Metrics ===
# {'district': 'GONDIA', 'rmse': 87.97265692647268, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.38351884, 'lag_2': 0.14736384, 'lag_3': 0.0568707, 'lag_4': 0.20998956, 'lag_5': 0.05235575, 'lag_6': 0.1499013}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   GONDIA 2020-07-01  1454.0  1679.691650
# 1   GONDIA 2020-08-01  1331.0  1418.972412
# 2   GONDIA 2020-09-01  1309.0  1307.349976
# 3   GONDIA 2020-10-01  1341.0  1283.840454
# 4   GONDIA 2020-11-01  1444.0  1373.739990
# 5   GONDIA 2020-12-01  1405.0  1421.726807
# 6   GONDIA 2021-01-01  1340.0  1345.049194
# 7   GONDIA 2021-02-01  1508.0  1475.640869
# 8   GONDIA 2021-03-01  1746.0  1783.656738
# === Metrics ===
# {'district': 'HINGOLI', 'rmse': 468.2043369781407, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.14414077, 'lag_2': 0.14464429, 'lag_3': 0.17329578, 'lag_4': 0.20209703, 'lag_5': 0.16180211, 'lag_6': 0.17402002}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  HINGOLI 2020-07-01    1514  1722.530640
# 1  HINGOLI 2020-08-01    1569  1841.495361
# 2  HINGOLI 2020-09-01    1745  1918.285278
# 3  HINGOLI 2020-10-01    1749  2041.884766
# 4  HINGOLI 2020-11-01    1616  2200.207031
# 5  HINGOLI 2020-12-01    1687  2307.145508
# 6  HINGOLI 2021-01-01    1732  2363.969238
# 7  HINGOLI 2021-02-01    1870  2399.548096
# 8  HINGOLI 2021-03-01    1716  2293.672119
# === Metrics ===
# {'district': 'JALGAON', 'rmse': 1483.7651275006172, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.08746439, 'lag_2': 0.1408903, 'lag_3': 0.1196921, 'lag_4': 0.4052386, 'lag_5': 0.14639206, 'lag_6': 0.100322545}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  JALGAON 2020-07-01    4641  5769.978516
# 1  JALGAON 2020-08-01    4335  5968.870605
# 2  JALGAON 2020-09-01    4806  6197.059570
# 3  JALGAON 2020-10-01    4731  6361.221191
# 4  JALGAON 2020-11-01    4652  6553.067871
# 5  JALGAON 2020-12-01    5392  6714.453125
# 6  JALGAON 2021-01-01    5235  6590.295410
# 7  JALGAON 2021-02-01    5794  6664.700195
# 8  JALGAON 2021-03-01    5061  6882.908691
# === Metrics ===
# {'district': 'JALNA', 'rmse': 197.7544084136448, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.29705685, 'lag_2': 0.05800611, 'lag_3': 0.11383788, 'lag_4': 0.12712304, 'lag_5': 0.22752029, 'lag_6': 0.1764558}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    JALNA 2020-07-01  2128.0  1921.914673
# 1    JALNA 2020-08-01  1604.0  1885.397705
# 2    JALNA 2020-09-01  1731.0  1687.832275
# 3    JALNA 2020-10-01  1698.0  1870.815308
# 4    JALNA 2020-11-01  1869.0  1638.541138
# 5    JALNA 2020-12-01  2109.0  1926.728638
# 6    JALNA 2021-01-01  2118.0  1790.209473
# 7    JALNA 2021-02-01  1948.0  1891.755981
# 8    JALNA 2021-03-01  1905.0  1945.406494
# === Metrics ===
# {'district': 'KOLHAPUR', 'rmse': 535.9038744795755, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.15272121, 'lag_2': 0.1308379, 'lag_3': 0.16918449, 'lag_4': 0.17241141, 'lag_5': 0.2058175, 'lag_6': 0.16902749}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  KOLHAPUR 2020-07-01    3357  3707.064941
# 1  KOLHAPUR 2020-08-01    3163  4005.940430
# 2  KOLHAPUR 2020-09-01    3576  4146.218750
# 3  KOLHAPUR 2020-10-01    3711  4127.416504
# 4  KOLHAPUR 2020-11-01    3480  4126.102051
# 5  KOLHAPUR 2020-12-01    4336  4136.593750
# 6  KOLHAPUR 2021-01-01    4042  4121.414551
# 7  KOLHAPUR 2021-02-01    4038  4451.409180
# 8  KOLHAPUR 2021-03-01    3954  4740.553223
# === Metrics ===
# {'district': 'LATUR', 'rmse': 505.0141928939985, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.1651062, 'lag_2': 0.12041502, 'lag_3': 0.26507947, 'lag_4': 0.16019532, 'lag_5': 0.14551769, 'lag_6': 0.14368626}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    LATUR 2020-07-01    3500  3427.953369
# 1    LATUR 2020-08-01    3274  3768.158936
# 2    LATUR 2020-09-01    3634  3997.651855
# 3    LATUR 2020-10-01    3408  4038.190674
# 4    LATUR 2020-11-01    3363  4248.146484
# 5    LATUR 2020-12-01    3601  4115.750000
# 6    LATUR 2021-01-01    3699  4171.737305
# 7    LATUR 2021-02-01    3954  4295.193848
# 8    LATUR 2021-03-01    3892  4250.108398
# === Metrics ===
# {'district': 'MUMBAI', 'rmse': 2026.8560502898576, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.11282258, 'lag_2': 0.10787649, 'lag_3': 0.09793073, 'lag_4': 0.1360244, 'lag_5': 0.30634773, 'lag_6': 0.23899814}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   MUMBAI 2020-07-01    1525  1489.985596
# 1   MUMBAI 2020-08-01    1497   709.259766
# 2   MUMBAI 2020-09-01    1472    -1.041992
# 3   MUMBAI 2020-10-01    1756  -155.616943
# 4   MUMBAI 2020-11-01    2196    55.188965
# 5   MUMBAI 2020-12-01    2738    34.915405
# 6   MUMBAI 2021-01-01    2397   -57.889526
# 7   MUMBAI 2021-02-01    2276  -196.761230
# 8   MUMBAI 2021-03-01    2515   -33.852173
# === Metrics ===
# {'district': 'NAGPUR', 'rmse': 1851.5990787626854, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.23652849, 'lag_2': 0.16840822, 'lag_3': 0.15956908, 'lag_4': 0.13033023, 'lag_5': 0.18601482, 'lag_6': 0.11914914}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NAGPUR 2020-07-01    5816  5062.171875
# 1   NAGPUR 2020-08-01    4461  5217.955078
# 2   NAGPUR 2020-09-01    4485  5314.345703
# 3   NAGPUR 2020-10-01    4837  5606.049316
# 4   NAGPUR 2020-11-01    5721  5207.451172
# 5   NAGPUR 2020-12-01    6553  4823.335938
# 6   NAGPUR 2021-01-01    6620  4620.204102
# 7   NAGPUR 2021-02-01    6722  4175.388672
# 8   NAGPUR 2021-03-01    8096  4262.541992
# === Metrics ===
# {'district': 'NANDED', 'rmse': 350.5310835993463, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.5485583, 'lag_2': 0.08693557, 'lag_3': 0.057646208, 'lag_4': 0.040537674, 'lag_5': 0.08331213, 'lag_6': 0.18301004}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NANDED 2020-07-01  4668.0  5092.972656
# 1   NANDED 2020-08-01  4358.0  4781.775879
# 2   NANDED 2020-09-01  5176.0  4825.458008
# 3   NANDED 2020-10-01  4553.0  5085.836426
# 4   NANDED 2020-11-01  4475.0  4793.341309
# 5   NANDED 2020-12-01  4906.0  4818.670898
# 6   NANDED 2021-01-01  5001.0  5209.468262
# 7   NANDED 2021-02-01  5274.0  4997.071289
# 8   NANDED 2021-03-01  4873.0  4541.714355
# === Metrics ===
# {'district': 'NANDURBAR', 'rmse': 1617.3151358809248, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.23827128, 'lag_2': 0.16208133, 'lag_3': 0.20479344, 'lag_4': 0.14805259, 'lag_5': 0.08737911, 'lag_6': 0.15942223}}
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  NANDURBAR 2020-07-01    3193  3807.192139
# 1  NANDURBAR 2020-08-01    2585  3909.698242
# 2  NANDURBAR 2020-09-01    2762  4033.489014
# 3  NANDURBAR 2020-10-01    2322  4119.027344
# 4  NANDURBAR 2020-11-01    2311  4287.289062
# 5  NANDURBAR 2020-12-01    2661  4460.150391
# 6  NANDURBAR 2021-01-01    2528  4352.890625
# 7  NANDURBAR 2021-02-01    2723  4549.083984
# 8  NANDURBAR 2021-03-01    2883  4543.077148
# === Metrics ===
# {'district': 'NASHIK', 'rmse': 915.8121267697172, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.10271532, 'lag_2': 0.11440323, 'lag_3': 0.16602491, 'lag_4': 0.2373473, 'lag_5': 0.2715699, 'lag_6': 0.107939325}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NASHIK 2020-07-01    6411  6849.901367
# 1   NASHIK 2020-08-01    6147  6381.052734
# 2   NASHIK 2020-09-01    6180  6108.119629
# 3   NASHIK 2020-10-01    6938  6283.720703
# 4   NASHIK 2020-11-01    7314  6826.659668
# 5   NASHIK 2020-12-01    7560  7019.598633
# 6   NASHIK 2021-01-01    7807  6968.296387
# 7   NASHIK 2021-02-01    8582  6500.539551
# 8   NASHIK 2021-03-01    7998  6856.812988
# === Metrics ===
# {'district': 'OSMANABAD', 'rmse': 450.5726892547172, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.22066054, 'lag_2': 0.21022777, 'lag_3': 0.12774478, 'lag_4': 0.15329005, 'lag_5': 0.1324251, 'lag_6': 0.1556517}}
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  OSMANABAD 2020-07-01    1856  2055.996582
# 1  OSMANABAD 2020-08-01    1675  2191.824707
# 2  OSMANABAD 2020-09-01    1793  2356.681641
# 3  OSMANABAD 2020-10-01    1701  2444.974609
# 4  OSMANABAD 2020-11-01    1857  2518.105957
# 5  OSMANABAD 2020-12-01    2177  2557.218262
# 6  OSMANABAD 2021-01-01    2344  2234.798096
# 7  OSMANABAD 2021-02-01    2300  2236.350586
# 8  OSMANABAD 2021-03-01    2538  2311.732910
# === Metrics ===
# {'district': 'PALGHAR', 'rmse': 412.72909919042036, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.12751177, 'lag_2': 0.21142063, 'lag_3': 0.1850985, 'lag_4': 0.21896009, 'lag_5': 0.087418064, 'lag_6': 0.16959095}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  PALGHAR 2020-07-01    3371  3599.510498
# 1  PALGHAR 2020-08-01    3171  3665.672852
# 2  PALGHAR 2020-09-01    3269  3910.549316
# 3  PALGHAR 2020-10-01    3271  3720.352783
# 4  PALGHAR 2020-11-01    3189  3725.880371
# 5  PALGHAR 2020-12-01    3657  3615.241699
# 6  PALGHAR 2021-01-01    3513  3524.349609
# 7  PALGHAR 2021-02-01    3791  3629.892822
# 8  PALGHAR 2021-03-01    4256  3702.269531
# === Metrics ===
# {'district': 'PARBHANI', 'rmse': 495.0489187125438, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.10209393, 'lag_2': 0.08806361, 'lag_3': 0.25613528, 'lag_4': 0.19822203, 'lag_5': 0.11914108, 'lag_6': 0.23634401}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  PARBHANI 2020-07-01    1441  1515.808838
# 1  PARBHANI 2020-08-01    1144  1443.600830
# 2  PARBHANI 2020-09-01    1478  1604.238892
# 3  PARBHANI 2020-10-01    1580  1653.658081
# 4  PARBHANI 2020-11-01    1311  1942.629150
# 5  PARBHANI 2020-12-01    1730  2030.024414
# 6  PARBHANI 2021-01-01    1473  2084.817139
# 7  PARBHANI 2021-02-01    1569  2389.714111
# 8  PARBHANI 2021-03-01    1622  2365.020996
# === Metrics ===
# {'district': 'PUNE', 'rmse': 864.1758080782213, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.19550598, 'lag_2': 0.07347399, 'lag_3': 0.093454815, 'lag_4': 0.088839486, 'lag_5': 0.22608732, 'lag_6': 0.32263845}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     PUNE 2020-07-01  5520.0  6723.308594
# 1     PUNE 2020-08-01  5630.0  6475.182617
# 2     PUNE 2020-09-01  5491.0  6460.140625
# 3     PUNE 2020-10-01  6135.0  6574.820312
# 4     PUNE 2020-11-01  6162.0  6558.206055
# 5     PUNE 2020-12-01  7696.0  6598.940430
# 6     PUNE 2021-01-01  7485.0  6840.118164
# 7     PUNE 2021-02-01  7795.0  6681.817383
# 8     PUNE 2021-03-01  7315.0  7955.835938
# === Metrics ===
# {'district': 'RAIGAD', 'rmse': 919.9150278398346, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.18172558, 'lag_2': 0.18716207, 'lag_3': 0.27981183, 'lag_4': 0.13541736, 'lag_5': 0.11486362, 'lag_6': 0.10101953}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   RAIGAD 2020-07-01    1563  1566.583496
# 1   RAIGAD 2020-08-01    1516  1523.550415
# 2   RAIGAD 2020-09-01    1568  1609.743530
# 3   RAIGAD 2020-10-01    1569  1714.692993
# 4   RAIGAD 2020-11-01    2801  2043.678467
# 5   RAIGAD 2020-12-01    3265  2298.642334
# 6   RAIGAD 2021-01-01    3701  1975.365845
# 7   RAIGAD 2021-02-01    3207  1986.362793
# 8   RAIGAD 2021-03-01    3532  2259.992676
# === Metrics ===
# {'district': 'RATNAGIRI', 'rmse': 266.61396157897343, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.30710968, 'lag_2': 0.07603402, 'lag_3': 0.17038584, 'lag_4': 0.16096662, 'lag_5': 0.14916487, 'lag_6': 0.13633896}}
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  RATNAGIRI 2020-07-01     772  851.459534
# 1  RATNAGIRI 2020-08-01     803  931.214417
# 2  RATNAGIRI 2020-09-01     545  899.164978
# 3  RATNAGIRI 2020-10-01     679  975.060425
# 4  RATNAGIRI 2020-11-01     551  890.916687
# 5  RATNAGIRI 2020-12-01     665  968.153076
# 6  RATNAGIRI 2021-01-01     683  876.071472
# 7  RATNAGIRI 2021-02-01     675  985.720764
# 8  RATNAGIRI 2021-03-01     749  999.280945
# === Metrics ===
# {'district': 'SANGLI', 'rmse': 303.78381937480066, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.23491421, 'lag_2': 0.098315515, 'lag_3': 0.26429063, 'lag_4': 0.21361215, 'lag_5': 0.09894148, 'lag_6': 0.08992612}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SANGLI 2020-07-01    1914  1713.271973
# 1   SANGLI 2020-08-01    1544  1577.088135
# 2   SANGLI 2020-09-01    1534  1717.977905
# 3   SANGLI 2020-10-01    1492  1812.133545
# 4   SANGLI 2020-11-01    1581  1818.738159
# 5   SANGLI 2020-12-01    1633  1936.831299
# 6   SANGLI 2021-01-01    1529  2160.526367
# 7   SANGLI 2021-02-01    1803  2069.034424
# 8   SANGLI 2021-03-01    1580  1765.496094
# === Metrics ===
# {'district': 'SATARA', 'rmse': 1879.8989959572086, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.35026762, 'lag_2': 0.113182016, 'lag_3': 0.05909582, 'lag_4': 0.11254057, 'lag_5': 0.16713752, 'lag_6': 0.19777636}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SATARA 2020-07-01    2118  2141.202148
# 1   SATARA 2020-08-01    1561  2213.031250
# 2   SATARA 2020-09-01    1380  2412.803223
# 3   SATARA 2020-10-01    1570  2269.494629
# 4   SATARA 2020-11-01    1571  2233.660400
# 5   SATARA 2020-12-01    2220  2243.554932
# 6   SATARA 2021-01-01    2617  2845.218750
# 7   SATARA 2021-02-01    2495  3236.213379
# 8   SATARA 2021-03-01    8575  3209.986572
# === Metrics ===
# {'district': 'SINDHUDURG', 'rmse': 61.97337311610496, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.20316514, 'lag_2': 0.16369843, 'lag_3': 0.1990593, 'lag_4': 0.10142381, 'lag_5': 0.23059355, 'lag_6': 0.10205978}}
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01     500  439.960022
# 1  SINDHUDURG 2020-08-01     376  403.696320
# 2  SINDHUDURG 2020-09-01     367  387.062927
# 3  SINDHUDURG 2020-10-01     361  361.536682
# 4  SINDHUDURG 2020-11-01     322  390.043549
# 5  SINDHUDURG 2020-12-01     359  410.699554
# 6  SINDHUDURG 2021-01-01     462  425.883057
# 7  SINDHUDURG 2021-02-01     407  387.077362
# 8  SINDHUDURG 2021-03-01     521  376.821350
# === Metrics ===
# {'district': 'SOLAPUR', 'rmse': 700.4251999320481, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.10066308, 'lag_2': 0.11565626, 'lag_3': 0.10570913, 'lag_4': 0.35894883, 'lag_5': 0.20617902, 'lag_6': 0.112843566}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  SOLAPUR 2020-07-01    3821  4632.506836
# 1  SOLAPUR 2020-08-01    3842  4485.537598
# 2  SOLAPUR 2020-09-01    4147  4769.373047
# 3  SOLAPUR 2020-10-01    3847  4762.716797
# 4  SOLAPUR 2020-11-01    3885  4931.246094
# 5  SOLAPUR 2020-12-01    5349  5125.970703
# 6  SOLAPUR 2021-01-01    4991  5293.205078
# 7  SOLAPUR 2021-02-01    5147  5138.848633
# 8  SOLAPUR 2021-03-01    4737  5675.627930
# === Metrics ===
# {'district': 'THANE', 'rmse': 1675.4906463982377, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.17533912, 'lag_2': 0.12972887, 'lag_3': 0.24321952, 'lag_4': 0.12785138, 'lag_5': 0.14501368, 'lag_6': 0.1788474}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    THANE 2020-07-01    9367  9398.275391
# 1    THANE 2020-08-01    9815  9016.130859
# 2    THANE 2020-09-01    9676  9356.638672
# 3    THANE 2020-10-01    9483  9902.225586
# 4    THANE 2020-11-01   10375  9636.794922
# 5    THANE 2020-12-01   11389  9380.832031
# 6    THANE 2021-01-01   11881  9540.315430
# 7    THANE 2021-02-01   10382  9087.371094
# 8    THANE 2021-03-01   12162  8610.105469
# === Metrics ===
# {'district': 'WARDHA', 'rmse': 155.00471853661728, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.17978026, 'lag_2': 0.096068144, 'lag_3': 0.12614284, 'lag_4': 0.20922229, 'lag_5': 0.10828646, 'lag_6': 0.2805}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WARDHA 2020-07-01  1258.0  1359.007935
# 1   WARDHA 2020-08-01  1219.0  1305.037720
# 2   WARDHA 2020-09-01  1186.0  1281.372925
# 3   WARDHA 2020-10-01  1151.0  1333.499512
# 4   WARDHA 2020-11-01  1033.0  1389.414307
# 5   WARDHA 2020-12-01  1337.0  1445.973145
# 6   WARDHA 2021-01-01  1369.0  1314.267822
# 7   WARDHA 2021-02-01  1492.0  1421.446411
# 8   WARDHA 2021-03-01  1483.0  1386.297974
# === Metrics ===
# {'district': 'WASHIM', 'rmse': 188.4518077668287, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.12920173, 'lag_2': 0.23065886, 'lag_3': 0.11220644, 'lag_4': 0.19406375, 'lag_5': 0.1964581, 'lag_6': 0.13741104}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WASHIM 2020-07-01    1320  1219.505005
# 1   WASHIM 2020-08-01    1354  1234.491821
# 2   WASHIM 2020-09-01    1281  1544.093628
# 3   WASHIM 2020-10-01    1304  1571.170776
# 4   WASHIM 2020-11-01    1237  1548.336792
# 5   WASHIM 2020-12-01    1499  1564.656494
# 6   WASHIM 2021-01-01    1392  1593.237183
# 7   WASHIM 2021-02-01    1584  1507.432373
# 8   WASHIM 2021-03-01    1701  1617.056885
# === Metrics ===
# {'district': 'YAVATMAL', 'rmse': 354.100852209474, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.21281989, 'lag_2': 0.07843906, 'lag_3': 0.21219738, 'lag_4': 0.27847245, 'lag_5': 0.12700751, 'lag_6': 0.09106366}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  YAVATMAL 2020-07-01  3187.0  2999.680908
# 1  YAVATMAL 2020-08-01  2613.0  3052.872559
# 2  YAVATMAL 2020-09-01  2629.0  2917.057861
# 3  YAVATMAL 2020-10-01  2797.0  2794.725342
# 4  YAVATMAL 2020-11-01  2682.0  3107.045654
# 5  YAVATMAL 2020-12-01  3140.0  2519.797119
# 6  YAVATMAL 2021-01-01  3105.0  2916.510254
# 7  YAVATMAL 2021-02-01  3242.0  3247.204346
# 8  YAVATMAL 2021-03-01  3717.0  3252.180664
# ⚠️ Skipping MUMBAI SUBURBAN: Only 5 samples after lag features
# === Metrics ===
# None
#
# === Forecast Data ===
# None

# %%
# !pip install "dask<2025.1"
