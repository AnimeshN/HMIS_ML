# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def sarima_forecast_district(series, district_name, seasonal=True, 
                            max_p=3, max_q=3, max_P=2, max_Q=2, m=12):
    """
    Complete SARIMA forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('SARIMA', exist_ok=True)
    
    # 1. Stationarity Check
    adf_result = adfuller(series.dropna())
    is_stationary = adf_result[1] < 0.05

    # 2. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 3. Auto-SARIMA Modeling
    model = auto_arima(
        train,
        start_p=0, start_q=0,
        max_p=max_p, max_q=max_q,
        d=None,
        start_P=0, start_Q=0,
        max_P=max_P, max_Q=max_Q,
        m=m,
        seasonal=seasonal,
        trace=False,
        error_action='ignore',
        suppress_warnings=True,
        stepwise=True
    )
    best_order = model.order
    best_seasonal_order = model.seasonal_order

    # 4. Model Fitting with SARIMAX
    sarima_model = SARIMAX(train, 
                          order=best_order,
                          seasonal_order=best_seasonal_order)
    model_fit = sarima_model.fit(disp=False)
    
    # 5. Forecasting with Confidence Intervals
    forecast_result = model_fit.get_forecast(steps=len(test))
    forecast = forecast_result.predicted_mean
    conf_int = forecast_result.conf_int()

    # 6. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast.values,
        'lower_ci': conf_int.iloc[:, 0],
        'upper_ci': conf_int.iloc[:, 1]
    })

    # 7. Save forecasts to CSV (append mode)
    forecast_csv_path = os.path.join('SARIMA', 'sarima_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 8. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'best_order': str(best_order),
        'best_seasonal_order': str(best_seasonal_order),
        'stationary': is_stationary
    }])

    metrics_csv_path = os.path.join('SARIMA', 'sarima_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 9. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(forecast, label='Forecast', color='darkorange')
    plt.fill_between(forecast.index, 
                    conf_int.iloc[:, 0],
                    conf_int.iloc[:, 1],
                    color='orange', alpha=0.1)
    plt.title(f'SARIMA{best_order}x{best_seasonal_order} Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('SARIMA', f'SARIMA_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        # ts = district_data["I8"].asfreq('MS')
        ts = district_data["I48"].astype(float).asfreq('MS')

        
        results = sarima_forecast_district(ts, district)
    
        # Show results
        # print("=== Metrics ===")
        # print(results['metrics_df'])
        # print("\n=== Forecast Data ===")
        # print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 22
#      15         # Show results
#      16         # print("=== Metrics ===")
#      17         # print(results['metrics_df'])
#      18         # print("\n=== Forecast Data ===")
#      19         # print(results['forecast_df'].head())
#      21     return results
# ---> 22 run_for_each_district()
#
# Cell In[4], line 13, in run_for_each_district()
#       9     # ts = district_data["I8"].asfreq('MS')
#      10     ts = district_data["I48"].astype(float).asfreq('MS')
# ---> 13     results = sarima_forecast_district(ts, district)
#      15     # Show results
#      16     # print("=== Metrics ===")
#      17     # print(results['metrics_df'])
#      18     # print("\n=== Forecast Data ===")
#      19     # print(results['forecast_df'].head())
#      21 return results
#
# Cell In[3], line 18, in sarima_forecast_district(series, district_name, seasonal, max_p, max_q, max_P, max_Q, m)
#      15 train, test = series.iloc[:train_size], series.iloc[train_size:]
#      17 # 3. Auto-SARIMA Modeling
# ---> 18 model = auto_arima(
#      19     train,
#      20     start_p=0, start_q=0,
#      21     max_p=max_p, max_q=max_q,
#      22     d=None,
#      23     start_P=0, start_Q=0,
#      24     max_P=max_P, max_Q=max_Q,
#      25     m=m,
#      26     seasonal=seasonal,
#      27     trace=False,
#      28     error_action='ignore',
#      29     suppress_warnings=True,
#      30     stepwise=True
#      31 )
#      32 best_order = model.order
#      33 best_seasonal_order = model.seasonal_order
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\auto.py:506, in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     504 # m must be > 1 for nsdiffs
#     505 elif D is None:  # we don't have a D yet and we need one (seasonal)
# --> 506     D = nsdiffs(xx, m=m, test=seasonal_test, max_D=max_D,
#     507                 **seasonal_test_args)
#     509     if D > 0 and X is not None:
#     510         diffxreg = diff(X, differences=D, lag=m)
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\utils.py:106, in nsdiffs(x, m, max_D, test, **kwargs)
#     103     return 0
#     105 D = 0
# --> 106 dodiff = testfunc(x)
#     107 while dodiff == 1 and D < max_D:
#     108     D += 1
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\seasonality.py:597, in OCSBTest.estimate_seasonal_differencing_term(self, x)
#     594 x = check_endog(x, dtype=DTYPE, preserve_series=False)
#     596 # Get the critical value for m
# --> 597 stat = self._compute_test_statistic(x)
#     598 crit_val = self._calc_ocsb_crit_val(self.m)
#     599 return int(stat > crit_val)
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\seasonality.py:537, in OCSBTest._compute_test_statistic(self, x)
#     535 for lag_term in range(1, maxlag + 1):  # 1 -> maxlag (incl)
#     536     try:
# --> 537         fit = self._fit_ocsb(x, m, lag_term, maxlag)
#     538         fits.append(fit)
#     539         icvals.append(icfunc(fit))
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\seasonality.py:476, in OCSBTest._fit_ocsb(x, m, lag, max_lag)
#     474 # if there are no more samples, we have to bail
#     475 if y_first_order_diff.shape[0] == 0:
# --> 476     raise ValueError(
#     477         "There are no more samples after a first-order "
#     478         "seasonal differencing. See http://alkaline-ml.com/pmdarima/"
#     479         "seasonal-differencing-issues.html for a more in-depth "
#     480         "explanation and potential work-arounds."
#     481     )
#     483 y = diff(y_first_order_diff)
#     484 ylag = OCSBTest._gen_lags(y, lag)
#
# ValueError: There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.
