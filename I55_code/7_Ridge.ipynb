# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def ridge_regression_lags_only(
    series,
    district_name,
    max_lags=3,
    differencing=True,
    alpha=1.0,
    use_cv=False,
    alphas=np.logspace(-3, 2, 20),  # Only used if use_cv=True
    cv=5,  # Only used if use_cv=True
    random_state=42
):
    """
    Ridge regression (L2 regularization) for time series forecasting with lag features only.
    Supports optional cross-validation for alpha selection.
    """
    # Create directory structure
    os.makedirs('RidgeRegression', exist_ok=True)
    
    # 1. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 2. Feature Engineering - Lag features only
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 3. Train-Test Split (time-based)
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 4. Model Training with Ridge or RidgeCV
    if use_cv:
        model = RidgeCV(alphas=alphas, cv=TimeSeriesSplit(n_splits=5), scoring='neg_mean_squared_error')
        model.fit(X_train, y_train)
        best_alpha = model.alpha_
    else:
        model = Ridge(alpha=alpha, random_state=random_state, max_iter=10000)
        model.fit(X_train, y_train)
        best_alpha = alpha

    # 5. Forecasting
    pred_test = model.predict(X_test)

    # 6. Inverse Differencing if applied
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = np.cumsum(pred_test) + last_train_value
        y_test = original_series.iloc[-len(test):]
    
    # 7. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test
    })

    # 8. Save forecasts to CSV
    forecast_csv_path = os.path.join('RidgeRegression', 'ridge_forecasts_lags_only.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, mode='a', header=write_header, index=False)

    # 9. Calculate metrics
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    r_squared = model.score(X_train, y_train)
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'r_squared': r_squared,
        'coefficients': model.coef_.tolist(),
        'intercept': model.intercept_,
        'best_alpha': best_alpha,
        'alphas_tried': alphas.tolist() if use_cv else [alpha],
        'differencing': d
    }])

    metrics_csv_path = os.path.join('RidgeRegression', 'ridge_metrics_lags_only.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, mode='a', header=write_header_metrics, index=False)

    # 10. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', color='darkorange')
    plt.title(
        f'Ridge Regression (Lags Only) for {district_name}\n'
        f'Alpha: {best_alpha:.4f} | RMSE: {rmse:.2f}, R²: {r_squared:.2f}'
    )
    plt.legend()
    plt.savefig(os.path.join('RidgeRegression', f'Ridge_forecast_lags_only_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_coefficients': model.coef_,
        'model_intercept': model.intercept_,
        'best_alpha': best_alpha,
        'alphas_tried': alphas if use_cv else [alpha]
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I55"].asfreq('MS')
        
        results = ridge_regression_lags_only(
            ts, 
            district, 
            max_lags=5, 
            use_cv=True, 
            alphas=np.logspace(-3, 2, 30), 
            cv=5
        )
        
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district       rmse  r_squared  \
# 0  AHMEDNAGAR  1049.6185   0.020921
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.046073230441835304, 0.029325841504081417, 0...  5304.699481       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AHMEDNAGAR 2020-07-01  6225.0  5766.834965
# 1  AHMEDNAGAR 2020-08-01  6609.0  5770.148283
# 2  AHMEDNAGAR 2020-09-01  7268.0  5687.955398
# 3  AHMEDNAGAR 2020-10-01  6799.0  5783.540310
# 4  AHMEDNAGAR 2020-11-01  5248.0  5814.359018
# === Metrics ===
#   district        rmse  r_squared  \
# 0    AKOLA  749.761986   0.288586
#
#                                         coefficients   intercept  best_alpha  \
# 0  [-0.5202094319775893, -0.5807175406324178, -0....  140.598653       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    AKOLA 2020-07-01    1999  2499.824160
# 1    AKOLA 2020-08-01    1927  2937.917252
# 2    AKOLA 2020-09-01    2604  3067.943182
# 3    AKOLA 2020-10-01    2342  2858.898759
# 4    AKOLA 2020-11-01    2550  2744.306642
# === Metrics ===
#    district       rmse  r_squared  \
# 0  AMRAVATI  847.30569   0.254881
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.3273209239766127, -0.08033804717947449, -0...  21.480915       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  AMRAVATI 2020-07-01    2772  2994.274458
# 1  AMRAVATI 2020-08-01    3081  2879.851502
# 2  AMRAVATI 2020-09-01    3483  2602.925179
# 3  AMRAVATI 2020-10-01    3505  2186.630897
# 4  AMRAVATI 2020-11-01    3484  2180.332960
# === Metrics ===
#      district         rmse  r_squared  \
# 0  AURANGABAD  1000.069429    0.23286
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.5422234843600503, -0.2704488414855676, -0.... -66.204902       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AURANGABAD 2020-07-01    5621  5630.938062
# 1  AURANGABAD 2020-08-01    5821  5603.515266
# 2  AURANGABAD 2020-09-01    6050  5404.806953
# 3  AURANGABAD 2020-10-01    6041  5124.925098
# 4  AURANGABAD 2020-11-01    6010  4983.549742
# === Metrics ===
#   district        rmse  r_squared  \
# 0     BEED  385.440053   0.272726
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.3306862828794501, 0.07726156668777934, 0.28...  1191.073702       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-07-01  2942.0  2326.432133
# 1     BEED 2020-08-01  2934.0  2437.063826
# 2     BEED 2020-09-01  2943.0  2465.464421
# 3     BEED 2020-10-01  3112.0  2629.779995
# 4     BEED 2020-11-01  2812.0  2631.321469
# === Metrics ===
#    district        rmse  r_squared  \
# 0  BHANDARA  220.377626   0.099112
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.06470483019597799, -0.13213612991412474, 0...  15.404388       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BHANDARA 2020-07-01    1119  1110.851476
# 1  BHANDARA 2020-08-01    1256  1108.834652
# 2  BHANDARA 2020-09-01    1297  1142.238356
# 3  BHANDARA 2020-10-01    1524  1103.370995
# 4  BHANDARA 2020-11-01    1320  1109.996757
# === Metrics ===
#    district        rmse  r_squared  \
# 0  BULDHANA  792.063596   0.316622
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.3915128429748542, -0.3637878043033628, -0....   3.875783       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-07-01    1172  1130.027757
# 1  BULDHANA 2020-08-01    1332  1087.250347
# 2  BULDHANA 2020-09-01    1442   812.773987
# 3  BULDHANA 2020-10-01    1664   767.160032
# 4  BULDHANA 2020-11-01    1582   618.426863
# === Metrics ===
#      district        rmse  r_squared  \
# 0  CHANDRAPUR  323.082196   0.469308
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.6201276102297787, 0.06803636570420656, -0.3...  1149.540073       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  CHANDRAPUR 2020-07-01  1983.0  1819.363435
# 1  CHANDRAPUR 2020-08-01  2295.0  1906.232639
# 2  CHANDRAPUR 2020-09-01  2647.0  2039.525041
# 3  CHANDRAPUR 2020-10-01  2760.0  2227.157353
# 4  CHANDRAPUR 2020-11-01  2186.0  2211.999258
# === Metrics ===
#   district        rmse  r_squared  \
# 0    DHULE  334.713394   0.161057
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.1673367411655473, 0.005929033283572035, -0....  1977.289073       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    DHULE 2020-07-01  1662.0  1741.737438
# 1    DHULE 2020-08-01  2372.0  1703.192936
# 2    DHULE 2020-09-01  2023.0  1721.918273
# 3    DHULE 2020-10-01  2028.0  1677.739570
# 4    DHULE 2020-11-01  1809.0  1514.082093
# === Metrics ===
#      district        rmse  r_squared  \
# 0  GADCHIROLI  158.515689   0.496056
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.7201534480368148, -0.35709162745816714, 0.0...  1186.210552       0.001
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  GADCHIROLI 2020-07-01  1238.0  1274.452361
# 1  GADCHIROLI 2020-08-01  1510.0  1386.145667
# 2  GADCHIROLI 2020-09-01  1648.0  1582.535400
# 3  GADCHIROLI 2020-10-01  1751.0  1583.988744
# 4  GADCHIROLI 2020-11-01  1807.0  1624.412793
# === Metrics ===
#   district        rmse  r_squared  \
# 0   GONDIA  229.257632   0.292473
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.4508401805226138, -0.21961446643944707, -0....  817.267312       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   GONDIA 2020-07-01   973.0  746.517753
# 1   GONDIA 2020-08-01   997.0  847.678527
# 2   GONDIA 2020-09-01   986.0  805.994665
# 3   GONDIA 2020-10-01  1065.0  759.754437
# 4   GONDIA 2020-11-01   934.0  819.042713
# === Metrics ===
#   district        rmse  r_squared  \
# 0  HINGOLI  131.957234   0.566758
#
#                                         coefficients  intercept  best_alpha  \
# 0  [0.8778291015069178, -0.3642329235887081, 0.33...  299.32845       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  HINGOLI 2020-07-01  1043.0   903.450739
# 1  HINGOLI 2020-08-01  1101.0  1061.920708
# 2  HINGOLI 2020-09-01  1343.0  1029.312289
# 3  HINGOLI 2020-10-01  1229.0  1275.253938
# 4  HINGOLI 2020-11-01  1073.0  1102.952279
# === Metrics ===
#   district         rmse  r_squared  \
# 0  JALGAON  4329.103916   0.138517
#
#                                         coefficients   intercept  best_alpha  \
# 0  [-0.34984737950990624, -0.18846539590719583, -...  137.792895       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  JALGAON 2020-07-01    3714  4318.616277
# 1  JALGAON 2020-08-01   15827  4773.598354
# 2  JALGAON 2020-09-01    5302   782.167832
# 3  JALGAON 2020-10-01    4900  2423.735270
# 4  JALGAON 2020-11-01    4163  2151.703459
# === Metrics ===
#   district        rmse  r_squared  \
# 0    JALNA  653.382945   0.068018
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.17443647745045912, -0.16125280941494574, 0...  27.408272       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    JALNA 2020-07-01    1894  1781.216811
# 1    JALNA 2020-08-01    1719  1808.257221
# 2    JALNA 2020-09-01    1730  1781.379198
# 3    JALNA 2020-10-01    2115  1805.216427
# 4    JALNA 2020-11-01    1968  1755.830061
# === Metrics ===
#    district         rmse  r_squared  \
# 0  KOLHAPUR  3871.246296   0.235918
#
#                                         coefficients   intercept  best_alpha  \
# 0  [-0.03793013875116793, -0.1606488009047111, -1...  298.264268       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  KOLHAPUR 2020-07-01    6281  2391.419392
# 1  KOLHAPUR 2020-08-01    6879  4320.004700
# 2  KOLHAPUR 2020-09-01    7432   713.103798
# 3  KOLHAPUR 2020-10-01    6246  1626.632667
# 4  KOLHAPUR 2020-11-01    5778  1284.413816
# === Metrics ===
#   district        rmse  r_squared  \
# 0    LATUR  476.595489   0.210756
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.14905615939303243, 0.1768721619599568, -0....  65.827422       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    LATUR 2020-07-01    2947  3351.600342
# 1    LATUR 2020-08-01    3092  3313.276888
# 2    LATUR 2020-09-01    3775  3134.340655
# 3    LATUR 2020-10-01    3978  3078.021636
# 4    LATUR 2020-11-01    3652  3178.987415
# === Metrics ===
#   district        rmse  r_squared  \
# 0   MUMBAI  833.055935     0.0894
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.10920146892403515, 0.08933532475243636, -0.... -113.354798       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   MUMBAI 2020-07-01    2667  4474.360272
# 1   MUMBAI 2020-08-01    2879  2861.948424
# 2   MUMBAI 2020-09-01    3817  4153.184540
# 3   MUMBAI 2020-10-01    3638  3893.878603
# 4   MUMBAI 2020-11-01    4551  3814.975951
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NAGPUR  887.83184   0.244624
#
#                                         coefficients   intercept  best_alpha  \
# 0  [-0.5262175259507875, -0.32508191082901583, -0... -125.377225       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NAGPUR 2020-07-01    2306  2306.917402
# 1   NAGPUR 2020-08-01    2264  2173.168152
# 2   NAGPUR 2020-09-01    2244  2079.397713
# 3   NAGPUR 2020-10-01    2712  2018.973566
# 4   NAGPUR 2020-11-01    2889  1707.351990
# === Metrics ===
#   district        rmse  r_squared  \
# 0   NANDED  974.938676    0.64841
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.8306044821836907, 0.021124954012894343, -0....  569.609076       0.001
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NANDED 2020-07-01  3902.0  2251.257294
# 1   NANDED 2020-08-01  4032.0  4054.632187
# 2   NANDED 2020-09-01  4237.0  3942.505884
# 3   NANDED 2020-10-01  4756.0  3674.437893
# 4   NANDED 2020-11-01  4347.0  4814.823090
# === Metrics ===
#     district        rmse  r_squared  \
# 0  NANDURBAR  333.502357   0.179867
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.09578781493736332, 0.09306401534286116, 0....  20.387445       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  NANDURBAR 2020-07-01    2523  2184.401414
# 1  NANDURBAR 2020-08-01    2577  2324.121026
# 2  NANDURBAR 2020-09-01    2654  2444.613412
# 3  NANDURBAR 2020-10-01    2593  2434.301684
# 4  NANDURBAR 2020-11-01    2566  2313.800037
# === Metrics ===
#   district         rmse  r_squared  \
# 0   NASHIK  1157.433255   0.290981
#
#                                         coefficients   intercept  best_alpha  \
# 0  [-0.2795609313494832, -0.2654810416532845, 0.0...  251.436019       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NASHIK 2020-07-01    7484  6893.353516
# 1   NASHIK 2020-08-01    7551  6769.488929
# 2   NASHIK 2020-09-01    8376  6010.635686
# 3   NASHIK 2020-10-01    7227  5957.645106
# 4   NASHIK 2020-11-01    6907  6142.434970
# === Metrics ===
#     district        rmse  r_squared  \
# 0  OSMANABAD  254.898332   0.152102
#
#                                         coefficients  intercept  best_alpha  \
# 0  [0.12141051814463083, -0.19901872835936502, -0...  20.539713       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  OSMANABAD 2020-07-01    1794  1597.234918
# 1  OSMANABAD 2020-08-01    1952  1775.804571
# 2  OSMANABAD 2020-09-01    2171  1833.803264
# 3  OSMANABAD 2020-10-01    2081  1763.977290
# 4  OSMANABAD 2020-11-01    1981  1637.168604
# === Metrics ===
#   district        rmse  r_squared  \
# 0  PALGHAR  593.897917    0.04333
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.12812080195561976, -0.02460440686444111, -... -15.948193       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  PALGHAR 2020-07-01    4269  4363.977327
# 1  PALGHAR 2020-08-01    4229  4373.428682
# 2  PALGHAR 2020-09-01    4522  4343.858681
# 3  PALGHAR 2020-10-01    5385  4252.046709
# 4  PALGHAR 2020-11-01    5076  4098.136891
# === Metrics ===
#    district        rmse  r_squared  \
# 0  PARBHANI  558.425481   0.364245
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.5838404679905513, -0.040197412271182835, -0...  839.829559       0.001
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  PARBHANI 2020-07-01  1573.0  1288.881362
# 1  PARBHANI 2020-08-01  1630.0  1353.944581
# 2  PARBHANI 2020-09-01  1966.0  1472.817789
# 3  PARBHANI 2020-10-01  1984.0  1539.506084
# 4  PARBHANI 2020-11-01   868.0  1600.316506
# === Metrics ===
#   district         rmse  r_squared  \
# 0     PUNE  1125.996839   0.580797
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.818689528507487, -0.10344368049551432, -0.1...  2486.335331       0.001
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0     PUNE 2020-07-01  11790.0  12064.092253
# 1     PUNE 2020-08-01  12579.0  11640.319567
# 2     PUNE 2020-09-01  14094.0  12106.041384
# 3     PUNE 2020-10-01  14381.0  13756.204372
# 4     PUNE 2020-11-01  14329.0  13274.415188
# === Metrics ===
#   district         rmse  r_squared  \
# 0   RAIGAD  2025.064818   0.098732
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.30854673815668354, -0.2011900342083188, -0...  10.741987       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   RAIGAD 2020-07-01    3532  2123.886691
# 1   RAIGAD 2020-08-01    3912  1783.687559
# 2   RAIGAD 2020-09-01    3990  1346.862545
# 3   RAIGAD 2020-10-01    3615  1232.787830
# 4   RAIGAD 2020-11-01    3367  1347.745965
# === Metrics ===
#     district        rmse  r_squared  \
# 0  RATNAGIRI  434.763031    0.38311
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.4323615113734755, -0.030875632481303993, 0....  342.293328       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  RATNAGIRI 2020-07-01  1387.0  1266.837623
# 1  RATNAGIRI 2020-08-01  2246.0  1273.236064
# 2  RATNAGIRI 2020-09-01  1755.0  1649.645529
# 3  RATNAGIRI 2020-10-01  1658.0  1470.521795
# 4  RATNAGIRI 2020-11-01  1155.0  1644.110932
# === Metrics ===
#   district        rmse  r_squared  \
# 0   SANGLI  868.175602   0.201238
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.24928848047929372, 0.3285614597958558, -0.1...  1397.03928       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SANGLI 2020-07-01  3899.0  2531.176579
# 1   SANGLI 2020-08-01  4244.0  2956.689924
# 2   SANGLI 2020-09-01  2465.0  3291.177175
# 3   SANGLI 2020-10-01  2330.0  2838.295534
# 4   SANGLI 2020-11-01  3203.0  2166.843257
# === Metrics ===
#   district        rmse  r_squared  \
# 0   SATARA  920.881842    0.36227
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.07828273531599918, 0.3309061300056645, -0.... -18.439133       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SATARA 2020-07-01    1934  1204.370568
# 1   SATARA 2020-08-01    2767  1533.104089
# 2   SATARA 2020-09-01    2016   995.706509
# 3   SATARA 2020-10-01    2412  1690.135183
# 4   SATARA 2020-11-01    2455  1240.265236
# === Metrics ===
#      district       rmse  r_squared  \
# 0  SINDHUDURG  87.714966   0.162882
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.28495637070827345, 0.019817150504860066, 0...  -4.507392       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01     479  438.577722
# 1  SINDHUDURG 2020-08-01     516  365.602813
# 2  SINDHUDURG 2020-09-01     446  351.333980
# 3  SINDHUDURG 2020-10-01     435  383.633175
# 4  SINDHUDURG 2020-11-01     458  379.438981
# === Metrics ===
#   district         rmse  r_squared  \
# 0  SOLAPUR  1630.666972   0.189841
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.24109185700885433, -0.292263259988813, -0....  72.832044       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  SOLAPUR 2020-07-01    2470  2263.628334
# 1  SOLAPUR 2020-08-01    1918  2266.978249
# 2  SOLAPUR 2020-09-01    2558  2619.668614
# 3  SOLAPUR 2020-10-01    2463  2536.634248
# 4  SOLAPUR 2020-11-01    3694  2963.516760
# === Metrics ===
#   district         rmse  r_squared  \
# 0    THANE  2560.972327   0.303428
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.47309414131534416, -0.22458094928439412, -...  89.443163       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual      forecast
# 0    THANE 2020-07-01    5153   9123.405532
# 1    THANE 2020-08-01   11494  11779.469284
# 2    THANE 2020-09-01   12157   9989.749731
# 3    THANE 2020-10-01   12242   9017.406626
# 4    THANE 2020-11-01    7730   7256.808740
# === Metrics ===
#   district        rmse  r_squared  \
# 0   WARDHA  272.437841   0.159755
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.3774691893162917, -0.23772239331226844, -0...  33.116519       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WARDHA 2020-07-01    1131  1173.234392
# 1   WARDHA 2020-08-01    1326  1189.225881
# 2   WARDHA 2020-09-01    1431  1145.731148
# 3   WARDHA 2020-10-01    1425  1076.695106
# 4   WARDHA 2020-11-01    1342  1072.072518
# === Metrics ===
#   district       rmse  r_squared  \
# 0   WASHIM  86.193347   0.346241
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.25308037879172973, 0.3087843006996041, -0.1...  218.947517       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WASHIM 2020-07-01   622.0  482.135141
# 1   WASHIM 2020-08-01   696.0  600.877934
# 2   WASHIM 2020-09-01   678.0  636.530959
# 3   WASHIM 2020-10-01   696.0  553.035429
# 4   WASHIM 2020-11-01   627.0  600.336297
# === Metrics ===
#    district        rmse  r_squared  \
# 0  YAVATMAL  457.045069   0.259654
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.4996205580608666, -0.09684821635311709, 0.0...  1691.700882       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  YAVATMAL 2020-07-01  4215.0  3093.014423
# 1  YAVATMAL 2020-08-01  3800.0  3662.555077
# 2  YAVATMAL 2020-09-01  3624.0  3393.167403
# 3  YAVATMAL 2020-10-01  3708.0  3346.385074
# 4  YAVATMAL 2020-11-01  3219.0  3142.809905
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 28
#      25         print(results['forecast_df'].head())
#      27     return results
# ---> 28 run_for_each_district()
#
# Cell In[4], line 11, in run_for_each_district()
#       8 district_data = data[data['district'] == district]
#       9 ts = district_data["I55"].asfreq('MS')
# ---> 11 results = ridge_regression_lags_only(
#      12     ts,
#      13     district,
#      14     max_lags=5,
#      15     use_cv=True,
#      16     alphas=np.logspace(-3, 2, 30),
#      17     cv=5
#      18 )
#      21 # Show results
#      22 print("=== Metrics ===")
#
# Cell In[3], line 47, in ridge_regression_lags_only(series, district_name, max_lags, differencing, alpha, use_cv, alphas, cv, random_state)
#      45 if use_cv:
#      46     model = RidgeCV(alphas=alphas, cv=TimeSeriesSplit(n_splits=5), scoring='neg_mean_squared_error')
# ---> 47     model.fit(X_train, y_train)
#      48     best_alpha = model.alpha_
#      49 else:
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_ridge.py:2418, in RidgeCV.fit(self, X, y, sample_weight)
#    2389 """Fit Ridge regression model with cv.
#    2390
#    2391 Parameters
#    (...)
#    2415 the validation score.
#    2416 """
#    2417 _raise_for_unsupported_routing(self, "fit", sample_weight=sample_weight)
# -> 2418 super().fit(X, y, sample_weight=sample_weight)
#    2419 return self
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_ridge.py:2240, in _BaseRidgeCV.fit(self, X, y, sample_weight)
#    2230 model = RidgeClassifier if is_classifier(self) else Ridge
#    2231 gs = GridSearchCV(
#    2232     model(
#    2233         fit_intercept=self.fit_intercept,
#    (...)
#    2238     scoring=self.scoring,
#    2239 )
# -> 2240 gs.fit(X, y, sample_weight=sample_weight)
#    2241 estimator = gs.best_estimator_
#    2242 self.alpha_ = gs.best_estimator_.alpha
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:928, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
#     916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
# --> 928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:1177, in TimeSeriesSplit.split(self, X, y, groups)
#    1175 # Make sure we have enough samples for the given split parameters
#    1176 if n_folds > n_samples:
# -> 1177     raise ValueError(
#    1178         f"Cannot have number of folds={n_folds} greater"
#    1179         f" than the number of samples={n_samples}."
#    1180     )
#    1181 if n_samples - gap - (test_size * n_splits) <= 0:
#    1182     raise ValueError(
#    1183         f"Too many splits={n_splits} for number of samples"
#    1184         f"={n_samples} with test_size={test_size} and gap={gap}."
#    1185     )
#
# ValueError: Cannot have number of folds=6 greater than the number of samples=4.
