# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def knn_regression_lags_only(
    series,
    district_name,
    max_lags=3,
    differencing=True,
    n_neighbors=5,
    weights='uniform',
    algorithm='auto',
    use_cv=False,
    cv_params=None,
    cv=5
):
    """
    K-Nearest Neighbors regression for time series forecasting with:
    - Lag features only
    - Optional differencing for stationarity
    - Optional hyperparameter tuning via cross-validation
    """
    # 1. Directory structure
    os.makedirs('KNNRegression', exist_ok=True)
    
    # 2. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 3. Feature Engineering - Lag features only
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 4. Train-Test Split (time-based)
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 5. Model Training (with optional CV)
    if use_cv:
        param_grid = cv_params or {
            'n_neighbors': [3, 5, 7, 9],
            'weights': ['uniform', 'distance'],
            'algorithm': ['auto', 'ball_tree', 'kd_tree']
        }
        grid_search = GridSearchCV(
            KNeighborsRegressor(),
            param_grid,
            cv=cv,
            scoring='neg_mean_squared_error'
        )
        grid_search.fit(X_train, y_train)
        model = grid_search.best_estimator_
        best_params = grid_search.best_params_
    else:
        model = KNeighborsRegressor(
            n_neighbors=n_neighbors,
            weights=weights,
            algorithm=algorithm
        )
        model.fit(X_train, y_train)
        best_params = {
            'n_neighbors': n_neighbors,
            'weights': weights,
            'algorithm': algorithm
        }

    # 6. Forecasting
    pred_test = model.predict(X_test)

    # 7. Inverse Differencing if applied
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = np.cumsum(pred_test) + last_train_value
        y_test = original_series.iloc[-len(test):]

    # 8. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test
    })

    # 9. Save forecasts to CSV
    forecast_csv_path = os.path.join('KNNRegression', 'knn_forecasts.csv')
    forecast_df.to_csv(
        forecast_csv_path,
        mode='a',
        header=not os.path.exists(forecast_csv_path),
        index=False
    )

    # 10. Calculate metrics
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    r_squared = model.score(X_train, y_train)
    metrics_data = {
        'district': district_name,
        'rmse': rmse,
        'r_squared': r_squared,
        'best_params': best_params,
        'differencing': d
    }
    metrics_df = pd.DataFrame([metrics_data])

    metrics_csv_path = os.path.join('KNNRegression', 'knn_metrics.csv')
    metrics_df.to_csv(
        metrics_csv_path,
        mode='a',
        header=not os.path.exists(metrics_csv_path),
        index=False
    )

    # 11. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='KNN Forecast', color='darkorange')
    plt.title(f'KNN Regression Forecast for {district_name}\nRMSE: {rmse:.2f}, R²: {r_squared:.2f}')
    plt.legend()
    plt.savefig(os.path.join('KNNRegression', f'knn_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'best_params': best_params
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I48"].asfreq('MS')
        
        results = knn_regression_lags_only(
            ts,
            district,
            max_lags=5,
            use_cv=True,
            cv_params={
                'n_neighbors': [3, 5, 7, 9],
                'weights': ['uniform', 'distance']
            }
        )

        
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district       rmse  r_squared                               best_params  \
# 0  AHMEDNAGAR  94.401264   0.222329  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  AHMEDNAGAR 2020-07-01   354.0  467.428571
# 1  AHMEDNAGAR 2020-08-01   391.0  418.857143
# 2  AHMEDNAGAR 2020-09-01   417.0  424.285714
# 3  AHMEDNAGAR 2020-10-01   343.0  417.571429
# 4  AHMEDNAGAR 2020-11-01   468.0  405.857143
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0    AKOLA  79.687722   0.127091  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    AKOLA 2020-07-01   407.0  471.222222
# 1    AKOLA 2020-08-01   306.0  467.000000
# 2    AKOLA 2020-09-01   504.0  441.555556
# 3    AKOLA 2020-10-01   493.0  452.777778
# 4    AKOLA 2020-11-01   514.0  464.333333
# === Metrics ===
#    district        rmse  r_squared                                best_params  \
# 0  AMRAVATI  186.197163        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  AMRAVATI 2020-07-01     470  337.372036
# 1  AMRAVATI 2020-08-01     482  339.484254
# 2  AMRAVATI 2020-09-01     586  468.291529
# 3  AMRAVATI 2020-10-01     819  425.602405
# 4  AMRAVATI 2020-11-01     609  427.784537
# === Metrics ===
#      district        rmse  r_squared  \
# 0  AURANGABAD  337.703271   0.071978
#
#                                 best_params  differencing
# 0  {'n_neighbors': 9, 'weights': 'uniform'}             1
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  AURANGABAD 2020-07-01     378  409.333333
# 1  AURANGABAD 2020-08-01     729  431.888889
# 2  AURANGABAD 2020-09-01     857  421.555556
# 3  AURANGABAD 2020-10-01     889  384.888889
# 4  AURANGABAD 2020-11-01     837  385.222222
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0     BEED  47.120742        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0     BEED 2020-07-01   465.0  474.820050
# 1     BEED 2020-08-01   554.0  480.477818
# 2     BEED 2020-09-01   485.0  484.768904
# 3     BEED 2020-10-01   495.0  477.709476
# 4     BEED 2020-11-01   472.0  482.857917
# === Metrics ===
#    district       rmse  r_squared                               best_params  \
# 0  BHANDARA  49.274469   0.373483  {'n_neighbors': 5, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual  forecast
# 0  BHANDARA 2020-07-01   267.0     287.8
# 1  BHANDARA 2020-08-01   323.0     287.8
# 2  BHANDARA 2020-09-01   344.0     331.0
# 3  BHANDARA 2020-10-01   397.0     373.6
# 4  BHANDARA 2020-11-01   285.0     385.2
# === Metrics ===
#    district       rmse  r_squared                               best_params  \
# 0  BULDHANA  46.342973   0.478118  {'n_neighbors': 5, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual  forecast
# 0  BULDHANA 2020-07-01   186.0     203.2
# 1  BULDHANA 2020-08-01   211.0     205.0
# 2  BULDHANA 2020-09-01   266.0     216.4
# 3  BULDHANA 2020-10-01   280.0     281.2
# 4  BULDHANA 2020-11-01   328.0     272.8
# === Metrics ===
#      district        rmse  r_squared  \
# 0  CHANDRAPUR  123.011169   0.016507
#
#                                 best_params  differencing
# 0  {'n_neighbors': 9, 'weights': 'uniform'}             1
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  CHANDRAPUR 2020-07-01     445  363.222222
# 1  CHANDRAPUR 2020-08-01     502  404.222222
# 2  CHANDRAPUR 2020-09-01     592  412.000000
# 3  CHANDRAPUR 2020-10-01     628  410.000000
# 4  CHANDRAPUR 2020-11-01     562  393.444444
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0    DHULE  149.404309   0.282398  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    DHULE 2020-07-01   106.0  368.222222
# 1    DHULE 2020-08-01   142.0  354.222222
# 2    DHULE 2020-09-01   210.0  363.111111
# 3    DHULE 2020-10-01   167.0  363.111111
# 4    DHULE 2020-11-01   356.0  387.666667
# === Metrics ===
#      district       rmse  r_squared                               best_params  \
# 0  GADCHIROLI  60.615465   0.511955  {'n_neighbors': 3, 'weights': 'uniform'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  GADCHIROLI 2020-07-01     294  298.333333
# 1  GADCHIROLI 2020-08-01     439  362.333333
# 2  GADCHIROLI 2020-09-01     482  375.000000
# 3  GADCHIROLI 2020-10-01     431  409.333333
# 4  GADCHIROLI 2020-11-01     434  367.666667
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0   GONDIA  93.686263        1.0  {'n_neighbors': 3, 'weights': 'distance'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   GONDIA 2020-07-01     335  301.039358
# 1   GONDIA 2020-08-01     304  246.075765
# 2   GONDIA 2020-09-01     282  344.281734
# 3   GONDIA 2020-10-01     335  385.378746
# 4   GONDIA 2020-11-01     425  451.320351
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0  HINGOLI  69.047652   0.273822  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  HINGOLI 2020-07-01   138.0  163.428571
# 1  HINGOLI 2020-08-01    86.0  138.142857
# 2  HINGOLI 2020-09-01   165.0  151.571429
# 3  HINGOLI 2020-10-01   164.0  148.571429
# 4  HINGOLI 2020-11-01   125.0  178.428571
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0  JALGAON  135.81281   0.334567  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  JALGAON 2020-07-01   244.0  345.666667
# 1  JALGAON 2020-08-01   292.0  321.333333
# 2  JALGAON 2020-09-01   362.0  246.000000
# 3  JALGAON 2020-10-01   415.0  267.111111
# 4  JALGAON 2020-11-01   469.0  321.222222
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0    JALNA  53.344392   0.130179  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    JALNA 2020-07-01   260.0  216.444444
# 1    JALNA 2020-08-01   218.0  240.555556
# 2    JALNA 2020-09-01   164.0  238.888889
# 3    JALNA 2020-10-01   226.0  219.000000
# 4    JALNA 2020-11-01   211.0  232.777778
# === Metrics ===
#    district       rmse  r_squared                               best_params  \
# 0  KOLHAPUR  85.209417    0.13201  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  KOLHAPUR 2020-07-01   383.0  372.333333
# 1  KOLHAPUR 2020-08-01   292.0  369.444444
# 2  KOLHAPUR 2020-09-01   390.0  385.000000
# 3  KOLHAPUR 2020-10-01   332.0  373.222222
# 4  KOLHAPUR 2020-11-01   381.0  367.555556
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0    LATUR  146.701701        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    LATUR 2020-07-01   345.0  298.630627
# 1    LATUR 2020-08-01   387.0  282.807471
# 2    LATUR 2020-09-01   426.0  293.167697
# 3    LATUR 2020-10-01   448.0  274.651912
# 4    LATUR 2020-11-01   462.0  307.233816
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0   MUMBAI  131.63414        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   MUMBAI 2020-07-01     513  518.749524
# 1   MUMBAI 2020-08-01     579  591.674756
# 2   MUMBAI 2020-09-01     683  517.602345
# 3   MUMBAI 2020-10-01     763  598.802518
# 4   MUMBAI 2020-11-01     583  724.931194
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0   NAGPUR  221.427906   0.392262  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NAGPUR 2020-07-01   617.0  720.857143
# 1   NAGPUR 2020-08-01   638.0  720.857143
# 2   NAGPUR 2020-09-01   488.0  720.857143
# 3   NAGPUR 2020-10-01   603.0  720.857143
# 4   NAGPUR 2020-11-01   560.0  720.857143
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0   NANDED  65.636047        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NANDED 2020-07-01   261.0  326.088966
# 1   NANDED 2020-08-01   400.0  322.565416
# 2   NANDED 2020-09-01   435.0  367.843053
# 3   NANDED 2020-10-01   391.0  413.643313
# 4   NANDED 2020-11-01   412.0  402.779426
# === Metrics ===
#     district       rmse  r_squared                                best_params  \
# 0  NANDURBAR  92.415829        1.0  {'n_neighbors': 3, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  NANDURBAR 2020-07-01   480.0  296.542120
# 1  NANDURBAR 2020-08-01   533.0  460.148239
# 2  NANDURBAR 2020-09-01   497.0  553.881343
# 3  NANDURBAR 2020-10-01   568.0  458.594989
# 4  NANDURBAR 2020-11-01   511.0  422.533766
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0   NASHIK  131.025511   0.440321  {'n_neighbors': 5, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual  forecast
# 0   NASHIK 2020-07-01   975.0     934.0
# 1   NASHIK 2020-08-01  1023.0     997.8
# 2   NASHIK 2020-09-01  1143.0     985.0
# 3   NASHIK 2020-10-01  1264.0    1030.8
# 4   NASHIK 2020-11-01  1037.0    1148.8
# === Metrics ===
#     district       rmse  r_squared                               best_params  \
# 0  OSMANABAD  38.545523   0.175849  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  OSMANABAD 2020-07-01   177.0  180.000000
# 1  OSMANABAD 2020-08-01   234.0  171.000000
# 2  OSMANABAD 2020-09-01   190.0  185.571429
# 3  OSMANABAD 2020-10-01   248.0  163.428571
# 4  OSMANABAD 2020-11-01   189.0  178.428571
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0  PALGHAR  141.917778        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  PALGHAR 2020-07-01   784.0  778.445903
# 1  PALGHAR 2020-08-01   785.0  729.783192
# 2  PALGHAR 2020-09-01   795.0  734.471460
# 3  PALGHAR 2020-10-01  1020.0  725.249865
# 4  PALGHAR 2020-11-01  1006.0  850.276372
# === Metrics ===
#    district      rmse  r_squared                               best_params  \
# 0  PARBHANI  71.67881   0.585004  {'n_neighbors': 3, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  PARBHANI 2020-07-01   257.0  132.333333
# 1  PARBHANI 2020-08-01   232.0  227.000000
# 2  PARBHANI 2020-09-01   291.0  166.666667
# 3  PARBHANI 2020-10-01   315.0  268.000000
# 4  PARBHANI 2020-11-01   205.0  236.333333
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0     PUNE  395.110923   0.392113  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     PUNE 2020-07-01  1326.0  1716.428571
# 1     PUNE 2020-08-01  1529.0  1681.714286
# 2     PUNE 2020-09-01  1439.0  1812.142857
# 3     PUNE 2020-10-01  1349.0  1738.428571
# 4     PUNE 2020-11-01  1578.0  1698.571429
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0   RAIGAD  90.470285   0.147586  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   RAIGAD 2020-07-01   420.0  397.777778
# 1   RAIGAD 2020-08-01   459.0  353.222222
# 2   RAIGAD 2020-09-01   475.0  361.111111
# 3   RAIGAD 2020-10-01   491.0  361.222222
# 4   RAIGAD 2020-11-01   465.0  361.111111
# === Metrics ===
#     district        rmse  r_squared                               best_params  \
# 0  RATNAGIRI  231.867803   0.300128  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  RATNAGIRI 2020-07-01     203  405.285714
# 1  RATNAGIRI 2020-08-01     179  401.714286
# 2  RATNAGIRI 2020-09-01     255  434.571429
# 3  RATNAGIRI 2020-10-01     253  460.142857
# 4  RATNAGIRI 2020-11-01     257  438.000000
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0   SANGLI  97.663675   0.221092  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   SANGLI 2020-07-01   547.0  461.222222
# 1   SANGLI 2020-08-01   406.0  471.888889
# 2   SANGLI 2020-09-01   461.0  457.000000
# 3   SANGLI 2020-10-01   373.0  449.444444
# 4   SANGLI 2020-11-01   410.0  466.444444
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0   SATARA  122.474126   0.089622  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   SATARA 2020-07-01   347.0  421.428571
# 1   SATARA 2020-08-01   349.0  443.142857
# 2   SATARA 2020-09-01   446.0  440.285714
# 3   SATARA 2020-10-01   494.0  477.571429
# 4   SATARA 2020-11-01   518.0  476.142857
# === Metrics ===
#      district       rmse  r_squared  \
# 0  SINDHUDURG  23.431121        1.0
#
#                                  best_params  differencing
# 0  {'n_neighbors': 9, 'weights': 'distance'}             0
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01   121.0  120.738964
# 1  SINDHUDURG 2020-08-01    97.0  116.840012
# 2  SINDHUDURG 2020-09-01   141.0  120.625721
# 3  SINDHUDURG 2020-10-01   144.0  108.819934
# 4  SINDHUDURG 2020-11-01   117.0  118.419158
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0  SOLAPUR  121.560703   0.523972  {'n_neighbors': 5, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual  forecast
# 0  SOLAPUR 2020-07-01   410.0     584.2
# 1  SOLAPUR 2020-08-01   405.0     620.2
# 2  SOLAPUR 2020-09-01   654.0     500.0
# 3  SOLAPUR 2020-10-01   535.0     539.0
# 4  SOLAPUR 2020-11-01   622.0     615.6
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0    THANE  382.395383  -0.046311  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    THANE 2020-07-01     708  738.222222
# 1    THANE 2020-08-01     893  670.777778
# 2    THANE 2020-09-01     916  599.444444
# 3    THANE 2020-10-01    1156  527.666667
# 4    THANE 2020-11-01     848  548.555556
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0   WARDHA  55.502222   0.180692  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WARDHA 2020-07-01   179.0  213.285714
# 1   WARDHA 2020-08-01   192.0  221.142857
# 2   WARDHA 2020-09-01   251.0  221.142857
# 3   WARDHA 2020-10-01   241.0  244.142857
# 4   WARDHA 2020-11-01   231.0  238.428571
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0   WASHIM  25.014564   0.433817  {'n_neighbors': 3, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WASHIM 2020-07-01   154.0  115.000000
# 1   WASHIM 2020-08-01   127.0  135.333333
# 2   WASHIM 2020-09-01   120.0  101.000000
# 3   WASHIM 2020-10-01   113.0   82.333333
# 4   WASHIM 2020-11-01   154.0  122.666667
# === Metrics ===
#    district      rmse  r_squared                                best_params  \
# 0  YAVATMAL  20.19939        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  YAVATMAL 2020-07-01   148.0  150.622249
# 1  YAVATMAL 2020-08-01   201.0  196.597586
# 2  YAVATMAL 2020-09-01   225.0  181.012296
# 3  YAVATMAL 2020-10-01   182.0  175.553786
# 4  YAVATMAL 2020-11-01   174.0  140.390217
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
# ...
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [-35021.42222222 -37399.62217788             nan             nan
#              nan             nan             nan             nan]
#   warnings.warn(
# === Metrics ===
#           district       rmse  r_squared  \
# 0  MUMBAI SUBURBAN  187.91384   0.064869
#
#                                 best_params  differencing
# 0  {'n_neighbors': 3, 'weights': 'uniform'}             0
#
# === Forecast Data ===
#           district       date  actual    forecast
# 0  MUMBAI SUBURBAN 2021-02-01   607.0  800.333333
# 1  MUMBAI SUBURBAN 2021-03-01   618.0  800.333333
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual    forecast
#  0  MUMBAI SUBURBAN 2021-02-01   607.0  800.333333
#  1  MUMBAI SUBURBAN 2021-03-01   618.0  800.333333,
#  'metrics_df':           district       rmse  r_squared  \
#  0  MUMBAI SUBURBAN  187.91384   0.064869
#
#                                  best_params  differencing
#  0  {'n_neighbors': 3, 'weights': 'uniform'}             0  ,
#  'best_params': {'n_neighbors': 3, 'weights': 'uniform'}}
