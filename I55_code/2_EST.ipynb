# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def exponential_smoothing_forecast_district(series, district_name, seasonal=False, seasonal_periods=12):
    """
    Complete Exponential Smoothing forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('ExponentialSmoothing', exist_ok=True)
    
    # 1. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 2. Model Fitting
    if seasonal:
        model = ExponentialSmoothing(train, seasonal='add', seasonal_periods=seasonal_periods)
    else:
        model = ExponentialSmoothing(train)
    model_fit = model.fit()
    
    # 3. Forecasting
    forecast = model_fit.forecast(steps=len(test))

    # 4. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast.values
    })

    # 5. Save forecasts to CSV (append mode)
    forecast_csv_path = os.path.join('ExponentialSmoothing', 'exp_smoothing_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 6. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'seasonal': seasonal
    }])

    metrics_csv_path = os.path.join('ExponentialSmoothing', 'exp_smoothing_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 7. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(forecast, label='Forecast', color='darkorange')
    plt.title(f'Exponential Smoothing Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('ExponentialSmoothing', f'ExpSmoothing_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I48"].asfreq('MS')
        
        results = exponential_smoothing_forecast_district(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district       rmse  seasonal
# 0  AHMEDNAGAR  58.619809     False
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  AHMEDNAGAR 2020-06-01     378  333.748869
# 1  AHMEDNAGAR 2020-07-01     354  333.748869
# 2  AHMEDNAGAR 2020-08-01     391  333.748869
# 3  AHMEDNAGAR 2020-09-01     417  333.748869
# 4  AHMEDNAGAR 2020-10-01     343  333.748869
# === Metrics ===
#   district       rmse  seasonal
# 0    AKOLA  74.043272     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    AKOLA 2020-06-01     339  452.842045
# 1    AKOLA 2020-07-01     407  452.842045
# 2    AKOLA 2020-08-01     306  452.842045
# 3    AKOLA 2020-09-01     504  452.842045
# 4    AKOLA 2020-10-01     493  452.842045
# === Metrics ===
#    district        rmse  seasonal
# 0  AMRAVATI  182.958179     False
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  AMRAVATI 2020-06-01     380  440.780165
# 1  AMRAVATI 2020-07-01     470  440.780165
# 2  AMRAVATI 2020-08-01     482  440.780165
# 3  AMRAVATI 2020-09-01     586  440.780165
# 4  AMRAVATI 2020-10-01     819  440.780165
# === Metrics ===
#      district        rmse  seasonal
# 0  AURANGABAD  240.225587     False
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  AURANGABAD 2020-06-01     426  473.099992
# 1  AURANGABAD 2020-07-01     378  473.099992
# 2  AURANGABAD 2020-08-01     729  473.099992
# 3  AURANGABAD 2020-09-01     857  473.099992
# 4  AURANGABAD 2020-10-01     889  473.099992
# === Metrics ===
#   district       rmse  seasonal
# 0     BEED  50.760158     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0     BEED 2020-06-01     546  474.327444
# 1     BEED 2020-07-01     465  474.327444
# 2     BEED 2020-08-01     554  474.327444
# 3     BEED 2020-09-01     485  474.327444
# 4     BEED 2020-10-01     495  474.327444
# === Metrics ===
#    district       rmse  seasonal
# 0  BHANDARA  86.794709     False
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  
False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   MUMBAI 2020-06-01     663  561.023738
# 1   MUMBAI 2020-07-01     513  561.023738
# 2   MUMBAI 2020-08-01     579  561.023738
# 3   MUMBAI 2020-09-01     683  561.023738
# 4   MUMBAI 2020-10-01     763  561.023738
# === Metrics ===
#   district        rmse  seasonal
# 0   NAGPUR  128.346931     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NAGPUR 2020-06-01     610  523.957305
# 1   NAGPUR 2020-07-01     617  523.957305
# 2   NAGPUR 2020-08-01     638  523.957305
# 3   NAGPUR 2020-09-01     488  523.957305
# 4   NAGPUR 2020-10-01     603  523.957305
# === Metrics ===
#   district       rmse  seasonal
# 0   NANDED  82.037978     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NANDED 2020-06-01     287  288.366954
# 1   NANDED 2020-07-01     261  288.366954
# 2   NANDED 2020-08-01     400  288.366954
# 3   NANDED 2020-09-01     435  288.366954
# 4   NANDED 2020-10-01     391  288.366954
# === Metrics ===
#     district        rmse  seasonal
# 0  NANDURBAR  143.319531     False
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  NANDURBAR 2020-06-01     434  337.54358
# 1  NANDURBAR 2020-07-01     480  337.54358
# 2  NANDURBAR 2020-08-01     533  337.54358
# 3  NANDURBAR 2020-09-01     497  337.54358
# 4  NANDURBAR 2020-10-01     568  337.54358
# === Metrics ===
#   district        rmse  seasonal
# 0   NASHIK  193.969085     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NASHIK 2020-06-01     800  852.306877
# 1   NASHIK 2020-07-01     975  852.306877
# 2   NASHIK 2020-08-01    1023  852.306877
# 3   NASHIK 2020-09-01    1143  852.306877
# 4   NASHIK 2020-10-01    1264  852.306877
# === Metrics ===
#     district       rmse  seasonal
# 0  OSMANABAD  38.580594     False
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  OSMANABAD 2020-06-01     182  168.631573
# 1  OSMANABAD 2020-07-01     177  168.631573
# 2  OSMANABAD 2020-08-01     234  168.631573
# 3  OSMANABAD 2020-09-01     190  168.631573
# 4  OSMANABAD 2020-10-01     248  168.631573
# === Metrics ===
#   district        rmse  seasonal
# 0  PALGHAR  143.966527     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  PALGHAR 2020-06-01     808  757.915285
# 1  PALGHAR 2020-07-01     784  757.915285
# 2  PALGHAR 2020-08-01     785  757.915285
# 3  PALGHAR 2020-09-01     795  757.915285
# 4  PALGHAR 2020-10-01    1020  757.915285
# === Metrics ===
#    district       rmse  seasonal
# 0  PARBHANI  98.587892     False
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  PARBHANI 2020-06-01     140  148.044542
# 1  PARBHANI 2020-07-01     257  148.044542
# 2  PARBHANI 2020-08-01     232  148.044542
# 3  PARBHANI 2020-09-01     291  148.044542
# 4  PARBHANI 2020-10-01     315  148.044542
# === Metrics ===
#   district        rmse  seasonal
# 0     PUNE  140.101607     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     PUNE 2020-06-01    1284  1360.094787
# 1     PUNE 2020-07-01    1326  1360.094787
# 2     PUNE 2020-08-01    1529  1360.094787
# 3     PUNE 2020-09-01    1439  1360.094787
# 4     PUNE 2020-10-01    1349  1360.094787
# === Metrics ===
#   district      rmse  seasonal
# 0   RAIGAD  99.20528     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   RAIGAD 2020-06-01     425  344.483304
# 1   RAIGAD 2020-07-01     420  344.483304
# 2   RAIGAD 2020-08-01     459  344.483304
# 3   RAIGAD 2020-09-01     475  344.483304
# 4   RAIGAD 2020-10-01     491  344.483304
# === Metrics ===
#     district       rmse  seasonal
# 0  RATNAGIRI  70.554621     False
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  RATNAGIRI 2020-06-01     415  223.55133
# 1  RATNAGIRI 2020-07-01     203  223.55133
# 2  RATNAGIRI 2020-08-01     179  223.55133
# 3  RATNAGIRI 2020-09-01     255  223.55133
# 4  RATNAGIRI 2020-10-01     253  223.55133
# === Metrics ===
#   district       rmse  seasonal
# 0   SANGLI  83.039245     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   SANGLI 2020-06-01     481  372.046222
# 1   SANGLI 2020-07-01     547  372.046222
# 2   SANGLI 2020-08-01     406  372.046222
# 3   SANGLI 2020-09-01     461  372.046222
# 4   SANGLI 2020-10-01     373  372.046222
# === Metrics ===
#   district        rmse  seasonal
# 0   SATARA  139.648674     False
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SATARA 2020-06-01     350  439.23102
# 1   SATARA 2020-07-01     347  439.23102
# 2   SATARA 2020-08-01     349  439.23102
# 3   SATARA 2020-09-01     446  439.23102
# 4   SATARA 2020-10-01     494  439.23102
# === Metrics ===
#      district      rmse  seasonal
# 0  SINDHUDURG  21.19074     False
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-06-01     116  119.315813
# 1  SINDHUDURG 2020-07-01     121  119.315813
# 2  SINDHUDURG 2020-08-01      97  119.315813
# 3  SINDHUDURG 2020-09-01     141  119.315813
# 4  SINDHUDURG 2020-10-01     144  119.315813
# === Metrics ===
#   district        rmse  seasonal
# 0  SOLAPUR  204.290534     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  SOLAPUR 2020-06-01     338  313.043507
# 1  SOLAPUR 2020-07-01     410  313.043507
# 2  SOLAPUR 2020-08-01     405  313.043507
# 3  SOLAPUR 2020-09-01     654  313.043507
# 4  SOLAPUR 2020-10-01     535  313.043507
# === Metrics ===
#   district        rmse  seasonal
# 0    THANE  171.080022     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    THANE 2020-06-01     749  919.184069
# 1    THANE 2020-07-01     708  919.184069
# 2    THANE 2020-08-01     893  919.184069
# 3    THANE 2020-09-01     916  919.184069
# 4    THANE 2020-10-01    1156  919.184069
# === Metrics ===
#   district       rmse  seasonal
# 0   WARDHA  58.219162     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WARDHA 2020-06-01     180  177.146089
# 1   WARDHA 2020-07-01     179  177.146089
# 2   WARDHA 2020-08-01     192  177.146089
# 3   WARDHA 2020-09-01     251  177.146089
# 4   WARDHA 2020-10-01     241  177.146089
# === Metrics ===
#   district       rmse  seasonal
# 0   WASHIM  19.688431     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WASHIM 2020-06-01     107  115.480434
# 1   WASHIM 2020-07-01     154  115.480434
# 2   WASHIM 2020-08-01     127  115.480434
# 3   WASHIM 2020-09-01     120  115.480434
# 4   WASHIM 2020-10-01     113  115.480434
# === Metrics ===
#    district       rmse  seasonal
# 0  YAVATMAL  42.576977     False
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  YAVATMAL 2020-06-01     152  135.178845
# 1  YAVATMAL 2020-07-01     148  135.178845
# 2  YAVATMAL 2020-08-01     201  135.178845
# 3  YAVATMAL 2020-09-01     225  135.178845
# 4  YAVATMAL 2020-10-01     182  135.178845
# === Metrics ===
#           district        rmse  seasonal
# 0  MUMBAI SUBURBAN  203.211802     False
#
# === Forecast Data ===
#           district       date  actual   forecast
# 0  MUMBAI SUBURBAN 2021-01-01     639  824.11108
# 1  MUMBAI SUBURBAN 2021-02-01     607  824.11108
# 2  MUMBAI SUBURBAN 2021-03-01     618  824.11108
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual   forecast
#  0  MUMBAI SUBURBAN 2021-01-01     639  824.11108
#  1  MUMBAI SUBURBAN 2021-02-01     607  824.11108
#  2  MUMBAI SUBURBAN 2021-03-01     618  824.11108,
#  'metrics_df':           district        rmse  seasonal
#  0  MUMBAI SUBURBAN  203.211802     False}
