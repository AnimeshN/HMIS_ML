# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def exponential_smoothing_forecast_district(series, district_name, seasonal=False, seasonal_periods=12):
    """
    Complete Exponential Smoothing forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('ExponentialSmoothing', exist_ok=True)
    
    # 1. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 2. Model Fitting
    if seasonal:
        model = ExponentialSmoothing(train, seasonal='add', seasonal_periods=seasonal_periods)
    else:
        model = ExponentialSmoothing(train)
    model_fit = model.fit()
    
    # 3. Forecasting
    forecast = model_fit.forecast(steps=len(test))

    # 4. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast.values
    })

    # 5. Save forecasts to CSV (append mode)
    forecast_csv_path = os.path.join('ExponentialSmoothing', 'exp_smoothing_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 6. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'seasonal': seasonal
    }])

    metrics_csv_path = os.path.join('ExponentialSmoothing', 'exp_smoothing_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 7. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(forecast, label='Forecast', color='darkorange')
    plt.title(f'Exponential Smoothing Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('ExponentialSmoothing', f'ExpSmoothing_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I55"].asfreq('MS')
        
        results = exponential_smoothing_forecast_district(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district         rmse  seasonal
# 0  AHMEDNAGAR  1090.853655     False
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AHMEDNAGAR 2020-06-01    5761  5670.5829
# 1  AHMEDNAGAR 2020-07-01    6225  5670.5829
# 2  AHMEDNAGAR 2020-08-01    6609  5670.5829
# 3  AHMEDNAGAR 2020-09-01    7268  5670.5829
# 4  AHMEDNAGAR 2020-10-01    6799  5670.5829
# === Metrics ===
#   district        rmse  seasonal
# 0    AKOLA  365.511742     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    AKOLA 2020-06-01    1889  2485.768404
# 1    AKOLA 2020-07-01    1999  2485.768404
# 2    AKOLA 2020-08-01    1927  2485.768404
# 3    AKOLA 2020-09-01    2604  2485.768404
# 4    AKOLA 2020-10-01    2342  2485.768404
# === Metrics ===
#    district        rmse  seasonal
# 0  AMRAVATI  693.037587     False
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  AMRAVATI 2020-06-01    3183  2474.91026
# 1  AMRAVATI 2020-07-01    2772  2474.91026
# 2  AMRAVATI 2020-08-01    3081  2474.91026
# 3  AMRAVATI 2020-09-01    3483  2474.91026
# 4  AMRAVATI 2020-10-01    3505  2474.91026
# === Metrics ===
#      district        rmse  seasonal
# 0  AURANGABAD  278.231234     False
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AURANGABAD 2020-06-01    5574  5776.362667
# 1  AURANGABAD 2020-07-01    5621  5776.362667
# 2  AURANGABAD 2020-08-01    5821  5776.362667
# 3  AURANGABAD 2020-09-01    6050  5776.362667
# 4  AURANGABAD 2020-10-01    6041  5776.362667
# === Metrics ===
#   district        rmse  seasonal
# 0     BEED  427.816978     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-06-01    2392  2393.065611
# 1     BEED 2020-07-01    2942  2393.065611
# 2     BEED 2020-08-01    2934  2393.065611
# 3     BEED 2020-09-01    2943  2393.065611
# 4     BEED 2020-10-01    3112  2393.065611
# === Metrics ===
#    district        rmse  seasonal
# 0  BHANDARA  302.481108     False
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BHANDARA 2020-06-01    1098  969.73004
# 1  BHANDARA 2020-07-01    1119  969.73004
# 2  BHANDARA 2020-08-01    1256  969.73004
# 3  BHANDARA 2020-09-01    1297  969.73004
# 4  BHANDARA 2020-10-01    1524  969.73004
# === Metrics ===
#    district        rmse  seasonal
# 0  BULDHANA  345.234511     False
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-06-01    1131  1092.355948
# 1  BULDHANA 2020-07-01    1172  1092.355948
# 2  BULDHANA 2020-08-01    1332  1092.355948
# 3  BULDHANA 2020-09-01    1442  1092.355948
# 4  BULDHANA 2020-10-01    1664  1092.355948
# === Metrics ===
#      district        rmse  seasonal
# 0  CHANDRAPUR  575.895402     False
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  CHANDRAPUR 2020-06-01    1843  1633.47603
# 1  CHANDRAPUR 2020-07-01    1983  1633.47603
# 2  CHANDRAPUR 2020-08-01    2295  1633.47603
# 3  CHANDRAPUR 2020-09-01    2647  1633.47603
# 4  CHANDRAPUR 2020-10-01    2760  1633.47603
# === Metrics ===
#   district        rmse  seasonal
# 0    DHULE  463.113568     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    DHULE 2020-06-01    1791  1440.497883
# 1    DHULE 2020-07-01    1662  1440.497883
# 2    DHULE 2020-08-01    2372  1440.497883
# 3    DHULE 2020-09-01    2023  1440.497883
# 4    DHULE 2020-10-01    2028  1440.497883
# === Metrics ===
#      district        rmse  seasonal
# 0  GADCHIROLI  427.194429     False
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  GADCHIROLI 2020-06-01    1153  1161.702526
# 1  GADCHIROLI 2020-07-01    1238  1161.702526
# 2  GADCHIROLI 2020-08-01    1510  1161.702526
# 3  GADCHIROLI 2020-09-01    1648  1161.702526
# 4  GADCHIROLI 2020-10-01    1751  1161.702526
# === Metrics ===
#   district       rmse  seasonal
# 0   GONDIA  54.658171     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 
False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NASHIK 2020-06-01    6559  6494.345578
# 1   NASHIK 2020-07-01    7484  6494.345578
# 2   NASHIK 2020-08-01    7551  6494.345578
# 3   NASHIK 2020-09-01    8376  6494.345578
# 4   NASHIK 2020-10-01    7227  6494.345578
# === Metrics ===
#     district        rmse  seasonal
# 0  OSMANABAD  369.093353     False
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  OSMANABAD 2020-06-01    1465  1551.98653
# 1  OSMANABAD 2020-07-01    1794  1551.98653
# 2  OSMANABAD 2020-08-01    1952  1551.98653
# 3  OSMANABAD 2020-09-01    2171  1551.98653
# 4  OSMANABAD 2020-10-01    2081  1551.98653
# === Metrics ===
#   district        rmse  seasonal
# 0  PALGHAR  627.863316     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  PALGHAR 2020-06-01    4417  4074.97944
# 1  PALGHAR 2020-07-01    4269  4074.97944
# 2  PALGHAR 2020-08-01    4229  4074.97944
# 3  PALGHAR 2020-09-01    4522  4074.97944
# 4  PALGHAR 2020-10-01    5385  4074.97944
# === Metrics ===
#    district        rmse  seasonal
# 0  PARBHANI  424.097346     False
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  PARBHANI 2020-06-01    1298  1298.619842
# 1  PARBHANI 2020-07-01    1573  1298.619842
# 2  PARBHANI 2020-08-01    1630  1298.619842
# 3  PARBHANI 2020-09-01    1966  1298.619842
# 4  PARBHANI 2020-10-01    1984  1298.619842
# === Metrics ===
#   district         rmse  seasonal
# 0     PUNE  1949.890885     False
#
# === Forecast Data ===
#   district       date  actual      forecast
# 0     PUNE 2020-06-01   13305  11450.492296
# 1     PUNE 2020-07-01   11790  11450.492296
# 2     PUNE 2020-08-01   12579  11450.492296
# 3     PUNE 2020-09-01   14094  11450.492296
# 4     PUNE 2020-10-01   14381  11450.492296
# === Metrics ===
#   district        rmse  seasonal
# 0   RAIGAD  866.323043     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   RAIGAD 2020-06-01    1924  2742.912211
# 1   RAIGAD 2020-07-01    3532  2742.912211
# 2   RAIGAD 2020-08-01    3912  2742.912211
# 3   RAIGAD 2020-09-01    3990  2742.912211
# 4   RAIGAD 2020-10-01    3615  2742.912211
# === Metrics ===
#     district        rmse  seasonal
# 0  RATNAGIRI  410.713989     False
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  RATNAGIRI 2020-06-01    1240  1257.522622
# 1  RATNAGIRI 2020-07-01    1387  1257.522622
# 2  RATNAGIRI 2020-08-01    2246  1257.522622
# 3  RATNAGIRI 2020-09-01    1755  1257.522622
# 4  RATNAGIRI 2020-10-01    1658  1257.522622
# === Metrics ===
#   district        rmse  seasonal
# 0   SANGLI  889.375484     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SANGLI 2020-06-01    2942  2352.511985
# 1   SANGLI 2020-07-01    3899  2352.511985
# 2   SANGLI 2020-08-01    4244  2352.511985
# 3   SANGLI 2020-09-01    2465  2352.511985
# 4   SANGLI 2020-10-01    2330  2352.511985
# === Metrics ===
#   district       rmse  seasonal
# 0   SATARA  458.02967     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SATARA 2020-06-01    1957  1881.805876
# 1   SATARA 2020-07-01    1934  1881.805876
# 2   SATARA 2020-08-01    2767  1881.805876
# 3   SATARA 2020-09-01    2016  1881.805876
# 4   SATARA 2020-10-01    2412  1881.805876
# === Metrics ===
#      district       rmse  seasonal
# 0  SINDHUDURG  52.168779     False
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-06-01     423  415.139316
# 1  SINDHUDURG 2020-07-01     479  415.139316
# 2  SINDHUDURG 2020-08-01     516  415.139316
# 3  SINDHUDURG 2020-09-01     446  415.139316
# 4  SINDHUDURG 2020-10-01     435  415.139316
# === Metrics ===
#   district         rmse  seasonal
# 0  SOLAPUR  1369.009465     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  SOLAPUR 2020-06-01    2283  3368.033437
# 1  SOLAPUR 2020-07-01    2470  3368.033437
# 2  SOLAPUR 2020-08-01    1918  3368.033437
# 3  SOLAPUR 2020-09-01    2558  3368.033437
# 4  SOLAPUR 2020-10-01    2463  3368.033437
# === Metrics ===
#   district         rmse  seasonal
# 0    THANE  2727.980156     False
#
# === Forecast Data ===
#   district       date  actual      forecast
# 0    THANE 2020-06-01    7942  11152.444553
# 1    THANE 2020-07-01    5153  11152.444553
# 2    THANE 2020-08-01   11494  11152.444553
# 3    THANE 2020-09-01   12157  11152.444553
# 4    THANE 2020-10-01   12242  11152.444553
# === Metrics ===
#   district        rmse  seasonal
# 0   WARDHA  153.943556     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WARDHA 2020-06-01    1078  1196.66781
# 1   WARDHA 2020-07-01    1131  1196.66781
# 2   WARDHA 2020-08-01    1326  1196.66781
# 3   WARDHA 2020-09-01    1431  1196.66781
# 4   WARDHA 2020-10-01    1425  1196.66781
# === Metrics ===
#   district       rmse  seasonal
# 0   WASHIM  120.21439     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WASHIM 2020-06-01     579  508.035078
# 1   WASHIM 2020-07-01     622  508.035078
# 2   WASHIM 2020-08-01     696  508.035078
# 3   WASHIM 2020-09-01     678  508.035078
# 4   WASHIM 2020-10-01     696  508.035078
# === Metrics ===
#    district        rmse  seasonal
# 0  YAVATMAL  705.164167     False
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  YAVATMAL 2020-06-01    2781  2877.520746
# 1  YAVATMAL 2020-07-01    4215  2877.520746
# 2  YAVATMAL 2020-08-01    3800  2877.520746
# 3  YAVATMAL 2020-09-01    3624  2877.520746
# 4  YAVATMAL 2020-10-01    3708  2877.520746
# === Metrics ===
#           district         rmse  seasonal
# 0  MUMBAI SUBURBAN  1239.450787     False
#
# === Forecast Data ===
#           district       date  actual     forecast
# 0  MUMBAI SUBURBAN 2021-01-01    5269  5798.064783
# 1  MUMBAI SUBURBAN 2021-02-01    3958  5798.064783
# 2  MUMBAI SUBURBAN 2021-03-01    4827  5798.064783
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual     forecast
#  0  MUMBAI SUBURBAN 2021-01-01    5269  5798.064783
#  1  MUMBAI SUBURBAN 2021-02-01    3958  5798.064783
#  2  MUMBAI SUBURBAN 2021-03-01    4827  5798.064783,
#  'metrics_df':           district         rmse  seasonal
#  0  MUMBAI SUBURBAN  1239.450787     False}
