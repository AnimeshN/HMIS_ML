# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tbats import TBATS as TBATSModel
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def tbats_forecast_district(series, district_name, seasonal_periods=None, 
                           use_box_cox=None, use_arma_errors=True, n_jobs=1):
    """
    TBATS forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('TBATS', exist_ok=True)
    
    # 1. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 2. TBATS Model Configuration
    estimator = TBATSModel(
        seasonal_periods=seasonal_periods,
        use_box_cox=use_box_cox,
        use_arma_errors=use_arma_errors,
        n_jobs=n_jobs
    )
    
    # 3. Model Fitting
    fitted_model = estimator.fit(train.values)
    
    # 4. Forecasting
    forecast = fitted_model.forecast(steps=len(test))
    
    # 5. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast,
        'model_params': str(fitted_model.params)
    })

    # 6. Save forecasts to CSV
    forecast_csv_path = os.path.join('TBATS', 'tbats_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 7. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'seasonal_periods': str(seasonal_periods),
        'box_cox_used': fitted_model.params.components.use_box_cox,
        # 'arma_used': fitted_model.params.components.use_arma
        'arma_errors_used': fitted_model.params.components.use_arma_errors

    }])

    metrics_csv_path = os.path.join('TBATS', 'tbats_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 8. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(test.index, forecast, label='TBATS Forecast', color='darkorange')
    plt.title(f'TBATS Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('TBATS', f'TBATS_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_summary': fitted_model.summary()
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I48"].asfreq('MS')
        
        results = tbats_forecast_district(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AHMEDNAGAR  55.725705             None         False             False
#
# === Forecast Data ===
#      district       date  actual    forecast  \
# 0  AHMEDNAGAR 2020-06-01     378  339.706771
# 1  AHMEDNAGAR 2020-07-01     354  339.706771
# 2  AHMEDNAGAR 2020-08-01     391  339.706771
# 3  AHMEDNAGAR 2020-09-01     417  339.706771
# 4  AHMEDNAGAR 2020-10-01     343  339.706771
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    AKOLA  69.746354             None          True             False
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0    AKOLA 2020-06-01     339  433.177408
# 1    AKOLA 2020-07-01     407  433.177408
# 2    AKOLA 2020-08-01     306  433.177408
# 3    AKOLA 2020-09-01     504  433.177408
# 4    AKOLA 2020-10-01     493  433.177408
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AMRAVATI  230.151812             None          True             False
#
# === Forecast Data ===
#    district       date  actual    forecast  \
# 0  AMRAVATI 2020-06-01     380  378.513302
# 1  AMRAVATI 2020-07-01     470  378.513302
# 2  AMRAVATI 2020-08-01     482  378.513302
# 3  AMRAVATI 2020-09-01     586  378.513302
# 4  AMRAVATI 2020-10-01     819  378.513302
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AURANGABAD  240.283369             None          True             False
#
# === Forecast Data ===
#      district       date  actual    forecast  \
# 0  AURANGABAD 2020-06-01     426  473.010913
# 1  AURANGABAD 2020-07-01     378  473.010913
# 2  AURANGABAD 2020-08-01     729  473.010913
# 3  AURANGABAD 2020-09-01     857  473.010913
# 4  AURANGABAD 2020-10-01     889  473.010913
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0     BEED  50.735351             None          True             False
#
# === Forecast Data ===
#   district       date  actual   forecast  \
# 0     BEED 2020-06-01     546  474.42718
# 1     BEED 2020-07-01     465  474.42718
# 2     BEED 2020-08-01     554  474.42718
# 3     BEED 2020-09-01     485  474.42718
# 4     BEED 2020-10-01     495  474.42718
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  BHANDARA  86.031068             None          True             False
#
# === Forecast Data ===
#    district       date  actual    forecast  \
# 0  BHANDARA 2020-06-01     250  222.457259
# 1  BHANDARA 2020-07-01     267  222.457259
# 2  BHANDARA 2020-08-01     323  222.457259
# 3  BHANDARA 2020-09-01     344  222.457259
# 4  BHANDARA 2020-10-01     397  222.457259
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  BULDHANA  52.076336             None          True              True
#
# === Forecast Data ===
#    district       date  actual    forecast  \
# 0  BULDHANA 2020-06-01     197  203.285501
# 1  BULDHANA 2020-07-01     186  198.843146
# 2  BULDHANA 2020-08-01     211  224.817300
# 3  BULDHANA 2020-09-01     266  219.722404
# 4  BULDHANA 2020-10-01     280  233.249272
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  CHANDRAPUR  95.884905             None          True             False
#
# === Forecast Data ===
#      district       date  actual    forecast  \
# 0  CHANDRAPUR 2020-06-01     327  493.382986
# 1  CHANDRAPUR 2020-07-01     445  493.382986
# 2  CHANDRAPUR 2020-08-01     502  493.382986
# 3  CHANDRAPUR 2020-09-01     592  493.382986
# 4  CHANDRAPUR 2020-10-01     628  493.382986
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    DHULE  154.978503             None         False              True
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0    DHULE 2020-06-01     227  301.926727
# 1    DHULE 2020-07-01     106  357.545151
# 2    DHULE 2020-08-01     142  384.001114
# 3    DHULE 2020-09-01     210  396.585397
# 4    DHULE 2020-10-01     167  402.571350
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  GADCHIROLI  87.935095             None         False             False
#
# === Forecast Data ===
#      district       date  actual    forecast  \
# 0  GADCHIROLI 2020-06-01     318  295.244865
# 1  GADCHIROLI 2020-07-01     294  311.592052
# 2  GADCHIROLI 2020-08-01     439  324.669802
# 3  GADCHIROLI 2020-09-01     482  335.132002
# 4  GADCHIROLI 2020-10-01     431  343.501762
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   GONDIA  76.30993             None          True             False
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0   GONDIA 2020-06-01     261  262.010954
# 1   GONDIA 2020-07-01     335  262.010954
# 2   GONDIA 2020-08-01     304  262.010954
# 3   GONDIA 2020-09-01     282  262.010954
# 4   GONDIA 2020-10-01     335  262.010954
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  HINGOLI  95.863141             None          True              True
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0  HINGOLI 2020-06-01      91  107.899339
# 1  HINGOLI 2020-07-01     138   99.021758
# 2  HINGOLI 2020-08-01      86   90.570626
# 3  HINGOLI 2020-09-01     165   82.291206
# 4  HINGOLI 2020-10-01     164   74.192912
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  JALGAON  111.463868             None          True             False
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    THANE  171.700118             None         False             False
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0    THANE 2020-06-01     749  920.834122
# 1    THANE 2020-07-01     708  920.834122
# 2    THANE 2020-08-01     893  920.834122
# 3    THANE 2020-09-01     916  920.834122
# 4    THANE 2020-10-01    1156  920.834122
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WARDHA  73.971149             None         False              True
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0   WARDHA 2020-06-01     180  167.755971
# 1   WARDHA 2020-07-01     179  161.702051
# 2   WARDHA 2020-08-01     192  157.240289
# 3   WARDHA 2020-09-01     251  153.573161
# 4   WARDHA 2020-10-01     241  150.302628
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WASHIM  20.177757             None          True             False
#
# === Forecast Data ===
#   district       date  actual   forecast  \
# 0   WASHIM 2020-06-01     107  126.66389
# 1   WASHIM 2020-07-01     154  126.66389
# 2   WASHIM 2020-08-01     127  126.66389
# 3   WASHIM 2020-09-01     120  126.66389
# 4   WASHIM 2020-10-01     113  126.66389
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  YAVATMAL  30.457875             None          True             False
#
# === Forecast Data ===
#    district       date  actual    forecast  \
# 0  YAVATMAL 2020-06-01     152  143.859650
# 1  YAVATMAL 2020-07-01     148  152.331138
# 2  YAVATMAL 2020-08-01     201  159.478797
# 3  YAVATMAL 2020-09-01     225  165.448189
# 4  YAVATMAL 2020-10-01     182  170.392879
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#           district        rmse seasonal_periods  box_cox_used  \
# 0  MUMBAI SUBURBAN  197.430146             None         False
#
#    arma_errors_used
# 0             False
#
# === Forecast Data ===
#           district       date  actual    forecast  \
# 0  MUMBAI SUBURBAN 2021-01-01     639  818.316684
# 1  MUMBAI SUBURBAN 2021-02-01     607  818.316684
# 2  MUMBAI SUBURBAN 2021-03-01     618  818.316684
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual    forecast  \
#  0  MUMBAI SUBURBAN 2021-01-01     639  818.316684
#  1  MUMBAI SUBURBAN 2021-02-01     607  818.316684
#  2  MUMBAI SUBURBAN 2021-03-01     618  818.316684
#
#                                          model_params
#  0  <tbats.tbats.ModelParams.ModelParams object at...
#  1  <tbats.tbats.ModelParams.ModelParams object at...
#  2  <tbats.tbats.ModelParams.ModelParams object at...  ,
#  'metrics_df':           district        rmse seasonal_periods  box_cox_used  \
#  0  MUMBAI SUBURBAN  197.430146             None         False
#
#     arma_errors_used
#  0             False  ,
#  'model_summary': 'Use Box-Cox: False\nUse trend: False\nUse damped trend: False\nSeasonal periods: []\nSeasonal harmonics []\nARMA errors (p, q): (0, 0)\nSmoothing (Alpha): -0.010000\nSeasonal Parameters (Gamma): []\nAR coefficients []\nMA coefficients []\nSeed vector [818.67792863]\n\nAIC 111.522928'}
