# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tbats import TBATS as TBATSModel
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def tbats_forecast_district(series, district_name, seasonal_periods=None, 
                           use_box_cox=None, use_arma_errors=True, n_jobs=1):
    """
    TBATS forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('TBATS', exist_ok=True)
    
    # 1. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 2. TBATS Model Configuration
    estimator = TBATSModel(
        seasonal_periods=seasonal_periods,
        use_box_cox=use_box_cox,
        use_arma_errors=use_arma_errors,
        n_jobs=n_jobs
    )
    
    # 3. Model Fitting
    fitted_model = estimator.fit(train.values)
    
    # 4. Forecasting
    forecast = fitted_model.forecast(steps=len(test))
    
    # 5. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast,
        'model_params': str(fitted_model.params)
    })

    # 6. Save forecasts to CSV
    forecast_csv_path = os.path.join('TBATS', 'tbats_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 7. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'seasonal_periods': str(seasonal_periods),
        'box_cox_used': fitted_model.params.components.use_box_cox,
        # 'arma_used': fitted_model.params.components.use_arma
        'arma_errors_used': fitted_model.params.components.use_arma_errors

    }])

    metrics_csv_path = os.path.join('TBATS', 'tbats_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 8. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(test.index, forecast, label='TBATS Forecast', color='darkorange')
    plt.title(f'TBATS Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('TBATS', f'TBATS_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_summary': fitted_model.summary()
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I55"].asfreq('MS')
        
        results = tbats_forecast_district(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AHMEDNAGAR  1089.161294             None          True             False
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  AHMEDNAGAR 2020-06-01    5761  5471.333448
# 1  AHMEDNAGAR 2020-07-01    6225  5471.333448
# 2  AHMEDNAGAR 2020-08-01    6609  5471.333448
# 3  AHMEDNAGAR 2020-09-01    7268  5471.333448
# 4  AHMEDNAGAR 2020-10-01    6799  5471.333448
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    AKOLA  390.751123             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    AKOLA 2020-06-01    1889  1933.847634
# 1    AKOLA 2020-07-01    1999  1933.847634
# 2    AKOLA 2020-08-01    1927  1933.847634
# 3    AKOLA 2020-09-01    2604  1933.847634
# 4    AKOLA 2020-10-01    2342  1933.847634
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AMRAVATI  975.331817             None         False              True
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  AMRAVATI 2020-06-01    3183  2316.298305
# 1  AMRAVATI 2020-07-01    2772  2218.191635
# 2  AMRAVATI 2020-08-01    3081  2164.927504
# 3  AMRAVATI 2020-09-01    3483  2136.009310
# 4  AMRAVATI 2020-10-01    3505  2120.309028
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AURANGABAD  292.980149             None         False             False
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  AURANGABAD 2020-06-01    5574  5752.210972
# 1  AURANGABAD 2020-07-01    5621  5752.210972
# 2  AURANGABAD 2020-08-01    5821  5752.210972
# 3  AURANGABAD 2020-09-01    6050  5752.210972
# 4  AURANGABAD 2020-10-01    6041  5752.210972
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0     BEED  438.992871             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0     BEED 2020-06-01    2392  2375.638997
# 1     BEED 2020-07-01    2942  2375.638997
# 2     BEED 2020-08-01    2934  2375.638997
# 3     BEED 2020-09-01    2943  2375.638997
# 4     BEED 2020-10-01    3112  2375.638997
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  BHANDARA  299.537345             None         False             False
#
# === Forecast Data ===
#    district       date  actual    forecast  \
# 0  BHANDARA 2020-06-01    1098  973.307623
# 1  BHANDARA 2020-07-01    1119  973.307623
# 2  BHANDARA 2020-08-01    1256  973.307623
# 3  BHANDARA 2020-09-01    1297  973.307623
# 4  BHANDARA 2020-10-01    1524  973.307623
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  BULDHANA  333.125731             None          True             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  BULDHANA 2020-06-01    1131  1106.475155
# 1  BULDHANA 2020-07-01    1172  1106.475155
# 2  BULDHANA 2020-08-01    1332  1106.475155
# 3  BULDHANA 2020-09-01    1442  1106.475155
# 4  BULDHANA 2020-10-01    1664  1106.475155
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  CHANDRAPUR  575.648551             None          True             False
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  CHANDRAPUR 2020-06-01    1843  1633.815765
# 1  CHANDRAPUR 2020-07-01    1983  1633.815765
# 2  CHANDRAPUR 2020-08-01    2295  1633.815765
# 3  CHANDRAPUR 2020-09-01    2647  1633.815765
# 4  CHANDRAPUR 2020-10-01    2760  1633.815765
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    DHULE  391.605086             None         False              True
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    DHULE 2020-06-01    1791  1519.417920
# 1    DHULE 2020-07-01    1662  1522.920615
# 2    DHULE 2020-08-01    2372  1524.098285
# 3    DHULE 2020-09-01    2023  1524.494240
# 4    DHULE 2020-10-01    2028  1524.627367
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  GADCHIROLI  298.565397             None         False              True
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  GADCHIROLI 2020-06-01    1153  1288.928663
# 1  GADCHIROLI 2020-07-01    1238  1323.439473
# 2  GADCHIROLI 2020-08-01    1510  1323.439473
# 3  GADCHIROLI 2020-09-01    1648  1323.439473
# 4  GADCHIROLI 2020-10-01    1751  1323.439473
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   GONDIA  208.198925             None         False             False
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0   GONDIA 2020-06-01     905  786.353859
# 1   GONDIA 2020-07-01     973  787.567832
# 2   GONDIA 2020-08-01     997  788.591638
# 3   GONDIA 2020-09-01     986  789.455065
# 4   GONDIA 2020-10-01    1065  790.183238
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  HINGOLI  176.118079             None          True              True
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0  HINGOLI 2020-06-01     891  963.322459
# 1  HINGOLI 2020-07-01    1043  962.198642
# 2  HINGOLI 2020-08-01    1101  961.288430
# 3  HINGOLI 2020-09-01    1343  960.548211
# 4  HINGOLI 2020-10-01    1229  959.946152
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  JALGAON  3819.599181             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  JALGAON 2020-06-01    4311  4270.682874
# 1  JALGAON 2020-07-01    3714  4270.682874
# 2  JALGAON 2020-08-01   15827  4270.682874
# 3  JALGAON 2020-09-01    5302  4270.682874
# 4  JALGAON 2020-10-01    4900  4270.682874
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    JALNA  498.239242             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    JALNA 2020-06-01    1794  1373.291611
# 1    JALNA 2020-07-01    1894  1373.291611
# 2    JALNA 2020-08-01    1719  1373.291611
# 3    JALNA 2020-09-01    1730  1373.291611
# 4    JALNA 2020-10-01    2115  1373.291611
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  KOLHAPUR  958.541262             None          True             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  KOLHAPUR 2020-06-01    6692  6664.676304
# 1  KOLHAPUR 2020-07-01    6281  6664.676304
# 2  KOLHAPUR 2020-08-01    6879  6664.676304
# 3  KOLHAPUR 2020-09-01    7432  6664.676304
# 4  KOLHAPUR 2020-10-01    6246  6664.676304
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    LATUR  588.015407             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    LATUR 2020-06-01    3154  2918.474301
# 1    LATUR 2020-07-01    2947  2918.474301
# 2    LATUR 2020-08-01    3092  2918.474301
# 3    LATUR 2020-09-01    3775  2918.474301
# 4    LATUR 2020-10-01    3978  2918.474301
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   MUMBAI  732.372974             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   MUMBAI 2020-06-01    2618  2786.633521
# 1   MUMBAI 2020-07-01    2667  2786.633521
# 2   MUMBAI 2020-08-01    2879  2786.633521
# 3   MUMBAI 2020-09-01    3817  2786.633521
# 4   MUMBAI 2020-10-01    3638  2786.633521
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   NAGPUR  301.689021             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   NAGPUR 2020-06-01    2379  2501.982245
# 1   NAGPUR 2020-07-01    2306  2501.982245
# 2   NAGPUR 2020-08-01    2264  2501.982245
# 3   NAGPUR 2020-09-01    2244  2501.982245
# 4   NAGPUR 2020-10-01    2712  2501.982245
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   NANDED  1238.707279             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   NANDED 2020-06-01    2096  2741.263506
# 1   NANDED 2020-07-01    3902  2741.263506
# 2   NANDED 2020-08-01    4032  2741.263506
# 3   NANDED 2020-09-01    4237  2741.263506
# 4   NANDED 2020-10-01    4756  2741.263506
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  NANDURBAR  521.599471             None         False             False
#
# === Forecast Data ===
#     district       date  actual     forecast  \
# 0  NANDURBAR 2020-06-01    2152  1881.317517
# 1  NANDURBAR 2020-07-01    2523  1881.317517
# 2  NANDURBAR 2020-08-01    2577  1881.317517
# 3  NANDURBAR 2020-09-01    2654  1881.317517
# 4  NANDURBAR 2020-10-01    2593  1881.317517
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   NASHIK  1065.072835             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   NASHIK 2020-06-01    6559  6297.207092
# 1   NASHIK 2020-07-01    7484  6468.881290
# 2   NASHIK 2020-08-01    7551  6643.121313
# 3   NASHIK 2020-09-01    8376  6819.934657
# 4   NASHIK 2020-10-01    7227  6999.328749
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  OSMANABAD  403.375209             None          True             False
#
# === Forecast Data ===
#     district       date  actual    forecast  \
# 0  OSMANABAD 2020-06-01    1465  1511.23183
# 1  OSMANABAD 2020-07-01    1794  1511.23183
# 2  OSMANABAD 2020-08-01    1952  1511.23183
# 3  OSMANABAD 2020-09-01    2171  1511.23183
# 4  OSMANABAD 2020-10-01    2081  1511.23183
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  PALGHAR  630.086139             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  PALGHAR 2020-06-01    4417  4071.970348
# 1  PALGHAR 2020-07-01    4269  4071.970348
# 2  PALGHAR 2020-08-01    4229  4071.970348
# 3  PALGHAR 2020-09-01    4522  4071.970348
# 4  PALGHAR 2020-10-01    5385  4071.970348
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  PARBHANI  527.570572             None         False              True
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  PARBHANI 2020-06-01    1298  1246.589314
# 1  PARBHANI 2020-07-01    1573  1194.180808
# 2  PARBHANI 2020-08-01    1630  1168.124138
# 3  PARBHANI 2020-09-01    1966  1155.169179
# 4  PARBHANI 2020-10-01    1984  1148.728180
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0     PUNE  1951.333645             None         False             False
#
# === Forecast Data ===
#   district       date  actual      forecast  \
# 0     PUNE 2020-06-01   13305  11448.826203
# 1     PUNE 2020-07-01   11790  11448.826203
# 2     PUNE 2020-08-01   12579  11448.826203
# 3     PUNE 2020-09-01   14094  11448.826203
# 4     PUNE 2020-10-01   14381  11448.826203
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   RAIGAD  996.607983             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   RAIGAD 2020-06-01    1924  2714.629135
# 1   RAIGAD 2020-07-01    3532  2672.627563
# 2   RAIGAD 2020-08-01    3912  2639.026306
# 3   RAIGAD 2020-09-01    3990  2612.145300
# 4   RAIGAD 2020-10-01    3615  2590.640495
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  RATNAGIRI  401.454009             None          True             False
#
# === Forecast Data ===
#     district       date  actual     forecast  \
# 0  RATNAGIRI 2020-06-01    1240  1367.644662
# 1  RATNAGIRI 2020-07-01    1387  1388.786460
# 2  RATNAGIRI 2020-08-01    2246  1410.255080
# 3  RATNAGIRI 2020-09-01    1755  1432.055574
# 4  RATNAGIRI 2020-10-01    1658  1454.193071
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   SANGLI  895.480527             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   SANGLI 2020-06-01    2942  2340.244379
# 1   SANGLI 2020-07-01    3899  2340.244379
# 2   SANGLI 2020-08-01    4244  2340.244379
# 3   SANGLI 2020-09-01    2465  2340.244379
# 4   SANGLI 2020-10-01    2330  2340.244379
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   SATARA  365.864126             None         False             False
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0   SATARA 2020-06-01    1957  2009.65505
# 1   SATARA 2020-07-01    1934  2009.65505
# 2   SATARA 2020-08-01    2767  2009.65505
# 3   SATARA 2020-09-01    2016  2009.65505
# 4   SATARA 2020-10-01    2412  2009.65505
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  SINDHUDURG  54.015516             None          True             False
#
# === Forecast Data ===
#      district       date  actual    forecast  \
# 0  SINDHUDURG 2020-06-01     423  411.453806
# 1  SINDHUDURG 2020-07-01     479  411.453806
# 2  SINDHUDURG 2020-08-01     516  411.453806
# 3  SINDHUDURG 2020-09-01     446  411.453806
# 4  SINDHUDURG 2020-10-01     435  411.453806
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  SOLAPUR  1390.512175             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  SOLAPUR 2020-06-01    2283  3334.237848
# 1  SOLAPUR 2020-07-01    2470  3240.808299
# 2  SOLAPUR 2020-08-01    1918  3156.782548
# 3  SOLAPUR 2020-09-01    2558  3081.214091
# 4  SOLAPUR 2020-10-01    2463  3013.251692
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    THANE  2726.684249             None         False             False
#
# === Forecast Data ===
#   district       date  actual      forecast  \
# 0    THANE 2020-06-01    7942  11149.317571
# 1    THANE 2020-07-01    5153  11149.317571
# 2    THANE 2020-08-01   11494  11149.317571
# 3    THANE 2020-09-01   12157  11149.317571
# 4    THANE 2020-10-01   12242  11149.317571
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WARDHA  154.207737             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   WARDHA 2020-06-01    1078  1193.514628
# 1   WARDHA 2020-07-01    1131  1193.514628
# 2   WARDHA 2020-08-01    1326  1193.514628
# 3   WARDHA 2020-09-01    1431  1193.514628
# 4   WARDHA 2020-10-01    1425  1193.514628
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WASHIM  76.77579             None         False             False
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0   WASHIM 2020-06-01     579  594.810947
# 1   WASHIM 2020-07-01     622  596.315752
# 2   WASHIM 2020-08-01     696  597.709351
# 3   WASHIM 2020-09-01     678  598.999962
# 4   WASHIM 2020-10-01     696  600.195197
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  YAVATMAL  437.682535             None         False              True
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  YAVATMAL 2020-06-01    2781  3103.545829
# 1  YAVATMAL 2020-07-01    4215  3320.122967
# 2  YAVATMAL 2020-08-01    3800  3292.459699
# 3  YAVATMAL 2020-09-01    3624  3264.796432
# 4  YAVATMAL 2020-10-01    3708  3237.133164
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#           district         rmse seasonal_periods  box_cox_used  \
# 0  MUMBAI SUBURBAN  2007.225319             None         False
#
#    arma_errors_used
# 0             False
#
# === Forecast Data ===
#           district       date  actual     forecast  \
# 0  MUMBAI SUBURBAN 2021-01-01    5269  6374.011997
# 1  MUMBAI SUBURBAN 2021-02-01    3958  6591.667496
# 2  MUMBAI SUBURBAN 2021-03-01    4827  6809.322994
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual     forecast  \
#  0  MUMBAI SUBURBAN 2021-01-01    5269  6374.011997
#  1  MUMBAI SUBURBAN 2021-02-01    3958  6591.667496
#  2  MUMBAI SUBURBAN 2021-03-01    4827  6809.322994
#
#                                          model_params
#  0  <tbats.tbats.ModelParams.ModelParams object at...
#  1  <tbats.tbats.ModelParams.ModelParams object at...
#  2  <tbats.tbats.ModelParams.ModelParams object at...  ,
#  'metrics_df':           district         rmse seasonal_periods  box_cox_used  \
#  0  MUMBAI SUBURBAN  2007.225319             None         False
#
#     arma_errors_used
#  0             False  ,
#  'model_summary': 'Use Box-Cox: False\nUse trend: True\nUse damped trend: False\nSeasonal periods: []\nSeasonal harmonics []\nARMA errors (p, q): (0, 0)\nSmoothing (Alpha): -0.020100\nTrend (Beta): 0.000100\nDamping Parameter (Phi): 1.000000\nSeasonal Parameters (Gamma): []\nAR coefficients []\nMA coefficients []\nSeed vector [4206.92945336  217.60952707]\n\nAIC 141.290736'}
