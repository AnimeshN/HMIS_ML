# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox

from statsmodels.stats.stattools import durbin_watson
from statsmodels.graphics.tsaplots import plot_acf
from scipy.stats import shapiro
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def linear_regression_lags_only(series, district_name, max_lags=3, differencing=True):
    """
    Simplified linear regression for time series forecasting with:
    - Lag features only
    - Ordinary Least Squares (OLS) regression
    - Optional differencing for stationarity
    """
    # Create directory structure
    os.makedirs('LinearRegression', exist_ok=True)
    
    # 1. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 2. Feature Engineering - Lag features only
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 3. Train-Test Split (time-based)
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 4. Model Training with OLS
    X_train_sm = sm.add_constant(X_train)
    model = sm.OLS(y_train, X_train_sm).fit()

    # 5. Forecasting
    X_test_sm = sm.add_constant(X_test)
    pred_test = model.predict(X_test_sm)

    # 6. Inverse Differencing if applied
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = pred_test.cumsum() + last_train_value
        y_test = original_series.iloc[-len(test):]
    
    # 7. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test.values
    })

    # 8. Save forecasts to CSV
    forecast_csv_path = os.path.join('LinearRegression', 'linear_forecasts_lags_only.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, mode='a', header=write_header, index=False)

    # 9. Calculate metrics
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'r_squared': model.rsquared,
        'params': model.params.to_dict(),
        'differencing': d
    }])

    metrics_csv_path = os.path.join('LinearRegression', 'linear_metrics_lags_only.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, mode='a', header=write_header_metrics, index=False)

    # 10. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', color='darkorange')
    plt.title(f'Linear Regression (Lags Only) Forecast for {district_name}\nRMSE: {rmse:.2f}, R²: {model.rsquared:.2f}')
    plt.legend()
    plt.savefig(os.path.join('LinearRegression', f'Linear_forecast_lags_only_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_summary': model.summary().as_text()
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I48"].asfreq('MS')
        
        results = linear_regression_lags_only(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district       rmse  r_squared  \
# 0  AHMEDNAGAR  86.561445   0.257791
#
#                                               params  differencing
# 0  {'const': 235.67657836377737, 'lag_1': 0.51708...             0
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  AHMEDNAGAR 2020-07-01   354.0  426.112780
# 1  AHMEDNAGAR 2020-08-01   391.0  410.012844
# 2  AHMEDNAGAR 2020-09-01   417.0  431.135392
# 3  AHMEDNAGAR 2020-10-01   343.0  442.979814
# 4  AHMEDNAGAR 2020-11-01   468.0  404.352376
# === Metrics ===
#   district       rmse  r_squared  \
# 0    AKOLA  62.948154   0.019075
#
#                                               params  differencing
# 0  {'const': 461.2308327808144, 'lag_1': 0.099849...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    AKOLA 2020-07-01   407.0  446.324454
# 1    AKOLA 2020-08-01   306.0  442.591805
# 2    AKOLA 2020-09-01   504.0  449.247312
# 3    AKOLA 2020-10-01   493.0  466.364163
# 4    AKOLA 2020-11-01   514.0  467.662061
# === Metrics ===
#    district        rmse  r_squared  \
# 0  AMRAVATI  435.721334   0.259415
#
#                                               params  differencing
# 0  {'const': -15.858518396397905, 'lag_1': -0.514...             1
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  AMRAVATI 2020-07-01     470  345.623108
# 1  AMRAVATI 2020-08-01     482  282.124582
# 2  AMRAVATI 2020-09-01     586  260.525925
# 3  AMRAVATI 2020-10-01     819  192.842632
# 4  AMRAVATI 2020-11-01     609   57.128784
# === Metrics ===
#      district        rmse  r_squared  \
# 0  AURANGABAD  330.874347   0.008415
#
#                                               params  differencing
# 0  {'const': -7.84407622358167, 'lag_1': -0.08389...             1
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  AURANGABAD 2020-07-01     378  426.509600
# 1  AURANGABAD 2020-08-01     729  420.997501
# 2  AURANGABAD 2020-09-01     857  384.080150
# 3  AURANGABAD 2020-10-01     889  372.456870
# 4  AURANGABAD 2020-11-01     837  355.666061
# === Metrics ===
#   district      rmse  r_squared  \
# 0     BEED  71.38753   0.118315
#
#                                               params  differencing
# 0  {'const': 205.68047108698136, 'lag_1': 0.26927...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0     BEED 2020-07-01   465.0  461.969291
# 1     BEED 2020-08-01   554.0  411.707050
# 2     BEED 2020-09-01   485.0  455.756798
# 3     BEED 2020-10-01   495.0  426.260178
# 4     BEED 2020-11-01   472.0  441.686216
# === Metrics ===
#    district       rmse  r_squared  \
# 0  BHANDARA  55.465238   0.411552
#
#                                               params  differencing
# 0  {'const': 147.9570942859728, 'lag_1': 0.716757...             0
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  BHANDARA 2020-07-01   267.0  277.368335
# 1  BHANDARA 2020-08-01   323.0  288.693268
# 2  BHANDARA 2020-09-01   344.0  323.800078
# 3  BHANDARA 2020-10-01   397.0  330.917814
# 4  BHANDARA 2020-11-01   285.0  360.690262
# === Metrics ===
#    district       rmse  r_squared  \
# 0  BULDHANA  43.764661   0.398228
#
#                                               params  differencing
# 0  {'const': 158.26946561567073, 'lag_1': 0.42353...             0
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  BULDHANA 2020-07-01   186.0  208.071841
# 1  BULDHANA 2020-08-01   211.0  224.227372
# 2  BULDHANA 2020-09-01   266.0  221.961263
# 3  BULDHANA 2020-10-01   280.0  259.972610
# 4  BULDHANA 2020-11-01   328.0  274.429225
# === Metrics ===
#      district        rmse  r_squared  \
# 0  CHANDRAPUR  221.263405   0.029451
#
#                                               params  differencing
# 0  {'const': -4.093457679974456, 'lag_1': -0.1188...             1
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  CHANDRAPUR 2020-07-01     445  329.106528
# 1  CHANDRAPUR 2020-08-01     502  316.848452
# 2  CHANDRAPUR 2020-09-01     592  301.738961
# 3  CHANDRAPUR 2020-10-01     628  275.629519
# 4  CHANDRAPUR 2020-11-01     562  259.144121
# === Metrics ===
#   district       rmse  r_squared  \
# 0    DHULE  108.25203   0.221371
#
#                                               params  differencing
# 0  {'const': 226.1743920065731, 'lag_1': 0.511042...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    DHULE 2020-07-01   106.0  317.990324
# 1    DHULE 2020-08-01   142.0  253.114297
# 2    DHULE 2020-09-01   210.0  281.967934
# 3    DHULE 2020-10-01   167.0  316.739929
# 4    DHULE 2020-11-01   356.0  287.168465
# === Metrics ===
#      district       rmse  r_squared  \
# 0  GADCHIROLI  86.393003   0.015568
#
#                                               params  differencing
# 0  {'const': -0.09018139682090154, 'lag_1': 0.105...             1
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  GADCHIROLI 2020-07-01     294  321.536408
# 1  GADCHIROLI 2020-08-01     439  321.292772
# 2  GADCHIROLI 2020-09-01     482  334.033473
# 3  GADCHIROLI 2020-10-01     431  347.409963
# 4  GADCHIROLI 2020-11-01     434  340.600782
# === Metrics ===
#   district        rmse  r_squared  \
# 0   GONDIA  158.769357   0.237667
#
#                                               params  differencing
# 0  {'const': -1.0522517710364063, 'lag_1': -0.546...             1
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   GONDIA 2020-07-01     335  247.115271
# 1   GONDIA 2020-08-01     304  195.679775
# 2   GONDIA 2020-09-01     282  189.872168
# 3   GONDIA 2020-10-01     335  203.168830
# 4   GONDIA 2020-11-01     425  181.097521
# === Metrics ===
#   district       rmse  r_squared  \
# 0  HINGOLI  91.391457   0.297901
#
#                                               params  differencing
# 0  {'const': 94.39677244885166, 'lag_1': 0.613225...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  HINGOLI 2020-07-01   138.0  139.094531
# 1  HINGOLI 2020-08-01    86.0  165.519723
# 2  HINGOLI 2020-09-01   165.0  113.896720
# 3  HINGOLI 2020-10-01   164.0  191.553543
# 4  HINGOLI 2020-11-01   125.0  150.543882
# === Metrics ===
#   district        rmse  r_squared  \
# 0  JALGAON  117.663791   0.299142
#
#                                               params  differencing
# 0  {'const': 109.9196513481661, 'lag_1': 0.262709...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  JALGAON 2020-07-01   244.0  317.312925
# 1  JALGAON 2020-08-01   292.0  282.596508
# 2  JALGAON 2020-09-01   362.0  280.535931
# 3  JALGAON 2020-10-01   415.0  315.891783
# 4  JALGAON 2020-11-01   469.0  356.222754
# === Metrics ===
#   district       rmse  r_squared  \
# 0    JALNA  49.199566   0.122869
#
#                                               params  differencing
# 0  {'const': 135.76358513568593, 'lag_1': 0.25633...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    JALNA 2020-07-01   260.0  221.101499
# 1    JALNA 2020-08-01   218.0  248.597963
# 2    JALNA 2020-09-01   164.0  228.592557
# 3    JALNA 2020-10-01   226.0  234.378112
# 4    JALNA 2020-11-01   211.0  240.783453
# === Metrics ===
#    district       rmse  r_squared  \
# 0  KOLHAPUR  87.014977   0.041098
#
#                                               params  differencing
# 0  {'const': 295.64438905356155, 'lag_1': 0.14044...             0
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  KOLHAPUR 2020-07-01   383.0  376.891928
# 1  KOLHAPUR 2020-08-01   292.0  376.428471
# 2  KOLHAPUR 2020-09-01   390.0  367.519654
# 3  KOLHAPUR 2020-10-01   332.0  368.983513
# 4  KOLHAPUR 2020-11-01   381.0  376.838879
# === Metrics ===
#   district        rmse  r_squared  \
# 0    LATUR  112.037045   0.131859
#
#                                               params  differencing
# 0  {'const': 173.32416354978506, 'lag_1': 0.31127...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    LATUR 2020-07-01   345.0  316.206005
# 1    LATUR 2020-08-01   387.0  317.261899
# 2    LATUR 2020-09-01   426.0  333.460048
# 3    LATUR 2020-10-01   448.0  338.328957
# 4    LATUR 2020-11-01   462.0  349.672043
# === Metrics ===
#   district        rmse  r_squared  \
# 0   MUMBAI  224.010195   0.031342
#
#                                               params  differencing
# 0  {'const': -25.021353367930704, 'lag_1': -0.063...             1
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   MUMBAI 2020-07-01     513  517.807260
# 1   MUMBAI 2020-08-01     579  518.877402
# 2   MUMBAI 2020-09-01     683  480.798549
# 3   MUMBAI 2020-10-01     763  439.974311
# 4   MUMBAI 2020-11-01     583  433.254948
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NAGPUR  195.03299   0.381905
#
#                                               params  differencing
# 0  {'const': 435.4656864411742, 'lag_1': 0.534168...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NAGPUR 2020-07-01   617.0  732.907785
# 1   NAGPUR 2020-08-01   638.0  750.774968
# 2   NAGPUR 2020-09-01   488.0  737.440800
# 3   NAGPUR 2020-10-01   603.0  660.355523
# 4   NAGPUR 2020-11-01   560.0  677.569234
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NANDED  67.430161   0.380684
#
#                                               params  differencing
# 0  {'const': 290.46898233357837, 'lag_1': 0.54897...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NANDED 2020-07-01   261.0  376.979026
# 1   NANDED 2020-08-01   400.0  348.091059
# 2   NANDED 2020-09-01   435.0  425.619391
# 3   NANDED 2020-10-01   391.0  452.166454
# 4   NANDED 2020-11-01   412.0  387.293150
# === Metrics ===
#     district       rmse  r_squared  \
# 0  NANDURBAR  55.391402    0.48106
#
#                                               params  differencing
# 0  {'const': 194.33549772623198, 'lag_1': 0.72936...             0
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  NANDURBAR 2020-07-01   480.0  458.246038
# 1  NANDURBAR 2020-08-01   533.0  494.461742
# 2  NANDURBAR 2020-09-01   497.0  516.578454
# 3  NANDURBAR 2020-10-01   568.0  483.318041
# 4  NANDURBAR 2020-11-01   511.0  524.941591
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NASHIK  84.925959   0.342427
#
#                                               params  differencing
# 0  {'const': 549.9343999911197, 'lag_1': 0.595312...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NASHIK 2020-07-01   975.0   916.168626
# 1   NASHIK 2020-08-01  1023.0  1001.018431
# 2   NASHIK 2020-09-01  1143.0  1048.204720
# 3   NASHIK 2020-10-01  1264.0  1088.803299
# 4   NASHIK 2020-11-01  1037.0  1156.653727
# === Metrics ===
#     district       rmse  r_squared  \
# 0  OSMANABAD  37.492386   0.105651
#
#                                               params  differencing
# 0  {'const': 140.50175967047838, 'lag_1': 0.31222...             0
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  OSMANABAD 2020-07-01   177.0  172.657424
# 1  OSMANABAD 2020-08-01   234.0  168.314920
# 2  OSMANABAD 2020-09-01   190.0  189.561195
# 3  OSMANABAD 2020-10-01   248.0  173.458842
# 4  OSMANABAD 2020-11-01   189.0  188.911209
# === Metrics ===
#   district        rmse  r_squared  \
# 0  PALGHAR  132.492257   0.257295
#
#                                               params  differencing
# 0  {'const': 319.7667412683377, 'lag_1': 0.258233...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  PALGHAR 2020-07-01   784.0  800.969302
# 1  PALGHAR 2020-08-01   785.0  793.168738
# 2  PALGHAR 2020-09-01   795.0  784.964946
# 3  PALGHAR 2020-10-01  1020.0  788.452279
# 4  PALGHAR 2020-11-01  1006.0  850.114847
# === Metrics ===
#    district       rmse  r_squared  \
# 0  PARBHANI  66.924359   0.472205
#
#                                               params  differencing
# 0  {'const': 74.8885789938117, 'lag_1': 0.7878083...             0
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  PARBHANI 2020-07-01   257.0  160.855539
# 1  PARBHANI 2020-08-01   232.0  255.061261
# 2  PARBHANI 2020-09-01   291.0  203.345621
# 3  PARBHANI 2020-10-01   315.0  268.390293
# 4  PARBHANI 2020-11-01   205.0  269.018971
# === Metrics ===
#   district        rmse  r_squared  \
# 0     PUNE  400.300426   0.200075
#
#                                               params  differencing
# 0  {'const': 1412.8823002535712, 'lag_1': 0.35726...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     PUNE 2020-07-01  1326.0  1758.917820
# 1     PUNE 2020-08-01  1529.0  1702.413100
# 2     PUNE 2020-09-01  1439.0  1807.151652
# 3     PUNE 2020-10-01  1349.0  1791.019086
# 4     PUNE 2020-11-01  1578.0  1695.428438
# === Metrics ===
#   district       rmse  r_squared  \
# 0   RAIGAD  67.727457   0.268962
#
#                                               params  differencing
# 0  {'const': 293.9562698032447, 'lag_1': 0.430864...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   RAIGAD 2020-07-01   420.0  403.020733
# 1   RAIGAD 2020-08-01   459.0  352.646190
# 2   RAIGAD 2020-09-01   475.0  386.614967
# 3   RAIGAD 2020-10-01   491.0  398.823081
# 4   RAIGAD 2020-11-01   465.0  393.979896
# === Metrics ===
#     district        rmse  r_squared  \
# 0  RATNAGIRI  215.128066   0.242496
#
#                                               params  differencing
# 0  {'const': 6.5165514346526265, 'lag_1': -0.2045...             1
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  RATNAGIRI 2020-07-01     203  375.605232
# 1  RATNAGIRI 2020-08-01     179  275.153421
# 2  RATNAGIRI 2020-09-01     255  404.892848
# 3  RATNAGIRI 2020-10-01     253  459.753988
# 4  RATNAGIRI 2020-11-01     257  414.580099
# === Metrics ===
#   district       rmse  r_squared  \
# 0   SANGLI  77.790383   0.393149
#
#                                               params  differencing
# 0  {'const': 153.97027447607223, 'lag_1': 0.34215...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   SANGLI 2020-07-01   547.0  422.571503
# 1   SANGLI 2020-08-01   406.0  480.506613
# 2   SANGLI 2020-09-01   461.0  461.483218
# 3   SANGLI 2020-10-01   373.0  452.322177
# 4   SANGLI 2020-11-01   410.0  423.735761
# === Metrics ===
#   district        rmse  r_squared  \
# 0   SATARA  124.312497   0.199399
#
#                                               params  differencing
# 0  {'const': 293.14868235705006, 'lag_1': 0.48926...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   SATARA 2020-07-01   347.0  426.028816
# 1   SATARA 2020-08-01   349.0  422.814317
# 2   SATARA 2020-09-01   446.0  418.088188
# 3   SATARA 2020-10-01   494.0  464.432191
# 4   SATARA 2020-11-01   518.0  458.856958
# === Metrics ===
#      district       rmse  r_squared  \
# 0  SINDHUDURG  21.003867   0.043331
#
#                                               params  differencing
# 0  {'const': 103.51777200728702, 'lag_1': 0.10481...             0
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01   121.0  119.470960
# 1  SINDHUDURG 2020-08-01    97.0  119.735283
# 2  SINDHUDURG 2020-09-01   141.0  118.061942
# 3  SINDHUDURG 2020-10-01   144.0  118.608632
# 4  SINDHUDURG 2020-11-01   117.0  128.068521
# === Metrics ===
#   district       rmse  r_squared  \
# 0  SOLAPUR  98.270383   0.365822
#
#                                               params  differencing
# 0  {'const': 195.6265490535493, 'lag_1': 0.569379...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  SOLAPUR 2020-07-01   410.0  407.440892
# 1  SOLAPUR 2020-08-01   405.0  448.499743
# 2  SOLAPUR 2020-09-01   654.0  450.208886
# 3  SOLAPUR 2020-10-01   535.0  593.764418
# 4  SOLAPUR 2020-11-01   622.0  534.848876
# === Metrics ===
#   district        rmse  r_squared  \
# 0    THANE  242.127446   0.058253
#
#                                               params  differencing
# 0  {'const': -11.400555152730387, 'lag_1': -0.107...             1
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    THANE 2020-07-01     708  749.463869
# 1    THANE 2020-08-01     893  776.400452
# 2    THANE 2020-09-01     916  745.435614
# 3    THANE 2020-10-01    1156  692.380886
# 4    THANE 2020-11-01     848  659.193961
# === Metrics ===
#   district       rmse  r_squared  \
# 0   WARDHA  50.591603   0.283391
#
#                                               params  differencing
# 0  {'const': 138.75327492388553, 'lag_1': 0.52389...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WARDHA 2020-07-01   179.0  203.712485
# 1   WARDHA 2020-08-01   192.0  204.060371
# 2   WARDHA 2020-09-01   251.0  210.257595
# 3   WARDHA 2020-10-01   241.0  241.781338
# 4   WARDHA 2020-11-01   231.0  235.930570
# === Metrics ===
#   district       rmse  r_squared  \
# 0   WASHIM  21.184196   0.293019
#
#                                               params  differencing
# 0  {'const': 52.73763776336138, 'lag_1': 0.439890...             0
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WASHIM 2020-07-01   154.0  113.476595
# 1   WASHIM 2020-08-01   127.0  135.223563
# 2   WASHIM 2020-09-01   120.0  124.363373
# 3   WASHIM 2020-10-01   113.0  123.544104
# 4   WASHIM 2020-11-01   154.0  118.057648
# === Metrics ===
#    district       rmse  r_squared  \
# 0  YAVATMAL  24.900824   0.498803
#
#                                               params  differencing
# 0  {'const': 52.08814483318436, 'lag_1': 0.698758...             0
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  YAVATMAL 2020-07-01   148.0  162.731864
# 1  YAVATMAL 2020-08-01   201.0  161.006356
# 2  YAVATMAL 2020-09-01   225.0  200.073574
# 3  YAVATMAL 2020-10-01   182.0  213.630570
# 4  YAVATMAL 2020-11-01   174.0  187.674082
# === Metrics ===
#           district       rmse  r_squared  \
# 0  MUMBAI SUBURBAN  124.14347    0.41352
#
#                                               params  differencing
# 0  {'const': 1320.1656744794452, 'lag_1': 0.25494...             0
#
# === Forecast Data ===
#           district       date  actual    forecast
# 0  MUMBAI SUBURBAN 2021-02-01   607.0  664.423725
# 1  MUMBAI SUBURBAN 2021-03-01   618.0  783.908764
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual    forecast
#  0  MUMBAI SUBURBAN 2021-02-01   607.0  664.423725
#  1  MUMBAI SUBURBAN 2021-03-01   618.0  783.908764,
#  'metrics_df':           district       rmse  r_squared  \
#  0  MUMBAI SUBURBAN  124.14347    0.41352
#
#                                                params  differencing
#  0  {'const': 1320.1656744794452, 'lag_1': 0.25494...             0  ,
#  'model_summary': '                            OLS Regression Results                            \n==============================================================================\nDep. Variable:                      y   R-squared:                       0.414\nModel:                            OLS   Adj. R-squared:                 -0.173\nMethod:                 Least Squares   F-statistic:                    0.7051\nDate:                Tue, 29 Apr 2025   Prob (F-statistic):              0.610\nTime:                        11:43:41   Log-Likelihood:                -42.940\nNo. Observations:                   7   AIC:                             93.88\nDf Residuals:                       3   BIC:                             93.66\nDf Model:                           3                                         \nCovariance Type:            nonrobust                                         \n==============================================================================\n                 coef    std err          t      P>|t|      [0.025      0.975]\n------------------------------------------------------------------------------\nconst       1320.1657    650.810      2.028      0.136    -751.003    3391.335\nlag_1          0.2549      0.511      0.499      0.652      -1.372       1.882\nlag_2         -0.3471      0.489     -0.709      0.529      -1.905       1.210\nlag_3         -0.5393      0.474     -1.138      0.338      -2.047       0.969\n==============================================================================\nOmnibus:                          nan   Durbin-Watson:                   2.606\nProb(Omnibus):                    nan   Jarque-Bera (JB):                0.172\nSkew:                           0.043   Prob(JB):                        0.918\nKurtosis:                       2.237   Cond. No.                     1.45e+04\n==============================================================================\n\nNotes:\n[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.\n[2] The condition number is large, 1.45e+04. This might indicate that there are\nstrong multicollinearity or other numerical problems.'}
