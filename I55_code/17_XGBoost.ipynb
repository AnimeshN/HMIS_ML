# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from xgboost import XGBRegressor

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def xgboost_forecast_lags(
    series,
    district_name,
    max_lags=12,
    differencing=True,
    use_cv=True,
    cv_params=None,
    custom_params=None
):
    """
    XGBoost time series forecasting with error handling
    Returns (None, None) if insufficient data, allowing pipeline continuation
    """
    try:
        # 1. Directory setup
        os.makedirs('XGBoost_Forecasts', exist_ok=True)
        
        # 2. Stationarity and differencing
        original_series = series.copy()
        d = 0
        if differencing:
            adf_result = adfuller(series.dropna())
            if adf_result[1] > 0.05:
                d = 1
                series = series.diff().dropna()
                if len(series) < 5:  # Check after differencing
                    raise ValueError(f"Series too short after differencing: {len(series)}")

        # 3. Create lag features with validation
        df = pd.DataFrame({'y': series.astype(float)})
        for lag in range(1, max_lags + 1):
            df[f'lag_{lag}'] = df['y'].shift(lag)
        df = df.dropna()
        
        if len(df) < 10:
            raise ValueError(f"Only {len(df)} samples after lag features")

        # 4. Temporal split validation
        train_size = int(len(df) * 0.8)
        if train_size < 5 or (len(df) - train_size) < 2:
            raise ValueError(f"Insufficient split: {train_size} train, {len(df)-train_size} test")
            
        train = df.iloc[:train_size]
        test = df.iloc[train_size:]

        X_train = train.drop(columns=['y'])
        y_train = train['y']
        X_test = test.drop(columns=['y'])
        y_test = test['y']

        # 5. Dynamic cross-validation setup
        xgb_params = custom_params or {
            'n_estimators': 500,
            'learning_rate': 0.05,
            'max_depth': 3,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': 42
        }
        
        if use_cv:
            n_splits = min(5, max(2, len(X_train)//2))  # Ensure 2 ≤ splits ≤5
            param_grid = cv_params or {
                'n_estimators': [100, 300],
                'learning_rate': [0.01, 0.05],
                'max_depth': [3, 5]
            }
            tscv = TimeSeriesSplit(n_splits=n_splits)
            
            grid_search = GridSearchCV(
                XGBRegressor(**xgb_params, verbosity=0),
                param_grid,
                cv=tscv,
                scoring='neg_mean_squared_error',
                n_jobs=-1
            )
            grid_search.fit(X_train, y_train)
            model = grid_search.best_estimator_
            best_params = grid_search.best_params_
        else:
            model = XGBRegressor(**xgb_params, verbosity=0)
            model.fit(X_train, y_train)
            best_params = xgb_params

        # 6. Forecasting and post-processing
        pred_test = model.predict(X_test)

        if d == 1:
            last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
            pred_test = np.cumsum(pred_test) + last_train_value
            y_test = original_series.iloc[-len(test):]

        # 7. Save results
        forecast_df = pd.DataFrame({
            'district': district_name,
            'date': y_test.index,
            'actual': y_test.values,
            'forecast': pred_test
        })
        forecast_df.to_csv(
            os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.csv'), 
            index=False
        )

        # 8. Metrics and visualization
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        
        plt.figure(figsize=(14, 7))
        plt.plot(original_series.index, original_series, label='Original')
        plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', alpha=0.7)
        plt.title(f'{district_name} Forecast (RMSE: {rmse:.2f})')
        plt.legend()
        plt.savefig(os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.png'))
        plt.close()

        return {
            'district': district_name,
            'rmse': rmse,
            'best_params': best_params,
            'differencing': d,
            'feature_importances': dict(zip(X_train.columns, model.feature_importances_))
        }, forecast_df

    except (ValueError, IndexError) as e:
        print(f"⚠️ Skipping {district_name}: {str(e)}")
        return None, None

# %%
districts = data['district'].unique()
rmse_values = []

# Usage Example


def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I48"].asfreq('MS')
        
        results, forecast = xgboost_forecast_lags(
            series=ts,  # pd.Series with DatetimeIndex
            district_name=district,
            max_lags=6,
            use_cv=True,
            cv_params={
                'n_estimators': [200, 500],
                'learning_rate': [0.05, 0.1],
                'max_depth': [3, 5]
            },
            custom_params={
                'subsample': 0.8,
                'colsample_bytree': 0.8,
                'random_state': 42
            }
        )

        
    
        # Show results
        print("=== Metrics ===")
        print(results)
        print("\n=== Forecast Data ===")
        print(forecast)
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
# {'district': 'AHMEDNAGAR', 'rmse': 82.0274910157311, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.29355434, 'lag_2': 0.110317685, 'lag_3': 0.13055982, 'lag_4': 0.13428164, 'lag_5': 0.15779209, 'lag_6': 0.1734944}}
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  AHMEDNAGAR 2020-07-01   354.0  414.289917
# 1  AHMEDNAGAR 2020-08-01   391.0  453.398651
# 2  AHMEDNAGAR 2020-09-01   417.0  412.170135
# 3  AHMEDNAGAR 2020-10-01   343.0  408.295044
# 4  AHMEDNAGAR 2020-11-01   468.0  456.265961
# 5  AHMEDNAGAR 2020-12-01   305.0  434.479095
# 6  AHMEDNAGAR 2021-01-01   372.0  397.441833
# 7  AHMEDNAGAR 2021-02-01   301.0  410.189423
# 8  AHMEDNAGAR 2021-03-01   316.0  454.813568
# === Metrics ===
# {'district': 'AKOLA', 'rmse': 71.93641293628302, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.12618703, 'lag_2': 0.14268354, 'lag_3': 0.112438284, 'lag_4': 0.32903233, 'lag_5': 0.12855227, 'lag_6': 0.16110657}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    AKOLA 2020-07-01   407.0  389.056274
# 1    AKOLA 2020-08-01   306.0  388.958130
# 2    AKOLA 2020-09-01   504.0  457.272675
# 3    AKOLA 2020-10-01   493.0  469.514648
# 4    AKOLA 2020-11-01   514.0  477.530731
# 5    AKOLA 2020-12-01   450.0  471.844238
# 6    AKOLA 2021-01-01   481.0  460.839264
# 7    AKOLA 2021-02-01   416.0  474.731842
# 8    AKOLA 2021-03-01   363.0  538.987305
# === Metrics ===
# {'district': 'AMRAVATI', 'rmse': 182.36209216062852, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.437702, 'lag_2': 0.073079035, 'lag_3': 0.22792578, 'lag_4': 0.05911063, 'lag_5': 0.052459784, 'lag_6': 0.14972277}}
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  AMRAVATI 2020-07-01     470  388.095245
# 1  AMRAVATI 2020-08-01     482  481.645203
# 2  AMRAVATI 2020-09-01     586  593.235901
# 3  AMRAVATI 2020-10-01     819  684.421753
# 4  AMRAVATI 2020-11-01     609  712.672546
# 5  AMRAVATI 2020-12-01     634  679.460693
# 6  AMRAVATI 2021-01-01     472  310.543518
# 7  AMRAVATI 2021-02-01     753  287.922516
# 8  AMRAVATI 2021-03-01     457  318.251007
# === Metrics ===
# {'district': 'AURANGABAD', 'rmse': 525.3903010501517, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.078033134, 'lag_2': 0.1265186, 'lag_3': 0.11509931, 'lag_4': 0.33640674, 'lag_5': 0.09852999, 'lag_6': 0.24541222}}
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  AURANGABAD 2020-07-01     378  367.445648
# 1  AURANGABAD 2020-08-01     729  312.680908
# 2  AURANGABAD 2020-09-01     857  333.985474
# 3  AURANGABAD 2020-10-01     889  214.462708
# 4  AURANGABAD 2020-11-01     837  152.742462
# 5  AURANGABAD 2020-12-01     522   90.826080
# 6  AURANGABAD 2021-01-01     685   23.341339
# 7  AURANGABAD 2021-02-01     477   -2.595123
# 8  AURANGABAD 2021-03-01     489  -21.307739
# === Metrics ===
# {'district': 'BEED', 'rmse': 58.949493552727446, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.36923236, 'lag_2': 0.10186262, 'lag_3': 0.17397049, 'lag_4': 0.13379227, 'lag_5': 0.1200964, 'lag_6': 0.10104591}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0     BEED 2020-07-01   465.0  441.608948
# 1     BEED 2020-08-01   554.0  452.862213
# 2     BEED 2020-09-01   485.0  548.916321
# 3     BEED 2020-10-01   495.0  481.446869
# 4     BEED 2020-11-01   472.0  474.259857
# 5     BEED 2020-12-01   561.0  480.989044
# 6     BEED 2021-01-01   439.0  479.138824
# 7     BEED 2021-02-01   414.0  488.757965
# 8     BEED 2021-03-01   439.0  490.221771
# === Metrics ===
# {'district': 'BHANDARA', 'rmse': 83.31942479559203, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.5438506, 'lag_2': 0.09060122, 'lag_3': 0.09489364, 'lag_4': 0.07190012, 'lag_5': 0.09752509, 'lag_6': 0.10122944}}
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  BHANDARA 2020-07-01   267.0  248.187317
# 1  BHANDARA 2020-08-01   323.0  280.288910
# 2  BHANDARA 2020-09-01   344.0  261.762177
# 3  BHANDARA 2020-10-01   397.0  272.841064
# 4  BHANDARA 2020-11-01   285.0  434.982727
# 5  BHANDARA 2020-12-01   316.0  306.513184
# 6  BHANDARA 2021-01-01   194.0  270.864471
# 7  BHANDARA 2021-02-01   173.0  267.137054
# 8  BHANDARA 2021-03-01   225.0  252.708008
# === Metrics ===
# {'district': 'BULDHANA', 'rmse': 47.65829489939117, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.16019058, 'lag_2': 0.23027492, 'lag_3': 0.111876205, 'lag_4': 0.23902997, 'lag_5': 0.17031513, 'lag_6': 0.08831323}}
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  BULDHANA 2020-07-01   186.0  188.410919
# 1  BULDHANA 2020-08-01   211.0  230.616699
# 2  BULDHANA 2020-09-01   266.0  201.552704
# 3  BULDHANA 2020-10-01   280.0  272.397186
# 4  BULDHANA 2020-11-01   328.0  268.595551
# 5  BULDHANA 2020-12-01   268.0  267.358459
# 6  BULDHANA 2021-01-01   168.0  223.007172
# 7  BULDHANA 2021-02-01   139.0  233.268036
# 8  BULDHANA 2021-03-01   195.0  175.040497
# === Metrics ===
# {'district': 'CHANDRAPUR', 'rmse': 191.25551279714205, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.072774336, 'lag_2': 0.116640046, 'lag_3': 0.07810891, 'lag_4': 0.26810443, 'lag_5': 0.28429568, 'lag_6': 0.18007654}}
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  CHANDRAPUR 2020-07-01     445  323.568909
# 1  CHANDRAPUR 2020-08-01     502  335.309448
# 2  CHANDRAPUR 2020-09-01     592  305.249420
# 3  CHANDRAPUR 2020-10-01     628  317.455719
# 4  CHANDRAPUR 2020-11-01     562  284.796967
# 5  CHANDRAPUR 2020-12-01     467  320.792969
# 6  CHANDRAPUR 2021-01-01     385  336.880371
# 7  CHANDRAPUR 2021-02-01     422  397.297577
# 8  CHANDRAPUR 2021-03-01     385  467.881958
# === Metrics ===
# {'district': 'DHULE', 'rmse': 117.89559667130321, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.23235756, 'lag_2': 0.08911002, 'lag_3': 0.09528876, 'lag_4': 0.15868755, 'lag_5': 0.22131433, 'lag_6': 0.2032418}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    DHULE 2020-07-01   106.0  349.445557
# 1    DHULE 2020-08-01   142.0  201.777588
# 2    DHULE 2020-09-01   210.0  204.339386
# 3    DHULE 2020-10-01   167.0  199.300018
# 4    DHULE 2020-11-01   356.0  271.773468
# 5    DHULE 2020-12-01   294.0  284.742645
# 6    DHULE 2021-01-01   398.0  239.353668
# 7    DHULE 2021-02-01   333.0  460.017242
# 8    DHULE 2021-03-01   368.0  255.314301
# === Metrics ===
# {'district': 'GADCHIROLI', 'rmse': 76.52420755313993, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.058404174, 'lag_2': 0.058531243, 'lag_3': 0.18642232, 'lag_4': 0.22891486, 'lag_5': 0.17297286, 'lag_6': 0.29475453}}
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  GADCHIROLI 2020-07-01     294  332.693604
# 1  GADCHIROLI 2020-08-01     439  398.991394
# 2  GADCHIROLI 2020-09-01     482  428.342682
# 3  GADCHIROLI 2020-10-01     431  445.715851
# 4  GADCHIROLI 2020-11-01     434  433.737701
# 5  GADCHIROLI 2020-12-01     399  413.942566
# 6  GADCHIROLI 2021-01-01     360  387.317474
# 7  GADCHIROLI 2021-02-01     235  385.871521
# 8  GADCHIROLI 2021-03-01     272  422.924591
# === Metrics ===
# {'district': 'GONDIA', 'rmse': 142.86056991803662, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.12614104, 'lag_2': 0.10626827, 'lag_3': 0.09550513, 'lag_4': 0.19967787, 'lag_5': 0.2832588, 'lag_6': 0.18914892}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   GONDIA 2020-07-01     335  338.023010
# 1   GONDIA 2020-08-01     304  300.678131
# 2   GONDIA 2020-09-01     282  371.634583
# 3   GONDIA 2020-10-01     335  396.864990
# 4   GONDIA 2020-11-01     425  425.755310
# 5   GONDIA 2020-12-01     365  405.769653
# 6   GONDIA 2021-01-01     314  540.179321
# 7   GONDIA 2021-02-01     254  533.591797
# 8   GONDIA 2021-03-01     336  538.012573
# === Metrics ===
# {'district': 'HINGOLI', 'rmse': 88.96269241768844, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.19327791, 'lag_2': 0.07219639, 'lag_3': 0.068067364, 'lag_4': 0.26706344, 'lag_5': 0.22291823, 'lag_6': 0.17647667}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  HINGOLI 2020-07-01   138.0  178.448074
# 1  HINGOLI 2020-08-01    86.0  196.459869
# 2  HINGOLI 2020-09-01   165.0  123.591049
# 3  HINGOLI 2020-10-01   164.0  131.010773
# 4  HINGOLI 2020-11-01   125.0  168.147156
# 5  HINGOLI 2020-12-01    79.0  117.689697
# 6  HINGOLI 2021-01-01   296.0  175.389191
# 7  HINGOLI 2021-02-01   102.0  293.461426
# 8  HINGOLI 2021-03-01   126.0  131.080490
# === Metrics ===
# {'district': 'JALGAON', 'rmse': 121.52414916732934, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.11956976, 'lag_2': 0.21497525, 'lag_3': 0.1881183, 'lag_4': 0.22863297, 'lag_5': 0.11081776, 'lag_6': 0.13788591}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  JALGAON 2020-07-01   244.0  351.830719
# 1  JALGAON 2020-08-01   292.0  310.955841
# 2  JALGAON 2020-09-01   362.0  250.858612
# 3  JALGAON 2020-10-01   415.0  291.125916
# 4  JALGAON 2020-11-01   469.0  329.826508
# 5  JALGAON 2020-12-01   593.0  359.809265
# 6  JALGAON 2021-01-01   340.0  397.132050
# 7  JALGAON 2021-02-01   239.0  350.852722
# 8  JALGAON 2021-03-01   243.0  303.883514
# === Metrics ===
# {'district': 'JALNA', 'rmse': 65.9105732850999, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.34564543, 'lag_2': 0.2400161, 'lag_3': 0.15951486, 'lag_4': 0.07872234, 'lag_5': 0.104484685, 'lag_6': 0.07161658}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    JALNA 2020-07-01   260.0  201.399857
# 1    JALNA 2020-08-01   218.0  195.531876
# 2    JALNA 2020-09-01   164.0  250.231873
# 3    JALNA 2020-10-01   226.0  235.517517
# 4    JALNA 2020-11-01   211.0  213.566635
# 5    JALNA 2020-12-01   163.0  252.317291
# 6    JALNA 2021-01-01   184.0  212.005554
# 7    JALNA 2021-02-01   166.0  220.220734
# 8    JALNA 2021-03-01   149.0  275.190948
# === Metrics ===
# {'district': 'KOLHAPUR', 'rmse': 89.76058568234706, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.13748486, 'lag_2': 0.14350004, 'lag_3': 0.14758697, 'lag_4': 0.17521513, 'lag_5': 0.21967694, 'lag_6': 0.17653607}}
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  KOLHAPUR 2020-07-01   383.0  404.616730
# 1  KOLHAPUR 2020-08-01   292.0  320.366730
# 2  KOLHAPUR 2020-09-01   390.0  337.947510
# 3  KOLHAPUR 2020-10-01   332.0  404.915619
# 4  KOLHAPUR 2020-11-01   381.0  429.143188
# 5  KOLHAPUR 2020-12-01   365.0  383.198883
# 6  KOLHAPUR 2021-01-01   395.0  373.573517
# 7  KOLHAPUR 2021-02-01   621.0  377.198456
# 8  KOLHAPUR 2021-03-01   408.0  382.167694
# === Metrics ===
# {'district': 'LATUR', 'rmse': 113.23674226118895, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.20859277, 'lag_2': 0.08886022, 'lag_3': 0.24216188, 'lag_4': 0.20717803, 'lag_5': 0.15699115, 'lag_6': 0.09621583}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    LATUR 2020-07-01   345.0  320.108459
# 1    LATUR 2020-08-01   387.0  249.152573
# 2    LATUR 2020-09-01   426.0  300.799072
# 3    LATUR 2020-10-01   448.0  314.828613
# 4    LATUR 2020-11-01   462.0  308.358093
# 5    LATUR 2020-12-01   367.0  413.386108
# 6    LATUR 2021-01-01   570.0  438.166199
# 7    LATUR 2021-02-01   322.0  413.975952
# 8    LATUR 2021-03-01   401.0  297.200134
# === Metrics ===
# {'district': 'MUMBAI', 'rmse': 378.80399003848316, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.057627246, 'lag_2': 0.09763785, 'lag_3': 0.31686488, 'lag_4': 0.2627991, 'lag_5': 0.08968117, 'lag_6': 0.17538978}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   MUMBAI 2020-07-01     513  115.275879
# 1   MUMBAI 2020-08-01     579  219.366516
# 2   MUMBAI 2020-09-01     683  241.719513
# 3   MUMBAI 2020-10-01     763  202.671326
# 4   MUMBAI 2020-11-01     583  350.245178
# 5   MUMBAI 2020-12-01     934  425.122314
# 6   MUMBAI 2021-01-01     474  282.537903
# 7   MUMBAI 2021-02-01     543  297.339386
# 8   MUMBAI 2021-03-01     484  192.321106
# === Metrics ===
# {'district': 'NAGPUR', 'rmse': 247.52365163392955, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.32258523, 'lag_2': 0.12864843, 'lag_3': 0.062004626, 'lag_4': 0.12165543, 'lag_5': 0.13142733, 'lag_6': 0.23367898}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NAGPUR 2020-07-01   617.0  649.190430
# 1   NAGPUR 2020-08-01   638.0  711.520813
# 2   NAGPUR 2020-09-01   488.0  810.976868
# 3   NAGPUR 2020-10-01   603.0  803.190918
# 4   NAGPUR 2020-11-01   560.0  811.652954
# 5   NAGPUR 2020-12-01   819.0  650.051636
# 6   NAGPUR 2021-01-01   599.0  689.815430
# 7   NAGPUR 2021-02-01   374.0  676.029297
# 8   NAGPUR 2021-03-01   416.0  873.425110
# === Metrics ===
# {'district': 'NANDED', 'rmse': 62.882970096574866, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.369816, 'lag_2': 0.09228024, 'lag_3': 0.10476926, 'lag_4': 0.143454, 'lag_5': 0.09261124, 'lag_6': 0.1970692}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NANDED 2020-07-01   261.0  326.990479
# 1   NANDED 2020-08-01   400.0  333.016785
# 2   NANDED 2020-09-01   435.0  411.353516
# 3   NANDED 2020-10-01   391.0  461.183105
# 4   NANDED 2020-11-01   412.0  421.830627
# 5   NANDED 2020-12-01   334.0  424.802277
# 6   NANDED 2021-01-01   287.0  383.693481
# 7   NANDED 2021-02-01   220.0  279.234467
# 8   NANDED 2021-03-01   285.0  277.123047
# === Metrics ===
# {'district': 'NANDURBAR', 'rmse': 87.61789057828372, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.4823602, 'lag_2': 0.08299615, 'lag_3': 0.060609207, 'lag_4': 0.11188088, 'lag_5': 0.17060779, 'lag_6': 0.09154577}}
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  NANDURBAR 2020-07-01   480.0  285.293701
# 1  NANDURBAR 2020-08-01   533.0  432.230225
# 2  NANDURBAR 2020-09-01   497.0  550.161194
# 3  NANDURBAR 2020-10-01   568.0  464.462067
# 4  NANDURBAR 2020-11-01   511.0  497.521210
# 5  NANDURBAR 2020-12-01   505.0  462.539917
# 6  NANDURBAR 2021-01-01   342.0  389.546173
# 7  NANDURBAR 2021-02-01   363.0  408.117065
# 8  NANDURBAR 2021-03-01   354.0  319.358673
# === Metrics ===
# {'district': 'NASHIK', 'rmse': 126.73475574561292, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.2568483, 'lag_2': 0.07916242, 'lag_3': 0.09965006, 'lag_4': 0.23467842, 'lag_5': 0.22679849, 'lag_6': 0.10286235}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NASHIK 2020-07-01   975.0   966.539307
# 1   NASHIK 2020-08-01  1023.0   920.416687
# 2   NASHIK 2020-09-01  1143.0   987.322449
# 3   NASHIK 2020-10-01  1264.0  1028.327515
# 4   NASHIK 2020-11-01  1037.0  1126.889771
# 5   NASHIK 2020-12-01   976.0  1103.080933
# 6   NASHIK 2021-01-01   882.0   836.737183
# 7   NASHIK 2021-02-01   909.0   843.093201
# 8   NASHIK 2021-03-01  1000.0   846.503479
# === Metrics ===
# {'district': 'OSMANABAD', 'rmse': 33.874981044275806, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.24589637, 'lag_2': 0.09062412, 'lag_3': 0.13673274, 'lag_4': 0.17484297, 'lag_5': 0.14354335, 'lag_6': 0.20836042}}
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  OSMANABAD 2020-07-01   177.0  174.020752
# 1  OSMANABAD 2020-08-01   234.0  180.462952
# 2  OSMANABAD 2020-09-01   190.0  178.156204
# 3  OSMANABAD 2020-10-01   248.0  178.823135
# 4  OSMANABAD 2020-11-01   189.0  180.073929
# 5  OSMANABAD 2020-12-01   200.0  165.775299
# 6  OSMANABAD 2021-01-01   138.0  169.495941
# 7  OSMANABAD 2021-02-01   133.0  149.489349
# 8  OSMANABAD 2021-03-01   169.0  165.546646
# === Metrics ===
# {'district': 'PALGHAR', 'rmse': 190.01196758499466, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.11197359, 'lag_2': 0.31597283, 'lag_3': 0.1617977, 'lag_4': 0.24636175, 'lag_5': 0.07879203, 'lag_6': 0.08510213}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  PALGHAR 2020-07-01   784.0  753.114563
# 1  PALGHAR 2020-08-01   785.0  681.117126
# 2  PALGHAR 2020-09-01   795.0  695.786926
# 3  PALGHAR 2020-10-01  1020.0  669.720825
# 4  PALGHAR 2020-11-01  1006.0  746.181946
# 5  PALGHAR 2020-12-01   948.0  822.799622
# 6  PALGHAR 2021-01-01   784.0  892.661621
# 7  PALGHAR 2021-02-01   589.0  875.100159
# 8  PALGHAR 2021-03-01   678.0  739.769165
# === Metrics ===
# {'district': 'PARBHANI', 'rmse': 76.48249656774473, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.3362193, 'lag_2': 0.12000568, 'lag_3': 0.12767385, 'lag_4': 0.17583828, 'lag_5': 0.13840139, 'lag_6': 0.10186143}}
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  PARBHANI 2020-07-01   257.0  117.332726
# 1  PARBHANI 2020-08-01   232.0  195.809021
# 2  PARBHANI 2020-09-01   291.0  208.074158
# 3  PARBHANI 2020-10-01   315.0  266.348206
# 4  PARBHANI 2020-11-01   205.0  297.437561
# 5  PARBHANI 2020-12-01   179.0  194.773407
# 6  PARBHANI 2021-01-01   287.0  172.548615
# 7  PARBHANI 2021-02-01   196.0  202.687210
# 8  PARBHANI 2021-03-01   212.0  186.536652
# === Metrics ===
# {'district': 'PUNE', 'rmse': 178.205901859933, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.2971425, 'lag_2': 0.087583214, 'lag_3': 0.067093834, 'lag_4': 0.107737474, 'lag_5': 0.1193118, 'lag_6': 0.3211312}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     PUNE 2020-07-01  1326.0  1396.334961
# 1     PUNE 2020-08-01  1529.0  1434.290283
# 2     PUNE 2020-09-01  1439.0  1484.083984
# 3     PUNE 2020-10-01  1349.0  1455.392456
# 4     PUNE 2020-11-01  1578.0  1435.623779
# 5     PUNE 2020-12-01  1364.0  1478.149292
# 6     PUNE 2021-01-01  1384.0  1582.951294
# 7     PUNE 2021-02-01  1070.0  1439.871460
# 8     PUNE 2021-03-01  1211.0  1432.042236
# === Metrics ===
# {'district': 'RAIGAD', 'rmse': 90.07957517386266, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.23582852, 'lag_2': 0.113891974, 'lag_3': 0.2526561, 'lag_4': 0.14923745, 'lag_5': 0.1339632, 'lag_6': 0.11442272}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   RAIGAD 2020-07-01   420.0  347.208221
# 1   RAIGAD 2020-08-01   459.0  342.207001
# 2   RAIGAD 2020-09-01   475.0  369.593048
# 3   RAIGAD 2020-10-01   491.0  385.517212
# 4   RAIGAD 2020-11-01   465.0  403.402039
# 5   RAIGAD 2020-12-01   444.0  378.583282
# 6   RAIGAD 2021-01-01   377.0  393.128845
# 7   RAIGAD 2021-02-01   298.0  419.899902
# 8   RAIGAD 2021-03-01   261.0  354.054260
# === Metrics ===
# {'district': 'RATNAGIRI', 'rmse': 282.94776588663734, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.11689735, 'lag_2': 0.24559525, 'lag_3': 0.13838544, 'lag_4': 0.31707478, 'lag_5': 0.10812248, 'lag_6': 0.073924705}}
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  RATNAGIRI 2020-07-01     203  381.078491
# 1  RATNAGIRI 2020-08-01     179  384.713806
# 2  RATNAGIRI 2020-09-01     255  439.638367
# 3  RATNAGIRI 2020-10-01     253  504.397095
# 4  RATNAGIRI 2020-11-01     257  462.843140
# 5  RATNAGIRI 2020-12-01     209  473.378357
# 6  RATNAGIRI 2021-01-01     184  522.882996
# 7  RATNAGIRI 2021-02-01     197  579.859985
# 8  RATNAGIRI 2021-03-01     151  569.953735
# === Metrics ===
# {'district': 'SANGLI', 'rmse': 110.04743262444627, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.13401216, 'lag_2': 0.125274, 'lag_3': 0.218289, 'lag_4': 0.25681472, 'lag_5': 0.12248073, 'lag_6': 0.14312944}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   SANGLI 2020-07-01   547.0  431.547760
# 1   SANGLI 2020-08-01   406.0  568.795898
# 2   SANGLI 2020-09-01   461.0  520.917053
# 3   SANGLI 2020-10-01   373.0  482.396484
# 4   SANGLI 2020-11-01   410.0  480.049072
# 5   SANGLI 2020-12-01   432.0  481.462830
# 6   SANGLI 2021-01-01   300.0  417.953613
# 7   SANGLI 2021-02-01   294.0  433.088776
# 8   SANGLI 2021-03-01   339.0  452.984131
# === Metrics ===
# {'district': 'SATARA', 'rmse': 122.08007375658049, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.14721729, 'lag_2': 0.10387917, 'lag_3': 0.09883846, 'lag_4': 0.102225, 'lag_5': 0.09809976, 'lag_6': 0.4497403}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   SATARA 2020-07-01   347.0  393.422699
# 1   SATARA 2020-08-01   349.0  423.491455
# 2   SATARA 2020-09-01   446.0  440.410828
# 3   SATARA 2020-10-01   494.0  461.019714
# 4   SATARA 2020-11-01   518.0  508.621124
# 5   SATARA 2020-12-01   814.0  479.883453
# 6   SATARA 2021-01-01   577.0  476.732941
# 7   SATARA 2021-02-01   423.0  456.631073
# 8   SATARA 2021-03-01   401.0  450.015869
# === Metrics ===
# {'district': 'SINDHUDURG', 'rmse': 29.26723852869725, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.11807257, 'lag_2': 0.1399767, 'lag_3': 0.10919717, 'lag_4': 0.1664992, 'lag_5': 0.25147352, 'lag_6': 0.21478085}}
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01   121.0  112.216789
# 1  SINDHUDURG 2020-08-01    97.0  125.040230
# 2  SINDHUDURG 2020-09-01   141.0  103.070236
# 3  SINDHUDURG 2020-10-01   144.0  114.163383
# 4  SINDHUDURG 2020-11-01   117.0  125.744392
# 5  SINDHUDURG 2020-12-01   117.0  119.911621
# 6  SINDHUDURG 2021-01-01    86.0  139.939423
# 7  SINDHUDURG 2021-02-01    90.0  118.690872
# 8  SINDHUDURG 2021-03-01    89.0  115.443939
# === Metrics ===
# {'district': 'SOLAPUR', 'rmse': 81.42456001460093, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.2760273, 'lag_2': 0.121481024, 'lag_3': 0.07972626, 'lag_4': 0.13374953, 'lag_5': 0.30971044, 'lag_6': 0.07930546}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0  SOLAPUR 2020-07-01   410.0  467.496033
# 1  SOLAPUR 2020-08-01   405.0  423.010712
# 2  SOLAPUR 2020-09-01   654.0  490.554504
# 3  SOLAPUR 2020-10-01   535.0  494.834961
# 4  SOLAPUR 2020-11-01   622.0  463.272339
# 5  SOLAPUR 2020-12-01   481.0  521.327209
# 6  SOLAPUR 2021-01-01   416.0  439.749146
# 7  SOLAPUR 2021-02-01   453.0  435.359009
# 8  SOLAPUR 2021-03-01   595.0  598.976196
# === Metrics ===
# {'district': 'THANE', 'rmse': 188.33430710438557, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.15421763, 'lag_2': 0.14052826, 'lag_3': 0.10031975, 'lag_4': 0.19116817, 'lag_5': 0.13303106, 'lag_6': 0.2807351}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    THANE 2020-07-01     708   858.093323
# 1    THANE 2020-08-01     893   827.276611
# 2    THANE 2020-09-01     916   890.231995
# 3    THANE 2020-10-01    1156   893.221558
# 4    THANE 2020-11-01     848   816.737244
# 5    THANE 2020-12-01    1031   925.205811
# 6    THANE 2021-01-01     949  1003.474243
# 7    THANE 2021-02-01     620   992.275879
# 8    THANE 2021-03-01     686   948.559875
# === Metrics ===
# {'district': 'WARDHA', 'rmse': 65.08099734218614, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.22511348, 'lag_2': 0.08992112, 'lag_3': 0.17887384, 'lag_4': 0.18718879, 'lag_5': 0.13742836, 'lag_6': 0.18147434}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WARDHA 2020-07-01   179.0  247.770432
# 1   WARDHA 2020-08-01   192.0  213.268845
# 2   WARDHA 2020-09-01   251.0  223.505157
# 3   WARDHA 2020-10-01   241.0  266.302704
# 4   WARDHA 2020-11-01   231.0  259.160889
# 5   WARDHA 2020-12-01   310.0  242.558716
# 6   WARDHA 2021-01-01   166.0  284.402435
# 7   WARDHA 2021-02-01   150.0  205.513168
# 8   WARDHA 2021-03-01   125.0  220.392273
# === Metrics ===
# {'district': 'WASHIM', 'rmse': 23.99002169291387, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.32215962, 'lag_2': 0.1349157, 'lag_3': 0.13640596, 'lag_4': 0.1239133, 'lag_5': 0.1367931, 'lag_6': 0.14581239}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WASHIM 2020-07-01   154.0  112.961571
# 1   WASHIM 2020-08-01   127.0  138.185135
# 2   WASHIM 2020-09-01   120.0  109.049080
# 3   WASHIM 2020-10-01   113.0  133.420135
# 4   WASHIM 2020-11-01   154.0  103.161568
# 5   WASHIM 2020-12-01   123.0  117.398239
# 6   WASHIM 2021-01-01   105.0  119.339256
# 7   WASHIM 2021-02-01   100.0  103.420609
# 8   WASHIM 2021-03-01    99.0   99.533859
# === Metrics ===
# {'district': 'YAVATMAL', 'rmse': 33.944509457512815, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.4387411, 'lag_2': 0.23424743, 'lag_3': 0.1458311, 'lag_4': 0.07098073, 'lag_5': 0.055481724, 'lag_6': 0.05471795}}
#
# === Forecast Data ===
#    district       date  actual    forecast
# 0  YAVATMAL 2020-07-01   148.0  143.656891
# 1  YAVATMAL 2020-08-01   201.0  182.070618
# 2  YAVATMAL 2020-09-01   225.0  155.408371
# 3  YAVATMAL 2020-10-01   182.0  158.086823
# 4  YAVATMAL 2020-11-01   174.0  130.197357
# 5  YAVATMAL 2020-12-01   163.0  135.996185
# 6  YAVATMAL 2021-01-01   146.0  126.529312
# 7  YAVATMAL 2021-02-01   140.0  130.356735
# 8  YAVATMAL 2021-03-01   161.0  122.815308
# ⚠️ Skipping MUMBAI SUBURBAN: Only 6 samples after lag features
# === Metrics ===
# None
#
# === Forecast Data ===
# None

# %%
# !pip install "dask<2025.1"
