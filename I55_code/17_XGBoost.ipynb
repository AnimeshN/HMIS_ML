# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from xgboost import XGBRegressor

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def xgboost_forecast_lags(
    series,
    district_name,
    max_lags=12,
    differencing=True,
    use_cv=True,
    cv_params=None,
    custom_params=None
):
    """
    XGBoost time series forecasting with error handling
    Returns (None, None) if insufficient data, allowing pipeline continuation
    """
    try:
        # 1. Directory setup
        os.makedirs('XGBoost_Forecasts', exist_ok=True)
        
        # 2. Stationarity and differencing
        original_series = series.copy()
        d = 0
        if differencing:
            adf_result = adfuller(series.dropna())
            if adf_result[1] > 0.05:
                d = 1
                series = series.diff().dropna()
                if len(series) < 5:  # Check after differencing
                    raise ValueError(f"Series too short after differencing: {len(series)}")

        # 3. Create lag features with validation
        df = pd.DataFrame({'y': series.astype(float)})
        for lag in range(1, max_lags + 1):
            df[f'lag_{lag}'] = df['y'].shift(lag)
        df = df.dropna()
        
        if len(df) < 10:
            raise ValueError(f"Only {len(df)} samples after lag features")

        # 4. Temporal split validation
        train_size = int(len(df) * 0.8)
        if train_size < 5 or (len(df) - train_size) < 2:
            raise ValueError(f"Insufficient split: {train_size} train, {len(df)-train_size} test")
            
        train = df.iloc[:train_size]
        test = df.iloc[train_size:]

        X_train = train.drop(columns=['y'])
        y_train = train['y']
        X_test = test.drop(columns=['y'])
        y_test = test['y']

        # 5. Dynamic cross-validation setup
        xgb_params = custom_params or {
            'n_estimators': 500,
            'learning_rate': 0.05,
            'max_depth': 3,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': 42
        }
        
        if use_cv:
            n_splits = min(5, max(2, len(X_train)//2))  # Ensure 2 ≤ splits ≤5
            param_grid = cv_params or {
                'n_estimators': [100, 300],
                'learning_rate': [0.01, 0.05],
                'max_depth': [3, 5]
            }
            tscv = TimeSeriesSplit(n_splits=n_splits)
            
            grid_search = GridSearchCV(
                XGBRegressor(**xgb_params, verbosity=0),
                param_grid,
                cv=tscv,
                scoring='neg_mean_squared_error',
                n_jobs=-1
            )
            grid_search.fit(X_train, y_train)
            model = grid_search.best_estimator_
            best_params = grid_search.best_params_
        else:
            model = XGBRegressor(**xgb_params, verbosity=0)
            model.fit(X_train, y_train)
            best_params = xgb_params

        # 6. Forecasting and post-processing
        pred_test = model.predict(X_test)

        if d == 1:
            last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
            pred_test = np.cumsum(pred_test) + last_train_value
            y_test = original_series.iloc[-len(test):]

        # 7. Save results
        forecast_df = pd.DataFrame({
            'district': district_name,
            'date': y_test.index,
            'actual': y_test.values,
            'forecast': pred_test
        })
        forecast_df.to_csv(
            os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.csv'), 
            index=False
        )

        # 8. Metrics and visualization
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        
        plt.figure(figsize=(14, 7))
        plt.plot(original_series.index, original_series, label='Original')
        plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', alpha=0.7)
        plt.title(f'{district_name} Forecast (RMSE: {rmse:.2f})')
        plt.legend()
        plt.savefig(os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.png'))
        plt.close()

        return {
            'district': district_name,
            'rmse': rmse,
            'best_params': best_params,
            'differencing': d,
            'feature_importances': dict(zip(X_train.columns, model.feature_importances_))
        }, forecast_df

    except (ValueError, IndexError) as e:
        print(f"⚠️ Skipping {district_name}: {str(e)}")
        return None, None

# %%
districts = data['district'].unique()
rmse_values = []

# Usage Example


def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I55"].asfreq('MS')
        
        results, forecast = xgboost_forecast_lags(
            series=ts,  # pd.Series with DatetimeIndex
            district_name=district,
            max_lags=6,
            use_cv=True,
            cv_params={
                'n_estimators': [200, 500],
                'learning_rate': [0.05, 0.1],
                'max_depth': [3, 5]
            },
            custom_params={
                'subsample': 0.8,
                'colsample_bytree': 0.8,
                'random_state': 42
            }
        )

        
    
        # Show results
        print("=== Metrics ===")
        print(results)
        print("\n=== Forecast Data ===")
        print(forecast)
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
# {'district': 'AHMEDNAGAR', 'rmse': 675.0551059175979, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.30757853, 'lag_2': 0.123109624, 'lag_3': 0.22037731, 'lag_4': 0.09869625, 'lag_5': 0.10244722, 'lag_6': 0.14779104}}
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AHMEDNAGAR 2020-07-01  6225.0  6571.268066
# 1  AHMEDNAGAR 2020-08-01  6609.0  6332.761230
# 2  AHMEDNAGAR 2020-09-01  7268.0  6709.071777
# 3  AHMEDNAGAR 2020-10-01  6799.0  5445.741699
# 4  AHMEDNAGAR 2020-11-01  5248.0  5409.741211
# 5  AHMEDNAGAR 2020-12-01  4923.0  4848.698730
# 6  AHMEDNAGAR 2021-01-01  4542.0  5066.544922
# 7  AHMEDNAGAR 2021-02-01  4301.0  5360.178223
# 8  AHMEDNAGAR 2021-03-01  3941.0  4517.792480
# === Metrics ===
# {'district': 'AKOLA', 'rmse': 1105.5837798056898, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.4334739, 'lag_2': 0.10460623, 'lag_3': 0.21620138, 'lag_4': 0.10707688, 'lag_5': 0.023251723, 'lag_6': 0.115389876}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    AKOLA 2020-07-01    1999  1100.735962
# 1    AKOLA 2020-08-01    1927  1015.302002
# 2    AKOLA 2020-09-01    2604  1084.631836
# 3    AKOLA 2020-10-01    2342  1016.511902
# 4    AKOLA 2020-11-01    2550  1067.468506
# 5    AKOLA 2020-12-01    2513  1370.583496
# 6    AKOLA 2021-01-01    2215  1077.542236
# 7    AKOLA 2021-02-01    1967  1508.789185
# 8    AKOLA 2021-03-01    2265  1725.938599
# === Metrics ===
# {'district': 'AMRAVATI', 'rmse': 587.6248812176079, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.12111284, 'lag_2': 0.07188177, 'lag_3': 0.07326406, 'lag_4': 0.4296324, 'lag_5': 0.08608959, 'lag_6': 0.21801937}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  AMRAVATI 2020-07-01    2772  2658.999512
# 1  AMRAVATI 2020-08-01    3081  2546.345215
# 2  AMRAVATI 2020-09-01    3483  2481.896484
# 3  AMRAVATI 2020-10-01    3505  2517.929199
# 4  AMRAVATI 2020-11-01    3484  2780.825439
# 5  AMRAVATI 2020-12-01    3227  2792.496094
# 6  AMRAVATI 2021-01-01    2783  2557.681885
# 7  AMRAVATI 2021-02-01    2216  2462.165527
# 8  AMRAVATI 2021-03-01    2626  2431.137695
# === Metrics ===
# {'district': 'AURANGABAD', 'rmse': 895.3464964319083, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.25488946, 'lag_2': 0.09753489, 'lag_3': 0.17476124, 'lag_4': 0.15337862, 'lag_5': 0.08586522, 'lag_6': 0.23357059}}
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AURANGABAD 2020-07-01    5621  5697.448730
# 1  AURANGABAD 2020-08-01    5821  5714.245605
# 2  AURANGABAD 2020-09-01    6050  5393.990723
# 3  AURANGABAD 2020-10-01    6041  5275.502930
# 4  AURANGABAD 2020-11-01    6010  5153.280273
# 5  AURANGABAD 2020-12-01    6373  4983.939453
# 6  AURANGABAD 2021-01-01    6136  4979.187012
# 7  AURANGABAD 2021-02-01    5864  4974.178711
# 8  AURANGABAD 2021-03-01    5897  4718.960449
# === Metrics ===
# {'district': 'BEED', 'rmse': 478.6299007125565, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.27374387, 'lag_2': 0.06308108, 'lag_3': 0.1897552, 'lag_4': 0.10705729, 'lag_5': 0.16084196, 'lag_6': 0.20552059}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-07-01  2942.0  2324.933350
# 1     BEED 2020-08-01  2934.0  2686.208252
# 2     BEED 2020-09-01  2943.0  2373.411377
# 3     BEED 2020-10-01  3112.0  2361.340820
# 4     BEED 2020-11-01  2812.0  2206.776123
# 5     BEED 2020-12-01  2752.0  2328.443848
# 6     BEED 2021-01-01  2275.0  2303.538818
# 7     BEED 2021-02-01  2079.0  2454.380127
# 8     BEED 2021-03-01  2382.0  2171.604248
# === Metrics ===
# {'district': 'BHANDARA', 'rmse': 268.02762298153243, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.15331735, 'lag_2': 0.113679744, 'lag_3': 0.1715346, 'lag_4': 0.20235935, 'lag_5': 0.16247611, 'lag_6': 0.19663283}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BHANDARA 2020-07-01    1119  1011.335632
# 1  BHANDARA 2020-08-01    1256  1044.637817
# 2  BHANDARA 2020-09-01    1297  1120.655640
# 3  BHANDARA 2020-10-01    1524  1008.576965
# 4  BHANDARA 2020-11-01    1320  1152.492920
# 5  BHANDARA 2020-12-01    1448  1050.330200
# 6  BHANDARA 2021-01-01    1100  1198.269409
# 7  BHANDARA 2021-02-01     954  1167.732422
# 8  BHANDARA 2021-03-01    1076  1304.006836
# === Metrics ===
# {'district': 'BULDHANA', 'rmse': 346.0702257515249, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.1849175, 'lag_2': 0.18949988, 'lag_3': 0.1350023, 'lag_4': 0.15879764, 'lag_5': 0.1987585, 'lag_6': 0.13302414}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-07-01    1172  1084.859863
# 1  BULDHANA 2020-08-01    1332  1176.968262
# 2  BULDHANA 2020-09-01    1442  1123.660522
# 3  BULDHANA 2020-10-01    1664  1093.935303
# 4  BULDHANA 2020-11-01    1582  1064.773682
# 5  BULDHANA 2020-12-01    1464  1074.958862
# 6  BULDHANA 2021-01-01    1211  1041.901978
# 7  BULDHANA 2021-02-01    1338  1199.975220
# 8  BULDHANA 2021-03-01    1567  1175.313477
# === Metrics ===
# {'district': 'CHANDRAPUR', 'rmse': 451.1332936267653, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.4165576, 'lag_2': 0.120700665, 'lag_3': 0.12068891, 'lag_4': 0.10280323, 'lag_5': 0.12560752, 'lag_6': 0.11364211}}
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  CHANDRAPUR 2020-07-01  1983.0  2069.780762
# 1  CHANDRAPUR 2020-08-01  2295.0  2031.118286
# 2  CHANDRAPUR 2020-09-01  2647.0  1913.365845
# 3  CHANDRAPUR 2020-10-01  2760.0  1782.711792
# 4  CHANDRAPUR 2020-11-01  2186.0  1743.922485
# 5  CHANDRAPUR 2020-12-01  1946.0  1768.128296
# 6  CHANDRAPUR 2021-01-01  1652.0  1765.156250
# 7  CHANDRAPUR 2021-02-01  1528.0  1631.841309
# 8  CHANDRAPUR 2021-03-01  1680.0  1577.251587
# === Metrics ===
# {'district': 'DHULE', 'rmse': 358.00485823653236, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.1278286, 'lag_2': 0.07936107, 'lag_3': 0.11904777, 'lag_4': 0.15873076, 'lag_5': 0.15190431, 'lag_6': 0.3631274}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    DHULE 2020-07-01  1662.0  1787.645020
# 1    DHULE 2020-08-01  2372.0  2087.824951
# 2    DHULE 2020-09-01  2023.0  1803.388794
# 3    DHULE 2020-10-01  2028.0  1313.457764
# 4    DHULE 2020-11-01  1809.0  1320.035156
# 5    DHULE 2020-12-01  1803.0  1585.782593
# 6    DHULE 2021-01-01  1700.0  1450.403809
# 7    DHULE 2021-02-01  1662.0  1366.796387
# 8    DHULE 2021-03-01  1633.0  1383.095947
# === Metrics ===
# {'district': 'GADCHIROLI', 'rmse': 180.66774254795314, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.1768552, 'lag_2': 0.040967464, 'lag_3': 0.09538504, 'lag_4': 0.16962932, 'lag_5': 0.15274046, 'lag_6': 0.36442247}}
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  GADCHIROLI 2020-07-01  1238.0  1417.628662
# 1  GADCHIROLI 2020-08-01  1510.0  1369.831787
# 2  GADCHIROLI 2020-09-01  1648.0  1494.009644
# 3  GADCHIROLI 2020-10-01  1751.0  1622.840820
# 4  GADCHIROLI 2020-11-01  1807.0  1651.039185
# 5  GADCHIROLI 2020-12-01  1797.0  1507.717285
# 6  GADCHIROLI 2021-01-01  1553.0  1392.396240
# 7  GADCHIROLI 2021-02-01  1320.0  1392.870483
# 8  GADCHIROLI 2021-03-01  1502.0  1251.791748
# === Metrics ===
# {'district': 'GONDIA', 'rmse': 221.65455190428412, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.19851267, 'lag_2': 0.12006579, 'lag_3': 0.15788814, 'lag_4': 0.18773608, 'lag_5': 0.25166348, 'lag_6': 0.08413376}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   GONDIA 2020-07-01   973.0  748.226074
# 1   GONDIA 2020-08-01   997.0  802.196045
# 2   GONDIA 2020-09-01   986.0  842.577637
# 3   GONDIA 2020-10-01  1065.0  868.419434
# 4   GONDIA 2020-11-01   934.0  773.844849
# 5   GONDIA 2020-12-01   990.0  739.892578
# 6   GONDIA 2021-01-01   953.0  745.435730
# 7   GONDIA 2021-02-01  1090.0  773.893555
# 8   GONDIA 2021-03-01  1022.0  770.442322
# === Metrics ===
# {'district': 'HINGOLI', 'rmse': 135.77570052658405, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.3121539, 'lag_2': 0.061421674, 'lag_3': 0.310053, 'lag_4': 0.0708844, 'lag_5': 0.09391475, 'lag_6': 0.15157235}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  HINGOLI 2020-07-01  1043.0   939.648254
# 1  HINGOLI 2020-08-01  1101.0  1040.035767
# 2  HINGOLI 2020-09-01  1343.0   985.168335
# 3  HINGOLI 2020-10-01  1229.0  1261.940918
# 4  HINGOLI 2020-11-01  1073.0  1127.858887
# 5  HINGOLI 2020-12-01   996.0   989.495239
# 6  HINGOLI 2021-01-01   848.0   934.594971
# 7  HINGOLI 2021-02-01   788.0   896.375549
# 8  HINGOLI 2021-03-01   890.0   899.632446
# === Metrics ===
# {'district': 'JALGAON', 'rmse': 4057.0869940108246, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.16917273, 'lag_2': 0.12503897, 'lag_3': 0.13003907, 'lag_4': 0.1733286, 'lag_5': 0.110103086, 'lag_6': 0.29231757}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  JALGAON 2020-07-01    3714  4337.863281
# 1  JALGAON 2020-08-01   15827  4171.864258
# 2  JALGAON 2020-09-01    5302  3978.455566
# 3  JALGAON 2020-10-01    4900  4019.392578
# 4  JALGAON 2020-11-01    4163  3997.883789
# 5  JALGAON 2020-12-01    6939  4102.906738
# 6  JALGAON 2021-01-01    3425  3819.060303
# 7  JALGAON 2021-02-01    3322  3856.709717
# 8  JALGAON 2021-03-01    2919  3851.241211
# === Metrics ===
# {'district': 'JALNA', 'rmse': 579.1831426822213, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.37565634, 'lag_2': 0.1411427, 'lag_3': 0.096461974, 'lag_4': 0.12611347, 'lag_5': 0.14521612, 'lag_6': 0.11540932}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    JALNA 2020-07-01    1894  1610.951172
# 1    JALNA 2020-08-01    1719  1560.931763
# 2    JALNA 2020-09-01    1730  1842.977295
# 3    JALNA 2020-10-01    2115  1804.938965
# 4    JALNA 2020-11-01    1968  1865.710327
# 5    JALNA 2020-12-01    1879  1714.008667
# 6    JALNA 2021-01-01     936  1806.544189
# 7    JALNA 2021-02-01     997  1906.539185
# 8    JALNA 2021-03-01     830  1917.327026
# === Metrics ===
# {'district': 'KOLHAPUR', 'rmse': 9119.031444910966, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.071975365, 'lag_2': 0.026301125, 'lag_3': 0.5710753, 'lag_4': 0.023917377, 'lag_5': 0.063578136, 'lag_6': 0.24315268}}
#
# === Forecast Data ===
#    district       date  actual      forecast
# 0  KOLHAPUR 2020-07-01    6281   6629.872070
# 1  KOLHAPUR 2020-08-01    6879   9080.732422
# 2  KOLHAPUR 2020-09-01    7432  10152.798828
# 3  KOLHAPUR 2020-10-01    6246  14307.803711
# 4  KOLHAPUR 2020-11-01    5778  14155.907227
# 5  KOLHAPUR 2020-12-01    5687  14088.710938
# 6  KOLHAPUR 2021-01-01    5502  16689.574219
# 7  KOLHAPUR 2021-02-01    5141  19136.195312
# 8  KOLHAPUR 2021-03-01    4987  19452.146484
# === Metrics ===
# {'district': 'LATUR', 'rmse': 558.5739966140625, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.19421025, 'lag_2': 0.22802848, 'lag_3': 0.10428664, 'lag_4': 0.09828927, 'lag_5': 0.15228197, 'lag_6': 0.22290336}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    LATUR 2020-07-01    2947  3002.395020
# 1    LATUR 2020-08-01    3092  3225.531494
# 2    LATUR 2020-09-01    3775  3029.818115
# 3    LATUR 2020-10-01    3978  2975.301514
# 4    LATUR 2020-11-01    3652  3131.564941
# 5    LATUR 2020-12-01    3509  3688.443604
# 6    LATUR 2021-01-01    3108  3825.844482
# 7    LATUR 2021-02-01    3476  3853.864746
# 8    LATUR 2021-03-01    3449  3964.082031
# === Metrics ===
# {'district': 'MUMBAI', 'rmse': 2388.8938655881184, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.13693854, 'lag_2': 0.27004766, 'lag_3': 0.1466006, 'lag_4': 0.17747703, 'lag_5': 0.15763324, 'lag_6': 0.111302935}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   MUMBAI 2020-07-01    2667  2458.579834
# 1   MUMBAI 2020-08-01    2879  1917.841431
# 2   MUMBAI 2020-09-01    3817  1733.351807
# 3   MUMBAI 2020-10-01    3638  1794.656982
# 4   MUMBAI 2020-11-01    4551  1313.440674
# 5   MUMBAI 2020-12-01    3083  1330.414551
# 6   MUMBAI 2021-01-01    2294   606.399414
# 7   MUMBAI 2021-02-01    2517 -1561.831055
# 8   MUMBAI 2021-03-01    2688  -413.024414
# === Metrics ===
# {'district': 'NAGPUR', 'rmse': 405.92063510877466, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.21605816, 'lag_2': 0.1088531, 'lag_3': 0.20046337, 'lag_4': 0.09073687, 'lag_5': 0.22900407, 'lag_6': 0.15488443}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NAGPUR 2020-07-01    2306  2392.104980
# 1   NAGPUR 2020-08-01    2264  2139.594238
# 2   NAGPUR 2020-09-01    2244  2208.701904
# 3   NAGPUR 2020-10-01    2712  2490.722900
# 4   NAGPUR 2020-11-01    2889  2026.592285
# 5   NAGPUR 2020-12-01    2822  2052.299316
# 6   NAGPUR 2021-01-01    2046  2070.876465
# 7   NAGPUR 2021-02-01    2416  2150.198730
# 8   NAGPUR 2021-03-01    2031  1982.129517
# === Metrics ===
# {'district': 'NANDED', 'rmse': 860.4916816971895, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.40914607, 'lag_2': 0.16957277, 'lag_3': 0.26402617, 'lag_4': 0.046634708, 'lag_5': 0.06550608, 'lag_6': 0.045114163}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NANDED 2020-07-01  3902.0  2554.173584
# 1   NANDED 2020-08-01  4032.0  3962.619141
# 2   NANDED 2020-09-01  4237.0  4210.217773
# 3   NANDED 2020-10-01  4756.0  4497.473145
# 4   NANDED 2020-11-01  4347.0  4342.601074
# 5   NANDED 2020-12-01  4200.0  4221.872559
# 6   NANDED 2021-01-01  2250.0  4171.064453
# 7   NANDED 2021-02-01  2131.0  3116.406982
# 8   NANDED 2021-03-01  3287.0  2950.849854
# === Metrics ===
# {'district': 'NANDURBAR', 'rmse': 485.9378645319932, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.21426697, 'lag_2': 0.09611439, 'lag_3': 0.19667797, 'lag_4': 0.17291287, 'lag_5': 0.11382386, 'lag_6': 0.20620392}}
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  NANDURBAR 2020-07-01    2523  2319.206055
# 1  NANDURBAR 2020-08-01    2577  2514.084717
# 2  NANDURBAR 2020-09-01    2654  2882.083008
# 3  NANDURBAR 2020-10-01    2593  3045.578613
# 4  NANDURBAR 2020-11-01    2566  2644.116211
# 5  NANDURBAR 2020-12-01    2217  2548.960449
# 6  NANDURBAR 2021-01-01    1855  2543.358398
# 7  NANDURBAR 2021-02-01    1625  2526.480957
# 8  NANDURBAR 2021-03-01    1865  2513.132568
# === Metrics ===
# {'district': 'NASHIK', 'rmse': 1865.662288517748, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.126914, 'lag_2': 0.11186325, 'lag_3': 0.09097284, 'lag_4': 0.3427529, 'lag_5': 0.1829656, 'lag_6': 0.1445314}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NASHIK 2020-07-01    7484  7468.457520
# 1   NASHIK 2020-08-01    7551  7752.756836
# 2   NASHIK 2020-09-01    8376  7584.623535
# 3   NASHIK 2020-10-01    7227  7707.350586
# 4   NASHIK 2020-11-01    6907  8209.205078
# 5   NASHIK 2020-12-01    6679  8313.399414
# 6   NASHIK 2021-01-01    6820  8626.981445
# 7   NASHIK 2021-02-01    6552  9335.250977
# 8   NASHIK 2021-03-01    5827  9706.385742
# === Metrics ===
# {'district': 'OSMANABAD', 'rmse': 337.70059051498146, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.10574971, 'lag_2': 0.14495037, 'lag_3': 0.16445085, 'lag_4': 0.16924463, 'lag_5': 0.14507516, 'lag_6': 0.27052924}}
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  OSMANABAD 2020-07-01    1794  1628.553955
# 1  OSMANABAD 2020-08-01    1952  1768.077026
# 2  OSMANABAD 2020-09-01    2171  1915.805176
# 3  OSMANABAD 2020-10-01    2081  2033.332642
# 4  OSMANABAD 2020-11-01    1981  1956.470215
# 5  OSMANABAD 2020-12-01    1981  2110.711914
# 6  OSMANABAD 2021-01-01    1830  2129.519287
# 7  OSMANABAD 2021-02-01    1598  2268.075195
# 8  OSMANABAD 2021-03-01    1712  2296.499023
# === Metrics ===
# {'district': 'PALGHAR', 'rmse': 723.8021362697611, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.10181993, 'lag_2': 0.14306034, 'lag_3': 0.16208653, 'lag_4': 0.24599667, 'lag_5': 0.16874889, 'lag_6': 0.1782876}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  PALGHAR 2020-07-01    4269  4489.445801
# 1  PALGHAR 2020-08-01    4229  4313.299316
# 2  PALGHAR 2020-09-01    4522  4203.964355
# 3  PALGHAR 2020-10-01    5385  4112.773926
# 4  PALGHAR 2020-11-01    5076  3905.032959
# 5  PALGHAR 2020-12-01    4708  3886.031982
# 6  PALGHAR 2021-01-01    4568  3770.973877
# 7  PALGHAR 2021-02-01    3787  3560.451416
# 8  PALGHAR 2021-03-01    4420  3965.877686
# === Metrics ===
# {'district': 'PARBHANI', 'rmse': 508.9436554843126, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.23351043, 'lag_2': 0.119549, 'lag_3': 0.1384032, 'lag_4': 0.16087718, 'lag_5': 0.19096127, 'lag_6': 0.15669887}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  PARBHANI 2020-07-01  1573.0  1366.133911
# 1  PARBHANI 2020-08-01  1630.0  1392.484009
# 2  PARBHANI 2020-09-01  1966.0  1350.022461
# 3  PARBHANI 2020-10-01  1984.0  1362.401123
# 4  PARBHANI 2020-11-01   868.0  1317.730957
# 5  PARBHANI 2020-12-01  1740.0   894.647644
# 6  PARBHANI 2021-01-01  1755.0  1183.685791
# 7  PARBHANI 2021-02-01  1299.0  1243.718628
# 8  PARBHANI 2021-03-01  1630.0  1161.110474
# === Metrics ===
# {'district': 'PUNE', 'rmse': 1842.5453472844144, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.4258266, 'lag_2': 0.09899698, 'lag_3': 0.09882986, 'lag_4': 0.17516762, 'lag_5': 0.08606851, 'lag_6': 0.1151104}}
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0     PUNE 2020-07-01  11790.0  11891.611328
# 1     PUNE 2020-08-01  12579.0  11463.757812
# 2     PUNE 2020-09-01  14094.0  11561.448242
# 3     PUNE 2020-10-01  14381.0  12378.416016
# 4     PUNE 2020-11-01  14329.0  12285.821289
# 5     PUNE 2020-12-01  13462.0  11528.141602
# 6     PUNE 2021-01-01  13048.0  10668.141602
# 7     PUNE 2021-02-01  11303.0  10635.631836
# 8     PUNE 2021-03-01  13097.0  10894.043945
# === Metrics ===
# {'district': 'RAIGAD', 'rmse': 913.8674416536469, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.22070503, 'lag_2': 0.12051062, 'lag_3': 0.106443465, 'lag_4': 0.2036904, 'lag_5': 0.12100215, 'lag_6': 0.22764829}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   RAIGAD 2020-07-01    3532  2236.437012
# 1   RAIGAD 2020-08-01    3912  2238.435059
# 2   RAIGAD 2020-09-01    3990  2739.374512
# 3   RAIGAD 2020-10-01    3615  2720.323730
# 4   RAIGAD 2020-11-01    3367  3126.535400
# 5   RAIGAD 2020-12-01    3787  3311.784912
# 6   RAIGAD 2021-01-01    3511  2995.175293
# 7   RAIGAD 2021-02-01    3272  2991.910645
# 8   RAIGAD 2021-03-01    3167  3377.695801
# === Metrics ===
# {'district': 'RATNAGIRI', 'rmse': 445.8229134769266, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.19289516, 'lag_2': 0.08476297, 'lag_3': 0.18172508, 'lag_4': 0.15808523, 'lag_5': 0.18447655, 'lag_6': 0.198055}}
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  RATNAGIRI 2020-07-01  1387.0  1236.884644
# 1  RATNAGIRI 2020-08-01  2246.0  1326.807739
# 2  RATNAGIRI 2020-09-01  1755.0  1160.189575
# 3  RATNAGIRI 2020-10-01  1658.0  1179.407104
# 4  RATNAGIRI 2020-11-01  1155.0  1170.082520
# 5  RATNAGIRI 2020-12-01  1683.0  1140.502075
# 6  RATNAGIRI 2021-01-01  1239.0  1077.414795
# 7  RATNAGIRI 2021-02-01  1047.0  1138.995483
# 8  RATNAGIRI 2021-03-01  1037.0  1134.049316
# === Metrics ===
# {'district': 'SANGLI', 'rmse': 820.5251945705907, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.2533703, 'lag_2': 0.12980598, 'lag_3': 0.13249385, 'lag_4': 0.12188752, 'lag_5': 0.21443999, 'lag_6': 0.14800243}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SANGLI 2020-07-01  3899.0  2726.759766
# 1   SANGLI 2020-08-01  4244.0  2591.562744
# 2   SANGLI 2020-09-01  2465.0  2319.943115
# 3   SANGLI 2020-10-01  2330.0  2837.858398
# 4   SANGLI 2020-11-01  3203.0  2516.423340
# 5   SANGLI 2020-12-01  2586.0  2443.241699
# 6   SANGLI 2021-01-01  1822.0  2597.627930
# 7   SANGLI 2021-02-01  1718.0  2289.380859
# 8   SANGLI 2021-03-01  2696.0  2190.179443
# === Metrics ===
# {'district': 'SATARA', 'rmse': 925.8089727755795, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.18129225, 'lag_2': 0.12774639, 'lag_3': 0.09231655, 'lag_4': 0.3792864, 'lag_5': 0.10302539, 'lag_6': 0.116332985}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SATARA 2020-07-01    1934  1403.170166
# 1   SATARA 2020-08-01    2767  1550.353271
# 2   SATARA 2020-09-01    2016  1294.322510
# 3   SATARA 2020-10-01    2412  1835.302002
# 4   SATARA 2020-11-01    2455  1595.809570
# 5   SATARA 2020-12-01    2576  1539.912842
# 6   SATARA 2021-01-01    2272   879.411621
# 7   SATARA 2021-02-01    1962  1161.833862
# 8   SATARA 2021-03-01    2076  1234.906250
# === Metrics ===
# {'district': 'SINDHUDURG', 'rmse': 93.32381724156834, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.11375525, 'lag_2': 0.14846568, 'lag_3': 0.119897686, 'lag_4': 0.28149605, 'lag_5': 0.12978905, 'lag_6': 0.2065963}}
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01     479  418.804016
# 1  SINDHUDURG 2020-08-01     516  396.210968
# 2  SINDHUDURG 2020-09-01     446  341.754547
# 3  SINDHUDURG 2020-10-01     435  376.624878
# 4  SINDHUDURG 2020-11-01     458  399.423889
# 5  SINDHUDURG 2020-12-01     456  336.063293
# 6  SINDHUDURG 2021-01-01     456  310.360748
# 7  SINDHUDURG 2021-02-01     391  308.135315
# 8  SINDHUDURG 2021-03-01     339  354.586975
# === Metrics ===
# {'district': 'SOLAPUR', 'rmse': 2531.6042680555347, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.25475916, 'lag_2': 0.108681075, 'lag_3': 0.10797345, 'lag_4': 0.11583644, 'lag_5': 0.30949378, 'lag_6': 0.10325608}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  SOLAPUR 2020-07-01    2470  2244.059082
# 1  SOLAPUR 2020-08-01    1918  2171.780273
# 2  SOLAPUR 2020-09-01    2558  1967.210571
# 3  SOLAPUR 2020-10-01    2463  1270.015625
# 4  SOLAPUR 2020-11-01    3694  1304.438965
# 5  SOLAPUR 2020-12-01    6427  1011.598145
# 6  SOLAPUR 2021-01-01    4111   470.855469
# 7  SOLAPUR 2021-02-01    2035   161.594727
# 8  SOLAPUR 2021-03-01    2190   190.848877
# === Metrics ===
# {'district': 'THANE', 'rmse': 3353.933205072912, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.23931123, 'lag_2': 0.054911796, 'lag_3': 0.14787029, 'lag_4': 0.15793954, 'lag_5': 0.28815317, 'lag_6': 0.11181395}}
#
# === Forecast Data ===
#   district       date  actual      forecast
# 0    THANE 2020-07-01    5153   8723.756836
# 1    THANE 2020-08-01   11494   8892.365234
# 2    THANE 2020-09-01   12157   8138.977539
# 3    THANE 2020-10-01   12242   6264.139648
# 4    THANE 2020-11-01    7730   5552.628418
# 5    THANE 2020-12-01   12598   8828.211914
# 6    THANE 2021-01-01    8749   8883.954102
# 7    THANE 2021-02-01    9308  11972.128906
# 8    THANE 2021-03-01   12833  10890.414062
# === Metrics ===
# {'district': 'WARDHA', 'rmse': 273.742249802001, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.18908662, 'lag_2': 0.10917848, 'lag_3': 0.09507308, 'lag_4': 0.17699598, 'lag_5': 0.20853314, 'lag_6': 0.2211328}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WARDHA 2020-07-01    1131  1132.165649
# 1   WARDHA 2020-08-01    1326  1062.088745
# 2   WARDHA 2020-09-01    1431  1037.596191
# 3   WARDHA 2020-10-01    1425   903.377197
# 4   WARDHA 2020-11-01    1342  1019.277344
# 5   WARDHA 2020-12-01    1209  1010.972107
# 6   WARDHA 2021-01-01    1027  1129.184692
# 7   WARDHA 2021-02-01    1006  1160.903931
# 8   WARDHA 2021-03-01    1105  1115.201050
# === Metrics ===
# {'district': 'WASHIM', 'rmse': 81.5620978655526, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.09178718, 'lag_2': 0.16934161, 'lag_3': 0.087770395, 'lag_4': 0.19162892, 'lag_5': 0.23838633, 'lag_6': 0.22108553}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   WASHIM 2020-07-01   622.0  459.788605
# 1   WASHIM 2020-08-01   696.0  558.709717
# 2   WASHIM 2020-09-01   678.0  740.317383
# 3   WASHIM 2020-10-01   696.0  618.329468
# 4   WASHIM 2020-11-01   627.0  610.557617
# 5   WASHIM 2020-12-01   616.0  598.361633
# 6   WASHIM 2021-01-01   509.0  553.954041
# 7   WASHIM 2021-02-01   477.0  522.118652
# 8   WASHIM 2021-03-01   521.0  533.491333
# === Metrics ===
# {'district': 'YAVATMAL', 'rmse': 462.7483454911766, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.2034455, 'lag_2': 0.07874505, 'lag_3': 0.17894118, 'lag_4': 0.090418436, 'lag_5': 0.09630192, 'lag_6': 0.3521479}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  YAVATMAL 2020-07-01  4215.0  3088.575439
# 1  YAVATMAL 2020-08-01  3800.0  3538.746338
# 2  YAVATMAL 2020-09-01  3624.0  3707.151367
# 3  YAVATMAL 2020-10-01  3708.0  3587.438721
# 4  YAVATMAL 2020-11-01  3219.0  3724.595215
# 5  YAVATMAL 2020-12-01  3613.0  3440.106445
# 6  YAVATMAL 2021-01-01  3199.0  3147.287598
# 7  YAVATMAL 2021-02-01  2808.0  2956.012939
# 8  YAVATMAL 2021-03-01  3435.0  2926.483887
# ⚠️ Skipping MUMBAI SUBURBAN: Only 5 samples after lag features
# === Metrics ===
# None
#
# === Forecast Data ===
# None

# %%
# !pip install "dask<2025.1"
