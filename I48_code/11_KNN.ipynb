# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def knn_regression_lags_only(
    series,
    district_name,
    max_lags=3,
    differencing=True,
    n_neighbors=5,
    weights='uniform',
    algorithm='auto',
    use_cv=False,
    cv_params=None,
    cv=5
):
    """
    K-Nearest Neighbors regression for time series forecasting with:
    - Lag features only
    - Optional differencing for stationarity
    - Optional hyperparameter tuning via cross-validation
    """
    # 1. Directory structure
    os.makedirs('KNNRegression', exist_ok=True)
    
    # 2. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 3. Feature Engineering - Lag features only
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 4. Train-Test Split (time-based)
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 5. Model Training (with optional CV)
    if use_cv:
        param_grid = cv_params or {
            'n_neighbors': [3, 5, 7, 9],
            'weights': ['uniform', 'distance'],
            'algorithm': ['auto', 'ball_tree', 'kd_tree']
        }
        grid_search = GridSearchCV(
            KNeighborsRegressor(),
            param_grid,
            cv=cv,
            scoring='neg_mean_squared_error'
        )
        grid_search.fit(X_train, y_train)
        model = grid_search.best_estimator_
        best_params = grid_search.best_params_
    else:
        model = KNeighborsRegressor(
            n_neighbors=n_neighbors,
            weights=weights,
            algorithm=algorithm
        )
        model.fit(X_train, y_train)
        best_params = {
            'n_neighbors': n_neighbors,
            'weights': weights,
            'algorithm': algorithm
        }

    # 6. Forecasting
    pred_test = model.predict(X_test)

    # 7. Inverse Differencing if applied
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = np.cumsum(pred_test) + last_train_value
        y_test = original_series.iloc[-len(test):]

    # 8. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test
    })

    # 9. Save forecasts to CSV
    forecast_csv_path = os.path.join('KNNRegression', 'knn_forecasts.csv')
    forecast_df.to_csv(
        forecast_csv_path,
        mode='a',
        header=not os.path.exists(forecast_csv_path),
        index=False
    )

    # 10. Calculate metrics
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    r_squared = model.score(X_train, y_train)
    metrics_data = {
        'district': district_name,
        'rmse': rmse,
        'r_squared': r_squared,
        'best_params': best_params,
        'differencing': d
    }
    metrics_df = pd.DataFrame([metrics_data])

    metrics_csv_path = os.path.join('KNNRegression', 'knn_metrics.csv')
    metrics_df.to_csv(
        metrics_csv_path,
        mode='a',
        header=not os.path.exists(metrics_csv_path),
        index=False
    )

    # 11. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='KNN Forecast', color='darkorange')
    plt.title(f'KNN Regression Forecast for {district_name}\nRMSE: {rmse:.2f}, R²: {r_squared:.2f}')
    plt.legend()
    plt.savefig(os.path.join('KNNRegression', f'knn_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'best_params': best_params
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I40"].asfreq('MS')
        
        results = knn_regression_lags_only(
            ts,
            district,
            max_lags=5,
            use_cv=True,
            cv_params={
                'n_neighbors': [3, 5, 7, 9],
                'weights': ['uniform', 'distance']
            }
        )

        
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district      rmse  r_squared                               best_params  \
# 0  AHMEDNAGAR  18.33896   0.083483  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AHMEDNAGAR 2020-07-01    40.0  37.714286
# 1  AHMEDNAGAR 2020-08-01    55.0  37.714286
# 2  AHMEDNAGAR 2020-09-01    36.0  39.857143
# 3  AHMEDNAGAR 2020-10-01    82.0  36.428571
# 4  AHMEDNAGAR 2020-11-01    49.0  48.142857
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0    AKOLA  10.775273        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    AKOLA 2020-07-01    34.0  44.883932
# 1    AKOLA 2020-08-01    45.0  44.580450
# 2    AKOLA 2020-09-01    54.0  44.752158
# 3    AKOLA 2020-10-01    48.0  47.731520
# 4    AKOLA 2020-11-01    39.0  50.204471
# === Metrics ===
#    district       rmse  r_squared                               best_params  \
# 0  AMRAVATI  15.780883   0.356033  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  AMRAVATI 2020-07-01    62.0  56.857143
# 1  AMRAVATI 2020-08-01    70.0  57.142857
# 2  AMRAVATI 2020-09-01    98.0  67.000000
# 3  AMRAVATI 2020-10-01    55.0  68.285714
# 4  AMRAVATI 2020-11-01    45.0  60.428571
# === Metrics ===
#      district       rmse  r_squared                               best_params  \
# 0  AURANGABAD  15.076121   -0.05921  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AURANGABAD 2020-07-01      53  65.888889
# 1  AURANGABAD 2020-08-01      74  71.222222
# 2  AURANGABAD 2020-09-01      76  69.444444
# 3  AURANGABAD 2020-10-01      56  68.111111
# 4  AURANGABAD 2020-11-01      57  67.222222
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0     BEED  10.059767   0.248521  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     BEED 2020-07-01    30.0  26.666667
# 1     BEED 2020-08-01    30.0  25.777778
# 2     BEED 2020-09-01    33.0  24.111111
# 3     BEED 2020-10-01    16.0  25.222222
# 4     BEED 2020-11-01    18.0  26.666667
# === Metrics ===
#    district      rmse  r_squared                               best_params  \
# 0  BHANDARA  4.090252   0.150288  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BHANDARA 2020-07-01    19.0  16.857143
# 1  BHANDARA 2020-08-01    22.0  16.428571
# 2  BHANDARA 2020-09-01    28.0  21.142857
# 3  BHANDARA 2020-10-01    22.0  21.857143
# 4  BHANDARA 2020-11-01    25.0  23.571429
# === Metrics ===
#    district      rmse  r_squared                                best_params  \
# 0  BULDHANA  5.982122        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BULDHANA 2020-07-01      31  25.241298
# 1  BULDHANA 2020-08-01      25  19.132980
# 2  BULDHANA 2020-09-01      17  27.012156
# 3  BULDHANA 2020-10-01      19  27.504336
# 4  BULDHANA 2020-11-01      24  24.887688
# === Metrics ===
#      district       rmse  r_squared                               best_params  \
# 0  CHANDRAPUR  13.386673   0.053698  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  CHANDRAPUR 2020-07-01    41.0  44.000000
# 1  CHANDRAPUR 2020-08-01    37.0  40.444444
# 2  CHANDRAPUR 2020-09-01    44.0  39.555556
# 3  CHANDRAPUR 2020-10-01    67.0  42.666667
# 4  CHANDRAPUR 2020-11-01    47.0  45.777778
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0    DHULE  15.802419        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    DHULE 2020-07-01    24.0  12.487207
# 1    DHULE 2020-08-01    31.0  10.553562
# 2    DHULE 2020-09-01    27.0  14.643014
# 3    DHULE 2020-10-01    50.0  14.956090
# 4    DHULE 2020-11-01    25.0  40.524175
# === Metrics ===
#      district      rmse  r_squared                                best_params  \
# 0  GADCHIROLI  10.47602        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  GADCHIROLI 2020-07-01    46.0  31.416709
# 1  GADCHIROLI 2020-08-01    44.0  33.094761
# 2  GADCHIROLI 2020-09-01    44.0  35.087034
# 3  GADCHIROLI 2020-10-01    41.0  29.630794
# 4  GADCHIROLI 2020-11-01    40.0  28.803820
# === Metrics ===
#   district      rmse  r_squared                                best_params  \
# 0   GONDIA  6.902062        1.0  {'n_neighbors': 5, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   GONDIA 2020-07-01    23.0  19.692945
# 1   GONDIA 2020-08-01    21.0  20.582547
# 2   GONDIA 2020-09-01    28.0  24.276869
# 3   GONDIA 2020-10-01    39.0  25.555062
# 4   GONDIA 2020-11-01    30.0  22.422631
# === Metrics ===
#   district      rmse  r_squared                               best_params  \
# 0  HINGOLI  3.872098   0.149544  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  HINGOLI 2020-07-01    12.0  11.888889
# 1  HINGOLI 2020-08-01    19.0  12.666667
# 2  HINGOLI 2020-09-01    14.0  14.222222
# 3  HINGOLI 2020-10-01    20.0  13.444444
# 4  HINGOLI 2020-11-01    12.0  15.666667
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0  JALGAON  15.502467   0.142493  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  JALGAON 2020-07-01    21.0  43.444444
# 1  JALGAON 2020-08-01    25.0  36.888889
# 2  JALGAON 2020-09-01    41.0  35.333333
# 3  JALGAON 2020-10-01    37.0  34.888889
# 4  JALGAON 2020-11-01    39.0  37.888889
# === Metrics ===
#   district      rmse  r_squared                               best_params  \
# 0    JALNA  5.577119   0.247383  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    JALNA 2020-07-01    38.0  28.222222
# 1    JALNA 2020-08-01    26.0  29.666667
# 2    JALNA 2020-09-01    25.0  29.666667
# 3    JALNA 2020-10-01    29.0  27.333333
# 4    JALNA 2020-11-01    20.0  27.333333
# === Metrics ===
#    district      rmse  r_squared                                best_params  \
# 0  KOLHAPUR  11.80405        1.0  {'n_neighbors': 3, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  KOLHAPUR 2020-07-01    23.0  14.391592
# 1  KOLHAPUR 2020-08-01    20.0  23.233390
# 2  KOLHAPUR 2020-09-01    16.0  23.745509
# 3  KOLHAPUR 2020-10-01    14.0  30.298857
# 4  KOLHAPUR 2020-11-01    15.0  30.041801
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0    LATUR  15.129314        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    LATUR 2020-07-01    16.0  23.203774
# 1    LATUR 2020-08-01    58.0  21.537746
# 2    LATUR 2020-09-01    35.0  28.395831
# 3    LATUR 2020-10-01    38.0  24.409578
# 4    LATUR 2020-11-01    14.0  23.340333
# === Metrics ===
#   district      rmse  r_squared                               best_params  \
# 0   MUMBAI  15.56094   0.227874  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   MUMBAI 2020-07-01      74  79.714286
# 1   MUMBAI 2020-08-01      66  76.714286
# 2   MUMBAI 2020-09-01      76  65.571429
# 3   MUMBAI 2020-10-01      90  65.000000
# 4   MUMBAI 2020-11-01      69  62.428571
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0   NAGPUR  20.138103   0.544853  {'n_neighbors': 3, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NAGPUR 2020-07-01    50.0  75.666667
# 1   NAGPUR 2020-08-01    52.0  53.333333
# 2   NAGPUR 2020-09-01    35.0  70.666667
# 3   NAGPUR 2020-10-01    76.0  49.333333
# 4   NAGPUR 2020-11-01    33.0  54.000000
# === Metrics ===
#   district      rmse  r_squared                                best_params  \
# 0   NANDED  9.953641        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NANDED 2020-07-01      26  19.907039
# 1   NANDED 2020-08-01      32  26.923727
# 2   NANDED 2020-09-01      50  24.000614
# 3   NANDED 2020-10-01      21  19.309081
# 4   NANDED 2020-11-01      33  27.562876
# === Metrics ===
#     district      rmse  r_squared                                best_params  \
# 0  NANDURBAR  9.399892        1.0  {'n_neighbors': 5, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  NANDURBAR 2020-07-01    42.0  34.855274
# 1  NANDURBAR 2020-08-01    48.0  39.400140
# 2  NANDURBAR 2020-09-01    52.0  44.686849
# 3  NANDURBAR 2020-10-01    44.0  49.034783
# 4  NANDURBAR 2020-11-01    56.0  43.848675
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0   NASHIK  16.138502    0.31344  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NASHIK 2020-07-01    68.0  95.428571
# 1   NASHIK 2020-08-01    94.0  87.714286
# 2   NASHIK 2020-09-01   111.0  88.000000
# 3   NASHIK 2020-10-01    96.0  94.571429
# 4   NASHIK 2020-11-01    87.0  92.285714
# === Metrics ===
#     district      rmse  r_squared                               best_params  \
# 0  OSMANABAD  6.793849   0.181885  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  OSMANABAD 2020-07-01    28.0  17.555556
# 1  OSMANABAD 2020-08-01    30.0  19.444444
# 2  OSMANABAD 2020-09-01    26.0  21.333333
# 3  OSMANABAD 2020-10-01    17.0  21.888889
# 4  OSMANABAD 2020-11-01    19.0  22.888889
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0  PALGHAR  10.411031   0.074332  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  PALGHAR 2020-07-01      45  33.777778
# 1  PALGHAR 2020-08-01      48  33.111111
# 2  PALGHAR 2020-09-01      33  28.555556
# 3  PALGHAR 2020-10-01      48  28.555556
# 4  PALGHAR 2020-11-01      42  29.000000
# === Metrics ===
#    district      rmse  r_squared                               best_params  \
# 0  PARBHANI  8.173278   0.637432  {'n_neighbors': 3, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  PARBHANI 2020-07-01    11.0  13.333333
# 1  PARBHANI 2020-08-01    33.0  11.666667
# 2  PARBHANI 2020-09-01    18.0  20.000000
# 3  PARBHANI 2020-10-01    12.0  16.000000
# 4  PARBHANI 2020-11-01    21.0  12.000000
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0     PUNE  66.578747        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     PUNE 2020-07-01      72  39.580206
# 1     PUNE 2020-08-01      69  42.234411
# 2     PUNE 2020-09-01      70  31.897326
# 3     PUNE 2020-10-01      58   9.890509
# 4     PUNE 2020-11-01      98   4.869440
# === Metrics ===
#   district      rmse  r_squared                               best_params  \
# 0   RAIGAD  7.735245   0.356493  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   RAIGAD 2020-07-01    21.0  23.555556
# 1   RAIGAD 2020-08-01    29.0  21.777778
# 2   RAIGAD 2020-09-01    35.0  22.222222
# 3   RAIGAD 2020-10-01    32.0  22.777778
# 4   RAIGAD 2020-11-01    11.0  24.888889
# === Metrics ===
#     district      rmse  r_squared                                best_params  \
# 0  RATNAGIRI  6.170942        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  RATNAGIRI 2020-07-01    23.0  14.774752
# 1  RATNAGIRI 2020-08-01    25.0  13.146882
# 2  RATNAGIRI 2020-09-01    22.0  14.251420
# 3  RATNAGIRI 2020-10-01    11.0  12.379767
# 4  RATNAGIRI 2020-11-01    19.0  12.715089
# === Metrics ===
#   district      rmse  r_squared                                best_params  \
# 0   SANGLI  9.115005        1.0  {'n_neighbors': 3, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SANGLI 2020-07-01    24.0  29.687431
# 1   SANGLI 2020-08-01    16.0  27.703669
# 2   SANGLI 2020-09-01    13.0  29.572307
# 3   SANGLI 2020-10-01    28.0  26.884895
# 4   SANGLI 2020-11-01    34.0  35.193695
# === Metrics ===
#   district      rmse  r_squared                               best_params  \
# 0   SATARA  6.746293   0.233736  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SATARA 2020-07-01    40.0  36.857143
# 1   SATARA 2020-08-01    40.0  35.000000
# 2   SATARA 2020-09-01    49.0  36.142857
# 3   SATARA 2020-10-01    39.0  37.857143
# 4   SATARA 2020-11-01    40.0  37.571429
# === Metrics ===
#      district      rmse  r_squared                               best_params  \
# 0  SINDHUDURG  2.535617   0.056144  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#      district       date  actual  forecast
# 0  SINDHUDURG 2020-07-01     9.0  6.000000
# 1  SINDHUDURG 2020-08-01     3.0  6.333333
# 2  SINDHUDURG 2020-09-01    10.0  6.666667
# 3  SINDHUDURG 2020-10-01     4.0  6.000000
# 4  SINDHUDURG 2020-11-01     6.0  5.777778
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0  SOLAPUR  28.253148    0.38231  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  SOLAPUR 2020-07-01      28  43.714286
# 1  SOLAPUR 2020-08-01      25  52.285714
# 2  SOLAPUR 2020-09-01      17  45.285714
# 3  SOLAPUR 2020-10-01      18  50.571429
# 4  SOLAPUR 2020-11-01      24  48.142857
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0    THANE  13.508375   0.091952  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    THANE 2020-07-01      98  72.714286
# 1    THANE 2020-08-01      79  65.571429
# 2    THANE 2020-09-01      76  65.428571
# 3    THANE 2020-10-01      68  63.285714
# 4    THANE 2020-11-01      78  61.142857
# === Metrics ===
#   district      rmse  r_squared                                best_params  \
# 0   WARDHA  3.454775   0.989222  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual  forecast
# 0   WARDHA 2020-07-01     4.0  7.464891
# 1   WARDHA 2020-08-01     6.0  6.844161
# 2   WARDHA 2020-09-01     9.0  7.598568
# 3   WARDHA 2020-10-01    16.0  8.525002
# 4   WARDHA 2020-11-01     7.0  8.262076
# === Metrics ===
#   district      rmse  r_squared                               best_params  \
# 0   WASHIM  4.382438   0.136179  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   WASHIM 2020-07-01    13.0   9.111111
# 1   WASHIM 2020-08-01    18.0   8.666667
# 2   WASHIM 2020-09-01     7.0  10.333333
# 3   WASHIM 2020-10-01    10.0   6.111111
# 4   WASHIM 2020-11-01     5.0   7.222222
# === Metrics ===
#    district      rmse  r_squared                                best_params  \
# 0  YAVATMAL  7.788279        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  YAVATMAL 2020-07-01     3.0   8.562469
# 1  YAVATMAL 2020-08-01     7.0   7.405873
# 2  YAVATMAL 2020-09-01     8.0   7.507186
# 3  YAVATMAL 2020-10-01    23.0   7.192944
# 4  YAVATMAL 2020-11-01     6.0  15.645660
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 31
#      28         print(results['forecast_df'].head())
#      30     return results
# ---> 31 run_for_each_district()
#
# Cell In[4], line 11, in run_for_each_district()
#       8 district_data = data[data['district'] == district]
#       9 ts = district_data["I40"].asfreq('MS')
# ---> 11 results = knn_regression_lags_only(
#      12     ts,
#      13     district,
#      14     max_lags=5,
#      15     use_cv=True,
#      16     cv_params={
#      17         'n_neighbors': [3, 5, 7, 9],
#      18         'weights': ['uniform', 'distance']
#      19     }
#      20 )
#      24 # Show results
#      25 print("=== Metrics ===")
#
# Cell In[3], line 60, in knn_regression_lags_only(series, district_name, max_lags, differencing, n_neighbors, weights, algorithm, use_cv, cv_params, cv)
#      49 param_grid = cv_params or {
#      50     'n_neighbors': [3, 5, 7, 9],
#      51     'weights': ['uniform', 'distance'],
#      52     'algorithm': ['auto', 'ball_tree', 'kd_tree']
#      53 }
#      54 grid_search = GridSearchCV(
#      55     KNeighborsRegressor(),
#      56     param_grid,
#      57     cv=cv,
#      58     scoring='neg_mean_squared_error'
#      59 )
# ---> 60 grid_search.fit(X_train, y_train)
#      61 model = grid_search.best_estimator_
#      62 best_params = grid_search.best_params_
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:928, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
#     916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
# --> 928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:370, in _BaseKFold.split(self, X, y, groups)
#     368 n_samples = _num_samples(X)
#     369 if self.n_splits > n_samples:
# --> 370     raise ValueError(
#     371         (
#     372             "Cannot have number of splits n_splits={0} greater"
#     373             " than the number of samples: n_samples={1}."
#     374         ).format(self.n_splits, n_samples)
#     375     )
#     377 for train, test in super().split(X, y, groups):
#     378     yield train, test
#
# ValueError: Cannot have number of splits n_splits=5 greater than the number of samples: n_samples=4.
