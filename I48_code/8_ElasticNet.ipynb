# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def elastic_net_regression_lags_only(
    series,
    district_name,
    max_lags=3,
    differencing=True,
    alpha=1.0,
    l1_ratio=0.5,  # Mix ratio (0=Ridge, 1=LASSO)
    use_cv=False,
    alphas=np.logspace(-3, 2, 20),
    l1_ratios=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1],  # Tested if use_cv=True
    cv=5,
    random_state=42
):
    """
    Elastic Net regression (L1/L2 regularization) for time series forecasting.
    Supports both fixed parameters and cross-validated hyperparameter tuning.
    """
    # Create directory structure
    os.makedirs('ElasticNetRegression', exist_ok=True)
    
    # 1. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 2. Feature Engineering - Lag features
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 3. Train-Test Split
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 4. Model Training
    if use_cv:
        model = ElasticNetCV(
            alphas=alphas,
            l1_ratio=l1_ratios,
            cv=TimeSeriesSplit(n_splits=5),
            max_iter=10000,
            random_state=random_state
        )
        model.fit(X_train, y_train)
        best_alpha = model.alpha_
        best_l1 = model.l1_ratio_
    else:
        model = ElasticNet(
            alpha=alpha,
            l1_ratio=l1_ratio,
            max_iter=10000,
            random_state=random_state
        )
        model.fit(X_train, y_train)
        best_alpha = alpha
        best_l1 = l1_ratio

    # 5. Forecasting
    pred_test = model.predict(X_test)

    # 6. Inverse Differencing
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = np.cumsum(pred_test) + last_train_value
        y_test = original_series.iloc[-len(test):]
    
    # 7. Forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test
    })

    # 8. Save Forecasts
    forecast_csv_path = os.path.join('ElasticNetRegression', 'elasticnet_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, mode='a', header=write_header, index=False)

    # 9. Metrics Calculation
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    r_squared = model.score(X_train, y_train)
    
    metrics_data = {
        'district': district_name,
        'rmse': rmse,
        'r_squared': r_squared,
        'coefficients': model.coef_.tolist(),
        'intercept': model.intercept_,
        'final_alpha': best_alpha,
        'final_l1_ratio': best_l1,
        'differencing': d
    }
    
    if use_cv:
        metrics_data.update({
            'alphas_tried': alphas.tolist(),
            'l1_ratios_tried': l1_ratios
        })

    metrics_df = pd.DataFrame([metrics_data])

    metrics_csv_path = os.path.join('ElasticNetRegression', 'elasticnet_metrics.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, mode='a', header=write_header_metrics, index=False)

    # 10. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', color='darkorange')
    plt.title(
        f'Elastic Net Forecast for {district_name}\n'
        f'Alpha: {best_alpha:.4f}, L1 Ratio: {best_l1:.2f} | '
        f'RMSE: {rmse:.2f}, R²: {r_squared:.2f}'
    )
    plt.legend()
    plt.savefig(os.path.join('ElasticNetRegression', f'elasticnet_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_coefficients': model.coef_,
        'model_intercept': model.intercept_,
        'best_alpha': best_alpha,
        'best_l1_ratio': best_l1
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I40"].asfreq('MS')
        
        results = elastic_net_regression_lags_only(
            ts,
            district,
            use_cv=True,
            alphas=np.logspace(-3, 1, 30),
            l1_ratios=[0.1, 0.3, 0.5, 0.7, 0.9, 1],
            cv=5
        )
        
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district       rmse  r_squared  \
# 0  AHMEDNAGAR  16.187799   0.097729
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.20986952790768584, -0.0, 0.061453117573267345]  31.917468         10.0
#
#    final_l1_ratio  differencing  \
# 0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AHMEDNAGAR 2020-07-01    40.0  42.130333
# 1  AHMEDNAGAR 2020-08-01    55.0  42.524562
# 2  AHMEDNAGAR 2020-09-01    36.0  45.856964
# 3  AHMEDNAGAR 2020-10-01    82.0  41.930896
# 4  AHMEDNAGAR 2020-11-01    49.0  52.506691
# === Metrics ===
#   district       rmse  r_squared  \
# 0    AKOLA  10.188539   0.175435
#
#                                     coefficients  intercept  final_alpha  \
# 0  [0.2175003046027803, 0.184640091030799, -0.0]  28.937692         10.0
#
#    final_l1_ratio  differencing  \
# 0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    AKOLA 2020-07-01    34.0  44.555447
# 1    AKOLA 2020-08-01    45.0  43.164386
# 2    AKOLA 2020-09-01    54.0  45.002969
# 3    AKOLA 2020-10-01    48.0  48.991513
# 4    AKOLA 2020-11-01    39.0  49.348272
# === Metrics ===
#    district       rmse  r_squared  \
# 0  AMRAVATI  17.981397   0.401029
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.45873702449927856, 0.27648232169060716, -0....  37.619227         10.0
#
#    final_l1_ratio  differencing  \
# 0             0.1             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  AMRAVATI 2020-07-01    62.0  58.125223
# 1  AMRAVATI 2020-08-01    70.0  61.324570
# 2  AMRAVATI 2020-09-01    98.0  68.035772
# 3  AMRAVATI 2020-10-01    55.0  79.029395
# 4  AMRAVATI 2020-11-01    45.0  64.090393
# === Metrics ===
#      district       rmse  r_squared                       coefficients  \
# 0  AURANGABAD  15.122201   0.047403  [-0.17543825170977123, 0.0, -0.0]
#
#    intercept  final_alpha  final_l1_ratio  differencing  \
# 0   0.478697         10.0             1.0             1
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AURANGABAD 2020-07-01      53  62.250629
# 1  AURANGABAD 2020-08-01      74  64.483708
# 2  AURANGABAD 2020-09-01      76  61.278201
# 3  AURANGABAD 2020-10-01      56  61.406022
# 4  AURANGABAD 2020-11-01      57  65.393483
# === Metrics ===
#   district      rmse  r_squared  \
# 0     BEED  7.644393    0.28975
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.5099420846712633, 0.02786666481094558, -0.1...  16.698589        0.001
#
#    final_l1_ratio  differencing  \
# 0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     BEED 2020-07-01    30.0  24.107198
# 1     BEED 2020-08-01    30.0  27.614558
# 2     BEED 2020-09-01    33.0  29.107231
# 3     BEED 2020-10-01    16.0  29.040363
# 4     BEED 2020-11-01    18.0  20.454948
# === Metrics ===
#    district      rmse  r_squared                     coefficients  intercept  \
# 0  BHANDARA  4.630915   0.020813  [0.03892571817100115, 0.0, 0.0]  18.556235
#
#    final_alpha  final_l1_ratio  differencing  \
# 0         10.0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BHANDARA 2020-07-01    19.0  19.179047
# 1  BHANDARA 2020-08-01    22.0  19.295824
# 2  BHANDARA 2020-09-01    28.0  19.412601
# 3  BHANDARA 2020-10-01    22.0  19.646156
# 4  BHANDARA 2020-11-01    25.0  19.412601
# === Metrics ===
#    district      rmse  r_squared  \
# 0  BULDHANA  9.847896   0.276826
#
#                                         coefficients  intercept  final_alpha  \
# 0  [-0.37635517138828545, 0.0, -0.10380289738398818]   0.506325         10.0
#
#    final_l1_ratio  differencing  \
# 0             0.7             1
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BULDHANA 2020-07-01      31  26.427785
# 1  BULDHANA 2020-08-01      25  24.572176
# 2  BULDHANA 2020-09-01      17  27.648041
# 3  BULDHANA 2020-10-01      19  30.542391
# 4  BULDHANA 2020-11-01      24  30.918823
# === Metrics ===
#      district       rmse  r_squared                      coefficients  \
# 0  CHANDRAPUR  14.263178   0.013977  [0.04387635723747184, 0.0, -0.0]
#
#    intercept  final_alpha  final_l1_ratio  differencing  \
# 0   41.07848         10.0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  CHANDRAPUR 2020-07-01    41.0  42.965164
# 1  CHANDRAPUR 2020-08-01    37.0  42.877411
# 2  CHANDRAPUR 2020-09-01    44.0  42.701906
# 3  CHANDRAPUR 2020-10-01    67.0  43.009040
# 4  CHANDRAPUR 2020-11-01    47.0  44.018196
# === Metrics ===
#   district       rmse  r_squared  \
# 0    DHULE  13.480603   0.410535
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.44968171710349486, -0.15884555195199648, 0....   5.922974      2.04336
#
#    final_l1_ratio  differencing  \
# 0             0.5             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    DHULE 2020-07-01    24.0  16.271610
# 1    DHULE 2020-08-01    31.0  21.847252
# 2    DHULE 2020-09-01    27.0  24.796948
# 3    DHULE 2020-10-01    50.0  23.635530
# 4    DHULE 2020-11-01    25.0  37.674739
# === Metrics ===
#      district      rmse  r_squared  \
# 0  GADCHIROLI  9.361654   0.086925
#
#                                        coefficients  intercept  final_alpha  \
# 0  [0.17808143610820587, 0.0, -0.03085286789697906]  26.637763         10.0
#
#    final_l1_ratio  differencing  \
# 0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  GADCHIROLI 2020-07-01    46.0  30.760163
# 1  GADCHIROLI 2020-08-01    44.0  34.119894
# 2  GADCHIROLI 2020-09-01    44.0  33.609466
# 3  GADCHIROLI 2020-10-01    41.0  33.054115
# 4  GADCHIROLI 2020-11-01    40.0  32.581576
# === Metrics ===
#   district      rmse  r_squared                     coefficients  intercept  \
# 0   GONDIA  7.195237    0.07062  [0.10950610727562402, 0.0, 0.0]  19.096548
#
#    final_alpha  final_l1_ratio  differencing  \
# 0         10.0             0.9             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   GONDIA 2020-07-01    23.0  21.286670
# 1   GONDIA 2020-08-01    21.0  21.615189
# 2   GONDIA 2020-09-01    28.0  21.396176
# 3   GONDIA 2020-10-01    39.0  22.162719
# 4   GONDIA 2020-11-01    30.0  23.367286
# === Metrics ===
#   district      rmse  r_squared                     coefficients  intercept  \
# 0  HINGOLI  3.991515   0.209694  [0.41991756551905157, 0.0, 0.0]   7.682242
#
#    final_alpha  final_l1_ratio  differencing  \
# 0     1.487352             0.9             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  HINGOLI 2020-07-01    12.0   9.781830
# 1  HINGOLI 2020-08-01    19.0  12.721253
# 2  HINGOLI 2020-09-01    14.0  15.660676
# 3  HINGOLI 2020-10-01    20.0  13.561088
# 4  HINGOLI 2020-11-01    12.0  16.080594
# === Metrics ===
#   district       rmse  r_squared  \
# 0  JALGAON  10.107893   0.301098
#
#                                     coefficients  intercept  final_alpha  \
# 0  [0.48510675097734, 0.0, 0.051325399420511494]    15.7521         10.0
#
#    final_l1_ratio  differencing  \
# 0             0.7             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  JALGAON 2020-07-01    21.0  31.719235
# 1  JALGAON 2020-08-01    25.0  27.941032
# 2  JALGAON 2020-09-01    41.0  29.368205
# 3  JALGAON 2020-10-01    37.0  36.719310
# 4  JALGAON 2020-11-01    39.0  34.984185
# === Metrics ===
#   district      rmse  r_squared                     coefficients  intercept  \
# 0    JALNA  6.247413   0.119483  [0.23151412101356114, 0.0, 0.0]  22.694003
#
#    final_alpha  final_l1_ratio  differencing  \
# 0         10.0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    JALNA 2020-07-01    38.0  28.944885
# 1    JALNA 2020-08-01    26.0  31.491540
# 2    JALNA 2020-09-01    25.0  28.713370
# 3    JALNA 2020-10-01    29.0  28.481856
# 4    JALNA 2020-11-01    20.0  29.407913
# === Metrics ===
#    district     rmse  r_squared  \
# 0  KOLHAPUR  7.54638   0.251504
#
#                                      coefficients  intercept  final_alpha  \
# 0  [0.3264528797555654, 0.0, 0.14825924337531662]  12.475517         10.0
#
#    final_l1_ratio  differencing  \
# 0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  KOLHAPUR 2020-07-01    23.0  24.551448
# 1  KOLHAPUR 2020-08-01    20.0  23.245637
# 2  KOLHAPUR 2020-09-01    16.0  23.007574
# 3  KOLHAPUR 2020-10-01    14.0  21.108726
# 4  KOLHAPUR 2020-11-01    15.0  20.011042
# === Metrics ===
#   district       rmse  r_squared  \
# 0    LATUR  16.987755   0.157142
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.31132932816706455, -0.18993006130965223, 0....   20.18172         10.0
#
#    final_l1_ratio  differencing  \
# 0             0.1             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    LATUR 2020-07-01    16.0  28.399616
# 1    LATUR 2020-08-01    58.0  18.552739
# 2    LATUR 2020-09-01    35.0  36.012308
# 3    LATUR 2020-10-01    38.0  20.413597
# 4    LATUR 2020-11-01    14.0  26.638124
# === Metrics ===
#   district       rmse  r_squared  \
# 0   MUMBAI  22.592465   0.315956
#
#                                         coefficients  intercept  final_alpha  \
# 0  [-0.558052987812594, -0.09166743355400075, 0.1...  -4.681015         10.0
#
#    final_l1_ratio  differencing  \
# 0             1.0             1
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   MUMBAI 2020-07-01      74  58.424688
# 1   MUMBAI 2020-08-01      66  54.322147
# 2   MUMBAI 2020-09-01      76  55.109573
# 3   MUMBAI 2020-10-01      90  45.034605
# 4   MUMBAI 2020-11-01      69  30.166143
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NAGPUR  16.471669    0.56515
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.27190284341100246, 0.6082147770398939, -0.1...  12.278459         10.0
#
#    final_l1_ratio  differencing  \
# 0             0.1             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NAGPUR 2020-07-01    50.0  72.874316
# 1   NAGPUR 2020-08-01    52.0  56.128279
# 2   NAGPUR 2020-09-01    35.0  50.144464
# 3   NAGPUR 2020-10-01    76.0  48.117718
# 4   NAGPUR 2020-11-01    33.0  48.713903
# === Metrics ===
#   district      rmse  r_squared  \
# 0   NANDED  13.31128   0.143619
#
#                                         coefficients  intercept  final_alpha  \
# 0  [-0.30439112657042544, -0.10471268043481438, 0...  -1.088379     7.278954
#
#    final_l1_ratio  differencing  \
# 0             0.3             1
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NANDED 2020-07-01      26  22.125646
# 1   NANDED 2020-08-01      32  21.404556
# 2   NANDED 2020-09-01      50  18.385118
# 3   NANDED 2020-10-01      21  11.256590
# 4   NANDED 2020-11-01      33  17.513734
# === Metrics ===
#     district      rmse  r_squared  \
# 0  NANDURBAR  9.065029   0.360151
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.6411860003389653, -0.05132789122793553, -0....  18.374871        0.001
#
#    final_l1_ratio  differencing  \
# 0             0.1             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  NANDURBAR 2020-07-01    42.0  35.209882
# 1  NANDURBAR 2020-08-01    48.0  42.002678
# 2  NANDURBAR 2020-09-01    52.0  45.388874
# 3  NANDURBAR 2020-10-01    44.0  47.075371
# 4  NANDURBAR 2020-11-01    56.0  41.429509
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NASHIK  16.328382   0.329801
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.5541216996383092, 0.029336982796121486, -0....  54.980726         10.0
#
#    final_l1_ratio  differencing  \
# 0             0.1             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NASHIK 2020-07-01    68.0   95.215391
# 1   NASHIK 2020-08-01    94.0   77.831857
# 2   NASHIK 2020-09-01   111.0   93.139163
# 3   NASHIK 2020-10-01    96.0  107.346720
# 4   NASHIK 2020-11-01    87.0   94.983932
# === Metrics ===
#     district      rmse  r_squared  \
# 0  OSMANABAD  6.368029   0.043106
#
#                                       coefficients  intercept  final_alpha  \
# 0  [0.009490028954405861, 0.0, 0.0689909386730897]  18.678165         10.0
#
#    final_l1_ratio  differencing  \
# 0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  OSMANABAD 2020-07-01    28.0  19.764848
# 1  OSMANABAD 2020-08-01    30.0  20.668660
# 2  OSMANABAD 2020-09-01    26.0  20.342685
# 3  OSMANABAD 2020-10-01    17.0  20.856652
# 4  OSMANABAD 2020-11-01    19.0  20.909224
# === Metrics ===
#   district       rmse  r_squared                      coefficients  intercept  \
# 0  PALGHAR  10.546623   0.079415  [-0.1691513611234837, 0.0, -0.0]  -0.080881
#
#    final_alpha  final_l1_ratio  differencing  \
# 0         10.0             1.0             1
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  PALGHAR 2020-07-01      45  34.287238
# 1  PALGHAR 2020-08-01      48  32.007389
# 2  PALGHAR 2020-09-01      33  31.419053
# 3  PALGHAR 2020-10-01      48  33.875442
# 4  PALGHAR 2020-11-01      42  31.257290
# === Metrics ===
#    district      rmse  r_squared  \
# 0  PARBHANI  8.971609   0.524548
#
#                                        coefficients  intercept  final_alpha  \
# 0  [0.6866711977769961, -0.0, -0.03311557951010894]   3.900898     0.788046
#
#    final_l1_ratio  differencing  \
# 0             0.9             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  PARBHANI 2020-07-01    11.0  12.430237
# 1  PARBHANI 2020-08-01    33.0  10.924432
# 2  PARBHANI 2020-09-01    18.0  26.130545
# 3  PARBHANI 2020-10-01    12.0  15.896709
# 4  PARBHANI 2020-11-01    21.0  11.048139
# === Metrics ===
#   district       rmse  r_squared  \
# 0     PUNE  48.060263   0.503413
#
#                                         coefficients  intercept  final_alpha  \
# 0  [-0.7757653777606319, -0.6394950981816977, -0....  -5.149888         10.0
#
#    final_l1_ratio  differencing  \
# 0             0.1             1
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     PUNE 2020-07-01      72  47.336609
# 1     PUNE 2020-08-01      69  37.604757
# 2     PUNE 2020-09-01      70  30.471026
# 3     PUNE 2020-10-01      58  22.130906
# 4     PUNE 2020-11-01      98  27.095025
# === Metrics ===
#   district      rmse  r_squared  \
# 0   RAIGAD  7.979311   0.466701
#
#                                      coefficients  intercept  final_alpha  \
# 0  [0.5104169231581356, 0.10679094841074041, 0.0]   9.545065         10.0
#
#    final_l1_ratio  differencing  \
# 0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   RAIGAD 2020-07-01    21.0  25.889304
# 1   RAIGAD 2020-08-01    29.0  23.147176
# 2   RAIGAD 2020-09-01    35.0  26.589765
# 3   RAIGAD 2020-10-01    32.0  30.506594
# 4   RAIGAD 2020-11-01    11.0  29.616089
# === Metrics ===
#     district      rmse  r_squared      coefficients  intercept  final_alpha  \
# 0  RATNAGIRI  6.470791        0.0  [0.0, 0.0, -0.0]  13.194444     7.278954
#
#    final_l1_ratio  differencing  \
# 0             0.9             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  RATNAGIRI 2020-07-01    23.0  13.194444
# 1  RATNAGIRI 2020-08-01    25.0  13.194444
# 2  RATNAGIRI 2020-09-01    22.0  13.194444
# 3  RATNAGIRI 2020-10-01    11.0  13.194444
# 4  RATNAGIRI 2020-11-01    19.0  13.194444
# === Metrics ===
#   district      rmse  r_squared      coefficients  intercept  final_alpha  \
# 0   SANGLI  8.272416        0.0  [0.0, -0.0, 0.0]  26.583333         10.0
#
#    final_l1_ratio  differencing  \
# 0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SANGLI 2020-07-01    24.0  26.583333
# 1   SANGLI 2020-08-01    16.0  26.583333
# 2   SANGLI 2020-09-01    13.0  26.583333
# 3   SANGLI 2020-10-01    28.0  26.583333
# 4   SANGLI 2020-11-01    34.0  26.583333
# === Metrics ===
#   district      rmse  r_squared                     coefficients  intercept  \
# 0   SATARA  7.040821    0.08731  [0.0, 0.14663774403470717, 0.0]  29.639913
#
#    final_alpha  final_l1_ratio  differencing  \
# 0         10.0             1.0             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SATARA 2020-07-01    40.0  35.212148
# 1   SATARA 2020-08-01    40.0  33.745770
# 2   SATARA 2020-09-01    49.0  35.505423
# 3   SATARA 2020-10-01    39.0  35.505423
# 4   SATARA 2020-11-01    40.0  36.825163
# === Metrics ===
#      district      rmse  r_squared  \
# 0  SINDHUDURG  2.764697   0.079616
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.0, -0.032185049417758335, -0.13972861621989...   6.876479     5.298317
#
#    final_l1_ratio  differencing  \
# 0             0.1             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#      district       date  actual  forecast
# 0  SINDHUDURG 2020-07-01     9.0  5.801823
# 1  SINDHUDURG 2020-08-01     3.0  6.167628
# 2  SINDHUDURG 2020-09-01    10.0  5.329256
# 3  SINDHUDURG 2020-10-01     4.0  5.522366
# 4  SINDHUDURG 2020-11-01     6.0  6.135443
# === Metrics ===
#   district       rmse  r_squared  \
# 0  SOLAPUR  45.015942   0.441995
#
#                                         coefficients  intercept  final_alpha  \
# 0  [-0.6846742178178962, -0.13108120960596678, 0....   -0.02687         10.0
#
#    final_l1_ratio  differencing  \
# 0             0.1             1
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  SOLAPUR 2020-07-01      28  45.838668
# 1  SOLAPUR 2020-08-01      25  60.775463
# 2  SOLAPUR 2020-09-01      17  64.040029
# 3  SOLAPUR 2020-10-01      18  67.477161
# 4  SOLAPUR 2020-11-01      24  67.389567
# === Metrics ===
#   district       rmse  r_squared  \
# 0    THANE  17.216445   0.086983
#
#                                         coefficients  intercept  final_alpha  \
# 0  [-0.2287803806185105, 0.046563906124175235, -0.0]  -0.294315         10.0
#
#    final_l1_ratio  differencing  \
# 0             1.0             1
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    THANE 2020-07-01      98  77.776997
# 1    THANE 2020-08-01      79  71.661966
# 2    THANE 2020-09-01      76  76.785448
# 3    THANE 2020-10-01      68  76.292760
# 4    THANE 2020-11-01      78  77.688996
# === Metrics ===
#   district      rmse  r_squared     coefficients  intercept  final_alpha  \
# 0   WARDHA  3.566065        0.0  [0.0, 0.0, 0.0]   8.305556         10.0
#
#    final_l1_ratio  differencing  \
# 0             0.5             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual  forecast
# 0   WARDHA 2020-07-01     4.0  8.305556
# 1   WARDHA 2020-08-01     6.0  8.305556
# 2   WARDHA 2020-09-01     9.0  8.305556
# 3   WARDHA 2020-10-01    16.0  8.305556
# 4   WARDHA 2020-11-01     7.0  8.305556
# === Metrics ===
#   district      rmse  r_squared  \
# 0   WASHIM  4.300689   0.119874
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.2369729364093347, -0.0596932721030658, -0.0...   7.838078      3.85662
#
#    final_l1_ratio  differencing  \
# 0             0.1             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   WASHIM 2020-07-01    13.0   9.033072
# 1   WASHIM 2020-08-01    18.0   8.912563
# 2   WASHIM 2020-09-01     7.0  10.454348
# 3   WASHIM 2020-10-01    10.0   7.390410
# 4   WASHIM 2020-11-01     5.0   8.361032
# === Metrics ===
#    district      rmse  r_squared  \
# 0  YAVATMAL  6.670737   0.401719
#
#                                         coefficients  intercept  final_alpha  \
# 0  [0.4576938721455352, 0.20232114033127488, -0.0...    4.44018     7.278954
#
#    final_l1_ratio  differencing  \
# 0             0.1             0
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  YAVATMAL 2020-07-01     3.0   5.805309
# 1  YAVATMAL 2020-08-01     7.0   5.752876
# 2  YAVATMAL 2020-09-01     8.0   8.207216
# 3  YAVATMAL 2020-10-01    23.0   9.386626
# 4  YAVATMAL 2020-11-01     6.0  16.279217
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# === Metrics ===
#           district      rmse  r_squared  \
# 0  MUMBAI SUBURBAN  2.107364    0.93842
#
#                                       coefficients  intercept  final_alpha  \
# 0  [-1.1044073202820268, -0.0, 0.3753937078040399]  -6.984349     1.082637
#
#    final_l1_ratio  differencing  \
# 0             0.3             1
#
#                                         alphas_tried  \
# 0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                 l1_ratios_tried
# 0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]
#
# === Forecast Data ===
#           district       date  actual   forecast
# 0  MUMBAI SUBURBAN 2021-02-01      28  25.152845
# 1  MUMBAI SUBURBAN 2021-03-01      28  28.880723
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual   forecast
#  0  MUMBAI SUBURBAN 2021-02-01      28  25.152845
#  1  MUMBAI SUBURBAN 2021-03-01      28  28.880723,
#  'metrics_df':           district      rmse  r_squared  \
#  0  MUMBAI SUBURBAN  2.107364    0.93842
#
#                                        coefficients  intercept  final_alpha  \
#  0  [-1.1044073202820268, -0.0, 0.3753937078040399]  -6.984349     1.082637
#
#     final_l1_ratio  differencing  \
#  0             0.3             1
#
#                                          alphas_tried  \
#  0  [0.001, 0.0013738237958832624, 0.0018873918221...
#
#                  l1_ratios_tried
#  0  [0.1, 0.3, 0.5, 0.7, 0.9, 1]  ,
#  'model_coefficients': array([-1.10440732, -0.        ,  0.37539371]),
#  'model_intercept': -6.9843488100225155,
#  'best_alpha': 1.0826367338740541,
#  'best_l1_ratio': 0.3}
