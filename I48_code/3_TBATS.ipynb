# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tbats import TBATS as TBATSModel
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def tbats_forecast_district(series, district_name, seasonal_periods=None, 
                           use_box_cox=None, use_arma_errors=True, n_jobs=1):
    """
    TBATS forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('TBATS', exist_ok=True)
    
    # 1. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 2. TBATS Model Configuration
    estimator = TBATSModel(
        seasonal_periods=seasonal_periods,
        use_box_cox=use_box_cox,
        use_arma_errors=use_arma_errors,
        n_jobs=n_jobs
    )
    
    # 3. Model Fitting
    fitted_model = estimator.fit(train.values)
    
    # 4. Forecasting
    forecast = fitted_model.forecast(steps=len(test))
    
    # 5. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast,
        'model_params': str(fitted_model.params)
    })

    # 6. Save forecasts to CSV
    forecast_csv_path = os.path.join('TBATS', 'tbats_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 7. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'seasonal_periods': str(seasonal_periods),
        'box_cox_used': fitted_model.params.components.use_box_cox,
        # 'arma_used': fitted_model.params.components.use_arma
        'arma_errors_used': fitted_model.params.components.use_arma_errors

    }])

    metrics_csv_path = os.path.join('TBATS', 'tbats_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 8. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(test.index, forecast, label='TBATS Forecast', color='darkorange')
    plt.title(f'TBATS Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('TBATS', f'TBATS_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_summary': fitted_model.summary()
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I40"].asfreq('MS')
        
        results = tbats_forecast_district(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  PARBHANI  6.841699             None          True             False
#
# === Forecast Data ===
#    district       date  actual   forecast  \
# 0  PARBHANI 2020-06-01      13  14.992671
# 1  PARBHANI 2020-07-01      11  14.992671
# 2  PARBHANI 2020-08-01      33  14.992671
# 3  PARBHANI 2020-09-01      18  14.992671
# 4  PARBHANI 2020-10-01      12  14.992671
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0     PUNE  39.403136             None         False             False
#
# === Forecast Data ===
#   district       date  actual   forecast  \
# 0     PUNE 2020-06-01      63  43.324334
# 1     PUNE 2020-07-01      72  39.959575
# 2     PUNE 2020-08-01      69  36.594817
# 3     PUNE 2020-09-01      70  33.230059
# 4     PUNE 2020-10-01      58  29.865300
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   RAIGAD  8.471186             None         False             False
#
# === Forecast Data ===
#   district       date  actual   forecast  \
# 0   RAIGAD 2020-06-01      27  18.840494
# 1   RAIGAD 2020-07-01      21  18.840494
# 2   RAIGAD 2020-08-01      29  18.840494
# 3   RAIGAD 2020-09-01      35  18.840494
# 4   RAIGAD 2020-10-01      32  18.840494
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  RATNAGIRI  5.884242             None         False             False
#
# === Forecast Data ===
#     district       date  actual   forecast  \
# 0  RATNAGIRI 2020-06-01      14  13.885763
# 1  RATNAGIRI 2020-07-01      23  13.885763
# 2  RATNAGIRI 2020-08-01      25  13.885763
# 3  RATNAGIRI 2020-09-01      22  13.885763
# 4  RATNAGIRI 2020-10-01      11  13.885763
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   SANGLI  9.437454             None         False             False
#
# === Forecast Data ===
#   district       date  actual   forecast  \
# 0   SANGLI 2020-06-01      15  28.723450
# 1   SANGLI 2020-07-01      24  28.454617
# 2   SANGLI 2020-08-01      16  28.236773
# 3   SANGLI 2020-09-01      13  28.060249
# 4   SANGLI 2020-10-01      28  27.917206
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   SATARA  7.436639             None         False             False
#
# === Forecast Data ===
#   district       date  actual   forecast  \
# 0   SATARA 2020-06-01      28  33.485381
# 1   SATARA 2020-07-01      40  33.478331
# 2   SATARA 2020-08-01      40  33.471864
# 3   SATARA 2020-09-01      49  33.465932
# 4   SATARA 2020-10-01      39  33.460491
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  SINDHUDURG  2.625102             None         False             False
#
# === Forecast Data ===
#      district       date  actual  forecast  \
# 0  SINDHUDURG 2020-06-01       9   6.13407
# 1  SINDHUDURG 2020-07-01       9   6.13407
# 2  SINDHUDURG 2020-08-01       3   6.13407
# 3  SINDHUDURG 2020-09-01      10   6.13407
# 4  SINDHUDURG 2020-10-01       4   6.13407
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  SOLAPUR  23.850503             None         False             False
#
# === Forecast Data ===
#   district       date  actual   forecast  \
# 0  SOLAPUR 2020-06-01      45  44.141165
# 1  SOLAPUR 2020-07-01      28  44.141165
# 2  SOLAPUR 2020-08-01      25  44.141165
# 3  SOLAPUR 2020-09-01      17  44.141165
# 4  SOLAPUR 2020-10-01      18  44.141165
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    THANE  21.271827             None          True             False
#
# === Forecast Data ===
#   district       date  actual  forecast  \
# 0    THANE 2020-06-01      75  85.66294
# 1    THANE 2020-07-01      98  85.66294
# 2    THANE 2020-08-01      79  85.66294
# 3    THANE 2020-09-01      76  85.66294
# 4    THANE 2020-10-01      68  85.66294
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WARDHA  3.767895             None         False             False
#
# === Forecast Data ===
#   district       date  actual  forecast  \
# 0   WARDHA 2020-06-01       9  6.327568
# 1   WARDHA 2020-07-01       4  6.327568
# 2   WARDHA 2020-08-01       6  6.327568
# 3   WARDHA 2020-09-01       9  6.327568
# 4   WARDHA 2020-10-01      16  6.327568
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WASHIM  4.029325             None         False              True
#
# === Forecast Data ===
#   district       date  actual   forecast  \
# 0   WASHIM 2020-06-01      11  12.806495
# 1   WASHIM 2020-07-01      13   9.133723
# 2   WASHIM 2020-08-01      18   9.133723
# 3   WASHIM 2020-09-01       7   9.133723
# 4   WASHIM 2020-10-01      10   9.133723
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  YAVATMAL  5.912422             None          True             False
#
# === Forecast Data ===
#    district       date  actual  forecast  \
# 0  YAVATMAL 2020-06-01       1  7.053831
# 1  YAVATMAL 2020-07-01       3  7.053831
# 2  YAVATMAL 2020-08-01       7  7.053831
# 3  YAVATMAL 2020-09-01       8  7.053831
# 4  YAVATMAL 2020-10-01      23  7.053831
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#           district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  MUMBAI SUBURBAN  22.125937             None         False             False
#
# === Forecast Data ===
#           district       date  actual   forecast  \
# 0  MUMBAI SUBURBAN 2021-01-01      36  52.468843
# 1  MUMBAI SUBURBAN 2021-02-01      28  52.468843
# 2  MUMBAI SUBURBAN 2021-03-01      28  52.468843
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual   forecast  \
#  0  MUMBAI SUBURBAN 2021-01-01      36  52.468843
#  1  MUMBAI SUBURBAN 2021-02-01      28  52.468843
#  2  MUMBAI SUBURBAN 2021-03-01      28  52.468843
#
#                                          model_params
#  0  <tbats.tbats.ModelParams.ModelParams object at...
#  1  <tbats.tbats.ModelParams.ModelParams object at...
#  2  <tbats.tbats.ModelParams.ModelParams object at...  ,
#  'metrics_df':           district       rmse seasonal_periods  box_cox_used  arma_errors_used
#  0  MUMBAI SUBURBAN  22.125937             None         False             False,
#  'model_summary': 'Use Box-Cox: False\nUse trend: False\nUse damped trend: False\nSeasonal periods: []\nSeasonal harmonics []\nARMA errors (p, q): (0, 0)\nSmoothing (Alpha): -0.010000\nSeasonal Parameters (Gamma): []\nAR coefficients []\nMA coefficients []\nSeed vector [52.44080639]\n\nAIC 66.412339'}
