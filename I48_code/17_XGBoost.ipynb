# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from xgboost import XGBRegressor

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def xgboost_forecast_lags(
    series,
    district_name,
    max_lags=12,
    differencing=True,
    use_cv=True,
    cv_params=None,
    custom_params=None
):
    """
    XGBoost time series forecasting with error handling
    Returns (None, None) if insufficient data, allowing pipeline continuation
    """
    try:
        # 1. Directory setup
        os.makedirs('XGBoost_Forecasts', exist_ok=True)
        
        # 2. Stationarity and differencing
        original_series = series.copy()
        d = 0
        if differencing:
            adf_result = adfuller(series.dropna())
            if adf_result[1] > 0.05:
                d = 1
                series = series.diff().dropna()
                if len(series) < 5:  # Check after differencing
                    raise ValueError(f"Series too short after differencing: {len(series)}")

        # 3. Create lag features with validation
        df = pd.DataFrame({'y': series.astype(float)})
        for lag in range(1, max_lags + 1):
            df[f'lag_{lag}'] = df['y'].shift(lag)
        df = df.dropna()
        
        if len(df) < 10:
            raise ValueError(f"Only {len(df)} samples after lag features")

        # 4. Temporal split validation
        train_size = int(len(df) * 0.8)
        if train_size < 5 or (len(df) - train_size) < 2:
            raise ValueError(f"Insufficient split: {train_size} train, {len(df)-train_size} test")
            
        train = df.iloc[:train_size]
        test = df.iloc[train_size:]

        X_train = train.drop(columns=['y'])
        y_train = train['y']
        X_test = test.drop(columns=['y'])
        y_test = test['y']

        # 5. Dynamic cross-validation setup
        xgb_params = custom_params or {
            'n_estimators': 500,
            'learning_rate': 0.05,
            'max_depth': 3,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': 42
        }
        
        if use_cv:
            n_splits = min(5, max(2, len(X_train)//2))  # Ensure 2 ≤ splits ≤5
            param_grid = cv_params or {
                'n_estimators': [100, 300],
                'learning_rate': [0.01, 0.05],
                'max_depth': [3, 5]
            }
            tscv = TimeSeriesSplit(n_splits=n_splits)
            
            grid_search = GridSearchCV(
                XGBRegressor(**xgb_params, verbosity=0),
                param_grid,
                cv=tscv,
                scoring='neg_mean_squared_error',
                n_jobs=-1
            )
            grid_search.fit(X_train, y_train)
            model = grid_search.best_estimator_
            best_params = grid_search.best_params_
        else:
            model = XGBRegressor(**xgb_params, verbosity=0)
            model.fit(X_train, y_train)
            best_params = xgb_params

        # 6. Forecasting and post-processing
        pred_test = model.predict(X_test)

        if d == 1:
            last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
            pred_test = np.cumsum(pred_test) + last_train_value
            y_test = original_series.iloc[-len(test):]

        # 7. Save results
        forecast_df = pd.DataFrame({
            'district': district_name,
            'date': y_test.index,
            'actual': y_test.values,
            'forecast': pred_test
        })
        forecast_df.to_csv(
            os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.csv'), 
            index=False
        )

        # 8. Metrics and visualization
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        
        plt.figure(figsize=(14, 7))
        plt.plot(original_series.index, original_series, label='Original')
        plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', alpha=0.7)
        plt.title(f'{district_name} Forecast (RMSE: {rmse:.2f})')
        plt.legend()
        plt.savefig(os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.png'))
        plt.close()

        return {
            'district': district_name,
            'rmse': rmse,
            'best_params': best_params,
            'differencing': d,
            'feature_importances': dict(zip(X_train.columns, model.feature_importances_))
        }, forecast_df

    except (ValueError, IndexError) as e:
        print(f"⚠️ Skipping {district_name}: {str(e)}")
        return None, None

# %%
districts = data['district'].unique()
rmse_values = []

# Usage Example


def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I40"].asfreq('MS')
        
        results, forecast = xgboost_forecast_lags(
            series=ts,  # pd.Series with DatetimeIndex
            district_name=district,
            max_lags=6,
            use_cv=True,
            cv_params={
                'n_estimators': [200, 500],
                'learning_rate': [0.05, 0.1],
                'max_depth': [3, 5]
            },
            custom_params={
                'subsample': 0.8,
                'colsample_bytree': 0.8,
                'random_state': 42
            }
        )

        
    
        # Show results
        print("=== Metrics ===")
        print(results)
        print("\n=== Forecast Data ===")
        print(forecast)
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
# {'district': 'AHMEDNAGAR', 'rmse': 19.84564083372177, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.17501973, 'lag_2': 0.1455218, 'lag_3': 0.12839392, 'lag_4': 0.2796089, 'lag_5': 0.17414103, 'lag_6': 0.09731462}}
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AHMEDNAGAR 2020-07-01    40.0  34.499107
# 1  AHMEDNAGAR 2020-08-01    55.0  39.973694
# 2  AHMEDNAGAR 2020-09-01    36.0  49.240891
# 3  AHMEDNAGAR 2020-10-01    82.0  31.536564
# 4  AHMEDNAGAR 2020-11-01    49.0  38.915791
# 5  AHMEDNAGAR 2020-12-01    36.0  43.764366
# 6  AHMEDNAGAR 2021-01-01    45.0  44.570454
# 7  AHMEDNAGAR 2021-02-01    28.0  37.221279
# 8  AHMEDNAGAR 2021-03-01    28.0  45.875198
# === Metrics ===
# {'district': 'AKOLA', 'rmse': 12.157113755240351, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.23141511, 'lag_2': 0.12661734, 'lag_3': 0.12427634, 'lag_4': 0.14845659, 'lag_5': 0.1124972, 'lag_6': 0.25673735}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    AKOLA 2020-07-01    34.0  41.882824
# 1    AKOLA 2020-08-01    45.0  48.517117
# 2    AKOLA 2020-09-01    54.0  46.998363
# 3    AKOLA 2020-10-01    48.0  50.758312
# 4    AKOLA 2020-11-01    39.0  43.816757
# 5    AKOLA 2020-12-01    33.0  51.108986
# 6    AKOLA 2021-01-01    31.0  46.750717
# 7    AKOLA 2021-02-01    26.0  48.575153
# 8    AKOLA 2021-03-01    33.0  42.495228
# === Metrics ===
# {'district': 'AMRAVATI', 'rmse': 17.263913144906436, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.14945738, 'lag_2': 0.14192824, 'lag_3': 0.17979956, 'lag_4': 0.19064347, 'lag_5': 0.23010452, 'lag_6': 0.10806676}}
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  AMRAVATI 2020-07-01    62.0  55.903709
# 1  AMRAVATI 2020-08-01    70.0  59.866734
# 2  AMRAVATI 2020-09-01    98.0  66.684608
# 3  AMRAVATI 2020-10-01    55.0  61.011425
# 4  AMRAVATI 2020-11-01    45.0  63.555862
# 5  AMRAVATI 2020-12-01    54.0  45.628609
# 6  AMRAVATI 2021-01-01    41.0  52.881306
# 7  AMRAVATI 2021-02-01    32.0  58.332275
# 8  AMRAVATI 2021-03-01    43.0  59.637039
# === Metrics ===
# {'district': 'AURANGABAD', 'rmse': 22.522848266895608, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.17165269, 'lag_2': 0.09670296, 'lag_3': 0.12382468, 'lag_4': 0.13808018, 'lag_5': 0.14323281, 'lag_6': 0.3265067}}
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AURANGABAD 2020-07-01      53  63.546947
# 1  AURANGABAD 2020-08-01      74  73.253876
# 2  AURANGABAD 2020-09-01      76  68.142288
# 3  AURANGABAD 2020-10-01      56  74.875160
# 4  AURANGABAD 2020-11-01      57  79.565536
# 5  AURANGABAD 2020-12-01      71  83.062813
# 6  AURANGABAD 2021-01-01      69  73.729935
# 7  AURANGABAD 2021-02-01      40  73.535881
# 8  AURANGABAD 2021-03-01      40  87.264740
# === Metrics ===
# {'district': 'BEED', 'rmse': 11.31168300441967, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.26115382, 'lag_2': 0.08247646, 'lag_3': 0.13243268, 'lag_4': 0.29018748, 'lag_5': 0.11817501, 'lag_6': 0.11557459}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     BEED 2020-07-01    30.0  23.262760
# 1     BEED 2020-08-01    30.0  26.600983
# 2     BEED 2020-09-01    33.0  26.516426
# 3     BEED 2020-10-01    16.0  29.148430
# 4     BEED 2020-11-01    18.0  19.869932
# 5     BEED 2020-12-01    11.0  23.697563
# 6     BEED 2021-01-01    19.0  22.954424
# 7     BEED 2021-02-01    11.0  26.077679
# 8     BEED 2021-03-01    14.0  35.726189
# === Metrics ===
# {'district': 'BHANDARA', 'rmse': 5.054288149007776, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.18990138, 'lag_2': 0.10380771, 'lag_3': 0.1309587, 'lag_4': 0.16106299, 'lag_5': 0.21247765, 'lag_6': 0.20179155}}
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BHANDARA 2020-07-01    19.0  16.362885
# 1  BHANDARA 2020-08-01    22.0  24.084728
# 2  BHANDARA 2020-09-01    28.0  22.763985
# 3  BHANDARA 2020-10-01    22.0  27.824495
# 4  BHANDARA 2020-11-01    25.0  18.180040
# 5  BHANDARA 2020-12-01    28.0  25.823645
# 6  BHANDARA 2021-01-01    19.0  24.045053
# 7  BHANDARA 2021-02-01    19.0  14.227955
# 8  BHANDARA 2021-03-01    21.0  13.397498
# === Metrics ===
# {'district': 'BULDHANA', 'rmse': 6.26301692907589, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.13684377, 'lag_2': 0.20820773, 'lag_3': 0.21023121, 'lag_4': 0.18318751, 'lag_5': 0.14048724, 'lag_6': 0.12104249}}
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BULDHANA 2020-07-01      31  23.768240
# 1  BULDHANA 2020-08-01      25  15.665339
# 2  BULDHANA 2020-09-01      17  24.667860
# 3  BULDHANA 2020-10-01      19  27.106096
# 4  BULDHANA 2020-11-01      24  24.624636
# 5  BULDHANA 2020-12-01      19  22.750807
# 6  BULDHANA 2021-01-01      18  26.527523
# 7  BULDHANA 2021-02-01      24  24.394592
# 8  BULDHANA 2021-03-01      20  18.674774
# === Metrics ===
# {'district': 'CHANDRAPUR', 'rmse': 16.667934278773895, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.19553426, 'lag_2': 0.116047956, 'lag_3': 0.11067679, 'lag_4': 0.08722448, 'lag_5': 0.13184397, 'lag_6': 0.35867253}}
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  CHANDRAPUR 2020-07-01    41.0  44.510303
# 1  CHANDRAPUR 2020-08-01    37.0  37.331253
# 2  CHANDRAPUR 2020-09-01    44.0  40.638313
# 3  CHANDRAPUR 2020-10-01    67.0  41.479527
# 4  CHANDRAPUR 2020-11-01    47.0  47.161343
# 5  CHANDRAPUR 2020-12-01    35.0  49.699181
# 6  CHANDRAPUR 2021-01-01    23.0  36.314548
# 7  CHANDRAPUR 2021-02-01    19.0  45.522690
# 8  CHANDRAPUR 2021-03-01    27.0  53.991306
# === Metrics ===
# {'district': 'DHULE', 'rmse': 8.869662513544702, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.28894356, 'lag_2': 0.075589284, 'lag_3': 0.21955647, 'lag_4': 0.19755897, 'lag_5': 0.038859192, 'lag_6': 0.17949249}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    DHULE 2020-07-01    24.0  21.104582
# 1    DHULE 2020-08-01    31.0  40.481251
# 2    DHULE 2020-09-01    27.0  41.043480
# 3    DHULE 2020-10-01    50.0  40.701038
# 4    DHULE 2020-11-01    25.0  40.018867
# 5    DHULE 2020-12-01    33.0  35.330254
# 6    DHULE 2021-01-01    34.0  41.505421
# 7    DHULE 2021-02-01    47.0  51.307480
# 8    DHULE 2021-03-01    44.0  39.506844
# === Metrics ===
# {'district': 'GADCHIROLI', 'rmse': 8.939429732767286, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.26783088, 'lag_2': 0.09575604, 'lag_3': 0.081024334, 'lag_4': 0.1350692, 'lag_5': 0.2269583, 'lag_6': 0.19336125}}
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  GADCHIROLI 2020-07-01    46.0  31.658594
# 1  GADCHIROLI 2020-08-01    44.0  34.729286
# 2  GADCHIROLI 2020-09-01    44.0  38.509670
# 3  GADCHIROLI 2020-10-01    41.0  25.926273
# 4  GADCHIROLI 2020-11-01    40.0  31.128220
# 5  GADCHIROLI 2020-12-01    35.0  29.741045
# 6  GADCHIROLI 2021-01-01    26.0  29.253807
# 7  GADCHIROLI 2021-02-01    25.0  21.999617
# 8  GADCHIROLI 2021-03-01    17.0  23.654545
# === Metrics ===
# {'district': 'GONDIA', 'rmse': 6.582258442103575, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.35249954, 'lag_2': 0.067085885, 'lag_3': 0.13750263, 'lag_4': 0.11460543, 'lag_5': 0.20738049, 'lag_6': 0.12092597}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   GONDIA 2020-07-01    23.0  20.566391
# 1   GONDIA 2020-08-01    21.0  22.828629
# 2   GONDIA 2020-09-01    28.0  29.846979
# 3   GONDIA 2020-10-01    39.0  25.599535
# 4   GONDIA 2020-11-01    30.0  24.756493
# 5   GONDIA 2020-12-01    23.0  20.219355
# 6   GONDIA 2021-01-01    17.0  27.941118
# 7   GONDIA 2021-02-01    14.0  20.537226
# 8   GONDIA 2021-03-01    16.0  15.876472
# === Metrics ===
# {'district': 'HINGOLI', 'rmse': 6.321506568991644, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.25596848, 'lag_2': 0.14555962, 'lag_3': 0.1050654, 'lag_4': 0.2162352, 'lag_5': 0.1326712, 'lag_6': 0.1445}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  HINGOLI 2020-07-01    12.0   7.913943
# 1  HINGOLI 2020-08-01    19.0   7.215856
# 2  HINGOLI 2020-09-01    14.0  16.129454
# 3  HINGOLI 2020-10-01    20.0  11.008874
# 4  HINGOLI 2020-11-01    12.0  17.060934
# 5  HINGOLI 2020-12-01    13.0   6.805472
# 6  HINGOLI 2021-01-01     8.0  13.856535
# 7  HINGOLI 2021-02-01    12.0  10.694726
# 8  HINGOLI 2021-03-01    16.0  11.672391
# === Metrics ===
# {'district': 'JALGAON', 'rmse': 15.77623332443617, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.20860818, 'lag_2': 0.105636, 'lag_3': 0.22284847, 'lag_4': 0.090817004, 'lag_5': 0.14888377, 'lag_6': 0.22320656}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  JALGAON 2020-07-01    21.0  39.497662
# 1  JALGAON 2020-08-01    25.0  32.278255
# 2  JALGAON 2020-09-01    41.0  33.826084
# 3  JALGAON 2020-10-01    37.0  33.809109
# 4  JALGAON 2020-11-01    39.0  39.606182
# 5  JALGAON 2020-12-01    17.0  54.842319
# 6  JALGAON 2021-01-01    24.0  34.430225
# 7  JALGAON 2021-02-01    16.0  30.273102
# 8  JALGAON 2021-03-01    16.0  22.188931
# === Metrics ===
# {'district': 'JALNA', 'rmse': 7.172411661024667, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.2769619, 'lag_2': 0.14097299, 'lag_3': 0.12151074, 'lag_4': 0.16847312, 'lag_5': 0.13369738, 'lag_6': 0.15838389}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    JALNA 2020-07-01    38.0  24.162457
# 1    JALNA 2020-08-01    26.0  35.310516
# 2    JALNA 2020-09-01    25.0  24.626106
# 3    JALNA 2020-10-01    29.0  27.590498
# 4    JALNA 2020-11-01    20.0  29.845932
# 5    JALNA 2020-12-01    25.0  25.496311
# 6    JALNA 2021-01-01    29.0  29.776237
# 7    JALNA 2021-02-01    18.0  27.200497
# 8    JALNA 2021-03-01    26.0  25.488924
# === Metrics ===
# {'district': 'KOLHAPUR', 'rmse': 11.542225138912588, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.19357118, 'lag_2': 0.13637842, 'lag_3': 0.18637529, 'lag_4': 0.16076796, 'lag_5': 0.1914664, 'lag_6': 0.13144079}}
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  KOLHAPUR 2020-07-01    23.0  20.678738
# 1  KOLHAPUR 2020-08-01    20.0  23.081528
# 2  KOLHAPUR 2020-09-01    16.0  33.530743
# 3  KOLHAPUR 2020-10-01    14.0  24.078264
# 4  KOLHAPUR 2020-11-01    15.0  28.700748
# 5  KOLHAPUR 2020-12-01    20.0  22.514488
# 6  KOLHAPUR 2021-01-01    40.0  20.410614
# 7  KOLHAPUR 2021-02-01    29.0  30.494041
# 8  KOLHAPUR 2021-03-01    21.0  34.971931
# === Metrics ===
# {'district': 'LATUR', 'rmse': 15.390190209773518, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.1747766, 'lag_2': 0.2302285, 'lag_3': 0.09083751, 'lag_4': 0.22094826, 'lag_5': 0.16415112, 'lag_6': 0.11905799}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    LATUR 2020-07-01    16.0  23.126669
# 1    LATUR 2020-08-01    58.0  25.980711
# 2    LATUR 2020-09-01    35.0  28.488085
# 3    LATUR 2020-10-01    38.0  22.554020
# 4    LATUR 2020-11-01    14.0  24.326887
# 5    LATUR 2020-12-01    17.0  20.296694
# 6    LATUR 2021-01-01    10.0  30.590036
# 7    LATUR 2021-02-01    25.0  24.848595
# 8    LATUR 2021-03-01    12.0  27.271826
# === Metrics ===
# {'district': 'MUMBAI', 'rmse': 42.14713663652291, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.2724282, 'lag_2': 0.03752785, 'lag_3': 0.095564745, 'lag_4': 0.23192288, 'lag_5': 0.10562444, 'lag_6': 0.2569318}}
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   MUMBAI 2020-07-01      74   55.899017
# 1   MUMBAI 2020-08-01      66   81.852905
# 2   MUMBAI 2020-09-01      76   61.105076
# 3   MUMBAI 2020-10-01      90   66.655495
# 4   MUMBAI 2020-11-01      69   71.802223
# 5   MUMBAI 2020-12-01      46   71.489174
# 6   MUMBAI 2021-01-01      54   94.191666
# 7   MUMBAI 2021-02-01      41  126.260460
# 8   MUMBAI 2021-03-01      50  121.409935
# === Metrics ===
# {'district': 'NAGPUR', 'rmse': 11.932834126282547, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.1691223, 'lag_2': 0.36827984, 'lag_3': 0.08295704, 'lag_4': 0.14413641, 'lag_5': 0.08899546, 'lag_6': 0.14650895}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NAGPUR 2020-07-01    50.0  60.418343
# 1   NAGPUR 2020-08-01    52.0  57.917622
# 2   NAGPUR 2020-09-01    35.0  36.075020
# 3   NAGPUR 2020-10-01    76.0  57.308842
# 4   NAGPUR 2020-11-01    33.0  34.070839
# 5   NAGPUR 2020-12-01    49.0  68.401131
# 6   NAGPUR 2021-01-01    48.0  48.349117
# 7   NAGPUR 2021-02-01    50.0  43.396358
# 8   NAGPUR 2021-03-01    32.0  51.135754
# === Metrics ===
# {'district': 'NANDED', 'rmse': 23.56427200023253, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.31131673, 'lag_2': 0.19632713, 'lag_3': 0.10734317, 'lag_4': 0.21408582, 'lag_5': 0.120480135, 'lag_6': 0.050447017}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NANDED 2020-07-01      26  18.849270
# 1   NANDED 2020-08-01      32  29.904396
# 2   NANDED 2020-09-01      50  26.219376
# 3   NANDED 2020-10-01      21   3.595512
# 4   NANDED 2020-11-01      33   2.712946
# 5   NANDED 2020-12-01      22  -5.106607
# 6   NANDED 2021-01-01      25  -5.340363
# 7   NANDED 2021-02-01      18  -8.038040
# 8   NANDED 2021-03-01      21  -7.686661
# === Metrics ===
# {'district': 'NANDURBAR', 'rmse': 9.250211339248695, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.06834741, 'lag_2': 0.064005375, 'lag_3': 0.111921445, 'lag_4': 0.10208376, 'lag_5': 0.2967689, 'lag_6': 0.3568731}}
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  NANDURBAR 2020-07-01    42.0  37.269432
# 1  NANDURBAR 2020-08-01    48.0  42.627892
# 2  NANDURBAR 2020-09-01    52.0  42.178978
# 3  NANDURBAR 2020-10-01    44.0  48.415485
# 4  NANDURBAR 2020-11-01    56.0  45.863224
# 5  NANDURBAR 2020-12-01    37.0  45.595474
# 6  NANDURBAR 2021-01-01    30.0  38.234016
# 7  NANDURBAR 2021-02-01    19.0  36.138664
# 8  NANDURBAR 2021-03-01    26.0  34.046219
# === Metrics ===
# {'district': 'NASHIK', 'rmse': 16.341153425737975, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.19349198, 'lag_2': 0.09736053, 'lag_3': 0.17767449, 'lag_4': 0.17607751, 'lag_5': 0.18025225, 'lag_6': 0.17514327}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   NASHIK 2020-07-01    68.0  98.339546
# 1   NASHIK 2020-08-01    94.0  74.299469
# 2   NASHIK 2020-09-01   111.0  94.295486
# 3   NASHIK 2020-10-01    96.0  89.951759
# 4   NASHIK 2020-11-01    87.0  91.708488
# 5   NASHIK 2020-12-01    83.0  78.997078
# 6   NASHIK 2021-01-01    66.0  81.691101
# 7   NASHIK 2021-02-01    62.0  66.959015
# 8   NASHIK 2021-03-01    64.0  85.681396
# === Metrics ===
# {'district': 'OSMANABAD', 'rmse': 6.63597588257736, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.10569705, 'lag_2': 0.21077016, 'lag_3': 0.23125347, 'lag_4': 0.16640383, 'lag_5': 0.20279945, 'lag_6': 0.08307613}}
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  OSMANABAD 2020-07-01    28.0  15.462887
# 1  OSMANABAD 2020-08-01    30.0  19.823202
# 2  OSMANABAD 2020-09-01    26.0  19.216742
# 3  OSMANABAD 2020-10-01    17.0  20.040817
# 4  OSMANABAD 2020-11-01    19.0  21.618517
# 5  OSMANABAD 2020-12-01    14.0  18.102049
# 6  OSMANABAD 2021-01-01    16.0  19.127642
# 7  OSMANABAD 2021-02-01    12.0  18.631844
# 8  OSMANABAD 2021-03-01    14.0  15.695013
# === Metrics ===
# {'district': 'PALGHAR', 'rmse': 16.250355051174164, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.21749084, 'lag_2': 0.05506306, 'lag_3': 0.15422794, 'lag_4': 0.117226705, 'lag_5': 0.29379073, 'lag_6': 0.16220073}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  PALGHAR 2020-07-01      45  33.396389
# 1  PALGHAR 2020-08-01      48  20.061285
# 2  PALGHAR 2020-09-01      33  21.737577
# 3  PALGHAR 2020-10-01      48  21.014076
# 4  PALGHAR 2020-11-01      42  19.913780
# 5  PALGHAR 2020-12-01      26  20.716026
# 6  PALGHAR 2021-01-01      26  20.150404
# 7  PALGHAR 2021-02-01      28  23.154568
# 8  PALGHAR 2021-03-01      22  27.740301
# === Metrics ===
# {'district': 'PARBHANI', 'rmse': 8.315246869333354, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.4259746, 'lag_2': 0.1426665, 'lag_3': 0.088885, 'lag_4': 0.06383192, 'lag_5': 0.07554906, 'lag_6': 0.2030929}}
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  PARBHANI 2020-07-01    11.0  13.731677
# 1  PARBHANI 2020-08-01    33.0  11.559155
# 2  PARBHANI 2020-09-01    18.0  16.665934
# 3  PARBHANI 2020-10-01    12.0  17.053307
# 4  PARBHANI 2020-11-01    21.0  12.850261
# 5  PARBHANI 2020-12-01    16.0  17.945269
# 6  PARBHANI 2021-01-01     8.0  14.408113
# 7  PARBHANI 2021-02-01    11.0  11.129991
# 8  PARBHANI 2021-03-01    13.0   8.935608
# === Metrics ===
# {'district': 'PUNE', 'rmse': 72.59592632128954, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.21813375, 'lag_2': 0.107370704, 'lag_3': 0.13372202, 'lag_4': 0.28558785, 'lag_5': 0.08636097, 'lag_6': 0.16882466}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     PUNE 2020-07-01      72  19.233257
# 1     PUNE 2020-08-01      69  29.801071
# 2     PUNE 2020-09-01      70  19.187916
# 3     PUNE 2020-10-01      58  -9.308266
# 4     PUNE 2020-11-01      98   4.457878
# 5     PUNE 2020-12-01      61 -16.881393
# 6     PUNE 2021-01-01      56  -1.242867
# 7     PUNE 2021-02-01      68 -43.721100
# 8     PUNE 2021-03-01      33 -40.650330
# === Metrics ===
# {'district': 'RAIGAD', 'rmse': 7.832075318406553, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.42455938, 'lag_2': 0.18135388, 'lag_3': 0.079055674, 'lag_4': 0.15024903, 'lag_5': 0.073574, 'lag_6': 0.091207966}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   RAIGAD 2020-07-01    21.0  27.214676
# 1   RAIGAD 2020-08-01    29.0  23.941305
# 2   RAIGAD 2020-09-01    35.0  26.079443
# 3   RAIGAD 2020-10-01    32.0  19.221861
# 4   RAIGAD 2020-11-01    11.0  16.609915
# 5   RAIGAD 2020-12-01    25.0  17.074730
# 6   RAIGAD 2021-01-01    20.0  18.148071
# 7   RAIGAD 2021-02-01    16.0  20.526955
# 8   RAIGAD 2021-03-01    19.0  30.260500
# === Metrics ===
# {'district': 'RATNAGIRI', 'rmse': 6.7039708277331895, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.11428942, 'lag_2': 0.12815654, 'lag_3': 0.13373314, 'lag_4': 0.18137631, 'lag_5': 0.116486676, 'lag_6': 0.32595792}}
#
# === Forecast Data ===
#     district       date  actual   forecast
# 0  RATNAGIRI 2020-07-01    23.0  12.053142
# 1  RATNAGIRI 2020-08-01    25.0  13.030291
# 2  RATNAGIRI 2020-09-01    22.0  14.106720
# 3  RATNAGIRI 2020-10-01    11.0  12.354757
# 4  RATNAGIRI 2020-11-01    19.0  14.916604
# 5  RATNAGIRI 2020-12-01    10.0  12.543899
# 6  RATNAGIRI 2021-01-01    10.0  16.773941
# 7  RATNAGIRI 2021-02-01    11.0  12.836010
# 8  RATNAGIRI 2021-03-01    13.0  10.800140
# === Metrics ===
# {'district': 'SANGLI', 'rmse': 9.47764227353699, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.10212632, 'lag_2': 0.13782223, 'lag_3': 0.1769264, 'lag_4': 0.25322428, 'lag_5': 0.17033912, 'lag_6': 0.15956163}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SANGLI 2020-07-01    24.0  29.175003
# 1   SANGLI 2020-08-01    16.0  27.496861
# 2   SANGLI 2020-09-01    13.0  29.886559
# 3   SANGLI 2020-10-01    28.0  29.937624
# 4   SANGLI 2020-11-01    34.0  36.993000
# 5   SANGLI 2020-12-01    24.0  27.191154
# 6   SANGLI 2021-01-01    38.0  29.786150
# 7   SANGLI 2021-02-01    16.0  32.501160
# 8   SANGLI 2021-03-01    24.0  22.709455
# === Metrics ===
# {'district': 'SATARA', 'rmse': 6.651128417893939, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.15597302, 'lag_2': 0.1905412, 'lag_3': 0.2429825, 'lag_4': 0.13710576, 'lag_5': 0.11503464, 'lag_6': 0.1583629}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SATARA 2020-07-01    40.0  36.694260
# 1   SATARA 2020-08-01    40.0  32.553368
# 2   SATARA 2020-09-01    49.0  37.693554
# 3   SATARA 2020-10-01    39.0  37.366180
# 4   SATARA 2020-11-01    40.0  36.520844
# 5   SATARA 2020-12-01    24.0  35.740124
# 6   SATARA 2021-01-01    32.0  30.647549
# 7   SATARA 2021-02-01    30.0  25.555906
# 8   SATARA 2021-03-01    29.0  34.453266
# === Metrics ===
# {'district': 'SINDHUDURG', 'rmse': 3.1246465837003576, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.18539397, 'lag_2': 0.14929119, 'lag_3': 0.13958429, 'lag_4': 0.2272325, 'lag_5': 0.14064893, 'lag_6': 0.1578491}}
#
# === Forecast Data ===
#      district       date  actual  forecast
# 0  SINDHUDURG 2020-07-01     9.0  7.703757
# 1  SINDHUDURG 2020-08-01     3.0  8.228384
# 2  SINDHUDURG 2020-09-01    10.0  6.468270
# 3  SINDHUDURG 2020-10-01     4.0  5.842745
# 4  SINDHUDURG 2020-11-01     6.0  4.433914
# 5  SINDHUDURG 2020-12-01     7.0  4.033697
# 6  SINDHUDURG 2021-01-01     2.0  6.233149
# 7  SINDHUDURG 2021-02-01     4.0  6.880501
# 8  SINDHUDURG 2021-03-01     7.0  9.348886
# === Metrics ===
# {'district': 'SOLAPUR', 'rmse': 46.09219571391501, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.29599446, 'lag_2': 0.08407589, 'lag_3': 0.0846806, 'lag_4': 0.14209388, 'lag_5': 0.07099357, 'lag_6': 0.3221616}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  SOLAPUR 2020-07-01      28  47.679295
# 1  SOLAPUR 2020-08-01      25  55.060555
# 2  SOLAPUR 2020-09-01      17  53.229305
# 3  SOLAPUR 2020-10-01      18  60.810249
# 4  SOLAPUR 2020-11-01      24  61.194653
# 5  SOLAPUR 2020-12-01       8  62.717400
# 6  SOLAPUR 2021-01-01      24  79.528732
# 7  SOLAPUR 2021-02-01      12  76.484833
# 8  SOLAPUR 2021-03-01      22  77.362923
# === Metrics ===
# {'district': 'THANE', 'rmse': 11.47209780384803, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.16743058, 'lag_2': 0.13813588, 'lag_3': 0.23023647, 'lag_4': 0.18304205, 'lag_5': 0.21526599, 'lag_6': 0.065889046}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    THANE 2020-07-01      98  76.344788
# 1    THANE 2020-08-01      79  77.584396
# 2    THANE 2020-09-01      76  66.224174
# 3    THANE 2020-10-01      68  68.056587
# 4    THANE 2020-11-01      78  69.307053
# 5    THANE 2020-12-01      56  64.459656
# 6    THANE 2021-01-01      60  65.466255
# 7    THANE 2021-02-01      50  70.994476
# 8    THANE 2021-03-01      55  54.578056
# === Metrics ===
# {'district': 'WARDHA', 'rmse': 2.9749914250549727, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.16051306, 'lag_2': 0.1542589, 'lag_3': 0.11303376, 'lag_4': 0.14931045, 'lag_5': 0.19345501, 'lag_6': 0.22942886}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   WARDHA 2020-07-01     4.0   6.230847
# 1   WARDHA 2020-08-01     6.0   5.248304
# 2   WARDHA 2020-09-01     9.0   8.128018
# 3   WARDHA 2020-10-01    16.0   9.556968
# 4   WARDHA 2020-11-01     7.0   8.809773
# 5   WARDHA 2020-12-01    11.0   9.567181
# 6   WARDHA 2021-01-01     8.0  10.688577
# 7   WARDHA 2021-02-01     5.0   8.986869
# 8   WARDHA 2021-03-01     5.0   6.840816
# === Metrics ===
# {'district': 'WASHIM', 'rmse': 3.8825985076304446, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.15201896, 'lag_2': 0.103137955, 'lag_3': 0.12302122, 'lag_4': 0.21543235, 'lag_5': 0.17907995, 'lag_6': 0.22730953}}
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   WASHIM 2020-07-01    13.0  10.533366
# 1   WASHIM 2020-08-01    18.0  10.305102
# 2   WASHIM 2020-09-01     7.0   8.660412
# 3   WASHIM 2020-10-01    10.0   7.211396
# 4   WASHIM 2020-11-01     5.0   9.035160
# 5   WASHIM 2020-12-01    10.0   6.735047
# 6   WASHIM 2021-01-01    11.0   7.370427
# 7   WASHIM 2021-02-01     8.0   9.135005
# 8   WASHIM 2021-03-01     3.0   7.293909
# === Metrics ===
# {'district': 'YAVATMAL', 'rmse': 6.145332080459826, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.47060007, 'lag_2': 0.09566984, 'lag_3': 0.08342431, 'lag_4': 0.09803081, 'lag_5': 0.11482425, 'lag_6': 0.1374507}}
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  YAVATMAL 2020-07-01     3.0   1.304006
# 1  YAVATMAL 2020-08-01     7.0   9.032259
# 2  YAVATMAL 2020-09-01     8.0   5.575510
# 3  YAVATMAL 2020-10-01    23.0   9.307758
# 4  YAVATMAL 2020-11-01     6.0  14.680715
# 5  YAVATMAL 2020-12-01     2.0   7.760721
# 6  YAVATMAL 2021-01-01     5.0   1.966596
# 7  YAVATMAL 2021-02-01     4.0   5.993951
# 8  YAVATMAL 2021-03-01     6.0  10.219687
# ⚠️ Skipping MUMBAI SUBURBAN: Only 5 samples after lag features
# === Metrics ===
# None
#
# === Forecast Data ===
# None

# %%
# !pip install "dask<2025.1"
