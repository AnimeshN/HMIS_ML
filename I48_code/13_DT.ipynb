# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def decision_tree_regression_lags_only(
    series,
    district_name,
    max_lags=3,
    differencing=True,
    max_depth=None,
    min_samples_split=2,
    random_state=42,
    use_cv=False,
    cv_params=None,
    cv=5
):
    """
    Decision Tree regression for time series forecasting with lag features.
    Includes tree visualization and proper time-series cross-validation.
    """
    # 1. Directory structure
    os.makedirs('DecisionTreeRegression', exist_ok=True)
    
    # 2. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 3. Feature Engineering - Lag features
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 4. Time-based split
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 5. Model Training (with time-series CV)
    if use_cv:
        param_grid = cv_params or {
            'max_depth': [None, 3, 5, 7, 10],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4]
        }
        tscv = TimeSeriesSplit(n_splits=cv)
        grid_search = GridSearchCV(
            DecisionTreeRegressor(random_state=random_state),
            param_grid,
            cv=tscv,
            scoring='neg_mean_squared_error'
        )
        grid_search.fit(X_train, y_train)
        model = grid_search.best_estimator_
        best_params = grid_search.best_params_
    else:
        model = DecisionTreeRegressor(
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            random_state=random_state
        )
        model.fit(X_train, y_train)
        best_params = {
            'max_depth': max_depth,
            'min_samples_split': min_samples_split
        }

    # 6. Forecasting
    pred_test = model.predict(X_test)

    # 7. Inverse differencing
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = np.cumsum(pred_test) + last_train_value
        y_test = original_series.iloc[-len(test):]

    # 8. Forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test
    })

    # 9. Save results
    forecast_csv_path = os.path.join('DecisionTreeRegression', 'dt_forecasts.csv')
    forecast_df.to_csv(
        forecast_csv_path,
        mode='a',
        header=not os.path.exists(forecast_csv_path),
        index=False
    )

    # 10. Metrics calculation
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    r_squared = model.score(X_train, y_train)
    metrics_data = {
        'district': district_name,
        'rmse': rmse,
        'r_squared': r_squared,
        'best_params': best_params,
        'differencing': d,
        'tree_depth': model.get_depth()
    }
    metrics_df = pd.DataFrame([metrics_data])

    metrics_csv_path = os.path.join('DecisionTreeRegression', 'dt_metrics.csv')
    metrics_df.to_csv(
        metrics_csv_path,
        mode='a',
        header=not os.path.exists(metrics_csv_path),
        index=False
    )

    # 11. Visualization
    plt.figure(figsize=(18, 10))
    plot_tree(
        model,
        feature_names=X_train.columns.tolist(),
        filled=True,
        rounded=True,
        proportion=True,
        max_depth=3  # Show first 3 levels for readability
    )
    plt.savefig(os.path.join('DecisionTreeRegression', f'dt_structure_{district_name}.png'))
    plt.close()

    # 12. Forecast plot
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='DT Forecast', color='purple')
    plt.title(f'Decision Tree Forecast for {district_name}\nRMSE: {rmse:.2f}, Depth: {model.get_depth()}')
    plt.legend()
    plt.savefig(os.path.join('DecisionTreeRegression', f'dt_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'tree_rules': model.tree_,
        'feature_importances': model.feature_importances_
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I40"].asfreq('MS')
        
        results = decision_tree_regression_lags_only(
            ts, 
            district, 
            max_lags=4,
            max_depth=5,
            min_samples_split=10
        )

        
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district       rmse  r_squared  \
# 0  AHMEDNAGAR  20.357996   0.624623
#
#                                  best_params  differencing  tree_depth
# 0  {'max_depth': 5, 'min_samples_split': 10}             0           5
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AHMEDNAGAR 2020-07-01    40.0  39.736842
# 1  AHMEDNAGAR 2020-08-01    55.0  39.736842
# 2  AHMEDNAGAR 2020-09-01    36.0  61.600000
# 3  AHMEDNAGAR 2020-10-01    82.0  39.736842
# 4  AHMEDNAGAR 2020-11-01    49.0  61.600000
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0    AKOLA  11.100983   0.573271  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           4
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    AKOLA 2020-07-01    34.0  43.888889
# 1    AKOLA 2020-08-01    45.0  43.888889
# 2    AKOLA 2020-09-01    54.0  43.888889
# 3    AKOLA 2020-10-01    48.0  64.666667
# 4    AKOLA 2020-11-01    39.0  43.888889
# === Metrics ===
#    district       rmse  r_squared                                best_params  \
# 0  AMRAVATI  21.698651   0.745077  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           5
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  AMRAVATI 2020-07-01    62.0  55.750000
# 1  AMRAVATI 2020-08-01    70.0  55.750000
# 2  AMRAVATI 2020-09-01    98.0  64.333333
# 3  AMRAVATI 2020-10-01    55.0  83.666667
# 4  AMRAVATI 2020-11-01    45.0  61.000000
# === Metrics ===
#      district       rmse  r_squared  \
# 0  AURANGABAD  36.089026   0.493634
#
#                                  best_params  differencing  tree_depth
# 0  {'max_depth': 5, 'min_samples_split': 10}             1           5
#
# === Forecast Data ===
#      district       date  actual   forecast
# 0  AURANGABAD 2020-07-01      53  88.000000
# 1  AURANGABAD 2020-08-01      74  98.222222
# 2  AURANGABAD 2020-09-01      76  87.622222
# 3  AURANGABAD 2020-10-01      56  85.907937
# 4  AURANGABAD 2020-11-01      57  96.130159
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0     BEED  14.492909   0.760772  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           5
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0     BEED 2020-07-01    30.0  22.071429
# 1     BEED 2020-08-01    30.0  22.071429
# 2     BEED 2020-09-01    33.0  22.071429
# 3     BEED 2020-10-01    16.0  29.400000
# 4     BEED 2020-11-01    18.0  22.071429
# === Metrics ===
#    district      rmse  r_squared                                best_params  \
# 0  BHANDARA  4.331396    0.60538  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           5
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  BHANDARA 2020-07-01    19.0  22.375000
# 1  BHANDARA 2020-08-01    22.0  22.375000
# 2  BHANDARA 2020-09-01    28.0  22.375000
# 3  BHANDARA 2020-10-01    22.0  24.333333
# 4  BHANDARA 2020-11-01    25.0  22.375000
# === Metrics ===
#    district      rmse  r_squared                                best_params  \
# 0
{'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           5
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SANGLI 2020-07-01    24.0  25.285714
# 1   SANGLI 2020-08-01    16.0  33.000000
# 2   SANGLI 2020-09-01    13.0  25.285714
# 3   SANGLI 2020-10-01    28.0  33.000000
# 4   SANGLI 2020-11-01    34.0  33.000000
# === Metrics ===
#   district     rmse  r_squared                                best_params  \
# 0   SATARA  8.99446   0.504924  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           4
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   SATARA 2020-07-01    40.0  27.000000
# 1   SATARA 2020-08-01    40.0  33.222222
# 2   SATARA 2020-09-01    49.0  37.333333
# 3   SATARA 2020-10-01    39.0  27.000000
# 4   SATARA 2020-11-01    40.0  37.333333
# === Metrics ===
#      district      rmse  r_squared                                best_params  \
# 0  SINDHUDURG  3.306099   0.690602  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           5
#
# === Forecast Data ===
#      district       date  actual  forecast
# 0  SINDHUDURG 2020-07-01     9.0  8.571429
# 1  SINDHUDURG 2020-08-01     3.0  8.571429
# 2  SINDHUDURG 2020-09-01    10.0  7.000000
# 3  SINDHUDURG 2020-10-01     4.0  4.222222
# 4  SINDHUDURG 2020-11-01     6.0  4.222222
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0  SOLAPUR  32.006377   0.789621  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             1           5
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0  SOLAPUR 2020-07-01      28  49.333333
# 1  SOLAPUR 2020-08-01      25  71.333333
# 2  SOLAPUR 2020-09-01      17  44.333333
# 3  SOLAPUR 2020-10-01      18  48.666667
# 4  SOLAPUR 2020-11-01      24  49.916667
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0    THANE  18.410427   0.597766  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             1           5
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0    THANE 2020-07-01      98  73.636364
# 1    THANE 2020-08-01      79  59.303030
# 2    THANE 2020-09-01      76  50.053030
# 3    THANE 2020-10-01      68  55.553030
# 4    THANE 2020-11-01      78  54.189394
# === Metrics ===
#   district      rmse  r_squared                                best_params  \
# 0   WARDHA  3.715272   0.483604  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           5
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   WARDHA 2020-07-01     4.0   8.357143
# 1   WARDHA 2020-08-01     6.0   6.888889
# 2   WARDHA 2020-09-01     9.0   6.888889
# 3   WARDHA 2020-10-01    16.0   8.357143
# 4   WARDHA 2020-11-01     7.0  10.000000
# === Metrics ===
#   district      rmse  r_squared                                best_params  \
# 0   WASHIM  4.272823   0.534489  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           4
#
# === Forecast Data ===
#   district       date  actual   forecast
# 0   WASHIM 2020-07-01    13.0  13.000000
# 1   WASHIM 2020-08-01    18.0   7.333333
# 2   WASHIM 2020-09-01     7.0   7.333333
# 3   WASHIM 2020-10-01    10.0   8.500000
# 4   WASHIM 2020-11-01     5.0  10.714286
# === Metrics ===
#    district      rmse  r_squared                                best_params  \
# 0  YAVATMAL  6.573519   0.781461  {'max_depth': 5, 'min_samples_split': 10}
#
#    differencing  tree_depth
# 0             0           5
#
# === Forecast Data ===
#    district       date  actual   forecast
# 0  YAVATMAL 2020-07-01     3.0   3.166667
# 1  YAVATMAL 2020-08-01     7.0   3.166667
# 2  YAVATMAL 2020-09-01     8.0   9.714286
# 3  YAVATMAL 2020-10-01    23.0   9.714286
# 4  YAVATMAL 2020-11-01     6.0  19.750000
# === Metrics ===
#           district      rmse  r_squared  \
# 0  MUMBAI SUBURBAN  2.828427        0.0
#
#                                  best_params  differencing  tree_depth
# 0  {'max_depth': 5, 'min_samples_split': 10}             1           0
#
# === Forecast Data ===
#           district       date  actual  forecast
# 0  MUMBAI SUBURBAN 2021-02-01      28      30.4
# 1  MUMBAI SUBURBAN 2021-03-01      28      24.8
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual  forecast
#  0  MUMBAI SUBURBAN 2021-02-01      28      30.4
#  1  MUMBAI SUBURBAN 2021-03-01      28      24.8,
#  'metrics_df':           district      rmse  r_squared  \
#  0  MUMBAI SUBURBAN  2.828427        0.0
#
#                                   best_params  differencing  tree_depth
#  0  {'max_depth': 5, 'min_samples_split': 10}             1           0  ,
#  'tree_rules': <sklearn.tree._tree.Tree at 0x15e195a9a00>,
#  'feature_importances': array([0., 0., 0., 0.])}
