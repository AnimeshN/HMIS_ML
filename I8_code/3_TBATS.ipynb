# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tbats import TBATS as TBATSModel
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def tbats_forecast_district(series, district_name, seasonal_periods=None, 
                           use_box_cox=None, use_arma_errors=True, n_jobs=1):
    """
    TBATS forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('TBATS', exist_ok=True)
    
    # 1. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 2. TBATS Model Configuration
    estimator = TBATSModel(
        seasonal_periods=seasonal_periods,
        use_box_cox=use_box_cox,
        use_arma_errors=use_arma_errors,
        n_jobs=n_jobs
    )
    
    # 3. Model Fitting
    fitted_model = estimator.fit(train.values)
    
    # 4. Forecasting
    forecast = fitted_model.forecast(steps=len(test))
    
    # 5. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast,
        'model_params': str(fitted_model.params)
    })

    # 6. Save forecasts to CSV
    forecast_csv_path = os.path.join('TBATS', 'tbats_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 7. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'seasonal_periods': str(seasonal_periods),
        'box_cox_used': fitted_model.params.components.use_box_cox,
        # 'arma_used': fitted_model.params.components.use_arma
        'arma_errors_used': fitted_model.params.components.use_arma_errors

    }])

    metrics_csv_path = os.path.join('TBATS', 'tbats_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 8. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(test.index, forecast, label='TBATS Forecast', color='darkorange')
    plt.title(f'TBATS Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('TBATS', f'TBATS_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_summary': fitted_model.summary()
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I8"].asfreq('MS')
        
        results = tbats_forecast_district(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AHMEDNAGAR  967.410252             None         False             False
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  AHMEDNAGAR 2020-06-01    6372  6868.468795
# 1  AHMEDNAGAR 2020-07-01    5982  6868.468795
# 2  AHMEDNAGAR 2020-08-01    5559  6868.468795
# 3  AHMEDNAGAR 2020-09-01    5903  6868.468795
# 4  AHMEDNAGAR 2020-10-01    5719  6868.468795
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    AKOLA  164.448219             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    AKOLA 2020-06-01    1575  1603.096776
# 1    AKOLA 2020-07-01    1555  1594.889794
# 2    AKOLA 2020-08-01    1523  1587.302278
# 3    AKOLA 2020-09-01    1606  1580.287470
# 4    AKOLA 2020-10-01    1395  1573.802143
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district      rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AMRAVATI  403.4331             None         False             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  AMRAVATI 2020-06-01    2017  2362.453527
# 1  AMRAVATI 2020-07-01    1905  2366.211726
# 2  AMRAVATI 2020-08-01    1776  2369.670029
# 3  AMRAVATI 2020-09-01    1794  2372.852367
# 4  AMRAVATI 2020-10-01    1814  2375.780760
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AURANGABAD  1160.261284             None         False             False
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  AURANGABAD 2020-06-01    3456  3589.891435
# 1  AURANGABAD 2020-07-01    2897  3589.891435
# 2  AURANGABAD 2020-08-01    3107  3589.891435
# 3  AURANGABAD 2020-09-01    3639  3589.891435
# 4  AURANGABAD 2020-10-01    5000  3589.891435
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0     BEED  583.382481             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0     BEED 2020-06-01    3448  3773.363665
# 1     BEED 2020-07-01    3407  3761.176906
# 2     BEED 2020-08-01    2907  3749.675416
# 3     BEED 2020-09-01    3136  3738.820662
# 4     BEED 2020-10-01    3117  3728.576279
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  BHANDARA  219.179776             None         False             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  BHANDARA 2020-06-01    1228  1388.253975
# 1  BHANDARA 2020-07-01    1165  1388.253975
# 2  BHANDARA 2020-08-01    1101  1388.253975
# 3  BHANDARA 2020-09-01    1151  1388.253975
# 4  BHANDARA 2020-10-01    1152  1388.253975
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  BULDHANA  201.454744             None          True             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  BULDHANA 2020-06-01    1522  1581.699112
# 1  BULDHANA 2020-07-01    1439  1587.854410
# 2  BULDHANA 2020-08-01    1345  1593.607028
# 3  BULDHANA 2020-09-01    1602  1598.983052
# 4  BULDHANA 2020-10-01    1459  1604.006915
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  CHANDRAPUR  545.472907             None          True              True
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  CHANDRAPUR 2020-06-01    2334  2381.889738
# 1  CHANDRAPUR 2020-07-01    2279  2699.558346
# 2  CHANDRAPUR 2020-08-01    2103  2639.119291
# 3  CHANDRAPUR 2020-09-01    2030  2639.119291
# 4  CHANDRAPUR 2020-10-01    2073  2639.119291
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    DHULE  345.178918             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    DHULE 2020-06-01    3508  3457.222065
# 1    DHULE 2020-07-01    3317  3457.222065
# 2    DHULE 2020-08-01    2764  3457.222065
# 3    DHULE 2020-09-01    3344  3457.222065
# 4    DHULE 2020-10-01    3020  3457.222065
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  GADCHIROLI  382.779262             None         False             False
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  GADCHIROLI 2020-06-01    1665  1735.493517
# 1  GADCHIROLI 2020-07-01    1437  1735.493517
# 2  GADCHIROLI 2020-08-01    1218  1735.493517
# 3  GADCHIROLI 2020-09-01    1327  1735.493517
# 4  GADCHIROLI 2020-10-01    1197  1735.493517
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   GONDIA  180.119101             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   GONDIA 2020-06-01    1556  1570.894511
# 1   GONDIA 2020-07-01    1454  1570.894511
# 2   GONDIA 2020-08-01    1331  1570.894511
# 3   GONDIA 2020-09-01    1309  1570.894511
# 4   GONDIA 2020-10-01    1341  1570.894511
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  HINGOLI  235.901428             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  HINGOLI 2020-06-01    1667  1788.740105
# 1  HINGOLI 2020-07-01    1514  1815.515831
# 2  HINGOLI 2020-08-01    1569  1842.301160
# 3  HINGOLI 2020-09-01    1745  1869.095957
# 4  HINGOLI 2020-10-01    1749  1895.900095
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  JALGAON  777.595809             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  JALGAON 2020-06-01    5556  5532.595175
# 1  JALGAON 2020-07-01    4641  5564.924768
# 2  JALGAON 2020-08-01    4335  5597.254360
# 3  JALGAON 2020-09-01    4806  5629.583953
# 4  JALGAON 2020-10-01    4731  5661.913546
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    JALNA  204.62799             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    JALNA 2020-06-01    1935  2011.384817
# 1    JALNA 2020-07-01    2128  2011.384817
# 2    JALNA 2020-08-01    1604  2011.384817
# 3    JALNA 2020-09-01    1731  2011.384817
# 4    JALNA 2020-10-01    1698  2011.384817
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  KOLHAPUR  371.081734             None          True             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  KOLHAPUR 2020-06-01    3692  3586.914315
# 1  KOLHAPUR 2020-07-01    3357  3586.914315
# 2  KOLHAPUR 2020-08-01    3163  3586.914315
# 3  KOLHAPUR 2020-09-01    3576  3586.914315
# 4  KOLHAPUR 2020-10-01    3711  3586.914315
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    LATUR  239.62481             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    LATUR 2020-06-01    3784  3725.342459
# 1    LATUR 2020-07-01    3500  3704.530543
# 2    LATUR 2020-08-01    3274  3685.498444
# 3    LATUR 2020-09-01    3634  3668.093953
# 4    LATUR 2020-10-01    3408  3652.177878
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   MUMBAI  1132.618908             None         False             False
#
# === Forecast Data ===
#   district       date  actual    forecast  \
# 0   MUMBAI 2020-06-01    1485  952.934208
# 1   MUMBAI 2020-07-01    1525  952.934208
# 2   MUMBAI 2020-08-01    1497  952.934208
# 3   MUMBAI 2020-09-01    1472  952.934208
# 4   MUMBAI 2020-10-01    1756  952.934208
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   NAGPUR  1205.756019             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   NAGPUR 2020-06-01    5763  5374.921514
# 1   NAGPUR 2020-07-01    5816  5374.921514
# 2   NAGPUR 2020-08-01    4461  5374.921514
# 3   NAGPUR 2020-09-01    4485  5374.921514
# 4   NAGPUR 2020-10-01    4837  5374.921514
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   NANDED  345.103521             None         False              True
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   NANDED 2020-06-01    4882  4793.503638
# 1   NANDED 2020-07-01    4668  4943.223058
# 2   NANDED 2020-08-01    4358  4970.515904
# 3   NANDED 2020-09-01    5176  4997.808751
# 4   NANDED 2020-10-01    4553  5025.101598
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  NANDURBAR  696.322448             None          True             False
#
# === Forecast Data ===
#     district       date  actual     forecast  \
# 0  NANDURBAR 2020-06-01    3463  3348.542864
# 1  NANDURBAR 2020-07-01    3193  3348.542864
# 2  NANDURBAR 2020-08-01    2585  3348.542864
# 3  NANDURBAR 2020-09-01    2762  3348.542864
# 4  NANDURBAR 2020-10-01    2322  3348.542864
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   NASHIK  532.755926             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   NASHIK 2020-06-01    6593  6713.106614
# 1   NASHIK 2020-07-01    6411  6886.749910
# 2   NASHIK 2020-08-01    6147  7060.393206
# 3   NASHIK 2020-09-01    6180  7234.036502
# 4   NASHIK 2020-10-01    6938  7407.679798
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  OSMANABAD  283.541194             None         False             False
#
# === Forecast Data ===
#     district       date  actual     forecast  \
# 0  OSMANABAD 2020-06-01    1977  2022.824175
# 1  OSMANABAD 2020-07-01    1856  2022.824175
# 2  OSMANABAD 2020-08-01    1675  2022.824175
# 3  OSMANABAD 2020-09-01    1793  2022.824175
# 4  OSMANABAD 2020-10-01    1701  2022.824175
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  PALGHAR  375.39125             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  PALGHAR 2020-06-01    3663  3709.124999
# 1  PALGHAR 2020-07-01    3371  3709.124999
# 2  PALGHAR 2020-08-01    3171  3709.124999
# 3  PALGHAR 2020-09-01    3269  3709.124999
# 4  PALGHAR 2020-10-01    3271  3709.124999
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  PARBHANI  260.365057             None         False             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  PARBHANI 2020-06-01    1546  1397.237550
# 1  PARBHANI 2020-07-01    1441  1369.518964
# 2  PARBHANI 2020-08-01    1144  1344.955069
# 3  PARBHANI 2020-09-01    1478  1323.186825
# 4  PARBHANI 2020-10-01    1580  1303.896055
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0     PUNE  876.691163             None          True              True
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0     PUNE 2020-06-01    6054  6071.270849
# 1     PUNE 2020-07-01    5520  6355.246543
# 2     PUNE 2020-08-01    5630  6508.812100
# 3     PUNE 2020-09-01    5491  6525.816271
# 4     PUNE 2020-10-01    6135  6499.872247
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   RAIGAD  1137.450595             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   RAIGAD 2020-06-01    1582  1731.905464
# 1   RAIGAD 2020-07-01    1563  1731.905464
# 2   RAIGAD 2020-08-01    1516  1731.905464
# 3   RAIGAD 2020-09-01    1568  1731.905464
# 4   RAIGAD 2020-10-01    1569  1731.905464
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  RATNAGIRI  145.849591             None         False             False
#
# === Forecast Data ===
#     district       date  actual    forecast  \
# 0  RATNAGIRI 2020-06-01     848  785.098981
# 1  RATNAGIRI 2020-07-01     772  789.658354
# 2  RATNAGIRI 2020-08-01     803  794.063162
# 3  RATNAGIRI 2020-09-01     545  798.318646
# 4  RATNAGIRI 2020-10-01     679  802.429868
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   SANGLI  130.453967             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   SANGLI 2020-06-01    1724  1636.716235
# 1   SANGLI 2020-07-01    1914  1636.716235
# 2   SANGLI 2020-08-01    1544  1636.716235
# 3   SANGLI 2020-09-01    1534  1636.716235
# 4   SANGLI 2020-10-01    1492  1636.716235
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   SATARA  2111.739031             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   SATARA 2020-06-01    2237  2026.275263
# 1   SATARA 2020-07-01    2118  2026.275263
# 2   SATARA 2020-08-01    1561  2026.275263
# 3   SATARA 2020-09-01    1380  2026.275263
# 4   SATARA 2020-10-01    1570  2026.275263
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  SINDHUDURG  68.553329             None          True             False
#
# === Forecast Data ===
#      district       date  actual  forecast  \
# 0  SINDHUDURG 2020-06-01     420  381.1926
# 1  SINDHUDURG 2020-07-01     500  381.1926
# 2  SINDHUDURG 2020-08-01     376  381.1926
# 3  SINDHUDURG 2020-09-01     367  381.1926
# 4  SINDHUDURG 2020-10-01     361  381.1926
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  SOLAPUR  720.383048             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  SOLAPUR 2020-06-01    4094  4467.632509
# 1  SOLAPUR 2020-07-01    3821  4577.812931
# 2  SOLAPUR 2020-08-01    3842  4690.151998
# 3  SOLAPUR 2020-09-01    4147  4804.681165
# 4  SOLAPUR 2020-10-01    3847  4921.432190
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    THANE  1811.895644             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    THANE 2020-06-01   10413  8587.391982
# 1    THANE 2020-07-01    9367  8652.370575
# 2    THANE 2020-08-01    9815  8717.349168
# 3    THANE 2020-09-01    9676  8782.327762
# 4    THANE 2020-10-01    9483  8847.306355
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WARDHA  198.066891             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   WARDHA 2020-06-01    1271  1422.802076
# 1   WARDHA 2020-07-01    1258  1422.802076
# 2   WARDHA 2020-08-01    1219  1422.802076
# 3   WARDHA 2020-09-01    1186  1422.802076
# 4   WARDHA 2020-10-01    1151  1422.802076
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WASHIM  134.521837             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   WASHIM 2020-06-01    1316  1398.930175
# 1   WASHIM 2020-07-01    1320  1404.717274
# 2   WASHIM 2020-08-01    1354  1410.114293
# 3   WASHIM 2020-09-01    1281  1415.146952
# 4   WASHIM 2020-10-01    1304  1419.839351
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  YAVATMAL  390.095298             None         False             False
#
# === Forecast Data ===
#    district       date  actual    forecast  \
# 0  YAVATMAL 2020-06-01    3011  3225.64135
# 1  YAVATMAL 2020-07-01    3187  3225.64135
# 2  YAVATMAL 2020-08-01    2613  3225.64135
# 3  YAVATMAL 2020-09-01    2629  3225.64135
# 4  YAVATMAL 2020-10-01    2797  3225.64135
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#           district         rmse seasonal_periods  box_cox_used  \
# 0  MUMBAI SUBURBAN  1421.586449             None         False
#
#    arma_errors_used
# 0             False
#
# === Forecast Data ===
#           district       date  actual      forecast  \
# 0  MUMBAI SUBURBAN 2021-01-01    9489   9984.778576
# 1  MUMBAI SUBURBAN 2021-02-01    9380  10577.236140
# 2  MUMBAI SUBURBAN 2021-03-01    9076  11169.693705
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual      forecast  \
#  0  MUMBAI SUBURBAN 2021-01-01    9489   9984.778576
#  1  MUMBAI SUBURBAN 2021-02-01    9380  10577.236140
#  2  MUMBAI SUBURBAN 2021-03-01    9076  11169.693705
#
#                                          model_params
#  0  <tbats.tbats.ModelParams.ModelParams object at...
#  1  <tbats.tbats.ModelParams.ModelParams object at...
#  2  <tbats.tbats.ModelParams.ModelParams object at...  ,
#  'metrics_df':           district         rmse seasonal_periods  box_cox_used  \
#  0  MUMBAI SUBURBAN  1421.586449             None         False
#
#     arma_errors_used
#  0             False  ,
#  'model_summary': 'Use Box-Cox: False\nUse trend: True\nUse damped trend: False\nSeasonal periods: []\nSeasonal harmonics []\nARMA errors (p, q): (0, 0)\nSmoothing (Alpha): -0.020097\nTrend (Beta): 0.000100\nDamping Parameter (Phi): 1.000000\nSeasonal Parameters (Gamma): []\nAR coefficients []\nMA coefficients []\nSeed vector [4042.53660192  592.54337895]\n\nAIC 145.023152'}
