# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def exponential_smoothing_forecast_district(series, district_name, seasonal=False, seasonal_periods=12):
    """
    Complete Exponential Smoothing forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('ExponentialSmoothing', exist_ok=True)
    
    # 1. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 2. Model Fitting
    if seasonal:
        model = ExponentialSmoothing(train, seasonal='add', seasonal_periods=seasonal_periods)
    else:
        model = ExponentialSmoothing(train)
    model_fit = model.fit()
    
    # 3. Forecasting
    forecast = model_fit.forecast(steps=len(test))

    # 4. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast.values
    })

    # 5. Save forecasts to CSV (append mode)
    forecast_csv_path = os.path.join('ExponentialSmoothing', 'exp_smoothing_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 6. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'seasonal': seasonal
    }])

    metrics_csv_path = os.path.join('ExponentialSmoothing', 'exp_smoothing_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 7. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(forecast, label='Forecast', color='darkorange')
    plt.title(f'Exponential Smoothing Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('ExponentialSmoothing', f'ExpSmoothing_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I8"].asfreq('MS')
        
        results = exponential_smoothing_forecast_district(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district        rmse  seasonal
# 0  AHMEDNAGAR  938.178817     False
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AHMEDNAGAR 2020-06-01    6372  6837.250673
# 1  AHMEDNAGAR 2020-07-01    5982  6837.250673
# 2  AHMEDNAGAR 2020-08-01    5559  6837.250673
# 3  AHMEDNAGAR 2020-09-01    5903  6837.250673
# 4  AHMEDNAGAR 2020-10-01    5719  6837.250673
# === Metrics ===
#   district        rmse  seasonal
# 0    AKOLA  181.152199     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    AKOLA 2020-06-01    1575  1652.06998
# 1    AKOLA 2020-07-01    1555  1652.06998
# 2    AKOLA 2020-08-01    1523  1652.06998
# 3    AKOLA 2020-09-01    1606  1652.06998
# 4    AKOLA 2020-10-01    1395  1652.06998
# === Metrics ===
#    district        rmse  seasonal
# 0  AMRAVATI  402.023159     False
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  AMRAVATI 2020-06-01    2017  2368.403811
# 1  AMRAVATI 2020-07-01    1905  2368.403811
# 2  AMRAVATI 2020-08-01    1776  2368.403811
# 3  AMRAVATI 2020-09-01    1794  2368.403811
# 4  AMRAVATI 2020-10-01    1814  2368.403811
# === Metrics ===
#      district         rmse  seasonal
# 0  AURANGABAD  1160.847945     False
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AURANGABAD 2020-06-01    3456  3588.957323
# 1  AURANGABAD 2020-07-01    2897  3588.957323
# 2  AURANGABAD 2020-08-01    3107  3588.957323
# 3  AURANGABAD 2020-09-01    3639  3588.957323
# 4  AURANGABAD 2020-10-01    5000  3588.957323
# === Metrics ===
#   district        rmse  seasonal
# 0     BEED  659.079375     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-06-01    3448  3804.235342
# 1     BEED 2020-07-01    3407  3804.235342
# 2     BEED 2020-08-01    2907  3804.235342
# 3     BEED 2020-09-01    3136  3804.235342
# 4     BEED 2020-10-01    3117  3804.235342
# === Metrics ===
#    district        rmse  seasonal
# 0  BHANDARA  219.556725     False
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BHANDARA 2020-06-01    1228  1388.902132
# 1  BHANDARA 2020-07-01    1165  1388.902132
# 2  BHANDARA 2020-08-01    1101  1388.902132
# 3  BHANDARA 2020-09-01    1151  1388.902132
# 4  BHANDARA 2020-10-01    1152  1388.902132
# === Metrics ===
#    district        rmse  seasonal
# 0  BULDHANA  252.971953     False
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-06-01    1522  1468.877367
# 1  BULDHANA 2020-07-01    1439  1468.877367
# 2  BULDHANA 2020-08-01    1345  1468.877367
# 3  BULDHANA 2020-09-01    1602  1468.877367
# 4  BULDHANA 2020-10-01    1459  1468.877367
# === Metrics ===
#      district        rmse  seasonal
# 0  CHANDRAPUR  550.044142     False
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  CHANDRAPUR 2020-06-01    2334  2641.149581
# 1  CHANDRAPUR 2020-07-01    2279  2641.149581
# 2  CHANDRAPUR 2020-08-01    2103  2641.149581
# 3  CHANDRAPUR 2020-09-01    2030  2641.149581
# 4  CHANDRAPUR 2020-10-01    2073  2641.149581
# === Metrics ===
#   district        rmse  seasonal
# 0    DHULE  338.228285     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    DHULE 2020-06-01    3508  3437.958094
# 1    DHULE 2020-07-01    3317  3437.958094
# 2    DHULE 2020-08-01    2764  3437.958094
# 3    DHULE 2020-09-01    3344  3437.958094
# 4    DHULE 2020-10-01    3020  3437.958094
# === Metrics ===
#      district        rmse  seasonal
# 0  GADCHIROLI  383.226508     False
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  GADCHIROLI 2020-06-01    1665  1735.988249
# 1  GADCHIROLI 2020-07-01    1437  1735.988249
# 2  GADCHIROLI 2020-08-01    1218  1735.988249
# 3  GADCHIROLI 2020-09-01    1327  1735.988249
# 4  GADCHIROLI 2020-10-01    1197  1735.988249
# === Metrics ===
#   district        rmse  seasonal
# 0   GONDIA  182.983044     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   GONDIA 2020-06-01    1556  1574.909521
# 1   GONDIA 2020-07-01    1454  1574.909521
# 2   GONDIA 2020-08-01    1331  1574.909521
# 3   GONDIA 2020-09-01    1309  1574.909521
# 4   GONDIA 2020-10-01    1341  1574.909521
# === Metrics ===
#   district       rmse  seasonal
# 0  HINGOLI  97.439486     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  HINGOLI 2020-06-01    1667  1672.043048
# 1  HINGOLI 2020-07-01    1514  1672.043048
# 2  HINGOLI 2020-08-01    1569  1672.043048
# 3  HINGOLI 2020-09-01    1745  1672.043048
# 4  HINGOLI 2020-10-01    1749  1672.043048
# === Metrics ===
#   district        rmse  seasonal
# 0  JALGAON  653.255647     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  JALGAON 2020-06-01    5556  5501.669017
# 1  JALGAON 2020-07-01    4641  5501.669017
# 2  JALGAON 2020-08-01    4335  5501.669017
# 3  JALGAON 2020-09-01    4806  5501.669017
# 4  JALGAON 2020-10-01    4731  5501.669017
# === Metrics ===
#   district        rmse  seasonal
# 0    JALNA  203.200205     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    JALNA 2020-06-01    1935  2008.625277
# 1    JALNA 2020-07-01    2128  2008.625277
# 2    JALNA 2020-08-01    1604  2008.625277
# 3    JALNA 2020-09-01    1731  2008.625277
# 4    JALNA 2020-10-01    1698  2008.625277
# === Metrics ===
#    district        rmse  seasonal
# 0  KOLHAPUR  370.640869     False
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  KOLHAPUR 2020-06-01    3692  3588.023305
# 1  KOLHAPUR 2020-07-01    3357  3588.023305
# 2  KOLHAPUR 2020-08-01    3163  3588.023305
# 3  KOLHAPUR 2020-09-01    3576  3588.023305
# 4  KOLHAPUR 2020-10-01    3711  3588.023305
# === Metrics ===
#   district        rmse  seasonal
# 0    LATUR  283.571068     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    LATUR 2020-06-01    3784  3795.456388
# 1    LATUR 2020-07-01    3500  3795.456388
# 2    LATUR 2020-08-01    3274  3795.456388
# 3    LATUR 2020-09-01    3634  3795.456388
# 4    LATUR 2020-10-01    3408  3795.456388
# === Metrics ===
#   district         rmse  seasonal
# 0   MUMBAI  1135.713674     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   MUMBAI 2020-06-01    1485  949.541161
# 1   MUMBAI 2020-07-01    1525  949.541161
# 2   MUMBAI 2020-08-01    1497  949.541161
# 3   MUMBAI 2020-09-01    1472  949.541161
# 4   MUMBAI 2020-10-01    1756  949.541161
# === Metrics ===
#   district        rmse  seasonal
# 0   NAGPUR  1196.52951     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0   NAGPUR 2020-06-01    5763  5396.15776
# 1   NAGPUR 2020-07-01    5816  5396.15776
# 2   NAGPUR 2020-08-01    4461  5396.15776
# 3   NAGPUR 2020-09-01    4485  5396.15776
# 4   NAGPUR 2020-10-01    4837  5396.15776
# === Metrics ===
#   district        rmse  seasonal
# 0   NANDED  325.867135     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NANDED 2020-06-01    4882  4656.760863
# 1   NANDED 2020-07-01    4668  4656.760863
# 2   NANDED 2020-08-01    4358  4656.760863
# 3   NANDED 2020-09-01    5176  4656.760863
# 4   NANDED 2020-10-01    4553  4656.760863
# === Metrics ===
#     district        rmse  seasonal
# 0  NANDURBAR  705.832822     False
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  NANDURBAR 2020-06-01    3463  3359.457107
# 1  NANDURBAR 2020-07-01    3193  3359.457107
# 2  NANDURBAR 2020-08-01    2585  3359.457107
# 3  NANDURBAR 2020-09-01    2762  3359.457107
# 4  NANDURBAR 2020-10-01    2322  3359.457107
# === Metrics ===
#   district         rmse  seasonal
# 0   NASHIK  1002.100023     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NASHIK 2020-06-01    6593  6536.758281
# 1   NASHIK 2020-07-01    6411  6536.758281
# 2   NASHIK 2020-08-01    6147  6536.758281
# 3   NASHIK 2020-09-01    6180  6536.758281
# 4   NASHIK 2020-10-01    6938  6536.758281
# === Metrics ===
#     district       rmse  seasonal
# 0  OSMANABAD  283.87225     False
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  OSMANABAD 2020-06-01    1977  2035.543883
# 1  OSMANABAD 2020-07-01    1856  2035.543883
# 2  OSMANABAD 2020-08-01    1675  2035.543883
# 3  OSMANABAD 2020-09-01    1793  2035.543883
# 4  OSMANABAD 2020-10-01    1701  2035.543883
# === Metrics ===
#   district        rmse  seasonal
# 0  PALGHAR  389.850811     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  PALGHAR 2020-06-01    3663  3735.805154
# 1  PALGHAR 2020-07-01    3371  3735.805154
# 2  PALGHAR 2020-08-01    3171  3735.805154
# 3  PALGHAR 2020-09-01    3269  3735.805154
# 4  PALGHAR 2020-10-01    3271  3735.805154
# === Metrics ===
#    district        rmse  seasonal
# 0  PARBHANI  166.858996     False
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  PARBHANI 2020-06-01    1546  1433.426038
# 1  PARBHANI 2020-07-01    1441  1433.426038
# 2  PARBHANI 2020-08-01    1144  1433.426038
# 3  PARBHANI 2020-09-01    1478  1433.426038
# 4  PARBHANI 2020-10-01    1580  1433.426038
# === Metrics ===
#   district         rmse  seasonal
# 0     PUNE  1010.041153     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     PUNE 2020-06-01    6054  6050.159517
# 1     PUNE 2020-07-01    5520  6050.159517
# 2     PUNE 2020-08-01    5630  6050.159517
# 3     PUNE 2020-09-01    5491  6050.159517
# 4     PUNE 2020-10-01    6135  6050.159517
# === Metrics ===
#   district         rmse  seasonal
# 0   RAIGAD  1087.379088     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   RAIGAD 2020-06-01    1582  1816.808897
# 1   RAIGAD 2020-07-01    1563  1816.808897
# 2   RAIGAD 2020-08-01    1516  1816.808897
# 3   RAIGAD 2020-09-01    1568  1816.808897
# 4   RAIGAD 2020-10-01    1569  1816.808897
# === Metrics ===
#     district        rmse  seasonal
# 0  RATNAGIRI  112.736022     False
#
# === Forecast Data ===
#     district       date  actual    forecast
# 0  RATNAGIRI 2020-06-01     848  758.870919
# 1  RATNAGIRI 2020-07-01     772  758.870919
# 2  RATNAGIRI 2020-08-01     803  758.870919
# 3  RATNAGIRI 2020-09-01     545  758.870919
# 4  RATNAGIRI 2020-10-01     679  758.870919
# === Metrics ===
#   district        rmse  seasonal
# 0   SANGLI  130.445087     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SANGLI 2020-06-01    1724  1636.346303
# 1   SANGLI 2020-07-01    1914  1636.346303
# 2   SANGLI 2020-08-01    1544  1636.346303
# 3   SANGLI 2020-09-01    1534  1636.346303
# 4   SANGLI 2020-10-01    1492  1636.346303
# === Metrics ===
#   district        rmse  seasonal
# 0   SATARA  2111.09606     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SATARA 2020-06-01    2237  2028.511782
# 1   SATARA 2020-07-01    2118  2028.511782
# 2   SATARA 2020-08-01    1561  2028.511782
# 3   SATARA 2020-09-01    1380  2028.511782
# 4   SATARA 2020-10-01    1570  2028.511782
# === Metrics ===
#      district       rmse  seasonal
# 0  SINDHUDURG  69.487409     False
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-06-01     420  379.000001
# 1  SINDHUDURG 2020-07-01     500  379.000001
# 2  SINDHUDURG 2020-08-01     376  379.000001
# 3  SINDHUDURG 2020-09-01     367  379.000001
# 4  SINDHUDURG 2020-10-01     361  379.000001
# === Metrics ===
#   district        rmse  seasonal
# 0  SOLAPUR  579.625404     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  SOLAPUR 2020-06-01    4094  4305.456785
# 1  SOLAPUR 2020-07-01    3821  4305.456785
# 2  SOLAPUR 2020-08-01    3842  4305.456785
# 3  SOLAPUR 2020-09-01    4147  4305.456785
# 4  SOLAPUR 2020-10-01    3847  4305.456785
# === Metrics ===
#   district         rmse  seasonal
# 0    THANE  2235.072306     False
#
# === Forecast Data ===
#   district       date  actual    forecast
# 0    THANE 2020-06-01   10413  8469.63252
# 1    THANE 2020-07-01    9367  8469.63252
# 2    THANE 2020-08-01    9815  8469.63252
# 3    THANE 2020-09-01    9676  8469.63252
# 4    THANE 2020-10-01    9483  8469.63252
# === Metrics ===
#   district        rmse  seasonal
# 0   WARDHA  184.325947     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WARDHA 2020-06-01    1271  1403.052607
# 1   WARDHA 2020-07-01    1258  1403.052607
# 2   WARDHA 2020-08-01    1219  1403.052607
# 3   WARDHA 2020-09-01    1186  1403.052607
# 4   WARDHA 2020-10-01    1151  1403.052607
# === Metrics ===
#   district        rmse  seasonal
# 0   WASHIM  151.470008     False
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WASHIM 2020-06-01    1316  1344.388572
# 1   WASHIM 2020-07-01    1320  1344.388572
# 2   WASHIM 2020-08-01    1354  1344.388572
# 3   WASHIM 2020-09-01    1281  1344.388572
# 4   WASHIM 2020-10-01    1304  1344.388572
# === Metrics ===
#    district      rmse  seasonal
# 0  YAVATMAL  386.3748     False
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  YAVATMAL 2020-06-01    3011  3218.759866
# 1  YAVATMAL 2020-07-01    3187  3218.759866
# 2  YAVATMAL 2020-08-01    2613  3218.759866
# 3  YAVATMAL 2020-09-01    2629  3218.759866
# 4  YAVATMAL 2020-10-01    2797  3218.759866
# === Metrics ===
#           district        rmse  seasonal
# 0  MUMBAI SUBURBAN  274.161056     False
#
# === Forecast Data ===
#           district       date  actual    forecast
# 0  MUMBAI SUBURBAN 2021-01-01    9489  9526.24303
# 1  MUMBAI SUBURBAN 2021-02-01    9380  9526.24303
# 2  MUMBAI SUBURBAN 2021-03-01    9076  9526.24303
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual    forecast
#  0  MUMBAI SUBURBAN 2021-01-01    9489  9526.24303
#  1  MUMBAI SUBURBAN 2021-02-01    9380  9526.24303
#  2  MUMBAI SUBURBAN 2021-03-01    9076  9526.24303,
#  'metrics_df':           district        rmse  seasonal
#  0  MUMBAI SUBURBAN  274.161056     False}
