# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox

from statsmodels.stats.stattools import durbin_watson
from statsmodels.graphics.tsaplots import plot_acf
from scipy.stats import shapiro
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def linear_regression_lags_only(series, district_name, max_lags=3, differencing=True):
    """
    Simplified linear regression for time series forecasting with:
    - Lag features only
    - Ordinary Least Squares (OLS) regression
    - Optional differencing for stationarity
    """
    # Create directory structure
    os.makedirs('LinearRegression', exist_ok=True)
    
    # 1. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 2. Feature Engineering - Lag features only
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 3. Train-Test Split (time-based)
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 4. Model Training with OLS
    X_train_sm = sm.add_constant(X_train)
    model = sm.OLS(y_train, X_train_sm).fit()

    # 5. Forecasting
    X_test_sm = sm.add_constant(X_test)
    pred_test = model.predict(X_test_sm)

    # 6. Inverse Differencing if applied
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = pred_test.cumsum() + last_train_value
        y_test = original_series.iloc[-len(test):]
    
    # 7. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test.values
    })

    # 8. Save forecasts to CSV
    forecast_csv_path = os.path.join('LinearRegression', 'linear_forecasts_lags_only.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, mode='a', header=write_header, index=False)

    # 9. Calculate metrics
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'r_squared': model.rsquared,
        'params': model.params.to_dict(),
        'differencing': d
    }])

    metrics_csv_path = os.path.join('LinearRegression', 'linear_metrics_lags_only.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, mode='a', header=write_header_metrics, index=False)

    # 10. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', color='darkorange')
    plt.title(f'Linear Regression (Lags Only) Forecast for {district_name}\nRMSE: {rmse:.2f}, R²: {model.rsquared:.2f}')
    plt.legend()
    plt.savefig(os.path.join('LinearRegression', f'Linear_forecast_lags_only_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_summary': model.summary().as_text()
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I8"].asfreq('MS')
        
        results = linear_regression_lags_only(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district         rmse  r_squared  \
# 0  AHMEDNAGAR  1779.660457    0.14262
#
#                                               params  differencing
# 0  {'const': 154.6054255124958, 'lag_1': -0.39705...             1
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AHMEDNAGAR 2020-07-01    5982  6556.252242
# 1  AHMEDNAGAR 2020-08-01    5559  6970.819649
# 2  AHMEDNAGAR 2020-09-01    5903  7460.043274
# 3  AHMEDNAGAR 2020-10-01    5719  7617.842182
# 4  AHMEDNAGAR 2020-11-01    5427  7834.872914
# === Metrics ===
#   district        rmse  r_squared  \
# 0    AKOLA  287.575667    0.10274
#
#                                               params  differencing
# 0  {'const': 37.772474948115054, 'lag_1': -0.2602...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    AKOLA 2020-07-01    1555  1639.141748
# 1    AKOLA 2020-08-01    1523  1631.117302
# 2    AKOLA 2020-09-01    1606  1710.668220
# 3    AKOLA 2020-10-01    1395  1735.099809
# 4    AKOLA 2020-11-01    1204  1825.885996
# === Metrics ===
#    district        rmse  r_squared  \
# 0  AMRAVATI  228.192268   0.541093
#
#                                               params  differencing
# 0  {'const': 663.7454496293469, 'lag_1': 0.598614...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  AMRAVATI 2020-07-01  1905.0  2085.217754
# 1  AMRAVATI 2020-08-01  1776.0  2077.174983
# 2  AMRAVATI 2020-09-01  1794.0  1936.141843
# 3  AMRAVATI 2020-10-01  1814.0  1937.864912
# 4  AMRAVATI 2020-11-01  1896.0  1920.990352
# === Metrics ===
#      district         rmse  r_squared  \
# 0  AURANGABAD  1316.560419    0.19073
#
#                                               params  differencing
# 0  {'const': 23.718325389114575, 'lag_1': -0.3671...             1
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AURANGABAD 2020-07-01    2897  3604.622992
# 1  AURANGABAD 2020-08-01    3107  3804.160519
# 2  AURANGABAD 2020-09-01    3639  3623.750868
# 3  AURANGABAD 2020-10-01    5000  3386.565721
# 4  AURANGABAD 2020-11-01    4498  3044.437500
# === Metrics ===
#   district        rmse  r_squared  \
# 0     BEED  846.659069   0.083544
#
#                                               params  differencing
# 0  {'const': 50.385593247486725, 'lag_1': -0.2879...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-07-01    3407  3610.134398
# 1     BEED 2020-08-01    2907  3734.822028
# 2     BEED 2020-09-01    3136  3913.191150
# 3     BEED 2020-10-01    3117  3959.263128
# 4     BEED 2020-11-01    2842  3959.378035
# === Metrics ===
#    district        rmse  r_squared  \
# 0  BHANDARA  189.418816   0.015551
#
#                                               params  differencing
# 0  {'const': 4.03521496009626, 'lag_1': -0.104546...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BHANDARA 2020-07-01    1165  1248.260714
# 1  BHANDARA 2020-08-01    1101  1253.875015
# 2  BHANDARA 2020-09-01    1151  1269.052574
# 3  BHANDARA 2020-10-01    1152  1268.370663
# 4  BHANDARA 2020-11-01    1031  1276.374676
# === Metrics ===
#    district        rmse  r_squared  \
# 0  BULDHANA  209.783904   0.174741
#
#                                               params  differencing
# 0  {'const': 54.559054379378956, 'lag_1': -0.4352...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-07-01    1439  1524.648998
# 1  BULDHANA 2020-08-01    1345  1597.282437
# 2  BULDHANA 2020-09-01    1602  1717.317776
# 3  BULDHANA 2020-10-01    1459  1694.659147
# 4  BULDHANA 2020-11-01    1389  1743.915284
# === Metrics ===
#      district        rmse  r_squared  \
# 0  CHANDRAPUR  580.298919   0.097467
#
#                                               params  differencing
# 0  {'const': 24.98340864503105, 'lag_1': -0.04570...             1
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  CHANDRAPUR 2020-07-01    2279  2469.064142
# 1  CHANDRAPUR 2020-08-01    2103  2545.861491
# 2  CHANDRAPUR 2020-09-01    2030  2571.576740
# 3  CHANDRAPUR 2020-10-01    2073  2646.722989
# 4  CHANDRAPUR 2020-11-01    1897  2675.260503
# === Metrics ===
#   district        rmse  r_squared  \
# 0    DHULE  861.988535    0.21446
#
#                                               params  differencing
# 0  {'const': 86.92144666423697, 'lag_1': -0.44492...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    DHULE 2020-07-01    3317  3506.005338
# 1    DHULE 2020-08-01    2764  3742.610960
# 2    DHULE 2020-09-01    3344  4146.656664
# 3    DHULE 2020-10-01    3020  4175.010944
# 4    DHULE 2020-11-01    2908  4208.761666
# === Metrics ===
#      district        rmse  r_squared  \
# 0  GADCHIROLI  478.954234   0.028415
#
#                                               params  differencing
# 0  {'const': 13.830182515139086, 'lag_1': -0.0582...             1
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  GADCHIROLI 2020-07-01    1437  1689.555434
# 1  GADCHIROLI 2020-08-01    1218  1727.391451
# 2  GADCHIROLI 2020-09-01    1327  1789.580093
# 3  GADCHIROLI 2020-10-01    1197  1830.787339
# 4  GADCHIROLI 2020-11-01    1211  1834.470596
# === Metrics ===
#   district       rmse  r_squared  \
# 0   GONDIA  115.00611   0.268438
#
#                                               params  differencing
# 0  {'const': 643.978540352306, 'lag_1': 0.5498009...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   GONDIA 2020-07-01  1454.0  1477.189508
# 1   GONDIA 2020-08-01  1331.0  1441.192111
# 2   GONDIA 2020-09-01  1309.0  1378.164911
# 3   GONDIA 2020-10-01  1341.0  1369.473128
# 4   GONDIA 2020-11-01  1444.0  1374.922598
# === Metrics ===
#   district        rmse  r_squared  \
# 0  HINGOLI  219.034547   0.204881
#
#                                               params  differencing
# 0  {'const': 49.582675850331555, 'lag_1': -0.2982...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  HINGOLI 2020-07-01    1514  1695.417292
# 1  HINGOLI 2020-08-01    1569  1794.273617
# 2  HINGOLI 2020-09-01    1745  1899.393745
# 3  HINGOLI 2020-10-01    1749  1901.970568
# 4  HINGOLI 2020-11-01    1616  1863.906841
# === Metrics ===
#   district         rmse  r_squared  \
# 0  JALGAON  1167.453956   0.019363
#
#                                               params  differencing
# 0  {'const': 87.23648463795699, 'lag_1': -0.13499...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  JALGAON 2020-07-01    4641  5626.018500
# 1  JALGAON 2020-08-01    4335  5833.223191
# 2  JALGAON 2020-09-01    4806  6003.790287
# 3  JALGAON 2020-10-01    4731  6072.334791
# 4  JALGAON 2020-11-01    4652  6157.462336
# === Metrics ===
#   district        rmse  r_squared  \
# 0    JALNA  219.585107   0.366859
#
#                                               params  differencing
# 0  {'const': 609.2613694058915, 'lag_1': 0.651288...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    JALNA 2020-07-01  2128.0  1814.933925
# 1    JALNA 2020-08-01  1604.0  1967.131132
# 2    JALNA 2020-09-01  1731.0  1591.384779
# 3    JALNA 2020-10-01  1698.0  1754.967591
# 4    JALNA 2020-11-01  1869.0  1667.206983
# === Metrics ===
#    district        rmse  r_squared  \
# 0  KOLHAPUR  360.816623   0.128719
#
#                                               params  differencing
# 0  {'const': 58.901521550300295, 'lag_1': -0.3326...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  KOLHAPUR 2020-07-01    3357  3578.735568
# 1  KOLHAPUR 2020-08-01    3163  3738.476214
# 2  KOLHAPUR 2020-09-01    3576  3937.892166
# 3  KOLHAPUR 2020-10-01    3711  3979.460492
# 4  KOLHAPUR 2020-11-01    3480  3940.315159
# === Metrics ===
#   district        rmse  r_squared  \
# 0    LATUR  827.853659   0.097159
#
#                                               params  differencing
# 0  {'const': 112.6211013665357, 'lag_1': -0.27921...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    LATUR 2020-07-01    3500  3808.559973
# 1    LATUR 2020-08-01    3274  3984.689183
# 2    LATUR 2020-09-01    3634  4223.513026
# 3    LATUR 2020-10-01    3408  4324.108220
# 4    LATUR 2020-11-01    3363  4473.417369
# === Metrics ===
#   district       rmse  r_squared  \
# 0   MUMBAI  846.78154   0.025257
#
#                                               params  differencing
# 0  {'const': -114.93057721958624, 'lag_1': -0.000...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   MUMBAI 2020-07-01    1525  2100.856154
# 1   MUMBAI 2020-08-01    1497  2024.812008
# 2   MUMBAI 2020-09-01    1472  1844.267892
# 3   MUMBAI 2020-10-01    1756  1720.822442
# 4   MUMBAI 2020-11-01    2196  1606.417123
# === Metrics ===
#   district         rmse  r_squared  \
# 0   NAGPUR  1471.289206   0.255677
#
#                                               params  differencing
# 0  {'const': 87.48601802125307, 'lag_1': -0.47174...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NAGPUR 2020-07-01    5816  5397.139867
# 1   NAGPUR 2020-08-01    4461  5447.613230
# 2   NAGPUR 2020-09-01    4485  6158.345038
# 3   NAGPUR 2020-10-01    4837  6759.361474
# 4   NAGPUR 2020-11-01    5721  6622.102575
# === Metrics ===
#   district        rmse  r_squared  \
# 0   NANDED  378.767868   0.448669
#
#                                               params  differencing
# 0  {'const': 1327.1436309292926, 'lag_1': 0.66080...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NANDED 2020-07-01  4668.0  4731.080237
# 1   NANDED 2020-08-01  4358.0  4578.097040
# 2   NANDED 2020-09-01  5176.0  4395.199560
# 3   NANDED 2020-10-01  4553.0  4929.994179
# 4   NANDED 2020-11-01  4475.0  4479.842477
# === Metrics ===
#     district         rmse  r_squared  \
# 0  NANDURBAR  1472.371542   0.287056
#
#                                               params  differencing
# 0  {'const': 61.79533635745554, 'lag_1': -0.46693...             1
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  NANDURBAR 2020-07-01    3193  3663.227145
# 1  NANDURBAR 2020-08-01    2585  3901.261599
# 2  NANDURBAR 2020-09-01    2762  4185.167486
# 3  NANDURBAR 2020-10-01    2322  4008.769521
# 4  NANDURBAR 2020-11-01    2311  4222.986740
# === Metrics ===
#   district       rmse  r_squared  \
# 0   NASHIK  501.01168   0.016075
#
#                                               params  differencing
# 0  {'const': 102.60230543293667, 'lag_1': 0.10314...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NASHIK 2020-07-01    6411  6720.698118
# 1   NASHIK 2020-08-01    6147  6796.137516
# 2   NASHIK 2020-09-01    6180  6859.043721
# 3   NASHIK 2020-10-01    6938  6958.949753
# 4   NASHIK 2020-11-01    7314  7153.624317
# === Metrics ===
#     district        rmse  r_squared  \
# 0  OSMANABAD  552.017866   0.376909
#
#                                               params  differencing
# 0  {'const': 34.0284108066154, 'lag_1': -0.497336...             1
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  OSMANABAD 2020-07-01    1856  1948.126869
# 1  OSMANABAD 2020-08-01    1675  2210.084519
# 2  OSMANABAD 2020-09-01    1793  2494.275898
# 3  OSMANABAD 2020-10-01    1701  2609.029465
# 4  OSMANABAD 2020-11-01    1857  2654.578815
# === Metrics ===
#   district        rmse  r_squared  \
# 0  PALGHAR  641.980905   0.079098
#
#                                               params  differencing
# 0  {'const': 36.47233648602493, 'lag_1': -0.13174...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  PALGHAR 2020-07-01    3371  3926.294616
# 1  PALGHAR 2020-08-01    3171  3823.493022
# 2  PALGHAR 2020-09-01    3269  3952.917705
# 3  PALGHAR 2020-10-01    3271  4081.057693
# 4  PALGHAR 2020-11-01    3189  4164.361896
# === Metrics ===
#    district        rmse  r_squared  \
# 0  PARBHANI  247.227735   0.145812
#
#                                               params  differencing
# 0  {'const': 28.299634398250795, 'lag_1': -0.2372...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  PARBHANI 2020-07-01    1441  1552.032042
# 1  PARBHANI 2020-08-01    1144  1601.238959
# 2  PARBHANI 2020-09-01    1478  1680.439135
# 3  PARBHANI 2020-10-01    1580  1704.290702
# 4  PARBHANI 2020-11-01    1311  1747.362845
# === Metrics ===
#   district       rmse  r_squared  \
# 0     PUNE  733.32566   0.338013
#
#                                               params  differencing
# 0  {'const': 3787.5706770169454, 'lag_1': 0.70036...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     PUNE 2020-07-01  5520.0  6497.200658
# 1     PUNE 2020-08-01  5630.0  6087.594332
# 2     PUNE 2020-09-01  5491.0  6383.590124
# 3     PUNE 2020-10-01  6135.0  6161.479053
# 4     PUNE 2020-11-01  6162.0  6685.686544
# === Metrics ===
#   district         rmse  r_squared  \
# 0   RAIGAD  1837.930645   0.181217
#
#                                               params  differencing
# 0  {'const': 1.7454550006943474, 'lag_1': -0.3207...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   RAIGAD 2020-07-01    1563  1239.090160
# 1   RAIGAD 2020-08-01    1516  1283.201947
# 2   RAIGAD 2020-09-01    1568  1272.709732
# 3   RAIGAD 2020-10-01    1569  1256.599469
# 4   RAIGAD 2020-11-01    2801  1241.124979
# === Metrics ===
#     district        rmse  r_squared  \
# 0  RATNAGIRI  372.199306   0.324681
#
#                                               params  differencing
# 0  {'const': 22.924389037745144, 'lag_1': -0.5626...             1
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  RATNAGIRI 2020-07-01     772   807.376877
# 1  RATNAGIRI 2020-08-01     803   817.640679
# 2  RATNAGIRI 2020-09-01     545   820.852722
# 3  RATNAGIRI 2020-10-01     679  1004.799177
# 4  RATNAGIRI 2020-11-01     551  1035.596158
# === Metrics ===
#   district        rmse  r_squared  \
# 0   SANGLI  312.851833   0.141038
#
#                                               params  differencing
# 0  {'const': 32.82137642290344, 'lag_1': -0.32549...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SANGLI 2020-07-01    1914  1775.098017
# 1   SANGLI 2020-08-01    1544  1669.355688
# 2   SANGLI 2020-09-01    1534  1824.787129
# 3   SANGLI 2020-10-01    1492  1937.643090
# 4   SANGLI 2020-11-01    1581  1925.138938
# === Metrics ===
#   district       rmse  r_squared  \
# 0   SATARA  2245.5122   0.129728
#
#                                               params  differencing
# 0  {'const': 20.63688127747948, 'lag_1': -0.38090...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SATARA 2020-07-01    2118  2163.154040
# 1   SATARA 2020-08-01    1561  2206.499262
# 2   SATARA 2020-09-01    1380  2437.580108
# 3   SATARA 2020-10-01    1570  2606.033747
# 4   SATARA 2020-11-01    1571  2622.065312
# === Metrics ===
#      district       rmse  r_squared  \
# 0  SINDHUDURG  119.88791   0.148119
#
#                                               params  differencing
# 0  {'const': 12.957052120043263, 'lag_1': -0.0115...             1
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01     500  443.116670
# 1  SINDHUDURG 2020-08-01     376  463.205207
# 2  SINDHUDURG 2020-09-01     367  450.055873
# 3  SINDHUDURG 2020-10-01     361  456.090880
# 4  SINDHUDURG 2020-11-01     322  513.552724
# === Metrics ===
#   district        rmse  r_squared  \
# 0  SOLAPUR  600.038453   0.148241
#
#                                               params  differencing
# 0  {'const': 98.74185431144979, 'lag_1': -0.34399...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  SOLAPUR 2020-07-01    3821  4358.669224
# 1  SOLAPUR 2020-08-01    3842  4552.567161
# 2  SOLAPUR 2020-09-01    4147  4652.232031
# 3  SOLAPUR 2020-10-01    3847  4600.685625
# 4  SOLAPUR 2020-11-01    3885  4762.610679
# === Metrics ===
#   district         rmse  r_squared  \
# 0    THANE  1819.220627   0.223317
#
#                                               params  differencing
# 0  {'const': 178.37232396195964, 'lag_1': -0.3682...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    THANE 2020-07-01    9367  9430.524329
# 1    THANE 2020-08-01    9815  9157.912371
# 2    THANE 2020-09-01    9676  8875.976577
# 3    THANE 2020-10-01    9483  9392.889654
# 4    THANE 2020-11-01   10375  9503.764427
# === Metrics ===
#   district        rmse  r_squared  \
# 0   WARDHA  152.623261    0.12348
#
#                                               params  differencing
# 0  {'const': 1179.4766839708147, 'lag_1': 0.35822...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WARDHA 2020-07-01  1258.0  1340.408591
# 1   WARDHA 2020-08-01  1219.0  1360.494633
# 2   WARDHA 2020-09-01  1186.0  1358.760699
# 3   WARDHA 2020-10-01  1151.0  1353.084730
# 4   WARDHA 2020-11-01  1033.0  1347.691912
# === Metrics ===
#   district        rmse  r_squared  \
# 0   WASHIM  160.445486   0.236958
#
#                                               params  differencing
# 0  {'const': 34.47967837309807, 'lag_1': -0.18740...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WASHIM 2020-07-01    1320  1374.306711
# 1   WASHIM 2020-08-01    1354  1419.821780
# 2   WASHIM 2020-09-01    1281  1446.897298
# 3   WASHIM 2020-10-01    1304  1478.315587
# 4   WASHIM 2020-11-01    1237  1537.134077
# === Metrics ===
#    district        rmse  r_squared  \
# 0  YAVATMAL  309.884558   0.400974
#
#                                               params  differencing
# 0  {'const': 883.1954063886543, 'lag_1': 0.336082...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  YAVATMAL 2020-07-01  3187.0  3120.281749
# 1  YAVATMAL 2020-08-01  2613.0  3091.950705
# 2  YAVATMAL 2020-09-01  2629.0  2923.929508
# 3  YAVATMAL 2020-10-01  2797.0  2782.081428
# 4  YAVATMAL 2020-11-01  2682.0  2793.401055
# === Metrics ===
#           district         rmse  r_squared  \
# 0  MUMBAI SUBURBAN  1672.466024   0.678944
#
#                                               params  differencing
# 0  {'const': 1505.7929836375686, 'lag_1': -0.9642...             1
#
# === Forecast Data ===
#           district       date  actual      forecast
# 0  MUMBAI SUBURBAN 2021-02-01    9380  10248.217249
# 1  MUMBAI SUBURBAN 2021-03-01    9076  11276.110000
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual      forecast
#  0  MUMBAI SUBURBAN 2021-02-01    9380  10248.217249
#  1  MUMBAI SUBURBAN 2021-03-01    9076  11276.110000,
#  'metrics_df':           district         rmse  r_squared  \
#  0  MUMBAI SUBURBAN  1672.466024   0.678944
#
#                                                params  differencing
#  0  {'const': 1505.7929836375686, 'lag_1': -0.9642...             1  ,
#  'model_summary': '                            OLS Regression Results                            \n==============================================================================\nDep. Variable:                      y   R-squared:                       0.679\nModel:                            OLS   Adj. R-squared:                  0.197\nMethod:                 Least Squares   F-statistic:                     1.410\nDate:                Mon, 28 Apr 2025   Prob (F-statistic):              0.441\nTime:                        20:31:52   Log-Likelihood:                -44.164\nNo. Observations:                   6   AIC:                             96.33\nDf Residuals:                       2   BIC:                             95.49\nDf Model:                           3                                         \nCovariance Type:            nonrobust                                         \n==============================================================================\n                 coef    std err          t      P>|t|      [0.025      0.975]\n------------------------------------------------------------------------------\nconst       1505.7930    634.213      2.374      0.141   -1223.004    4234.590\nlag_1         -0.9642      0.559     -1.723      0.227      -3.372       1.443\nlag_2         -0.6260      0.321     -1.948      0.191      -2.009       0.757\nlag_3         -0.4516      0.358     -1.260      0.335      -1.993       1.090\n==============================================================================\nOmnibus:                          nan   Durbin-Watson:                   1.657\nProb(Omnibus):                    nan   Jarque-Bera (JB):                1.336\nSkew:                           1.153   Prob(JB):                        0.513\nKurtosis:                       2.844   Cond. No.                     3.20e+03\n==============================================================================\n\nNotes:\n[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.\n[2] The condition number is large, 3.2e+03. This might indicate that there are\nstrong multicollinearity or other numerical problems.'}
