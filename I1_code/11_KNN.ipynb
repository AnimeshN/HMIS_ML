# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def knn_regression_lags_only(
    series,
    district_name,
    max_lags=3,
    differencing=True,
    n_neighbors=5,
    weights='uniform',
    algorithm='auto',
    use_cv=False,
    cv_params=None,
    cv=5
):
    """
    K-Nearest Neighbors regression for time series forecasting with:
    - Lag features only
    - Optional differencing for stationarity
    - Optional hyperparameter tuning via cross-validation
    """
    # 1. Directory structure
    os.makedirs('KNNRegression', exist_ok=True)
    
    # 2. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 3. Feature Engineering - Lag features only
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 4. Train-Test Split (time-based)
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 5. Model Training (with optional CV)
    if use_cv:
        param_grid = cv_params or {
            'n_neighbors': [3, 5, 7, 9],
            'weights': ['uniform', 'distance'],
            'algorithm': ['auto', 'ball_tree', 'kd_tree']
        }
        grid_search = GridSearchCV(
            KNeighborsRegressor(),
            param_grid,
            cv=cv,
            scoring='neg_mean_squared_error'
        )
        grid_search.fit(X_train, y_train)
        model = grid_search.best_estimator_
        best_params = grid_search.best_params_
    else:
        model = KNeighborsRegressor(
            n_neighbors=n_neighbors,
            weights=weights,
            algorithm=algorithm
        )
        model.fit(X_train, y_train)
        best_params = {
            'n_neighbors': n_neighbors,
            'weights': weights,
            'algorithm': algorithm
        }

    # 6. Forecasting
    pred_test = model.predict(X_test)

    # 7. Inverse Differencing if applied
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = np.cumsum(pred_test) + last_train_value
        y_test = original_series.iloc[-len(test):]

    # 8. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test
    })

    # 9. Save forecasts to CSV
    forecast_csv_path = os.path.join('KNNRegression', 'knn_forecasts.csv')
    forecast_df.to_csv(
        forecast_csv_path,
        mode='a',
        header=not os.path.exists(forecast_csv_path),
        index=False
    )

    # 10. Calculate metrics
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    r_squared = model.score(X_train, y_train)
    metrics_data = {
        'district': district_name,
        'rmse': rmse,
        'r_squared': r_squared,
        'best_params': best_params,
        'differencing': d
    }
    metrics_df = pd.DataFrame([metrics_data])

    metrics_csv_path = os.path.join('KNNRegression', 'knn_metrics.csv')
    metrics_df.to_csv(
        metrics_csv_path,
        mode='a',
        header=not os.path.exists(metrics_csv_path),
        index=False
    )

    # 11. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='KNN Forecast', color='darkorange')
    plt.title(f'KNN Regression Forecast for {district_name}\nRMSE: {rmse:.2f}, R²: {r_squared:.2f}')
    plt.legend()
    plt.savefig(os.path.join('KNNRegression', f'knn_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'best_params': best_params
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I1"].asfreq('MS')
        
        results = knn_regression_lags_only(
            ts,
            district,
            max_lags=5,
            use_cv=True,
            cv_params={
                'n_neighbors': [3, 5, 7, 9],
                'weights': ['uniform', 'distance']
            }
        )

        
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district        rmse  r_squared  \
# 0  AHMEDNAGAR  455.389627    0.06175
#
#                                 best_params  differencing
# 0  {'n_neighbors': 9, 'weights': 'uniform'}             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AHMEDNAGAR 2020-07-01  6478.0  6749.555556
# 1  AHMEDNAGAR 2020-08-01  5975.0  6454.333333
# 2  AHMEDNAGAR 2020-09-01  6550.0  6791.777778
# 3  AHMEDNAGAR 2020-10-01  6471.0  6872.222222
# 4  AHMEDNAGAR 2020-11-01  6107.0  6811.000000
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0    AKOLA  293.823585   0.135128  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    AKOLA 2020-07-01  3121.0  2753.777778
# 1    AKOLA 2020-08-01  3029.0  2683.222222
# 2    AKOLA 2020-09-01  2763.0  2614.333333
# 3    AKOLA 2020-10-01  2737.0  2619.777778
# 4    AKOLA 2020-11-01  2700.0  2668.111111
# === Metrics ===
#    district        rmse  r_squared                               best_params  \
# 0  AMRAVATI  416.063168   0.162605  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  AMRAVATI 2020-07-01  3459.0  3702.888889
# 1  AMRAVATI 2020-08-01  3049.0  3656.111111
# 2  AMRAVATI 2020-09-01  3325.0  3722.333333
# 3  AMRAVATI 2020-10-01  3191.0  3923.666667
# 4  AMRAVATI 2020-11-01  3502.0  3877.777778
# === Metrics ===
#      district        rmse  r_squared  \
# 0  AURANGABAD  396.551512   0.062575
#
#                                 best_params  differencing
# 0  {'n_neighbors': 9, 'weights': 'uniform'}             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AURANGABAD 2020-07-01  6028.0  6573.555556
# 1  AURANGABAD 2020-08-01  6173.0  6473.333333
# 2  AURANGABAD 2020-09-01  6644.0  6606.555556
# 3  AURANGABAD 2020-10-01  6246.0  6351.666667
# 4  AURANGABAD 2020-11-01  5765.0  6386.555556
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0     BEED  380.878687        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-07-01  3821.0  4291.931835
# 1     BEED 2020-08-01  3261.0  3850.685102
# 2     BEED 2020-09-01  3819.0  3618.846509
# 3     BEED 2020-10-01  3751.0  3480.121147
# 4     BEED 2020-11-01  3332.0  4017.707123
# === Metrics ===
#    district       rmse  r_squared                                best_params  \
# 0  BHANDARA  224.41295        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BHANDARA 2020-07-01    1262  1396.064046
# 1  BHANDARA 2020-08-01    1185  1374.523914
# 2  BHANDARA 2020-09-01    1200  1370.150801
# 3  BHANDARA 2020-10-01    1233  1422.065458
# 4  BHANDARA 2020-11-01    1093  1550.059412
# === Metrics ===
#    district        rmse  r_squared                                best_params  \
# 0  BULDHANA  364.599132        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-07-01  3900.0  4113.034652
# 1  BULDHANA 2020-08-01  3612.0  4165.178008
# 2  BULDHANA 2020-09-01  4073.0  4101.626188
# 3  BULDHANA 2020-10-01  3614.0  4131.368053
# 4  BULDHANA 2020-11-01  3484.0  4149.230249
# === Metrics ===
#      district        rmse  r_squared  \
# 0  CHANDRAPUR  255.872981        1.0
#
#                                  best_params  differencing
# 0  {'n_neighbors': 3, 'weights': 'distance'}             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  CHANDRAPUR 2020-07-01  2316.0  2539.536883
# 1  CHANDRAPUR 2020-08-01  2209.0  2464.047952
# 2  CHANDRAPUR 2020-09-01  2247.0  2573.908288
# 3  CHANDRAPUR 2020-10-01  2187.0  2364.433015
# 4  CHANDRAPUR 2020-11-01  2220.0  2310.071209
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0    DHULE  350.989479   0.010518  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    DHULE 2020-07-01  3857.0  3661.444444
# 1    DHULE 2020-08-01  3076.0  3696.666667
# 2    DHULE 2020-09-01  3376.0  3604.111111
# 3    DHULE 2020-10-01  3157.0  3578.444444
# 4    DHULE 2020-11-01  3146.0  3626.666667
# === Metrics ===
#      district        rmse  r_squared  \
# 0  GADCHIROLI  366.153522   0.127943
#
#                                 best_params  differencing
# 0  {'n_neighbors': 7, 'weights': 'uniform'}             1
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  GADCHIROLI 2020-07-01    1431  1684.142857
# 1  GADCHIROLI 2020-08-01    1224  1756.428571
# 2  GADCHIROLI 2020-09-01    1361  1702.571429
# 3  GADCHIROLI 2020-10-01    1251  1678.714286
# 4  GADCHIROLI 2020-11-01    1256  1765.857143
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0   GONDIA  137.257099   0.502929  {'n_neighbors': 5, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual  forecast
# 0   GONDIA 2020-07-01  1703.0    1726.0
# 1   GONDIA 2020-08-01  1383.0    1537.8
# 2   GONDIA 2020-09-01  1445.0    1548.8
# 3   GONDIA 2020-10-01  1472.0    1565.4
# 4   GONDIA 2020-11-01  1519.0    1588.2
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0  HINGOLI  119.459034   0.013592  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  HINGOLI 2020-07-01  1886.0  1862.111111
# 1  HINGOLI 2020-08-01  1692.0  1928.111111
# 2  HINGOLI 2020-09-01  2019.0  1924.333333
# 3  HINGOLI 2020-10-01  1976.0  1960.111111
# 4  HINGOLI 2020-11-01  1722.0  1876.111111
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0  JALGAON  655.189422   0.085506  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  JALGAON 2020-07-01  6176.0  7039.888889
# 1  JALGAON 2020-08-01  5950.0  6910.000000
# 2  JALGAON 2020-09-01  6369.0  6831.222222
# 3  JALGAON 2020-10-01  6370.0  6711.444444
# 4  JALGAON 2020-11-01  6429.0  6729.666667
# === Metrics ===
#   district       rmse  r_squared                                best_params  \
# 0    JALNA  219.44467        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    JALNA 2020-07-01  3234.0  3649.771261
# 1    JALNA 2020-08-01  3247.0  3552.861133
# 2    JALNA 2020-09-01  3401.0  3519.421705
# 3    JALNA 2020-10-01  3244.0  3467.317447
# 4    JALNA 2020-11-01  3164.0  3390.559614
# === Metrics ===
#    district        rmse  r_squared                                best_params  \
# 0  KOLHAPUR  406.153653        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  KOLHAPUR 2020-07-01  4670.0  5059.954396
# 1  KOLHAPUR 2020-08-01  4437.0  5025.090995
# 2  KOLHAPUR 2020-09-01  5026.0  5070.868856
# 3  KOLHAPUR 2020-10-01  4973.0  5312.378021
# 4  KOLHAPUR 2020-11-01  4789.0  5291.652265
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0    LATUR  307.562869   0.281557  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    LATUR 2020-07-01  3694.0  3903.142857
# 1    LATUR 2020-08-01  3498.0  3861.428571
# 2    LATUR 2020-09-01  3654.0  3989.285714
# 3    LATUR 2020-10-01  3751.0  4105.571429
# 4    LATUR 2020-11-01  3673.0  3986.571429
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0   MUMBAI  3497.12128    0.09289  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   MUMBAI 2020-07-01    2916  3089.111111
# 1   MUMBAI 2020-08-01    2676  2610.000000
# 2   MUMBAI 2020-09-01    3035  2230.555556
# 3   MUMBAI 2020-10-01    2924  1548.333333
# 4   MUMBAI 2020-11-01    3608  1047.444444
# === Metrics ===
#   district         rmse  r_squared                               best_params  \
# 0   NAGPUR  1266.985353  -0.006416  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NAGPUR 2020-07-01  7018.0  7147.444444
# 1   NAGPUR 2020-08-01  5585.0  7201.000000
# 2   NAGPUR 2020-09-01  5078.0  7156.000000
# 3   NAGPUR 2020-10-01  5618.0  6999.888889
# 4   NAGPUR 2020-11-01  6429.0  6889.111111
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0   NANDED  460.430107        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NANDED 2020-07-01  5261.0  5579.207975
# 1   NANDED 2020-08-01  4984.0  5576.821898
# 2   NANDED 2020-09-01  5871.0  5472.394156
# 3   NANDED 2020-10-01  5214.0  5767.061161
# 4   NANDED 2020-11-01  5237.0  5681.740413
# === Metrics ===
#     district        rmse  r_squared                               best_params  \
# 0  NANDURBAR  229.936573   0.421971  {'n_neighbors': 7, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  NANDURBAR 2020-07-01  3577.0  3600.142857
# 1  NANDURBAR 2020-08-01  2901.0  3265.857143
# 2  NANDURBAR 2020-09-01  3040.0  3119.285714
# 3  NANDURBAR 2020-10-01  2588.0  2903.428571
# 4  NANDURBAR 2020-11-01  2581.0  2721.285714
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0   NASHIK  669.66823   0.394969  {'n_neighbors': 5, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date   actual  forecast
# 0   NASHIK 2020-07-01  10668.0   10223.4
# 1   NASHIK 2020-08-01   9838.0   10288.4
# 2   NASHIK 2020-09-01  10420.0   10488.8
# 3   NASHIK 2020-10-01  10365.0    9999.6
# 4   NASHIK 2020-11-01   9966.0    9905.2
# === Metrics ===
#     district        rmse  r_squared                               best_params  \
# 0  OSMANABAD  212.051408   0.014134  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  OSMANABAD 2020-07-01  2273.0  2317.555556
# 1  OSMANABAD 2020-08-01  1935.0  2409.111111
# 2  OSMANABAD 2020-09-01  2241.0  2367.777778
# 3  OSMANABAD 2020-10-01  2207.0  2367.555556
# 4  OSMANABAD 2020-11-01  2274.0  2347.666667
# === Metrics ===
#   district        rmse  r_squared                               best_params  \
# 0  PALGHAR  494.112322   0.251013  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  PALGHAR 2020-07-01  4867.0  5350.000000
# 1  PALGHAR 2020-08-01  4606.0  5221.888889
# 2  PALGHAR 2020-09-01  4753.0  5053.000000
# 3  PALGHAR 2020-10-01  4616.0  4863.111111
# 4  PALGHAR 2020-11-01  4554.0  4934.333333
# === Metrics ===
#    district        rmse  r_squared                                best_params  \
# 0  PARBHANI  360.102276        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  PARBHANI 2020-07-01  3186.0  3051.927751
# 1  PARBHANI 2020-08-01  2743.0  2995.854889
# 2  PARBHANI 2020-09-01  3099.0  2968.722475
# 3  PARBHANI 2020-10-01  2920.0  3076.483108
# 4  PARBHANI 2020-11-01  2538.0  3009.256077
# === Metrics ===
#   district         rmse  r_squared                                best_params  \
# 0     PUNE  1549.497918        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0     PUNE 2020-07-01  14939.0  16675.335535
# 1     PUNE 2020-08-01  14322.0  15432.553938
# 2     PUNE 2020-09-01  16328.0  15016.586272
# 3     PUNE 2020-10-01  15750.0  17040.632573
# 4     PUNE 2020-11-01  15551.0  16681.845373
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0   RAIGAD  914.382479        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   RAIGAD 2020-07-01    3465  4118.287872
# 1   RAIGAD 2020-08-01    3013  4492.743443
# 2   RAIGAD 2020-09-01    3412  4828.945660
# 3   RAIGAD 2020-10-01    3704  4709.359437
# 4   RAIGAD 2020-11-01    3998  4697.561331
# === Metrics ===
#     district        rmse  r_squared                               best_params  \
# 0  RATNAGIRI  244.175806   0.204237  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  RATNAGIRI 2020-07-01  1742.0  1575.111111
# 1  RATNAGIRI 2020-08-01  1206.0  1490.333333
# 2  RATNAGIRI 2020-09-01  1279.0  1450.444444
# 3  RATNAGIRI 2020-10-01  1186.0  1420.000000
# 4  RATNAGIRI 2020-11-01  1074.0  1400.777778
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0   SANGLI  258.444022        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SANGLI 2020-07-01  4264.0  4220.521932
# 1   SANGLI 2020-08-01  3874.0  4327.688053
# 2   SANGLI 2020-09-01  3891.0  4136.693237
# 3   SANGLI 2020-10-01  3891.0  4026.648086
# 4   SANGLI 2020-11-01  3821.0  3965.581786
# === Metrics ===
#   district       rmse  r_squared                               best_params  \
# 0   SATARA  510.54898   0.127302  {'n_neighbors': 9, 'weights': 'uniform'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SATARA 2020-07-01  3915.0  4045.555556
# 1   SATARA 2020-08-01  3233.0  3965.333333
# 2   SATARA 2020-09-01  3103.0  4010.222222
# 3   SATARA 2020-10-01  3760.0  4142.888889
# 4   SATARA 2020-11-01  3582.0  4204.777778
# === Metrics ===
#      district        rmse  r_squared  \
# 0  SINDHUDURG  101.490774  -0.050721
#
#                                 best_params  differencing
# 0  {'n_neighbors': 9, 'weights': 'uniform'}             0
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01   721.0  652.777778
# 1  SINDHUDURG 2020-08-01   549.0  671.111111
# 2  SINDHUDURG 2020-09-01   579.0  649.333333
# 3  SINDHUDURG 2020-10-01   530.0  687.111111
# 4  SINDHUDURG 2020-11-01   476.0  656.222222
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0  SOLAPUR  491.340946        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  SOLAPUR 2020-07-01  6858.0  7012.969908
# 1  SOLAPUR 2020-08-01  6356.0  6758.472514
# 2  SOLAPUR 2020-09-01  6758.0  6764.917480
# 3  SOLAPUR 2020-10-01  6321.0  6984.715192
# 4  SOLAPUR 2020-11-01  6058.0  6977.764565
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0    THANE  1552.25299        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0    THANE 2020-07-01  12050.0  14105.615995
# 1    THANE 2020-08-01  12215.0  13959.306661
# 2    THANE 2020-09-01  13770.0  14093.447049
# 3    THANE 2020-10-01  13402.0  14104.944823
# 4    THANE 2020-11-01  13995.0  14098.949858
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0   WARDHA  175.579748        1.0  {'n_neighbors': 3, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WARDHA 2020-07-01  1452.0  1454.034920
# 1   WARDHA 2020-08-01  1358.0  1419.081196
# 2   WARDHA 2020-09-01  1360.0  1536.499021
# 3   WARDHA 2020-10-01  1306.0  1553.553587
# 4   WARDHA 2020-11-01  1196.0  1613.382845
# === Metrics ===
#   district        rmse  r_squared                                best_params  \
# 0   WASHIM  146.786974        1.0  {'n_neighbors': 9, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WASHIM 2020-07-01  1629.0  1571.656253
# 1   WASHIM 2020-08-01  1502.0  1648.084573
# 2   WASHIM 2020-09-01  1599.0  1548.851431
# 3   WASHIM 2020-10-01  1501.0  1614.926932
# 4   WASHIM 2020-11-01  1453.0  1715.607676
# === Metrics ===
#    district       rmse  r_squared                                best_params  \
# 0  YAVATMAL  185.87704        1.0  {'n_neighbors': 7, 'weights': 'distance'}
#
#    differencing
# 0             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  YAVATMAL 2020-07-01  3673.0  3674.035914
# 1  YAVATMAL 2020-08-01  3425.0  3796.755720
# 2  YAVATMAL 2020-09-01  3507.0  3525.861088
# 3  YAVATMAL 2020-10-01  3562.0  3601.806020
# 4  YAVATMAL 2020-11-01  3501.0  3804.631373
# === Metrics ===
#           district        rmse  r_squared  \
# 0  MUMBAI SUBURBAN  221.589572        1.0
#
#                                  best_params  differencing
# 0  {'n_neighbors': 3, 'weights': 'distance'}             0
#
# === Forecast Data ===
#           district       date   actual      forecast
# 0  MUMBAI SUBURBAN 2021-02-01  13444.0  13166.303563
# 1  MUMBAI SUBURBAN 2021-03-01  13294.0  13148.780972
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# ...
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 345, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_regression.py", line 245, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 4, n_samples = 1
#
#   warnings.warn(
# c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [-500479.88888889 -392920.23980855              nan              nan
#               nan              nan              nan              nan]
#   warnings.warn(
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date   actual      forecast
#  0  MUMBAI SUBURBAN 2021-02-01  13444.0  13166.303563
#  1  MUMBAI SUBURBAN 2021-03-01  13294.0  13148.780972,
#  'metrics_df':           district        rmse  r_squared  \
#  0  MUMBAI SUBURBAN  221.589572        1.0
#
#                                   best_params  differencing
#  0  {'n_neighbors': 3, 'weights': 'distance'}             0  ,
#  'best_params': {'n_neighbors': 3, 'weights': 'distance'}}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
