# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def ridge_regression_lags_only(
    series,
    district_name,
    max_lags=3,
    differencing=True,
    alpha=1.0,
    use_cv=False,
    alphas=np.logspace(-3, 2, 20),  # Only used if use_cv=True
    cv=5,  # Only used if use_cv=True
    random_state=42
):
    """
    Ridge regression (L2 regularization) for time series forecasting with lag features only.
    Supports optional cross-validation for alpha selection.
    """
    # Create directory structure
    os.makedirs('RidgeRegression', exist_ok=True)
    
    # 1. Stationarity and Differencing
    original_series = series.copy()
    d = 0
    if differencing:
        adf_result = adfuller(series.dropna())
        if adf_result[1] > 0.05:
            d = 1
            series = series.diff().dropna()

    # 2. Feature Engineering - Lag features only
    df = pd.DataFrame({'y': series.astype(float)})
    for lag in range(1, max_lags + 1):
        df[f'lag_{lag}'] = df['y'].shift(lag).astype(float)
    df = df.dropna()

    # 3. Train-Test Split (time-based)
    train_size = int(len(df) * 0.8)
    train = df.iloc[:train_size]
    test = df.iloc[train_size:]

    X_train = train.drop(columns=['y'])
    y_train = train['y']
    X_test = test.drop(columns=['y'])
    y_test = test['y']

    # 4. Model Training with Ridge or RidgeCV
    if use_cv:
        model = RidgeCV(alphas=alphas, cv=TimeSeriesSplit(n_splits=5), scoring='neg_mean_squared_error')
        model.fit(X_train, y_train)
        best_alpha = model.alpha_
    else:
        model = Ridge(alpha=alpha, random_state=random_state, max_iter=10000)
        model.fit(X_train, y_train)
        best_alpha = alpha

    # 5. Forecasting
    pred_test = model.predict(X_test)

    # 6. Inverse Differencing if applied
    if d == 1:
        last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
        pred_test = np.cumsum(pred_test) + last_train_value
        y_test = original_series.iloc[-len(test):]
    
    # 7. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': y_test.index,
        'actual': y_test.values,
        'forecast': pred_test
    })

    # 8. Save forecasts to CSV
    forecast_csv_path = os.path.join('RidgeRegression', 'ridge_forecasts_lags_only.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, mode='a', header=write_header, index=False)

    # 9. Calculate metrics
    rmse = np.sqrt(mean_squared_error(forecast_df['actual'], forecast_df['forecast']))
    r_squared = model.score(X_train, y_train)
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'r_squared': r_squared,
        'coefficients': model.coef_.tolist(),
        'intercept': model.intercept_,
        'best_alpha': best_alpha,
        'alphas_tried': alphas.tolist() if use_cv else [alpha],
        'differencing': d
    }])

    metrics_csv_path = os.path.join('RidgeRegression', 'ridge_metrics_lags_only.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, mode='a', header=write_header_metrics, index=False)

    # 10. Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(original_series.index, original_series.values, label='Original Series')
    plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', color='darkorange')
    plt.title(
        f'Ridge Regression (Lags Only) for {district_name}\n'
        f'Alpha: {best_alpha:.4f} | RMSE: {rmse:.2f}, R²: {r_squared:.2f}'
    )
    plt.legend()
    plt.savefig(os.path.join('RidgeRegression', f'Ridge_forecast_lags_only_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_coefficients': model.coef_,
        'model_intercept': model.intercept_,
        'best_alpha': best_alpha,
        'alphas_tried': alphas if use_cv else [alpha]
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I1"].asfreq('MS')
        
        results = ridge_regression_lags_only(
            ts, 
            district, 
            max_lags=5, 
            use_cv=True, 
            alphas=np.logspace(-3, 2, 30), 
            cv=5
        )
        
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district        rmse  r_squared  \
# 0  AHMEDNAGAR  531.926635    0.08101
#
#                                         coefficients    intercept  best_alpha  \
# 0  [-0.038637636313003945, 0.01551755833707656, -...  8385.798099       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AHMEDNAGAR 2020-07-01  6478.0  6810.827867
# 1  AHMEDNAGAR 2020-08-01  5975.0  6566.397125
# 2  AHMEDNAGAR 2020-09-01  6550.0  6942.121345
# 3  AHMEDNAGAR 2020-10-01  6471.0  7081.527746
# 4  AHMEDNAGAR 2020-11-01  6107.0  7158.594751
# === Metrics ===
#   district        rmse  r_squared  \
# 0    AKOLA  295.673932    0.19196
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.16317944421535768, -0.17591083085224643, -0...  3712.509868       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    AKOLA 2020-07-01  3121.0  2906.728101
# 1    AKOLA 2020-08-01  3029.0  2674.860848
# 2    AKOLA 2020-09-01  2763.0  2622.232518
# 3    AKOLA 2020-10-01  2737.0  2544.815901
# 4    AKOLA 2020-11-01  2700.0  2601.768611
# === Metrics ===
#    district        rmse  r_squared  \
# 0  AMRAVATI  361.693383    0.27521
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.43646210502566113, -0.29663401301312675, -0...  4555.067778       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  AMRAVATI 2020-07-01  3459.0  3712.731459
# 1  AMRAVATI 2020-08-01  3049.0  3618.806976
# 2  AMRAVATI 2020-09-01  3325.0  3574.495983
# 3  AMRAVATI 2020-10-01  3191.0  3889.470423
# 4  AMRAVATI 2020-11-01  3502.0  3830.400634
# === Metrics ===
#      district        rmse  r_squared  \
# 0  AURANGABAD  402.774123   0.173511
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.24356318091618515, -0.060710603470293764, 0...  3153.890926       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  AURANGABAD 2020-07-01  6028.0  6462.116528
# 1  AURANGABAD 2020-08-01  6173.0  6293.848993
# 2  AURANGABAD 2020-09-01  6644.0  6613.927410
# 3  AURANGABAD 2020-10-01  6246.0  6417.275534
# 4  AURANGABAD 2020-11-01  5765.0  6392.785932
# === Metrics ===
#   district        rmse  r_squared  \
# 0     BEED  352.530907   0.295761
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.2690150663093805, 0.12297436424082274, 0.10...  4176.508237       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-07-01  3821.0  4201.274011
# 1     BEED 2020-08-01  3261.0  3581.105514
# 2     BEED 2020-09-01  3819.0  3120.878300
# 3     BEED 2020-10-01  3751.0  3597.941245
# 4     BEED 2020-11-01  3332.0  3843.110226
# === Metrics ===
#    district        rmse  r_squared  \
# 0  BHANDARA  277.659711   0.099315
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.26558649441763377, -0.22504376804165818, -...  -3.185695       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BHANDARA 2020-07-01    1262  1396.708203
# 1  BHANDARA 2020-08-01    1185  1444.638239
# 2  BHANDARA 2020-09-01    1200  1489.938295
# 3  BHANDARA 2020-10-01    1233  1533.256266
# 4  BHANDARA 2020-11-01    1093  1551.903376
# === Metrics ===
#    district        rmse  r_squared  \
# 0  BULDHANA  342.713575   0.269564
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.03375564253903256, -0.15101145568772975, -0...  7175.801775       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-07-01  3900.0  4083.176504
# 1  BULDHANA 2020-08-01  3612.0  4004.962636
# 2  BULDHANA 2020-09-01  4073.0  4142.470484
# 3  BULDHANA 2020-10-01  3614.0  4092.000645
# 4  BULDHANA 2020-11-01  3484.0  4204.804045
# === Metrics ===
#      district        rmse  r_squared  \
# 0  CHANDRAPUR  193.994141   0.406981
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.5333631184228974, -0.19502812133044062, 0.1...  2533.174767       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  CHANDRAPUR 2020-07-01  2316.0  2457.857143
# 1  CHANDRAPUR 2020-08-01  2209.0  2333.960290
# 2  CHANDRAPUR 2020-09-01  2247.0  2293.275376
# 3  CHANDRAPUR 2020-10-01  2187.0  2477.592818
# 4  CHANDRAPUR 2020-11-01  2220.0  2536.542539
# === Metrics ===
#   district        rmse  r_squared  \
# 0    DHULE  336.719974   0.172709
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.4267818894861537, -0.020870377867557337, -0...  2342.396584       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    DHULE 2020-07-01  3857.0  3843.625199
# 1    DHULE 2020-08-01  3076.0  3733.102550
# 2    DHULE 2020-09-01  3376.0  3439.364254
# 3    DHULE 2020-10-01  3157.0  3601.474978
# 4    DHULE 2020-11-01  3146.0  3570.401011
# === Metrics ===
#      district        rmse  r_squared  \
# 0  GADCHIROLI  304.942265   0.176095
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.2444741362226576, 0.11683904167682804, 0.1...  -1.063946       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  GADCHIROLI 2020-07-01    1431  1725.298994
# 1  GADCHIROLI 2020-08-01    1224  1663.691364
# 2  GADCHIROLI 2020-09-01    1361  1612.889028
# 3  GADCHIROLI 2020-10-01    1251  1573.956060
# 4  GADCHIROLI 2020-11-01    1256  1728.752852
# === Metrics ===
#   district        rmse  r_squared  \
# 0   GONDIA  139.447169   0.387432
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.2949175971735315, 0.14885790698801699, -0.0...  1744.008651       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   GONDIA 2020-07-01  1703.0  1678.567169
# 1   GONDIA 2020-08-01  1383.0  1601.446380
# 2   GONDIA 2020-09-01  1445.0  1485.609341
# 3   GONDIA 2020-10-01  1472.0  1495.224340
# 4   GONDIA 2020-11-01  1519.0  1579.865015
# === Metrics ===
#   district        rmse  r_squared  \
# 0  HINGOLI  126.535273   0.149235
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.2062094907647676, -0.30889062965755515, 0.1...  2050.335686       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  HINGOLI 2020-07-01  1886.0  1978.608764
# 1  HINGOLI 2020-08-01  1692.0  1918.973064
# 2  HINGOLI 2020-09-01  2019.0  1893.646316
# 3  HINGOLI 2020-10-01  1976.0  2050.355090
# 4  HINGOLI 2020-11-01  1722.0  1929.811859
# === Metrics ===
#   district        rmse  r_squared  \
# 0  JALGAON  614.936971   0.173958
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.35528761954711485, -0.07515099368817821, 0....  3116.311615       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  JALGAON 2020-07-01  6176.0  6903.056198
# 1  JALGAON 2020-08-01  5950.0  6647.725438
# 2  JALGAON 2020-09-01  6369.0  6648.098090
# 3  JALGAON 2020-10-01  6370.0  6750.720482
# 4  JALGAON 2020-11-01  6429.0  6663.609900
# === Metrics ===
#   district        rmse  r_squared  \
# 0    JALNA  167.754836    0.25099
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.4088069188533135, -0.17919003353499377, -0....  3634.912697       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    JALNA 2020-07-01  3234.0  3551.701399
# 1    JALNA 2020-08-01  3247.0  3365.779384
# 2    JALNA 2020-09-01  3401.0  3451.360879
# 3    JALNA 2020-10-01  3244.0  3529.684514
# 4    JALNA 2020-11-01  3164.0  3327.560965
# === Metrics ===
#    district        rmse  r_squared  \
# 0  KOLHAPUR  406.302936   0.177246
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.37169713849928626, -0.22776848005517902, 0....  3719.00703       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  KOLHAPUR 2020-07-01  4670.0  5078.250367
# 1  KOLHAPUR 2020-08-01  4437.0  4831.628679
# 2  KOLHAPUR 2020-09-01  5026.0  5021.899419
# 3  KOLHAPUR 2020-10-01  4973.0  5310.387724
# 4  KOLHAPUR 2020-11-01  4789.0  5072.760970
# === Metrics ===
#   district        rmse  r_squared  \
# 0    LATUR  346.737754   0.150264
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.06756066966579573, -0.3709008914505385, 0.0...  4984.972354       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    LATUR 2020-07-01  3694.0  3815.103576
# 1    LATUR 2020-08-01  3498.0  3866.645078
# 2    LATUR 2020-09-01  3654.0  3960.359508
# 3    LATUR 2020-10-01  3751.0  4037.905269
# 4    LATUR 2020-11-01  3673.0  3979.441248
# === Metrics ===
#   district         rmse  r_squared  \
# 0   MUMBAI  3399.674013   0.187937
#
#                                         coefficients   intercept  best_alpha  \
# 0  [-0.057592373741736334, -0.04052406375129354, ... -923.805054       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   MUMBAI 2020-07-01    2916  6888.209049
# 1   MUMBAI 2020-08-01    2676  7615.000346
# 2   MUMBAI 2020-09-01    3035  8462.621886
# 3   MUMBAI 2020-10-01    2924  7231.416759
# 4   MUMBAI 2020-11-01    3608  6229.461994
# === Metrics ===
#   district         rmse  r_squared  \
# 0   NAGPUR  1003.810389   0.137891
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.36836871217246586, -0.004250258276449122, -...  4518.763424       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NAGPUR 2020-07-01  7018.0  7083.721270
# 1   NAGPUR 2020-08-01  5585.0  6972.258767
# 2   NAGPUR 2020-09-01  5078.0  6600.886838
# 3   NAGPUR 2020-10-01  5618.0  6316.067173
# 4   NAGPUR 2020-11-01  6429.0  6606.509309
# === Metrics ===
#   district        rmse  r_squared  \
# 0   NANDED  450.159739   0.284409
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.40422955580958064, -0.391934168381116, 0.00...  6486.277593       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NANDED 2020-07-01  5261.0  5681.743220
# 1   NANDED 2020-08-01  4984.0  5558.035800
# 2   NANDED 2020-09-01  5871.0  5508.433735
# 3   NANDED 2020-10-01  5214.0  5967.264437
# 4   NANDED 2020-11-01  5237.0  5392.638734
# === Metrics ===
#     district        rmse  r_squared  \
# 0  NANDURBAR  211.709659   0.438475
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.46354971384017457, 0.1751166001977429, -0.0...  2611.648045       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  NANDURBAR 2020-07-01  3577.0  3657.363074
# 1  NANDURBAR 2020-08-01  2901.0  3376.341919
# 2  NANDURBAR 2020-09-01  3040.0  2842.992225
# 3  NANDURBAR 2020-10-01  2588.0  2679.863589
# 4  NANDURBAR 2020-11-01  2581.0  2593.361016
# === Metrics ===
#   district        rmse  r_squared  \
# 0   NASHIK  548.401016   0.239835
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.4276766432200335, -0.03355907832383914, 0.0...  4343.076025       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0   NASHIK 2020-07-01  10668.0  10672.134543
# 1   NASHIK 2020-08-01   9838.0  10404.669145
# 2   NASHIK 2020-09-01  10420.0  10206.009824
# 3   NASHIK 2020-10-01  10365.0  10382.559535
# 4   NASHIK 2020-11-01   9966.0  10582.036655
# === Metrics ===
#     district        rmse  r_squared  \
# 0  OSMANABAD  202.646223   0.191887
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.30515672613066325, -0.11793145448687178, 0....  2862.130088       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  OSMANABAD 2020-07-01  2273.0  2425.397872
# 1  OSMANABAD 2020-08-01  1935.0  2369.461021
# 2  OSMANABAD 2020-09-01  2241.0  2095.840766
# 3  OSMANABAD 2020-10-01  2207.0  2285.133804
# 4  OSMANABAD 2020-11-01  2274.0  2352.739931
# === Metrics ===
#   district        rmse  r_squared  \
# 0  PALGHAR  502.695528   0.205097
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.3325768264556029, 0.25469206116225296, -0.1...  2760.332396       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  PALGHAR 2020-07-01  4867.0  5521.746636
# 1  PALGHAR 2020-08-01  4606.0  5086.805814
# 2  PALGHAR 2020-09-01  4753.0  4868.798830
# 3  PALGHAR 2020-10-01  4616.0  4955.146750
# 4  PALGHAR 2020-11-01  4554.0  4980.566349
# === Metrics ===
#    district        rmse  r_squared  \
# 0  PARBHANI  346.362105    0.11998
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.3152300460717642, -0.03166600764257026, -0....  2717.455954       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  PARBHANI 2020-07-01  3186.0  3153.957189
# 1  PARBHANI 2020-08-01  2743.0  3108.244383
# 2  PARBHANI 2020-09-01  3099.0  2912.229309
# 3  PARBHANI 2020-10-01  2920.0  3097.738307
# 4  PARBHANI 2020-11-01  2538.0  2967.835954
# === Metrics ===
#   district         rmse  r_squared  \
# 0     PUNE  1535.017415   0.312329
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.3495049455659551, -0.036530592329371614, -0...  8182.010763       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0     PUNE 2020-07-01  14939.0  16654.213071
# 1     PUNE 2020-08-01  14322.0  14605.770203
# 2     PUNE 2020-09-01  16328.0  14687.510558
# 3     PUNE 2020-10-01  15750.0  16720.355586
# 4     PUNE 2020-11-01  15551.0  16519.690328
# === Metrics ===
#   district         rmse  r_squared  \
# 0   RAIGAD  1186.304604   0.285522
#
#                                         coefficients  intercept  best_alpha  \
# 0  [-0.5474336306685228, -0.3135053281686146, -0....  37.130514       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             1
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   RAIGAD 2020-07-01    3465  4067.208619
# 1   RAIGAD 2020-08-01    3013  4406.181833
# 2   RAIGAD 2020-09-01    3412  4895.149849
# 3   RAIGAD 2020-10-01    3704  5001.681949
# 4   RAIGAD 2020-11-01    3998  4926.677877
# === Metrics ===
#     district        rmse  r_squared  \
# 0  RATNAGIRI  200.226601   0.313857
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.6406312130830392, -0.08326748138228718, -0....  799.423662       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  RATNAGIRI 2020-07-01  1742.0  1782.831739
# 1  RATNAGIRI 2020-08-01  1206.0  1640.954637
# 2  RATNAGIRI 2020-09-01  1279.0  1289.030153
# 3  RATNAGIRI 2020-10-01  1186.0  1358.063776
# 4  RATNAGIRI 2020-11-01  1074.0  1281.460591
# === Metrics ===
#   district       rmse  r_squared  \
# 0   SANGLI  283.93706   0.318229
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.5542238053078907, -0.33035342660322653, 0.4...  1419.468565       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SANGLI 2020-07-01  4264.0  4443.547108
# 1   SANGLI 2020-08-01  3874.0  4115.536949
# 2   SANGLI 2020-09-01  3891.0  4088.540315
# 3   SANGLI 2020-10-01  3891.0  4174.412401
# 4   SANGLI 2020-11-01  3821.0  4006.236168
# === Metrics ===
#   district        rmse  r_squared  \
# 0   SATARA  521.559053   0.083818
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.15606832352681452, -0.22877279744873963, 0....  3490.39919       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SATARA 2020-07-01  3915.0  3936.365070
# 1   SATARA 2020-08-01  3233.0  3882.190067
# 2   SATARA 2020-09-01  3103.0  4048.171254
# 3   SATARA 2020-10-01  3760.0  4155.410272
# 4   SATARA 2020-11-01  3582.0  4183.817777
# === Metrics ===
#      district       rmse  r_squared  \
# 0  SINDHUDURG  89.540388   0.028137
#
#                                         coefficients   intercept  best_alpha  \
# 0  [0.09226266447595305, -0.001585369588967745, -...  754.848564       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01   721.0  696.492370
# 1  SINDHUDURG 2020-08-01   549.0  658.335097
# 2  SINDHUDURG 2020-09-01   579.0  632.639167
# 3  SINDHUDURG 2020-10-01   530.0  639.671459
# 4  SINDHUDURG 2020-11-01   476.0  644.894466
# === Metrics ===
#   district        rmse  r_squared  \
# 0  SOLAPUR  508.679103   0.336136
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.6416351130820814, -0.42842173364308916, 0.1...  3980.704165       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  SOLAPUR 2020-07-01  6858.0  7060.442907
# 1  SOLAPUR 2020-08-01  6356.0  6916.267429
# 2  SOLAPUR 2020-09-01  6758.0  6703.356491
# 3  SOLAPUR 2020-10-01  6321.0  7139.520161
# 4  SOLAPUR 2020-11-01  6058.0  6602.845139
# === Metrics ===
#   district         rmse  r_squared  \
# 0    THANE  1678.655593   0.206801
#
#                                         coefficients     intercept  \
# 0  [0.033330120169737174, -0.021934806974453547, ...  21246.376894
#
#    best_alpha                                       alphas_tried  differencing
# 0       100.0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0    THANE 2020-07-01  12050.0  14439.413494
# 1    THANE 2020-08-01  12215.0  14316.703513
# 2    THANE 2020-09-01  13770.0  14146.741167
# 3    THANE 2020-10-01  13402.0  14451.061980
# 4    THANE 2020-11-01  13995.0  14673.965840
# === Metrics ===
#   district        rmse  r_squared  \
# 0   WARDHA  190.247622   0.283989
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.44389710251910963, -0.37069545600690923, -0...  1786.904631       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WARDHA 2020-07-01  1452.0  1502.956920
# 1   WARDHA 2020-08-01  1358.0  1559.891869
# 2   WARDHA 2020-09-01  1360.0  1534.047706
# 3   WARDHA 2020-10-01  1306.0  1590.949661
# 4   WARDHA 2020-11-01  1196.0  1572.789106
# === Metrics ===
#   district       rmse  r_squared  \
# 0   WASHIM  176.61598   0.295359
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.49795564700972256, -0.544662302744955, 0.35...  1647.171578       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WASHIM 2020-07-01  1629.0  1566.155046
# 1   WASHIM 2020-08-01  1502.0  1718.316725
# 2   WASHIM 2020-09-01  1599.0  1522.862585
# 3   WASHIM 2020-10-01  1501.0  1744.359078
# 4   WASHIM 2020-11-01  1453.0  1565.969473
# === Metrics ===
#    district        rmse  r_squared  \
# 0  YAVATMAL  209.922941   0.127394
#
#                                         coefficients    intercept  best_alpha  \
# 0  [0.22321207321557227, 0.19382152157788174, -0....  2341.277516       100.0
#
#                                         alphas_tried  differencing
# 0  [0.001, 0.0014873521072935117, 0.0022122162910...             0
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  YAVATMAL 2020-07-01  3673.0  3821.118621
# 1  YAVATMAL 2020-08-01  3425.0  3764.493520
# 2  YAVATMAL 2020-09-01  3507.0  3726.570116
# 3  YAVATMAL 2020-10-01  3562.0  3697.086053
# 4  YAVATMAL 2020-11-01  3501.0  3730.553850
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 28
#      25         print(results['forecast_df'].head())
#      27     return results
# ---> 28 run_for_each_district()
#
# Cell In[6], line 11, in run_for_each_district()
#       8 district_data = data[data['district'] == district]
#       9 ts = district_data["I1"].asfreq('MS')
# ---> 11 results = ridge_regression_lags_only(
#      12     ts,
#      13     district,
#      14     max_lags=5,
#      15     use_cv=True,
#      16     alphas=np.logspace(-3, 2, 30),
#      17     cv=5
#      18 )
#      21 # Show results
#      22 print("=== Metrics ===")
#
# Cell In[5], line 47, in ridge_regression_lags_only(series, district_name, max_lags, differencing, alpha, use_cv, alphas, cv, random_state)
#      45 if use_cv:
#      46     model = RidgeCV(alphas=alphas, cv=TimeSeriesSplit(n_splits=5), scoring='neg_mean_squared_error')
# ---> 47     model.fit(X_train, y_train)
#      48     best_alpha = model.alpha_
#      49 else:
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_ridge.py:2418, in RidgeCV.fit(self, X, y, sample_weight)
#    2389 """Fit Ridge regression model with cv.
#    2390
#    2391 Parameters
#    (...)
#    2415 the validation score.
#    2416 """
#    2417 _raise_for_unsupported_routing(self, "fit", sample_weight=sample_weight)
# -> 2418 super().fit(X, y, sample_weight=sample_weight)
#    2419 return self
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_ridge.py:2240, in _BaseRidgeCV.fit(self, X, y, sample_weight)
#    2230 model = RidgeClassifier if is_classifier(self) else Ridge
#    2231 gs = GridSearchCV(
#    2232     model(
#    2233         fit_intercept=self.fit_intercept,
#    (...)
#    2238     scoring=self.scoring,
#    2239 )
# -> 2240 gs.fit(X, y, sample_weight=sample_weight)
#    2241 estimator = gs.best_estimator_
#    2242 self.alpha_ = gs.best_estimator_.alpha
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:928, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
#     916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
# --> 928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File c:\Users\nauti\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:1177, in TimeSeriesSplit.split(self, X, y, groups)
#    1175 # Make sure we have enough samples for the given split parameters
#    1176 if n_folds > n_samples:
# -> 1177     raise ValueError(
#    1178         f"Cannot have number of folds={n_folds} greater"
#    1179         f" than the number of samples={n_samples}."
#    1180     )
#    1181 if n_samples - gap - (test_size * n_splits) <= 0:
#    1182     raise ValueError(
#    1183         f"Too many splits={n_splits} for number of samples"
#    1184         f"={n_samples} with test_size={test_size} and gap={gap}."
#    1185     )
#
# ValueError: Cannot have number of folds=6 greater than the number of samples=5.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
