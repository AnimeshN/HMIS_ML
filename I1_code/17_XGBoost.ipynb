# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from xgboost import XGBRegressor

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def xgboost_forecast_lags(
    series,
    district_name,
    max_lags=12,
    differencing=True,
    use_cv=True,
    cv_params=None,
    custom_params=None
):
    """
    XGBoost time series forecasting with error handling
    Returns (None, None) if insufficient data, allowing pipeline continuation
    """
    try:
        # 1. Directory setup
        os.makedirs('XGBoost_Forecasts', exist_ok=True)
        
        # 2. Stationarity and differencing
        original_series = series.copy()
        d = 0
        if differencing:
            adf_result = adfuller(series.dropna())
            if adf_result[1] > 0.05:
                d = 1
                series = series.diff().dropna()
                if len(series) < 5:  # Check after differencing
                    raise ValueError(f"Series too short after differencing: {len(series)}")

        # 3. Create lag features with validation
        df = pd.DataFrame({'y': series.astype(float)})
        for lag in range(1, max_lags + 1):
            df[f'lag_{lag}'] = df['y'].shift(lag)
        df = df.dropna()
        
        if len(df) < 10:
            raise ValueError(f"Only {len(df)} samples after lag features")

        # 4. Temporal split validation
        train_size = int(len(df) * 0.8)
        if train_size < 5 or (len(df) - train_size) < 2:
            raise ValueError(f"Insufficient split: {train_size} train, {len(df)-train_size} test")
            
        train = df.iloc[:train_size]
        test = df.iloc[train_size:]

        X_train = train.drop(columns=['y'])
        y_train = train['y']
        X_test = test.drop(columns=['y'])
        y_test = test['y']

        # 5. Dynamic cross-validation setup
        xgb_params = custom_params or {
            'n_estimators': 500,
            'learning_rate': 0.05,
            'max_depth': 3,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': 42
        }
        
        if use_cv:
            n_splits = min(5, max(2, len(X_train)//2))  # Ensure 2 ≤ splits ≤5
            param_grid = cv_params or {
                'n_estimators': [100, 300],
                'learning_rate': [0.01, 0.05],
                'max_depth': [3, 5]
            }
            tscv = TimeSeriesSplit(n_splits=n_splits)
            
            grid_search = GridSearchCV(
                XGBRegressor(**xgb_params, verbosity=0),
                param_grid,
                cv=tscv,
                scoring='neg_mean_squared_error',
                n_jobs=-1
            )
            grid_search.fit(X_train, y_train)
            model = grid_search.best_estimator_
            best_params = grid_search.best_params_
        else:
            model = XGBRegressor(**xgb_params, verbosity=0)
            model.fit(X_train, y_train)
            best_params = xgb_params

        # 6. Forecasting and post-processing
        pred_test = model.predict(X_test)

        if d == 1:
            last_train_value = original_series.iloc[len(original_series) - len(test) - 1]
            pred_test = np.cumsum(pred_test) + last_train_value
            y_test = original_series.iloc[-len(test):]

        # 7. Save results
        forecast_df = pd.DataFrame({
            'district': district_name,
            'date': y_test.index,
            'actual': y_test.values,
            'forecast': pred_test
        })
        forecast_df.to_csv(
            os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.csv'), 
            index=False
        )

        # 8. Metrics and visualization
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        
        plt.figure(figsize=(14, 7))
        plt.plot(original_series.index, original_series, label='Original')
        plt.plot(forecast_df['date'], forecast_df['forecast'], label='Forecast', alpha=0.7)
        plt.title(f'{district_name} Forecast (RMSE: {rmse:.2f})')
        plt.legend()
        plt.savefig(os.path.join('XGBoost_Forecasts', f'{district_name}_forecast.png'))
        plt.close()

        return {
            'district': district_name,
            'rmse': rmse,
            'best_params': best_params,
            'differencing': d,
            'feature_importances': dict(zip(X_train.columns, model.feature_importances_))
        }, forecast_df

    except (ValueError, IndexError) as e:
        print(f"⚠️ Skipping {district_name}: {str(e)}")
        return None, None

# %%
districts = data['district'].unique()
rmse_values = []

# Usage Example


def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I1"].asfreq('MS')
        
        results, forecast = xgboost_forecast_lags(
            series=ts,  # pd.Series with DatetimeIndex
            district_name=district,
            max_lags=6,
            use_cv=True,
            cv_params={
                'n_estimators': [200, 500],
                'learning_rate': [0.05, 0.1],
                'max_depth': [3, 5]
            },
            custom_params={
                'subsample': 0.8,
                'colsample_bytree': 0.8,
                'random_state': 42
            }
        )

        
    
        # Show results
        print("=== Metrics ===")
        print(
 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.061113697, 'lag_2': 0.08105345, 'lag_3': 0.07266019, 'lag_4': 0.13585044, 'lag_5': 0.26430997, 'lag_6': 0.38501224}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0     BEED 2020-07-01  3821.0  3759.405518
# 1     BEED 2020-08-01  3261.0  3836.026611
# 2     BEED 2020-09-01  3819.0  3907.420166
# 3     BEED 2020-10-01  3751.0  3375.526611
# 4     BEED 2020-11-01  3332.0  3550.142578
# 5     BEED 2020-12-01  4156.0  3808.354004
# 6     BEED 2021-01-01  4018.0  3975.540039
# 7     BEED 2021-02-01  4267.0  4206.572266
# 8     BEED 2021-03-01  4241.0  4769.385742
# === Metrics ===
# {'district': 'BHANDARA', 'rmse': 398.65871392740667, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.12670097, 'lag_2': 0.15102749, 'lag_3': 0.106381565, 'lag_4': 0.18186529, 'lag_5': 0.2338833, 'lag_6': 0.20014137}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BHANDARA 2020-07-01    1262  1418.428711
# 1  BHANDARA 2020-08-01    1185  1553.477783
# 2  BHANDARA 2020-09-01    1200  1626.043457
# 3  BHANDARA 2020-10-01    1233  1655.566162
# 4  BHANDARA 2020-11-01    1093  1835.272949
# 5  BHANDARA 2020-12-01    1395  1811.459351
# 6  BHANDARA 2021-01-01    1416  1832.288574
# 7  BHANDARA 2021-02-01    1690  1770.006104
# 8  BHANDARA 2021-03-01    1729  1806.027588
# === Metrics ===
# {'district': 'BULDHANA', 'rmse': 348.9019530156102, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.11087493, 'lag_2': 0.15936503, 'lag_3': 0.17392059, 'lag_4': 0.11806454, 'lag_5': 0.28354263, 'lag_6': 0.15423232}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  BULDHANA 2020-07-01  3900.0  3959.404541
# 1  BULDHANA 2020-08-01  3612.0  4208.539062
# 2  BULDHANA 2020-09-01  4073.0  4157.168457
# 3  BULDHANA 2020-10-01  3614.0  3764.972900
# 4  BULDHANA 2020-11-01  3484.0  4138.375488
# 5  BULDHANA 2020-12-01  4289.0  4313.374023
# 6  BULDHANA 2021-01-01  4304.0  4108.101562
# 7  BULDHANA 2021-02-01  4508.0  4233.985840
# 8  BULDHANA 2021-03-01  4443.0  4037.948242
# === Metrics ===
# {'district': 'CHANDRAPUR', 'rmse': 284.5925126804626, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.19796838, 'lag_2': 0.039213415, 'lag_3': 0.05837716, 'lag_4': 0.19510989, 'lag_5': 0.24419908, 'lag_6': 0.2651321}}
#
# === Forecast Data ===
#      district       date  actual     forecast
# 0  CHANDRAPUR 2020-07-01  2316.0  2447.460938
# 1  CHANDRAPUR 2020-08-01  2209.0  2238.638672
# 2  CHANDRAPUR 2020-09-01  2247.0  2289.374756
# 3  CHANDRAPUR 2020-10-01  2187.0  2284.382324
# 4  CHANDRAPUR 2020-11-01  2220.0  2602.014648
# 5  CHANDRAPUR 2020-12-01  2940.0  3377.060547
# 6  CHANDRAPUR 2021-01-01  3096.0  3514.283203
# 7  CHANDRAPUR 2021-02-01  3083.0  3352.042725
# 8  CHANDRAPUR 2021-03-01  3033.0  3372.403564
# === Metrics ===
# {'district': 'DHULE', 'rmse': 501.5485072931401, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.2125516, 'lag_2': 0.13974695, 'lag_3': 0.19631894, 'lag_4': 0.14633255, 'lag_5': 0.10223843, 'lag_6': 0.20281154}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    DHULE 2020-07-01  3857.0  
 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.32683483, 'lag_2': 0.10272588, 'lag_3': 0.123941824, 'lag_4': 0.12126821, 'lag_5': 0.14366117, 'lag_6': 0.18156812}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    JALNA 2020-07-01  3234.0  3922.179199
# 1    JALNA 2020-08-01  3247.0  3445.693359
# 2    JALNA 2020-09-01  3401.0  3520.398193
# 3    JALNA 2020-10-01  3244.0  3498.408691
# 4    JALNA 2020-11-01  3164.0  3336.677979
# 5    JALNA 2020-12-01  3529.0  3569.654785
# 6    JALNA 2021-01-01  3637.0  3636.474854
# 7    JALNA 2021-02-01  3715.0  3466.121826
# 8    JALNA 2021-03-01  3560.0  3740.046875
# === Metrics ===
# {'district': 'KOLHAPUR', 'rmse': 447.39466327468347, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.1691756, 'lag_2': 0.1610364, 'lag_3': 0.18786237, 'lag_4': 0.15683682, 'lag_5': 0.18158537, 'lag_6': 0.14350344}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  KOLHAPUR 2020-07-01  4670.0  4989.212891
# 1  KOLHAPUR 2020-08-01  4437.0  5245.134766
# 2  KOLHAPUR 2020-09-01  5026.0  5059.705566
# 3  KOLHAPUR 2020-10-01  4973.0  5337.533203
# 4  KOLHAPUR 2020-11-01  4789.0  5326.782227
# 5  KOLHAPUR 2020-12-01  5795.0  5273.287598
# 6  KOLHAPUR 2021-01-01  5111.0  5222.461914
# 7  KOLHAPUR 2021-02-01  5237.0  4936.026855
# 8  KOLHAPUR 2021-03-01  4708.0  5206.052734
# === Metrics ===
# {'district': 'LATUR', 'rmse': 357.2272148422441, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.11717489, 'lag_2': 0.20485726, 'lag_3': 0.077225775, 'lag_4': 0.10748313, 'lag_5': 0.08599272, 'lag_6': 0.40726623}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0    LATUR 2020-07-01  3694.0  3954.596924
# 1    LATUR 2020-08-01  3498.0  4040.049805
# 2    LATUR 2020-09-01  3654.0  4065.755371
# 3    LATUR 2020-10-01  3751.0  4000.199463
# 4    LATUR 2020-11-01  3673.0  3704.437988
# 5    LATUR 2020-12-01  4091.0  3908.956787
# 6    LATUR 2021-01-01  4179.0  3977.024658
# 7    LATUR 2021-02-01  4416.0  3842.057129
# 8    LATUR 2021-03-01  4366.0  3977.673584
# === Metrics ===
# {'district': 'MUMBAI', 'rmse': 6683.414536967952, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 1, 'feature_importances': {'lag_1': 0.11827257, 'lag_2': 0.16939141, 'lag_3': 0.24484302, 'lag_4': 0.071547404, 'lag_5': 0.091876194, 'lag_6': 0.3040694}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   MUMBAI 2020-07-01    2916  2613.660889
# 1   MUMBAI 2020-08-01    2676  1110.195435
# 2   MUMBAI 2020-09-01    3035    80.488281
# 3   MUMBAI 2020-10-01    2924  -779.050537
# 4   MUMBAI 2020-11-01    3608 -2043.594727
# 5   MUMBAI 2020-12-01    4419 -2658.300781
# 6   MUMBAI 2021-01-01    4239 -4612.547852
# 7   MUMBAI 2021-02-01    4034 -5575.048828
# 8   MUMBAI 2021-03-01    4119 -7030.662109
# === Metrics ===
# {'district': 'NAGPUR', 'rmse': 1263.7115425457157, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.21386461, 'lag_2': 0.17079279, 'lag_3': 0.09877738, 'lag_4': 0.156591, 'lag_5': 0.17846617, 'lag_6': 0.18150805}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NAGPUR 2020-07-01  7018.0  7368.202148
# 1   NAGPUR 2020-08-01  5585.0  7013.706543
# 2   NAGPUR 2020-09-01  5078.0  7304.885742
# 3   NAGPUR 2020-10-01  5618.0  6632.677734
# 4   NAGPUR 2020-11-01  6429.0  6322.472656
# 5   NAGPUR 2020-12-01  7872.0  6381.267578
# 6   NAGPUR 2021-01-01  7618.0  7258.487793
# 7   NAGPUR 2021-02-01  8330.0  7250.420898
# 8   NAGPUR 2021-03-01  8796.0  7155.300293
# === Metrics ===
# {'district': 'NANDED', 'rmse': 455.407641362697, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.16701153, 'lag_2': 0.13181426, 'lag_3': 0.1725473, 'lag_4': 0.21622023, 'lag_5': 0.15610172, 'lag_6': 0.15630494}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   NANDED 2020-07-01  5261.0  5513.069824
# 1   NANDED 2020-08-01  4984.0  5680.728027
# 2   NANDED 2020-09-01  5871.0  6028.136230
# 3   NANDED 2020-10-01  5214.0  5880.365723
# 4   NANDED 2020-11-01  5237.0  5380.680664
# 5   NANDED 2020-12-01  6097.0  5628.132324
# 6   NANDED 2021-01-01  5865.0  5758.001953
# 7   NANDED 2021-02-01  6268.0  5587.066895
# 8   NANDED 2021-03-01  5883.0  5517.950195
# === Metrics ===
# {'district': 'NANDURBAR', 'rmse': 198.5839308168141, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.17214534, 'lag_2': 0.09113654, 'lag_3': 0.055642482, 'lag_4': 0.15361303, 'lag_5': 0.27516302, 'lag_6': 0.25229967}}
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  NANDURBAR 2020-07-01  3577.0  3250.375732
# 1  NANDURBAR 2020-08-01  2901.0  2958.501465
# 2  NANDURBAR 2020-09-01  3040.0  2995.670410
# 3  NANDURBAR 2020-10-01  2588.0  2821.660889
# 4  NANDURBAR 2020-11-01  2581.0  2820.071045
# 5  NANDURBAR 2020-12-01  2989.0  2690.437256
# 6  NANDURBAR 2021-01-01  2803.0  2946.201660
# 7  NANDURBAR 2021-02-01  3130.0  3117.103516
# 8  NANDURBAR 2021-03-01  3365.0  3218.712158
# === Metrics ===
# {'district': 'NASHIK', 'rmse': 841.6705306087848, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.3628632, 'lag_2': 0.07845677, 'lag_3': 0.09848733, 'lag_4': 0.19486181, 'lag_5': 0.12221305, 'lag_6': 0.14311789}}
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0   NASHIK 2020-07-01  10668.0  10610.534180
# 1   NASHIK 2020-08-01   9838.0  10443.963867
# 2   NASHIK 2020-09-01  10420.0  10436.177734
# 3   NASHIK 2020-10-01  10365.0   9290.239258
# 4   NASHIK 2020-11-01   9966.0  10120.301758
# 5   NASHIK 2020-12-01  11339.0  10209.817383
# 6   NASHIK 2021-01-01  11056.0  10466.449219
# 7   NASHIK 2021-02-01  11802.0  10685.255859
# 8   NASHIK 2021-03-01  10787.0  12185.666016
# === Metrics ===
# {'district': 'OSMANABAD', 'rmse': 211.66600021375655, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.12775432, 'lag_2': 0.074357286, 'lag_3': 0.13672476, 'lag_4': 0.16792962, 'lag_5': 0.21197154, 'lag_6': 0.2812625}}
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  OSMANABAD 2020-07-01  2273.0  2461.199463
# 1  OSMANABAD 2020-08-01  1935.0  2342.876221
# 2  OSMANABAD 2020-09-01  2241.0  2195.858887
# 3  OSMANABAD 2020-10-01  2207.0  2107.950684
# 4  OSMANABAD 2020-11-01  2274.0  2283.206055
# 5  OSMANABAD 2020-12-01  2540.0  2424.349609
# 6  OSMANABAD 2021-01-01  2519.0  2497.802734
# 7  OSMANABAD 2021-02-01  2847.0  2430.298828
# 8  OSMANABAD 2021-03-01  2677.0  2722.199219
# === Metrics ===
# {'district': 'PALGHAR', 'rmse': 550.9940526997188, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.20990017, 'lag_2': 0.13927463, 'lag_3': 0.17550571, 'lag_4': 0.16384773, 'lag_5': 0.15167598, 'lag_6': 0.15979584}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  PALGHAR 2020-07-01  4867.0  5507.629883
# 1  PALGHAR 2020-08-01  4606.0  5174.869629
# 2  PALGHAR 2020-09-01  4753.0  5101.751465
# 3  PALGHAR 2020-10-01  4616.0  4874.315918
# 4  PALGHAR 2020-11-01  4554.0  5175.821289
# 5  PALGHAR 2020-12-01  5005.0  5132.361816
# 6  PALGHAR 2021-01-01  5509.0  5235.975586
# 7  PALGHAR 2021-02-01  5817.0  5214.425293
# 8  PALGHAR 2021-03-01  6435.0  5450.391113
# === Metrics ===
# {'district': 'PARBHANI', 'rmse': 313.11005033168965, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.20189996, 'lag_2': 0.1454615, 'lag_3': 0.14580075, 'lag_4': 0.14137246, 'lag_5': 0.100345306, 'lag_6': 0.26512003}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  PARBHANI 2020-07-01  3186.0  3407.644775
# 1  PARBHANI 2020-08-01  2743.0  2847.532959
# 2  PARBHANI 2020-09-01  3099.0  3034.010742
# 3  PARBHANI 2020-10-01  2920.0  3159.411865
# 4  PARBHANI 2020-11-01  2538.0  2946.830078
# 5  PARBHANI 2020-12-01  3472.0  2900.425781
# 6  PARBHANI 2021-01-01  3279.0  3126.804443
# 7  PARBHANI 2021-02-01  3530.0  3080.976074
# 8  PARBHANI 2021-03-01  3595.0  3389.766357
# === Metrics ===
# {'district': 'PUNE', 'rmse': 1332.7852908696998, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.118956946, 'lag_2': 0.104537226, 'lag_3': 0.23120353, 'lag_4': 0.090504356, 'lag_5': 0.22496474, 'lag_6': 0.22983322}}
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0     PUNE 2020-07-01  14939.0  16381.415039
# 1     PUNE 2020-08-01  14322.0  15390.697266
# 2     PUNE 2020-09-01  16328.0  14140.908203
# 3     PUNE 2020-10-01  15750.0  16390.546875
# 4     PUNE 2020-11-01  15551.0  16258.794922
# 5     PUNE 2020-12-01  18113.0  16356.553711
# 6     PUNE 2021-01-01  17234.0  15626.055664
# 7     PUNE 2021-02-01  17537.0  17211.861328
# 8     PUNE 2021-03-01  18280.0  17142.798828
# === Metrics ===
# {'district': 'RAIGAD', 'rmse': 1047.2092836868828, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 1, 'feature_importances': {'lag_1': 0.24018542, 'lag_2': 0.094711535, 'lag_3': 0.18197943, 'lag_4': 0.19210301, 'lag_5': 0.17841123, 'lag_6': 0.11260939}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   RAIGAD 2020-07-01    3465  3947.531738
# 1   RAIGAD 2020-08-01    3013  4798.825195
# 2   RAIGAD 2020-09-01    3412  5163.401855
# 3   RAIGAD 2020-10-01    3704  5088.871094
# 4   RAIGAD 2020-11-01    3998  4923.917480
# 5   RAIGAD 2020-12-01    5251  4715.286621
# 6   RAIGAD 2021-01-01    4693  4701.616699
# 7   RAIGAD 2021-02-01    4937  4816.840820
# 8   RAIGAD 2021-03-01    4981  4429.895508
# === Metrics ===
# {'district': 'RATNAGIRI', 'rmse': 334.9205175973155, 'best_params': {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.2582991, 'lag_2': 0.123501346, 'lag_3': 0.08644127, 'lag_4': 0.15062036, 'lag_5': 0.15822749, 'lag_6': 0.2229104}}
#
# === Forecast Data ===
#     district       date  actual     forecast
# 0  RATNAGIRI 2020-07-01  1742.0  1667.148560
# 1  RATNAGIRI 2020-08-01  1206.0  1615.461914
# 2  RATNAGIRI 2020-09-01  1279.0  1513.712891
# 3  RATNAGIRI 2020-10-01  1186.0  1489.293701
# 4  RATNAGIRI 2020-11-01  1074.0  1372.684570
# 5  RATNAGIRI 2020-12-01  1108.0  1472.124634
# 6  RATNAGIRI 2021-01-01  1177.0  1563.819214
# 7  RATNAGIRI 2021-02-01  1246.0  1460.044800
# 8  RATNAGIRI 2021-03-01  1164.0  1685.500977
# === Metrics ===
# {'district': 'SANGLI', 'rmse': 321.02569251548454, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.16937341, 'lag_2': 0.114996016, 'lag_3': 0.17784049, 'lag_4': 0.20343697, 'lag_5': 0.1738633, 'lag_6': 0.16048989}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SANGLI 2020-07-01  4264.0  4311.069824
# 1   SANGLI 2020-08-01  3874.0  4274.981445
# 2   SANGLI 2020-09-01  3891.0  4415.960449
# 3   SANGLI 2020-10-01  3891.0  4338.594238
# 4   SANGLI 2020-11-01  3821.0  4105.950684
# 5   SANGLI 2020-12-01  4539.0  4172.185547
# 6   SANGLI 2021-01-01  4333.0  4424.160156
# 7   SANGLI 2021-02-01  4393.0  4156.882812
# 8   SANGLI 2021-03-01  4144.0  4237.704102
# === Metrics ===
# {'district': 'SATARA', 'rmse': 484.12621618916137, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.2059783, 'lag_2': 0.22679718, 'lag_3': 0.13953923, 'lag_4': 0.119260095, 'lag_5': 0.16232583, 'lag_6': 0.14609939}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   SATARA 2020-07-01  3915.0  4078.481689
# 1   SATARA 2020-08-01  3233.0  4054.380859
# 2   SATARA 2020-09-01  3103.0  3927.110107
# 3   SATARA 2020-10-01  3760.0  4108.663086
# 4   SATARA 2020-11-01  3582.0  4146.006836
# 5   SATARA 2020-12-01  4595.0  4116.458984
# 6   SATARA 2021-01-01  4175.0  4196.512695
# 7   SATARA 2021-02-01  4151.0  4019.068359
# 8   SATARA 2021-03-01  3735.0  3940.702637
# === Metrics ===
# {'district': 'SINDHUDURG', 'rmse': 102.63542305113072, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.12132359, 'lag_2': 0.14714587, 'lag_3': 0.13646983, 'lag_4': 0.15164132, 'lag_5': 0.1333685, 'lag_6': 0.31005093}}
#
# === Forecast Data ===
#      district       date  actual    forecast
# 0  SINDHUDURG 2020-07-01   721.0  715.889099
# 1  SINDHUDURG 2020-08-01   549.0  680.575256
# 2  SINDHUDURG 2020-09-01   579.0  699.460876
# 3  SINDHUDURG 2020-10-01   530.0  652.790405
# 4  SINDHUDURG 2020-11-01   476.0  617.570007
# 5  SINDHUDURG 2020-12-01   592.0  658.653748
# 6  SINDHUDURG 2021-01-01   618.0  698.511841
# 7  SINDHUDURG 2021-02-01   640.0  732.017944
# 8  SINDHUDURG 2021-03-01   659.0  750.899658
# === Metrics ===
# {'district': 'SOLAPUR', 'rmse': 658.221225945605, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.36821967, 'lag_2': 0.12159994, 'lag_3': 0.14343989, 'lag_4': 0.16518436, 'lag_5': 0.12778541, 'lag_6': 0.073770665}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0  SOLAPUR 2020-07-01  6858.0  7029.957520
# 1  SOLAPUR 2020-08-01  6356.0  6613.416016
# 2  SOLAPUR 2020-09-01  6758.0  6910.416504
# 3  SOLAPUR 2020-10-01  6321.0  7237.764648
# 4  SOLAPUR 2020-11-01  6058.0  7362.310059
# 5  SOLAPUR 2020-12-01  7648.0  6814.409668
# 6  SOLAPUR 2021-01-01  7550.0  7768.999512
# 7  SOLAPUR 2021-02-01  6956.0  7487.133789
# 8  SOLAPUR 2021-03-01  7219.0  6756.815430
# === Metrics ===
# {'district': 'THANE', 'rmse': 1319.4083246127466, 'best_params': {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.07803229, 'lag_2': 0.12913369, 'lag_3': 0.1868793, 'lag_4': 0.27055386, 'lag_5': 0.12689017, 'lag_6': 0.20851071}}
#
# === Forecast Data ===
#   district       date   actual      forecast
# 0    THANE 2020-07-01  12050.0  13496.727539
# 1    THANE 2020-08-01  12215.0  13798.841797
# 2    THANE 2020-09-01  13770.0  14319.288086
# 3    THANE 2020-10-01  13402.0  14433.056641
# 4    THANE 2020-11-01  13995.0  14044.340820
# 5    THANE 2020-12-01  14285.0  14410.073242
# 6    THANE 2021-01-01  15181.0  14213.916016
# 7    THANE 2021-02-01  16357.0  14703.529297
# 8    THANE 2021-03-01  16591.0  14138.678711
# === Metrics ===
# {'district': 'WARDHA', 'rmse': 197.25243531158043, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}, 'differencing': 0, 'feature_importances': {'lag_1': 0.22951771, 'lag_2': 0.114545465, 'lag_3': 0.15703727, 'lag_4': 0.20769477, 'lag_5': 0.082123466, 'lag_6': 0.20908135}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WARDHA 2020-07-01  1452.0  1511.782227
# 1   WARDHA 2020-08-01  1358.0  1548.631958
# 2   WARDHA 2020-09-01  1360.0  1499.526855
# 3   WARDHA 2020-10-01  1306.0  1558.779053
# 4   WARDHA 2020-11-01  1196.0  1664.311279
# 5   WARDHA 2020-12-01  1561.0  1623.323730
# 6   WARDHA 2021-01-01  1640.0  1612.000488
# 7   WARDHA 2021-02-01  1787.0  1734.582764
# 8   WARDHA 2021-03-01  1743.0  1730.115234
# === Metrics ===
# {'district': 'WASHIM', 'rmse': 168.97690509268733, 'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.17292358, 'lag_2': 0.15414482, 'lag_3': 0.104704194, 'lag_4': 0.23418486, 'lag_5': 0.17621987, 'lag_6': 0.15782261}}
#
# === Forecast Data ===
#   district       date  actual     forecast
# 0   WASHIM 2020-07-01  1629.0  1527.008545
# 1   WASHIM 2020-08-01  1502.0  1613.942871
# 2   WASHIM 2020-09-01  1599.0  1745.610596
# 3   WASHIM 2020-10-01  1501.0  1726.596191
# 4   WASHIM 2020-11-01  1453.0  1559.961304
# 5   WASHIM 2020-12-01  1839.0  1873.308228
# 6   WASHIM 2021-01-01  1658.0  1809.185181
# 7   WASHIM 2021-02-01  1858.0  1523.894531
# 8   WASHIM 2021-03-01  1844.0  1964.647339
# === Metrics ===
# {'district': 'YAVATMAL', 'rmse': 277.724729379316, 'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}, 'differencing': 0, 'feature_importances': {'lag_1': 0.21838437, 'lag_2': 0.11419817, 'lag_3': 0.15840194, 'lag_4': 0.1339392, 'lag_5': 0.20262578, 'lag_6': 0.17245051}}
#
# === Forecast Data ===
#    district       date  actual     forecast
# 0  YAVATMAL 2020-07-01  3673.0  3344.619385
# 1  YAVATMAL 2020-08-01  3425.0  3325.822266
# 2  YAVATMAL 2020-09-01  3507.0  3339.413086
# 3  YAVATMAL 2020-10-01  3562.0  3666.253906
# 4  YAVATMAL 2020-11-01  3501.0  3759.620605
# 5  YAVATMAL 2020-12-01  3918.0  3602.967285
# 6  YAVATMAL 2021-01-01  3851.0  3963.006348
# 7  YAVATMAL 2021-02-01  3983.0  3686.191162
# 8  YAVATMAL 2021-03-01  4182.0  3661.631104
# ⚠️ Skipping MUMBAI SUBURBAN: Only 6 samples after lag features
# === Metrics ===
# None
#
# === Forecast Data ===
# None

# %%
# !pip install "dask<2025.1"
