# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tbats import TBATS as TBATSModel
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("../data/HMIS_DATA_CORRECTED_17_21/mh_dist17_21_with_IDs_date_correction.csv")
data = data[(data['indicator_type'] == 'Total [(A+B) or (C+D)]')]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.index = pd.DatetimeIndex(data.index)

# %%
def tbats_forecast_district(series, district_name, seasonal_periods=None, 
                           use_box_cox=None, use_arma_errors=True, n_jobs=1):
    """
    TBATS forecasting with data storage and plot saving
    """
    # Create directory structure
    os.makedirs('TBATS', exist_ok=True)
    
    # 1. Train-Test Split (80:20)
    train_size = int(len(series) * 0.8)
    train, test = series.iloc[:train_size], series.iloc[train_size:]

    # 2. TBATS Model Configuration
    estimator = TBATSModel(
        seasonal_periods=seasonal_periods,
        use_box_cox=use_box_cox,
        use_arma_errors=use_arma_errors,
        n_jobs=n_jobs
    )
    
    # 3. Model Fitting
    fitted_model = estimator.fit(train.values)
    
    # 4. Forecasting
    forecast = fitted_model.forecast(steps=len(test))
    
    # 5. Create forecast DataFrame
    forecast_df = pd.DataFrame({
        'district': district_name,
        'date': test.index,
        'actual': test.values,
        'forecast': forecast,
        'model_params': str(fitted_model.params)
    })

    # 6. Save forecasts to CSV
    forecast_csv_path = os.path.join('TBATS', 'tbats_forecasts.csv')
    write_header = not os.path.exists(forecast_csv_path)
    forecast_df.to_csv(forecast_csv_path, 
                      mode='a', 
                      header=write_header, 
                      index=False)

    # 7. Calculate and save metrics
    rmse = np.sqrt(mean_squared_error(test, forecast))
    metrics_df = pd.DataFrame([{
        'district': district_name,
        'rmse': rmse,
        'seasonal_periods': str(seasonal_periods),
        'box_cox_used': fitted_model.params.components.use_box_cox,
        # 'arma_used': fitted_model.params.components.use_arma
        'arma_errors_used': fitted_model.params.components.use_arma_errors

    }])

    metrics_csv_path = os.path.join('TBATS', 'tbats_results.csv')
    write_header_metrics = not os.path.exists(metrics_csv_path)
    metrics_df.to_csv(metrics_csv_path, 
                     mode='a', 
                     header=write_header_metrics, 
                     index=False)

    # 8. Save plot
    plt.figure(figsize=(12, 6))
    plt.plot(train, label='Training Data')
    plt.plot(test, label='Actual Values', color='navy')
    plt.plot(test.index, forecast, label='TBATS Forecast', color='darkorange')
    plt.title(f'TBATS Forecast for {district_name}\nRMSE: {rmse:.2f}')
    plt.legend()
    plt.savefig(os.path.join('TBATS', f'TBATS_forecast_{district_name}.png'))
    plt.close()

    return {
        'district': district_name,
        'forecast_df': forecast_df,
        'metrics_df': metrics_df,
        'model_summary': fitted_model.summary()
    }

# %%
districts = data['district'].unique()
rmse_values = []

def run_for_each_district():
    results = {}
    
    for district in districts:
        district_data = data[data['district'] == district]
        ts = district_data["I1"].asfreq('MS')
        
        results = tbats_forecast_district(ts, district)
    
        # Show results
        print("=== Metrics ===")
        print(results['metrics_df'])
        print("\n=== Forecast Data ===")
        print(results['forecast_df'].head())
    
    return results
run_for_each_district()
# Out:
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AHMEDNAGAR  557.321765             None         False             False
#
# === Forecast Data ===
#      district       date  actual    forecast  \
# 0  AHMEDNAGAR 2020-06-01    6875  6955.24443
# 1  AHMEDNAGAR 2020-07-01    6478  6955.24443
# 2  AHMEDNAGAR 2020-08-01    5975  6955.24443
# 3  AHMEDNAGAR 2020-09-01    6550  6955.24443
# 4  AHMEDNAGAR 2020-10-01    6471  6955.24443
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    AKOLA  256.933008             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    AKOLA 2020-06-01    2999  2739.108565
# 1    AKOLA 2020-07-01    3121  2739.108565
# 2    AKOLA 2020-08-01    3029  2739.108565
# 3    AKOLA 2020-09-01    2763  2739.108565
# 4    AKOLA 2020-10-01    2737  2739.108565
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AMRAVATI  488.604354             None         False              True
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  AMRAVATI 2020-06-01    3883  3926.181917
# 1  AMRAVATI 2020-07-01    3459  3894.004152
# 2  AMRAVATI 2020-08-01    3049  3894.004152
# 3  AMRAVATI 2020-09-01    3325  3894.004152
# 4  AMRAVATI 2020-10-01    3191  3894.004152
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  AURANGABAD  581.076571             None         False             False
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  AURANGABAD 2020-06-01    7193  6158.194913
# 1  AURANGABAD 2020-07-01    6028  6158.194913
# 2  AURANGABAD 2020-08-01    6173  6158.194913
# 3  AURANGABAD 2020-09-01    6644  6158.194913
# 4  AURANGABAD 2020-10-01    6246  6158.194913
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0     BEED  1001.727063             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0     BEED 2020-06-01    3954  4808.029444
# 1     BEED 2020-07-01    3821  4808.029444
# 2     BEED 2020-08-01    3261  4808.029444
# 3     BEED 2020-09-01    3819  4808.029444
# 4     BEED 2020-10-01    3751  4808.029444
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district       rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  BHANDARA  232.64653             None         False              True
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  BHANDARA 2020-06-01    1341  1484.341598
# 1  BHANDARA 2020-07-01    1262  1474.614103
# 2  BHANDARA 2020-08-01    1185  1470.614503
# 3  BHANDARA 2020-09-01    1200  1468.970009
# 4  BHANDARA 2020-10-01    1233  1468.293851
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  BULDHANA  373.118975             None          True             False
#
# === Forecast Data ===
#    district       date  actual    forecast  \
# 0  BULDHANA 2020-06-01    4320  4158.77862
# 1  BULDHANA 2020-07-01    3900  4158.77862
# 2  BULDHANA 2020-08-01    3612  4158.77862
# 3  BULDHANA 2020-09-01    4073  4158.77862
# 4  BULDHANA 2020-10-01    3614  4158.77862
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  CHANDRAPUR  453.634917             None          True             False
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  CHANDRAPUR 2020-06-01    2500  2872.233744
# 1  CHANDRAPUR 2020-07-01    2316  2825.016386
# 2  CHANDRAPUR 2020-08-01    2209  2787.557373
# 3  CHANDRAPUR 2020-09-01    2247  2757.753222
# 4  CHANDRAPUR 2020-10-01    2187  2733.983919
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    DHULE  364.272111             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    DHULE 2020-06-01    3995  3706.829113
# 1    DHULE 2020-07-01    3857  3702.396100
# 2    DHULE 2020-08-01    3076  3698.596391
# 3    DHULE 2020-09-01    3376  3695.339512
# 4    DHULE 2020-10-01    3157  3692.547914
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  GADCHIROLI  512.525525             None         False             False
#
# === Forecast Data ===
#      district       date  actual     forecast  \
# 0  GADCHIROLI 2020-06-01    1678  1981.491214
# 1  GADCHIROLI 2020-07-01    1431  1981.491214
# 2  GADCHIROLI 2020-08-01    1224  1981.491214
# 3  GADCHIROLI 2020-09-01    1361  1981.491214
# 4  GADCHIROLI 2020-10-01    1251  1981.491214
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   GONDIA  224.812055             None         False              True
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   GONDIA 2020-06-01    1680  1782.775916
# 1   GONDIA 2020-07-01    1703  1751.875075
# 2   GONDIA 2020-08-01    1383  1737.456423
# 3   GONDIA 2020-09-01    1445  1730.728532
# 4   GONDIA 2020-10-01    1472  1727.589228
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  HINGOLI  123.873319             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  HINGOLI 2020-06-01    1988  1943.220326
# 1  HINGOLI 2020-07-01    1886  1943.220326
# 2  HINGOLI 2020-08-01    1692  1943.220326
# 3  HINGOLI 2020-09-01    2019  1943.220326
# 4  HINGOLI 2020-10-01    1976  1943.220326
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  JALGAON  677.025173             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  JALGAON 2020-06-01    6888  7065.880591
# 1  JALGAON 2020-07-01    6176  7065.880591
# 2  JALGAON 2020-08-01    5950  7065.880591
# 3  JALGAON 2020-09-01    6369  7065.880591
# 4  JALGAON 2020-10-01    6370  7065.880591
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    JALNA  282.996076             None         False              True
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    JALNA 2020-06-01    3865  3683.045671
# 1    JALNA 2020-07-01    3234  3635.923572
# 2    JALNA 2020-08-01    3247  3635.923572
# 3    JALNA 2020-09-01    3401  3635.923572
# 4    JALNA 2020-10-01    3244  3635.923572
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  KOLHAPUR  372.378806             None          True             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  KOLHAPUR 2020-06-01    4861  5061.559623
# 1  KOLHAPUR 2020-07-01    4670  5071.371101
# 2  KOLHAPUR 2020-08-01    4437  5079.567562
# 3  KOLHAPUR 2020-09-01    5026  5086.414721
# 4  KOLHAPUR 2020-10-01    4973  5092.134615
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    LATUR  307.196063             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0    LATUR 2020-06-01    3989  3874.078620
# 1    LATUR 2020-07-01    3694  3876.276522
# 2    LATUR 2020-08-01    3498  3878.202478
# 3    LATUR 2020-09-01    3654  3879.890136
# 4    LATUR 2020-10-01    3751  3881.368980
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   MUMBAI  1616.988799             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   MUMBAI 2020-06-01    2613  1983.903457
# 1   MUMBAI 2020-07-01    2916  1983.903457
# 2   MUMBAI 2020-08-01    2676  1983.903457
# 3   MUMBAI 2020-09-01    3035  1983.903457
# 4   MUMBAI 2020-10-01    2924  1983.903457
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   NAGPUR  1255.501446             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   NAGPUR 2020-06-01    7368  6731.223503
# 1   NAGPUR 2020-07-01    7018  6716.483806
# 2   NAGPUR 2020-08-01    5585  6701.744109
# 3   NAGPUR 2020-09-01    5078  6687.004412
# 4   NAGPUR 2020-10-01    5618  6672.264715
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   NANDED  421.971657             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   NANDED 2020-06-01    5423  5686.590689
# 1   NANDED 2020-07-01    5261  5686.590689
# 2   NANDED 2020-08-01    4984  5686.590689
# 3   NANDED 2020-09-01    5871  5686.590689
# 4   NANDED 2020-10-01    5214  5686.590689
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  NANDURBAR  353.807087             None         False              True
#
# === Forecast Data ===
#     district       date  actual     forecast  \
# 0  NANDURBAR 2020-06-01    4043  3421.732203
# 1  NANDURBAR 2020-07-01    3577  3214.865085
# 2  NANDURBAR 2020-08-01    2901  3134.162457
# 3  NANDURBAR 2020-09-01    3040  3102.678893
# 4  NANDURBAR 2020-10-01    2588  3090.396581
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   NASHIK  1007.650092             None          True             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   NASHIK 2020-06-01   10644  9856.556818
# 1   NASHIK 2020-07-01   10668  9856.556818
# 2   NASHIK 2020-08-01    9838  9856.556818
# 3   NASHIK 2020-09-01   10420  9856.556818
# 4   NASHIK 2020-10-01   10365  9856.556818
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  OSMANABAD  268.920298             None         False             False
#
# === Forecast Data ===
#     district       date  actual    forecast  \
# 0  OSMANABAD 2020-06-01    2582  2493.10668
# 1  OSMANABAD 2020-07-01    2273  2493.10668
# 2  OSMANABAD 2020-08-01    1935  2493.10668
# 3  OSMANABAD 2020-09-01    2241  2493.10668
# 4  OSMANABAD 2020-10-01    2207  2493.10668
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  PALGHAR  706.779556             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  PALGHAR 2020-06-01    5473  5547.276095
# 1  PALGHAR 2020-07-01    4867  5547.276095
# 2  PALGHAR 2020-08-01    4606  5547.276095
# 3  PALGHAR 2020-09-01    4753  5547.276095
# 4  PALGHAR 2020-10-01    4616  5547.276095
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  PARBHANI  379.819648             None         False             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  PARBHANI 2020-06-01    3561  3040.029993
# 1  PARBHANI 2020-07-01    3186  3040.029993
# 2  PARBHANI 2020-08-01    2743  3040.029993
# 3  PARBHANI 2020-09-01    3099  3040.029993
# 4  PARBHANI 2020-10-01    2920  3040.029993
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0     PUNE  3163.367309             None         False             False
#
# === Forecast Data ===
#   district       date  actual      forecast  \
# 0     PUNE 2020-06-01   16981  14793.099166
# 1     PUNE 2020-07-01   14939  14585.529935
# 2     PUNE 2020-08-01   14322  14377.960703
# 3     PUNE 2020-09-01   16328  14170.391472
# 4     PUNE 2020-10-01   15750  13962.822240
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   RAIGAD  734.984296             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   RAIGAD 2020-06-01    3940  4102.787501
# 1   RAIGAD 2020-07-01    3465  4102.787501
# 2   RAIGAD 2020-08-01    3013  4102.787501
# 3   RAIGAD 2020-09-01    3412  4102.787501
# 4   RAIGAD 2020-10-01    3704  4102.787501
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#     district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  RATNAGIRI  314.168961             None         False             False
#
# === Forecast Data ===
#     district       date  actual     forecast  \
# 0  RATNAGIRI 2020-06-01    1939  1466.387543
# 1  RATNAGIRI 2020-07-01    1742  1466.387543
# 2  RATNAGIRI 2020-08-01    1206  1466.387543
# 3  RATNAGIRI 2020-09-01    1279  1466.387543
# 4  RATNAGIRI 2020-10-01    1186  1466.387543
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   SANGLI  320.890228             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   SANGLI 2020-06-01    4359  4353.523415
# 1   SANGLI 2020-07-01    4264  4353.523415
# 2   SANGLI 2020-08-01    3874  4353.523415
# 3   SANGLI 2020-09-01    3891  4353.523415
# 4   SANGLI 2020-10-01    3891  4353.523415
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   SATARA  484.318188             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   SATARA 2020-06-01    4063  4058.462728
# 1   SATARA 2020-07-01    3915  4058.462728
# 2   SATARA 2020-08-01    3233  4058.462728
# 3   SATARA 2020-09-01    3103  4058.462728
# 4   SATARA 2020-10-01    3760  4058.462728
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#      district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  SINDHUDURG  109.767865             None         False             False
#
# === Forecast Data ===
#      district       date  actual    forecast  \
# 0  SINDHUDURG 2020-06-01     792  680.892757
# 1  SINDHUDURG 2020-07-01     721  680.892757
# 2  SINDHUDURG 2020-08-01     549  680.892757
# 3  SINDHUDURG 2020-09-01     579  680.892757
# 4  SINDHUDURG 2020-10-01     530  680.892757
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  SOLAPUR  579.471671             None         False              True
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0  SOLAPUR 2020-06-01    6951  7027.419947
# 1  SOLAPUR 2020-07-01    6858  7177.730980
# 2  SOLAPUR 2020-08-01    6356  7177.730980
# 3  SOLAPUR 2020-09-01    6758  7177.730980
# 4  SOLAPUR 2020-10-01    6321  7177.730980
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district         rmse seasonal_periods  box_cox_used  arma_errors_used
# 0    THANE  1456.553498             None         False             False
#
# === Forecast Data ===
#   district       date  actual      forecast  \
# 0    THANE 2020-06-01   13519  14085.048635
# 1    THANE 2020-07-01   12050  14085.048635
# 2    THANE 2020-08-01   12215  14085.048635
# 3    THANE 2020-09-01   13770  14085.048635
# 4    THANE 2020-10-01   13402  14085.048635
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WARDHA  203.840499             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   WARDHA 2020-06-01    1435  1571.578066
# 1   WARDHA 2020-07-01    1452  1571.578066
# 2   WARDHA 2020-08-01    1358  1571.578066
# 3   WARDHA 2020-09-01    1360  1571.578066
# 4   WARDHA 2020-10-01    1306  1571.578066
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#   district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0   WASHIM  143.957662             None         False             False
#
# === Forecast Data ===
#   district       date  actual     forecast  \
# 0   WASHIM 2020-06-01    1583  1651.329517
# 1   WASHIM 2020-07-01    1629  1651.329517
# 2   WASHIM 2020-08-01    1502  1651.329517
# 3   WASHIM 2020-09-01    1599  1651.329517
# 4   WASHIM 2020-10-01    1501  1651.329517
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#    district        rmse seasonal_periods  box_cox_used  arma_errors_used
# 0  YAVATMAL  273.241956             None          True             False
#
# === Forecast Data ===
#    district       date  actual     forecast  \
# 0  YAVATMAL 2020-06-01    3616  3864.944742
# 1  YAVATMAL 2020-07-01    3673  3859.827094
# 2  YAVATMAL 2020-08-01    3425  3855.412484
# 3  YAVATMAL 2020-09-01    3507  3851.604170
# 4  YAVATMAL 2020-10-01    3562  3848.318761
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# 3  <tbats.tbats.ModelParams.ModelParams object at...
# 4  <tbats.tbats.ModelParams.ModelParams object at...
# === Metrics ===
#           district         rmse seasonal_periods  box_cox_used  \
# 0  MUMBAI SUBURBAN  2631.198075             None         False
#
#    arma_errors_used
# 0             False
#
# === Forecast Data ===
#           district       date  actual      forecast  \
# 0  MUMBAI SUBURBAN 2021-01-01   13242  15034.672362
# 1  MUMBAI SUBURBAN 2021-02-01   13444  15871.799575
# 2  MUMBAI SUBURBAN 2021-03-01   13294  16708.926787
#
#                                         model_params
# 0  <tbats.tbats.ModelParams.ModelParams object at...
# 1  <tbats.tbats.ModelParams.ModelParams object at...
# 2  <tbats.tbats.ModelParams.ModelParams object at...
# {'district': 'MUMBAI SUBURBAN',
#  'forecast_df':           district       date  actual      forecast  \
#  0  MUMBAI SUBURBAN 2021-01-01   13242  15034.672362
#  1  MUMBAI SUBURBAN 2021-02-01   13444  15871.799575
#  2  MUMBAI SUBURBAN 2021-03-01   13294  16708.926787
#
#                                          model_params
#  0  <tbats.tbats.ModelParams.ModelParams object at...
#  1  <tbats.tbats.ModelParams.ModelParams object at...
#  2  <tbats.tbats.ModelParams.ModelParams object at...  ,
#  'metrics_df':           district         rmse seasonal_periods  box_cox_used  \
#  0  MUMBAI SUBURBAN  2631.198075             None         False
#
#     arma_errors_used
#  0             False  ,
#  'model_summary': 'Use Box-Cox: False\nUse trend: True\nUse damped trend: False\nSeasonal periods: []\nSeasonal harmonics []\nARMA errors (p, q): (0, 0)\nSmoothing (Alpha): -0.020100\nTrend (Beta): 0.019655\nDamping Parameter (Phi): 1.000000\nSeasonal Parameters (Gamma): []\nAR coefficients []\nMA coefficients []\nSeed vector [6424.60680317  877.02069241]\n\nAIC 152.435528'}
